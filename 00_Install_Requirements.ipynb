# %% [markdown]
# # Environment Setup
#
# This notebook installs the required Python packages for reproducing the
# experiments in the paper.
#
# Execute each cell sequentially.

# %%
import platform

print("Python:", platform.python_version())
# Out:
# Python: 3.10.8

# %%
# !python -m pip install --upgrade pip
# !python -m pip install -r requirements.txt

# %%
import tensorflow as tf
import pandas as pd
import sklearn
import matplotlib

print("TensorFlow:", tf.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
# Out:
# TensorFlow: 2.9.3
# Pandas: 2.2.3
# Scikit-learn: 1.6.1
# Matplotlib: 3.10.0

# %% [markdown]
# ## Install an Influence Implementation
#
# Choose **one** of the following cells.

# %% [markdown]
# ## Cell A

# %%
# !python -m pip install Influenciae

# %% [markdown]
# ## Cell B

# %%
# !python -m pip install -e ./third_party/influenciae_tabular
