# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 16)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.500408  -0.000046   0.000839  -0.000464  -0.000101  -0.002933
# 1     -5.289236  -5.128507  -3.091696   4.008487  -6.272612  -3.344968
# 2     -1.679289   4.082524  -3.098553  -6.783943 -11.624065   3.378836
# 3      1.499856  -0.000409  -0.001420   0.000043   0.000340   0.000627
# 4      1.497268  -0.001230  -0.001158   0.000637  -0.000504  -0.001355
# ...         ...        ...        ...        ...        ...        ...
# 7995   1.500418   0.001592   0.000829  -0.001017   0.001121   0.000054
# 7996   1.499166  -0.000403  -0.002879  -0.000333  -0.000565   0.000468
# 7997   1.499489  -0.000623  -0.001511   0.002488  -0.001251  -0.001028
# 7998  -1.499878   0.001207   0.001583   0.000085  -0.000315   0.000066
# 7999  -0.275943  -7.013027   1.929183   2.139779  -3.507250   2.668141
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id  \
# 0     -0.002506  -0.000774  -0.000489    0.001781      1     1    1_dense
# 1      5.091848  -1.523394   6.006030   -4.578813      1     2   1_sparse
# 2      3.852263   6.903260   1.981434    5.396749      1     3   1_sparse
# 3     -0.000957  -0.000784   0.000196    0.001110      1     4    1_dense
# 4     -0.002836  -0.000574   0.000479   -0.000694      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 7995   0.003217  -0.002525  -0.000742    0.000852      1  8496    1_dense
# 7996   0.001078  -0.000170   0.000429   -0.000987      0  8497    1_dense
# 7997   0.000701  -0.001935   0.000536   -0.002053      1  8498    1_dense
# 7998  -0.000095  -0.001657   0.001552    0.000246      0  8499    0_dense
# 7999   6.026415 -10.639815   7.508137   -1.002476      1  8500   1_sparse
#
#       clean_label  is_noisy  noisy_label
# 0               1         0            1
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               1         0            1
# ...           ...       ...          ...
# 7995            1         0            1
# 7996            1         1            0
# 7997            1         0            1
# 7998            0         0            0
# 7999            1         0            1
#
# [8000 rows x 16 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.253589    0.016287
# 1            2            1            1         0       0.807421   -0.185965
# 2            3            1            1         0       0.552101    0.193638
# 3            4            1            1         0       0.253502    0.017229
# 4            5            1            1         0       0.253445    0.015795
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.253480    0.017473
# 7996      8497            1            0         1       1.496383   -0.061271
# 7997      8498            1            1         0       0.253534    0.016287
# 7998      8499            0            0         0       0.248012    0.019080
# 7999      8500            1            1         0       0.699040   -0.311264
#
#       TracIn_Score
# 0        -0.011053
# 1        -0.011350
# 2        -0.027200
# 3        -0.011054
# 4        -0.011053
# ...            ...
# 7995     -0.011058
# 7996      0.030230
# 7997     -0.011050
# 7998      0.025206
# 7999      0.008917
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.253589    0.016287
# 1            2            1            1         0       0.807421   -0.185965
# 2            3            1            1         0       0.552101    0.193638
# 3            4            1            1         0       0.253502    0.017229
# 4            5            1            1         0       0.253445    0.015795
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.253480    0.017473
# 7996      8497            1            0         1       1.496383   -0.061271
# 7997      8498            1            1         0       0.253534    0.016287
# 7998      8499            0            0         0       0.248012    0.019080
# 7999      8500            1            1         0       0.699040   -0.311264
#
#       TracIn_Score  Random_Score
# 0        -0.011053      0.773956
# 1        -0.011350      0.438878
# 2        -0.027200      0.858598
# 3        -0.011054      0.697368
# 4        -0.011053      0.094177
# ...            ...           ...
# 7995     -0.011058      0.339107
# 7996      0.030230      0.135326
# 7997     -0.011050      0.479135
# 7998      0.025206      0.232246
# 7999      0.008917      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.20
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.2
# Removed samples: 1600
# Remaining samples: 6400

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 709
# Noisy fraction among removed: 0.443125

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (6400, 11)
# (6400, 2)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(512), epochs=1, validation_data=test_ds.batch(512), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 13/13 - 1s - loss: 0.7437 - accuracy: 0.5050 - val_loss: 0.7367 - val_accuracy: 0.5280 - 553ms/epoch - 43ms/step
# 13/13 - 0s - loss: 0.7079 - accuracy: 0.5205 - val_loss: 0.7099 - val_accuracy: 0.7860 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6728 - accuracy: 0.7320 - val_loss: 0.6939 - val_accuracy: 0.7900 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6498 - accuracy: 0.7763 - val_loss: 0.6829 - val_accuracy: 0.7900 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6321 - accuracy: 0.7820 - val_loss: 0.6730 - val_accuracy: 0.7940 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6171 - accuracy: 0.7864 - val_loss: 0.6641 - val_accuracy: 0.7960 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6044 - accuracy: 0.7906 - val_loss: 0.6567 - val_accuracy: 0.7980 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5939 - accuracy: 0.7941 - val_loss: 0.6509 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5847 - accuracy: 0.7970 - val_loss: 0.6457 - val_accuracy: 0.8040 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5763 - accuracy: 0.8011 - val_loss: 0.6412 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5686 - accuracy: 0.8037 - val_loss: 0.6367 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5614 - accuracy: 0.8073 - val_loss: 0.6324 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5545 - accuracy: 0.8083 - val_loss: 0.6284 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5478 - accuracy: 0.8100 - val_loss: 0.6246 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5413 - accuracy: 0.8119 - val_loss: 0.6202 - val_accuracy: 0.8040 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5345 - accuracy: 0.8141 - val_loss: 0.6158 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5276 - accuracy: 0.8166 - val_loss: 0.6115 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5209 - accuracy: 0.8175 - val_loss: 0.6076 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5145 - accuracy: 0.8178 - val_loss: 0.6037 - val_accuracy: 0.8040 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5084 - accuracy: 0.8192 - val_loss: 0.6003 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5027 - accuracy: 0.8205 - val_loss: 0.5971 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4972 - accuracy: 0.8214 - val_loss: 0.5939 - val_accuracy: 0.8140 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4920 - accuracy: 0.8220 - val_loss: 0.5909 - val_accuracy: 0.8140 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4869 - accuracy: 0.8238 - val_loss: 0.5881 - val_accuracy: 0.8140 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4820 - accuracy: 0.8250 - val_loss: 0.5854 - val_accuracy: 0.8140 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4774 - accuracy: 0.8252 - val_loss: 0.5829 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4729 - accuracy: 0.8269 - val_loss: 0.5806 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4686 - accuracy: 0.8270 - val_loss: 0.5784 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4644 - accuracy: 0.8278 - val_loss: 0.5764 - val_accuracy: 0.8040 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4605 - accuracy: 0.8286 - val_loss: 0.5745 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4566 - accuracy: 0.8286 - val_loss: 0.5728 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4530 - accuracy: 0.8292 - val_loss: 0.5712 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4495 - accuracy: 0.8288 - val_loss: 0.5697 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4462 - accuracy: 0.8292 - val_loss: 0.5685 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4430 - accuracy: 0.8294 - val_loss: 0.5674 - val_accuracy: 0.8100 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4399 - accuracy: 0.8294 - val_loss: 0.5665 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4370 - accuracy: 0.8302 - val_loss: 0.5656 - val_accuracy: 0.8100 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4342 - accuracy: 0.8305 - val_loss: 0.5649 - val_accuracy: 0.8060 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4314 - accuracy: 0.8309 - val_loss: 0.5641 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4288 - accuracy: 0.8316 - val_loss: 0.5635 - val_accuracy: 0.8060 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4263 - accuracy: 0.8308 - val_loss: 0.5628 - val_accuracy: 0.8060 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4239 - accuracy: 0.8308 - val_loss: 0.5621 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4216 - accuracy: 0.8308 - val_loss: 0.5614 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4194 - accuracy: 0.8316 - val_loss: 0.5610 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4172 - accuracy: 0.8314 - val_loss: 0.5605 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4152 - accuracy: 0.8316 - val_loss: 0.5604 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4133 - accuracy: 0.8320 - val_loss: 0.5603 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4115 - accuracy: 0.8328 - val_loss: 0.5601 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4098 - accuracy: 0.8325 - val_loss: 0.5600 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4081 - accuracy: 0.8330 - val_loss: 0.5600 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4065 - accuracy: 0.8333 - val_loss: 0.5599 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4050 - accuracy: 0.8331 - val_loss: 0.5600 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4035 - accuracy: 0.8333 - val_loss: 0.5602 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4020 - accuracy: 0.8331 - val_loss: 0.5604 - val_accuracy: 0.8120 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4006 - accuracy: 0.8331 - val_loss: 0.5605 - val_accuracy: 0.8140 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3993 - accuracy: 0.8330 - val_loss: 0.5606 - val_accuracy: 0.8140 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3979 - accuracy: 0.8331 - val_loss: 0.5608 - val_accuracy: 0.8140 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3966 - accuracy: 0.8331 - val_loss: 0.5610 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3954 - accuracy: 0.8338 - val_loss: 0.5612 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3941 - accuracy: 0.8341 - val_loss: 0.5613 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3929 - accuracy: 0.8338 - val_loss: 0.5614 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3918 - accuracy: 0.8338 - val_loss: 0.5616 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3906 - accuracy: 0.8334 - val_loss: 0.5617 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3895 - accuracy: 0.8334 - val_loss: 0.5619 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3885 - accuracy: 0.8334 - val_loss: 0.5621 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3874 - accuracy: 0.8336 - val_loss: 0.5623 - val_accuracy: 0.8100 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3864 - accuracy: 0.8333 - val_loss: 0.5626 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3855 - accuracy: 0.8334 - val_loss: 0.5628 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3846 - accuracy: 0.8339 - val_loss: 0.5630 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3837 - accuracy: 0.8339 - val_loss: 0.5634 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3828 - accuracy: 0.8342 - val_loss: 0.5635 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3820 - accuracy: 0.8344 - val_loss: 0.5638 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3812 - accuracy: 0.8345 - val_loss: 0.5641 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3804 - accuracy: 0.8344 - val_loss: 0.5644 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3796 - accuracy: 0.8344 - val_loss: 0.5647 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3789 - accuracy: 0.8344 - val_loss: 0.5649 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3782 - accuracy: 0.8342 - val_loss: 0.5652 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3775 - accuracy: 0.8342 - val_loss: 0.5654 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3768 - accuracy: 0.8341 - val_loss: 0.5657 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3762 - accuracy: 0.8342 - val_loss: 0.5660 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3755 - accuracy: 0.8342 - val_loss: 0.5662 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3749 - accuracy: 0.8342 - val_loss: 0.5665 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3743 - accuracy: 0.8345 - val_loss: 0.5669 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3737 - accuracy: 0.8352 - val_loss: 0.5671 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3731 - accuracy: 0.8350 - val_loss: 0.5674 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3725 - accuracy: 0.8345 - val_loss: 0.5678 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3720 - accuracy: 0.8345 - val_loss: 0.5680 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3714 - accuracy: 0.8342 - val_loss: 0.5682 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3709 - accuracy: 0.8341 - val_loss: 0.5684 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3704 - accuracy: 0.8342 - val_loss: 0.5688 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3699 - accuracy: 0.8347 - val_loss: 0.5690 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3694 - accuracy: 0.8347 - val_loss: 0.5692 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3689 - accuracy: 0.8345 - val_loss: 0.5694 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3684 - accuracy: 0.8345 - val_loss: 0.5696 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3680 - accuracy: 0.8348 - val_loss: 0.5698 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3675 - accuracy: 0.8347 - val_loss: 0.5700 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3671 - accuracy: 0.8347 - val_loss: 0.5702 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3667 - accuracy: 0.8348 - val_loss: 0.5704 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3662 - accuracy: 0.8352 - val_loss: 0.5706 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3658 - accuracy: 0.8353 - val_loss: 0.5708 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3654 - accuracy: 0.8353 - val_loss: 0.5710 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3650 - accuracy: 0.8353 - val_loss: 0.5712 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3646 - accuracy: 0.8355 - val_loss: 0.5714 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3642 - accuracy: 0.8356 - val_loss: 0.5716 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3639 - accuracy: 0.8355 - val_loss: 0.5718 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3635 - accuracy: 0.8358 - val_loss: 0.5720 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3632 - accuracy: 0.8358 - val_loss: 0.5722 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3628 - accuracy: 0.8358 - val_loss: 0.5724 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3625 - accuracy: 0.8359 - val_loss: 0.5727 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3622 - accuracy: 0.8359 - val_loss: 0.5730 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3618 - accuracy: 0.8359 - val_loss: 0.5732 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3615 - accuracy: 0.8359 - val_loss: 0.5735 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3612 - accuracy: 0.8366 - val_loss: 0.5737 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3609 - accuracy: 0.8366 - val_loss: 0.5739 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3606 - accuracy: 0.8363 - val_loss: 0.5742 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3603 - accuracy: 0.8363 - val_loss: 0.5744 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3600 - accuracy: 0.8367 - val_loss: 0.5748 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3598 - accuracy: 0.8366 - val_loss: 0.5750 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3595 - accuracy: 0.8366 - val_loss: 0.5752 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3592 - accuracy: 0.8366 - val_loss: 0.5755 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3590 - accuracy: 0.8366 - val_loss: 0.5756 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3587 - accuracy: 0.8366 - val_loss: 0.5759 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3584 - accuracy: 0.8369 - val_loss: 0.5761 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3582 - accuracy: 0.8367 - val_loss: 0.5764 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3580 - accuracy: 0.8367 - val_loss: 0.5767 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3577 - accuracy: 0.8366 - val_loss: 0.5770 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3575 - accuracy: 0.8367 - val_loss: 0.5772 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3573 - accuracy: 0.8366 - val_loss: 0.5775 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3571 - accuracy: 0.8366 - val_loss: 0.5778 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3569 - accuracy: 0.8367 - val_loss: 0.5781 - val_accuracy: 0.8060 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3567 - accuracy: 0.8367 - val_loss: 0.5783 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3565 - accuracy: 0.8366 - val_loss: 0.5787 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3563 - accuracy: 0.8367 - val_loss: 0.5790 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3561 - accuracy: 0.8369 - val_loss: 0.5791 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3559 - accuracy: 0.8372 - val_loss: 0.5794 - val_accuracy: 0.8060 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3557 - accuracy: 0.8370 - val_loss: 0.5795 - val_accuracy: 0.8060 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3555 - accuracy: 0.8369 - val_loss: 0.5797 - val_accuracy: 0.8080 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3553 - accuracy: 0.8370 - val_loss: 0.5800 - val_accuracy: 0.8080 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3551 - accuracy: 0.8370 - val_loss: 0.5802 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3549 - accuracy: 0.8370 - val_loss: 0.5803 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3548 - accuracy: 0.8369 - val_loss: 0.5805 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3546 - accuracy: 0.8366 - val_loss: 0.5808 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3544 - accuracy: 0.8363 - val_loss: 0.5810 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3543 - accuracy: 0.8364 - val_loss: 0.5813 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3541 - accuracy: 0.8367 - val_loss: 0.5815 - val_accuracy: 0.8120 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3540 - accuracy: 0.8367 - val_loss: 0.5818 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3538 - accuracy: 0.8369 - val_loss: 0.5820 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3537 - accuracy: 0.8367 - val_loss: 0.5823 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3535 - accuracy: 0.8372 - val_loss: 0.5825 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3534 - accuracy: 0.8375 - val_loss: 0.5827 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3532 - accuracy: 0.8378 - val_loss: 0.5830 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3531 - accuracy: 0.8378 - val_loss: 0.5832 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3529 - accuracy: 0.8378 - val_loss: 0.5835 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3528 - accuracy: 0.8377 - val_loss: 0.5837 - val_accuracy: 0.8120 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3527 - accuracy: 0.8375 - val_loss: 0.5841 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3525 - accuracy: 0.8373 - val_loss: 0.5843 - val_accuracy: 0.8100 - 39ms/epoch - 3ms/step
# 13/13 - 0s - loss: 0.3524 - accuracy: 0.8372 - val_loss: 0.5847 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3523 - accuracy: 0.8372 - val_loss: 0.5849 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3521 - accuracy: 0.8372 - val_loss: 0.5851 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3520 - accuracy: 0.8373 - val_loss: 0.5853 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3519 - accuracy: 0.8372 - val_loss: 0.5855 - val_accuracy: 0.8120 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3517 - accuracy: 0.8372 - val_loss: 0.5858 - val_accuracy: 0.8120 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3516 - accuracy: 0.8373 - val_loss: 0.5859 - val_accuracy: 0.8100 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3515 - accuracy: 0.8373 - val_loss: 0.5861 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3514 - accuracy: 0.8373 - val_loss: 0.5861 - val_accuracy: 0.8100 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3512 - accuracy: 0.8375 - val_loss: 0.5864 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3511 - accuracy: 0.8373 - val_loss: 0.5865 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3510 - accuracy: 0.8373 - val_loss: 0.5867 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3509 - accuracy: 0.8373 - val_loss: 0.5870 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3507 - accuracy: 0.8375 - val_loss: 0.5872 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3506 - accuracy: 0.8375 - val_loss: 0.5874 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3505 - accuracy: 0.8377 - val_loss: 0.5875 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3504 - accuracy: 0.8373 - val_loss: 0.5879 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3503 - accuracy: 0.8373 - val_loss: 0.5881 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3502 - accuracy: 0.8373 - val_loss: 0.5882 - val_accuracy: 0.8100 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3501 - accuracy: 0.8372 - val_loss: 0.5884 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3500 - accuracy: 0.8373 - val_loss: 0.5885 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3498 - accuracy: 0.8372 - val_loss: 0.5887 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3497 - accuracy: 0.8372 - val_loss: 0.5890 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3496 - accuracy: 0.8370 - val_loss: 0.5890 - val_accuracy: 0.8100 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3495 - accuracy: 0.8370 - val_loss: 0.5893 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3494 - accuracy: 0.8370 - val_loss: 0.5893 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3493 - accuracy: 0.8369 - val_loss: 0.5897 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3492 - accuracy: 0.8372 - val_loss: 0.5899 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3491 - accuracy: 0.8370 - val_loss: 0.5899 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3490 - accuracy: 0.8372 - val_loss: 0.5903 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3489 - accuracy: 0.8372 - val_loss: 0.5903 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3488 - accuracy: 0.8372 - val_loss: 0.5907 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3488 - accuracy: 0.8372 - val_loss: 0.5908 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3486 - accuracy: 0.8375 - val_loss: 0.5911 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3486 - accuracy: 0.8377 - val_loss: 0.5913 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3485 - accuracy: 0.8378 - val_loss: 0.5917 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3484 - accuracy: 0.8378 - val_loss: 0.5918 - val_accuracy: 0.8100 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3483 - accuracy: 0.8381 - val_loss: 0.5921 - val_accuracy: 0.8100 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3482 - accuracy: 0.8383 - val_loss: 0.5924 - val_accuracy: 0.8100 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3481 - accuracy: 0.8384 - val_loss: 0.5925 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3480 - accuracy: 0.8384 - val_loss: 0.5927 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3479 - accuracy: 0.8386 - val_loss: 0.5930 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3478 - accuracy: 0.8386 - val_loss: 0.5932 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3477 - accuracy: 0.8386 - val_loss: 0.5935 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3477 - accuracy: 0.8386 - val_loss: 0.5936 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3476 - accuracy: 0.8388 - val_loss: 0.5939 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3475 - accuracy: 0.8388 - val_loss: 0.5942 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3474 - accuracy: 0.8391 - val_loss: 0.5945 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3473 - accuracy: 0.8391 - val_loss: 0.5947 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3472 - accuracy: 0.8391 - val_loss: 0.5949 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3472 - accuracy: 0.8391 - val_loss: 0.5953 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3471 - accuracy: 0.8392 - val_loss: 0.5954 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3470 - accuracy: 0.8392 - val_loss: 0.5956 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3469 - accuracy: 0.8392 - val_loss: 0.5958 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3468 - accuracy: 0.8389 - val_loss: 0.5960 - val_accuracy: 0.8080 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3468 - accuracy: 0.8388 - val_loss: 0.5963 - val_accuracy: 0.8080 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3467 - accuracy: 0.8388 - val_loss: 0.5965 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3466 - accuracy: 0.8388 - val_loss: 0.5967 - val_accuracy: 0.8080 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3465 - accuracy: 0.8388 - val_loss: 0.5970 - val_accuracy: 0.8060 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3465 - accuracy: 0.8388 - val_loss: 0.5973 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3464 - accuracy: 0.8388 - val_loss: 0.5974 - val_accuracy: 0.8040 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3463 - accuracy: 0.8389 - val_loss: 0.5978 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3462 - accuracy: 0.8389 - val_loss: 0.5981 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3462 - accuracy: 0.8388 - val_loss: 0.5982 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3461 - accuracy: 0.8388 - val_loss: 0.5985 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3460 - accuracy: 0.8389 - val_loss: 0.5989 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3460 - accuracy: 0.8388 - val_loss: 0.5990 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3459 - accuracy: 0.8386 - val_loss: 0.5993 - val_accuracy: 0.8040 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3458 - accuracy: 0.8388 - val_loss: 0.5996 - val_accuracy: 0.8040 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3457 - accuracy: 0.8388 - val_loss: 0.5999 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3457 - accuracy: 0.8388 - val_loss: 0.6001 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3456 - accuracy: 0.8386 - val_loss: 0.6004 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3455 - accuracy: 0.8388 - val_loss: 0.6006 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3455 - accuracy: 0.8388 - val_loss: 0.6008 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3454 - accuracy: 0.8388 - val_loss: 0.6010 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3453 - accuracy: 0.8389 - val_loss: 0.6014 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3453 - accuracy: 0.8388 - val_loss: 0.6016 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3452 - accuracy: 0.8384 - val_loss: 0.6018 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3451 - accuracy: 0.8384 - val_loss: 0.6019 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3451 - accuracy: 0.8386 - val_loss: 0.6023 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3450 - accuracy: 0.8386 - val_loss: 0.6025 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3449 - accuracy: 0.8388 - val_loss: 0.6026 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3449 - accuracy: 0.8389 - val_loss: 0.6028 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3448 - accuracy: 0.8389 - val_loss: 0.6030 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3448 - accuracy: 0.8389 - val_loss: 0.6034 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3447 - accuracy: 0.8391 - val_loss: 0.6036 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3446 - accuracy: 0.8391 - val_loss: 0.6039 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3446 - accuracy: 0.8391 - val_loss: 0.6042 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3445 - accuracy: 0.8389 - val_loss: 0.6043 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3445 - accuracy: 0.8389 - val_loss: 0.6046 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3444 - accuracy: 0.8391 - val_loss: 0.6049 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3444 - accuracy: 0.8391 - val_loss: 0.6052 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3443 - accuracy: 0.8391 - val_loss: 0.6054 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3443 - accuracy: 0.8392 - val_loss: 0.6056 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3442 - accuracy: 0.8391 - val_loss: 0.6058 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3441 - accuracy: 0.8392 - val_loss: 0.6060 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3441 - accuracy: 0.8392 - val_loss: 0.6062 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3440 - accuracy: 0.8394 - val_loss: 0.6065 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3440 - accuracy: 0.8395 - val_loss: 0.6067 - val_accuracy: 0.8000 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3439 - accuracy: 0.8397 - val_loss: 0.6069 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3439 - accuracy: 0.8397 - val_loss: 0.6072 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3438 - accuracy: 0.8397 - val_loss: 0.6073 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3437 - accuracy: 0.8397 - val_loss: 0.6076 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3437 - accuracy: 0.8395 - val_loss: 0.6078 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3436 - accuracy: 0.8392 - val_loss: 0.6079 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3436 - accuracy: 0.8392 - val_loss: 0.6081 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3435 - accuracy: 0.8392 - val_loss: 0.6082 - val_accuracy: 0.8000 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3435 - accuracy: 0.8391 - val_loss: 0.6085 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3434 - accuracy: 0.8389 - val_loss: 0.6086 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3433 - accuracy: 0.8391 - val_loss: 0.6088 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3433 - accuracy: 0.8391 - val_loss: 0.6089 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3432 - accuracy: 0.8395 - val_loss: 0.6091 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3432 - accuracy: 0.8394 - val_loss: 0.6092 - val_accuracy: 0.8000 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3431 - accuracy: 0.8395 - val_loss: 0.6094 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3431 - accuracy: 0.8394 - val_loss: 0.6095 - val_accuracy: 0.8000 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3430 - accuracy: 0.8394 - val_loss: 0.6097 - val_accuracy: 0.8000 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3430 - accuracy: 0.8391 - val_loss: 0.6099 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3429 - accuracy: 0.8391 - val_loss: 0.6101 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3429 - accuracy: 0.8391 - val_loss: 0.6102 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3428 - accuracy: 0.8392 - val_loss: 0.6103 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3428 - accuracy: 0.8392 - val_loss: 0.6105 - val_accuracy: 0.8020 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3427 - accuracy: 0.8392 - val_loss: 0.6107 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3427 - accuracy: 0.8391 - val_loss: 0.6108 - val_accuracy: 0.8020 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3426 - accuracy: 0.8392 - val_loss: 0.6109 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3426 - accuracy: 0.8389 - val_loss: 0.6110 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3425 - accuracy: 0.8388 - val_loss: 0.6112 - val_accuracy: 0.8020 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3424 - accuracy: 0.8388 - val_loss: 0.6113 - val_accuracy: 0.8020 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3424 - accuracy: 0.8391 - val_loss: 0.6114 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3423 - accuracy: 0.8389 - val_loss: 0.6116 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3423 - accuracy: 0.8389 - val_loss: 0.6117 - val_accuracy: 0.8040 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3422 - accuracy: 0.8388 - val_loss: 0.6118 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3422 - accuracy: 0.8389 - val_loss: 0.6119 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3421 - accuracy: 0.8386 - val_loss: 0.6121 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3421 - accuracy: 0.8386 - val_loss: 0.6122 - val_accuracy: 0.8020 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3420 - accuracy: 0.8386 - val_loss: 0.6122 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3420 - accuracy: 0.8386 - val_loss: 0.6123 - val_accuracy: 0.8020 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3419 - accuracy: 0.8388 - val_loss: 0.6125 - val_accuracy: 0.8020 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3419 - accuracy: 0.8388 - val_loss: 0.6126 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3418 - accuracy: 0.8388 - val_loss: 0.6127 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3417 - accuracy: 0.8388 - val_loss: 0.6128 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3417 - accuracy: 0.8386 - val_loss: 0.6128 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3416 - accuracy: 0.8388 - val_loss: 0.6129 - val_accuracy: 0.8020 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3416 - accuracy: 0.8386 - val_loss: 0.6131 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3415 - accuracy: 0.8389 - val_loss: 0.6131 - val_accuracy: 0.8020 - 28ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6132 - accuracy: 0.8020 - 19ms/epoch - 1ms/step
# 0.6131512522697449

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
