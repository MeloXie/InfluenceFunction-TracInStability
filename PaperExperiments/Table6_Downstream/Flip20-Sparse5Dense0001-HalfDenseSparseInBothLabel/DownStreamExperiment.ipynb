# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# ERROR:absl:cannot import name 'builder' from 'google.protobuf.internal' (/rds/bear-apps/2022a/EL8-ice/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# Traceback (most recent call last):
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/__init__.py", line 79, in <module>
#     from tensorflow_datasets import rlds  # pylint: disable=g-bad-import-order
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/rlds/__init__.py", line 21, in <module>
#     from tensorflow_datasets.rlds import envlogger_reader
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/rlds/envlogger_reader.py", line 21, in <module>
#     from tensorflow_datasets.core.utils.lazy_imports_utils import tree
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/__init__.py", line 21, in <module>
#     from tensorflow_datasets.core import community
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/community/__init__.py", line 19, in <module>
#     from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/community/huggingface_wrapper.py", line 32, in <module>
#     from tensorflow_datasets.core import dataset_builder
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py", line 162, in <module>
#     class DatasetBuilder(registered.RegisteredDataset):
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/etils/epy/lazy_imports_utils.py", line 123, in __getattr__
#     return getattr(self._module, name)
#   File "/rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/functools.py", line 981, in __get__
#     val = self.func(instance)
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/etils/epy/lazy_imports_utils.py", line 84, in _module
#     module = importlib.import_module(self.module_name)
#   File "/rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/registered.py", line 36, in <module>
#     import tensorflow_datasets.core.logging as _tfds_logging
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/logging/__init__.py", line 29, in <module>
#     from tensorflow_datasets.core.logging import logging_logger
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/logging/logging_logger.py", line 21, in <module>
#     from tensorflow_datasets.core import decode
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/decode/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.decode.partial_decode import PartialDecoding
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/decode/partial_decode.py", line 21, in <module>
#     from tensorflow_datasets.core import features as features_lib
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.features.audio_feature import Audio
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/audio_feature.py", line 33, in <module>
#     from tensorflow_datasets.core.features import feature as feature_lib
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/feature.py", line 36, in <module>
#     from tensorflow_datasets.core.proto import feature_pb2
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/proto/__init__.py", line 18, in <module>
#     from tensorflow_datasets.core.proto import dataset_info_generated_pb2 as dataset_info_pb2  # pylint: disable=line-too-long
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/proto/dataset_info_generated_pb2.py", line 25, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/rds/bear-apps/2022a/EL8-ice/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
total_size = 8500
test_size = 500
n_features=10
seed=42
sep= 1.5
std0 = 1.0          
std1_dense = 0.001   
std1_sparse = 5.0

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
n_per_class = total_size // 2

# %%
big_size = n_per_class // 2
small_size = n_per_class - big_size

# %%
c0 = np.zeros(n_features)
c0[0] = -sep

c1 = np.zeros(n_features)
c1[0] = sep

# %%
X0_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c0],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed
)

X0_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c0],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 1
)

X1_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c1],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed + 2
)

X1_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c1],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 3
)

# %%
X = np.vstack([X0_dense, X0_sparse, X1_dense, X1_sparse])
y = np.hstack([
    np.zeros(big_size, dtype=int),
    np.zeros(small_size, dtype=int),
    np.ones(big_size, dtype=int),
    np.ones(small_size, dtype=int),
])

# %%
cluster_id = (
    (["0_dense"] * big_size) +
    (["0_sparse"] * small_size) +
    (["1_dense"] * big_size) +
    (["1_sparse"] * small_size)
)
rng = np.random.RandomState(seed)
idx = rng.permutation(X.shape[0])
X = X[idx]; y = y[idx]
cluster_id = np.array(cluster_id, dtype=object)[idx]

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
df["cluster_id"] = cluster_id 
print(df)
print(df["label"].value_counts())
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.500408  -0.000046   0.000839  -0.000464  -0.000101  -0.002933
# 1     -5.289236  -5.128507  -3.091696   4.008487  -6.272612  -3.344968
# 2     -1.679289   4.082524  -3.098553  -6.783943 -11.624065   3.378836
# 3      1.499856  -0.000409  -0.001420   0.000043   0.000340   0.000627
# 4      1.497268  -0.001230  -0.001158   0.000637  -0.000504  -0.001355
# ...         ...        ...        ...        ...        ...        ...
# 8495   1.500418   0.001592   0.000829  -0.001017   0.001121   0.000054
# 8496   1.499166  -0.000403  -0.002879  -0.000333  -0.000565   0.000468
# 8497   1.499489  -0.000623  -0.001511   0.002488  -0.001251  -0.001028
# 8498  -1.499878   0.001207   0.001583   0.000085  -0.000315   0.000066
# 8499  -0.275943  -7.013027   1.929183   2.139779  -3.507250   2.668141
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id
# 0     -0.002506  -0.000774  -0.000489    0.001781      1     1    1_dense
# 1      5.091848  -1.523394   6.006030   -4.578813      1     2   1_sparse
# 2      3.852263   6.903260   1.981434    5.396749      1     3   1_sparse
# 3     -0.000957  -0.000784   0.000196    0.001110      1     4    1_dense
# 4     -0.002836  -0.000574   0.000479   -0.000694      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 8495   0.003217  -0.002525  -0.000742    0.000852      1  8496    1_dense
# 8496   0.001078  -0.000170   0.000429   -0.000987      1  8497    1_dense
# 8497   0.000701  -0.001935   0.000536   -0.002053      1  8498    1_dense
# 8498  -0.000095  -0.001657   0.001552    0.000246      0  8499    0_dense
# 8499   6.026415 -10.639815   7.508137   -1.002476      1  8500   1_sparse
#
# [8500 rows x 13 columns]
# 1    4250
# 0    4250
# Name: label, dtype: int64

# %%
print(df["cluster_id"].value_counts())
# Out:
# 1_dense     2125
# 1_sparse    2125
# 0_sparse    2125
# 0_dense     2125
# Name: cluster_id, dtype: int64

# %%
n0 = test_size //2
n1_big = (test_size - n0) // 2
n1_small = test_size - n0 - n1_big
n0,n1_big,n1_small
# Out:
# (250, 125, 125)

# %%
g = df.groupby("cluster_id", group_keys=False)
test_df = pd.concat([
    g.get_group("0_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("0_sparse").sample(n=n1_small, random_state=seed, replace=False),
    g.get_group("1_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("1_sparse").sample(n=n1_small, random_state=seed, replace=False)
]).sample(frac=1, random_state=seed)

train_df = df.drop(test_df.index).reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df["clean_label"] = train_df["label"].copy()

# Randomly select 20% of the training samples
noise_ratio = 0.20
noise_seed = 42

rng = np.random.default_rng(noise_seed)

n_noisy = int(len(train_df) * noise_ratio)

noisy_positions = rng.choice(
    len(train_df),
    size=n_noisy,
    replace=False
)

# Indicator showing which samples were corrupted
train_df["is_noisy"] = 0
train_df.loc[train_df.index[noisy_positions], "is_noisy"] = 1

# Flip the binary labels: 0 -> 1 and 1 -> 0
train_df.loc[
    train_df.index[noisy_positions],
    "label"
] = 1 - train_df.loc[
    train_df.index[noisy_positions],
    "label"
]

# Save a clearer name for the labels used during training
train_df["noisy_label"] = train_df["label"]

print("Number of training samples:", len(train_df))
print("Number of flipped labels:", train_df["is_noisy"].sum())
print("Noise ratio:", train_df["is_noisy"].mean())

print(
    train_df[
        ["id", "clean_label", "noisy_label", "is_noisy"]
    ].head()
)
# Out:
# Number of training samples: 8000
# Number of flipped labels: 1600
# Noise ratio: 0.2
#    id  clean_label  noisy_label  is_noisy
# 0   1            1            1         0
# 1   2            1            1         0
# 2   3            1            1         0
# 3   4            1            1         0
# 4   5            1            1         0

# %%
# Feature columns used by the model
selected_features = [
    col for col in train_df.columns
    if col.startswith("feature_")
]

# Preserve IDs separately
train_ids_original = train_df["id"].to_numpy()

# Scale IDs only for the influence pipeline
IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

# Model features
X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

# Append the ID column, as required by your existing influence code
X_train = np.hstack([
    X_train_features,
    IDs
])

# Use the corrupted labels for training
y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (8000, 11)
# (8000, 2)

# %%
# X_train = train_df.drop(columns=["label"])
# y_train = train_df["label"]
# IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
# IDs = IDs  / 1e10

# X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
# X_train = np.hstack((X_train, IDs))
# y_train = to_categorical(y_train.values,num_classes=2)

# print(X_train)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
# Out:
# 2026-08-01 14:09:21.620105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38477 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:31:00.0, compute capability: 8.0

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
initial_model = tf.keras.models.clone_model(model)
initial_model.set_weights(model.get_weights())
model_list.append(InfluenceModel(initial_model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(512), epochs=1, validation_data=test_ds.batch(512), verbose=2)
  checkpoint_model = tf.keras.models.clone_model(model)
  checkpoint_model.set_weights(model.get_weights())
  model_list.append(InfluenceModel(checkpoint_model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 16/16 - 2s - loss: 0.8082 - accuracy: 0.5115 - val_loss: 0.7344 - val_accuracy: 0.5180 - 2s/epoch - 97ms/step
# 2026-08-01 14:09:23.391989: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 16/16 - 0s - loss: 0.7823 - accuracy: 0.5120 - val_loss: 0.7110 - val_accuracy: 0.5280 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7583 - accuracy: 0.5132 - val_loss: 0.6925 - val_accuracy: 0.5280 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7406 - accuracy: 0.5599 - val_loss: 0.6792 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7279 - accuracy: 0.6546 - val_loss: 0.6694 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7185 - accuracy: 0.6665 - val_loss: 0.6621 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7108 - accuracy: 0.6658 - val_loss: 0.6563 - val_accuracy: 0.7780 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7042 - accuracy: 0.6656 - val_loss: 0.6511 - val_accuracy: 0.7800 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6985 - accuracy: 0.6658 - val_loss: 0.6465 - val_accuracy: 0.7820 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6936 - accuracy: 0.6655 - val_loss: 0.6424 - val_accuracy: 0.7840 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6893 - accuracy: 0.6666 - val_loss: 0.6387 - val_accuracy: 0.7820 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6854 - accuracy: 0.6659 - val_loss: 0.6353 - val_accuracy: 0.7860 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6820 - accuracy: 0.6656 - val_loss: 0.6321 - val_accuracy: 0.7840 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6789 - accuracy: 0.6674 - val_loss: 0.6291 - val_accuracy: 0.7820 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6762 - accuracy: 0.6680 - val_loss: 0.6263 - val_accuracy: 0.7800 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6737 - accuracy: 0.6695 - val_loss: 0.6237 - val_accuracy: 0.7820 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6714 - accuracy: 0.6694 - val_loss: 0.6213 - val_accuracy: 0.7820 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6693 - accuracy: 0.6700 - val_loss: 0.6189 - val_accuracy: 0.7840 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6674 - accuracy: 0.6691 - val_loss: 0.6167 - val_accuracy: 0.7840 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6656 - accuracy: 0.6676 - val_loss: 0.6145 - val_accuracy: 0.7840 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6639 - accuracy: 0.6679 - val_loss: 0.6125 - val_accuracy: 0.7880 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6624 - accuracy: 0.6675 - val_loss: 0.6105 - val_accuracy: 0.7900 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6609 - accuracy: 0.6678 - val_loss: 0.6085 - val_accuracy: 0.7900 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6595 - accuracy: 0.6681 - val_loss: 0.6066 - val_accuracy: 0.7900 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6581 - accuracy: 0.6681 - val_loss: 0.6048 - val_accuracy: 0.7860 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6569 - accuracy: 0.6680 - val_loss: 0.6030 - val_accuracy: 0.7880 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6557 - accuracy: 0.6681 - val_loss: 0.6012 - val_accuracy: 0.7840 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6545 - accuracy: 0.6679 - val_loss: 0.5995 - val_accuracy: 0.7860 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6534 - accuracy: 0.6681 - val_loss: 0.5978 - val_accuracy: 0.7920 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6524 - accuracy: 0.6681 - val_loss: 0.5962 - val_accuracy: 0.7920 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6514 - accuracy: 0.6683 - val_loss: 0.5946 - val_accuracy: 0.7920 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6504 - accuracy: 0.6691 - val_loss: 0.5930 - val_accuracy: 0.7920 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6495 - accuracy: 0.6693 - val_loss: 0.5915 - val_accuracy: 0.7920 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6486 - accuracy: 0.6684 - val_loss: 0.5899 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6477 - accuracy: 0.6678 - val_loss: 0.5884 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6468 - accuracy: 0.6675 - val_loss: 0.5869 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6459 - accuracy: 0.6680 - val_loss: 0.5854 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6451 - accuracy: 0.6687 - val_loss: 0.5839 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6443 - accuracy: 0.6685 - val_loss: 0.5824 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6435 - accuracy: 0.6687 - val_loss: 0.5809 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6427 - accuracy: 0.6693 - val_loss: 0.5794 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6420 - accuracy: 0.6691 - val_loss: 0.5779 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6412 - accuracy: 0.6693 - val_loss: 0.5765 - val_accuracy: 0.7940 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6405 - accuracy: 0.6699 - val_loss: 0.5751 - val_accuracy: 0.7940 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6398 - accuracy: 0.6700 - val_loss: 0.5737 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6391 - accuracy: 0.6701 - val_loss: 0.5724 - val_accuracy: 0.7920 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6384 - accuracy: 0.6700 - val_loss: 0.5710 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6377 - accuracy: 0.6702 - val_loss: 0.5697 - val_accuracy: 0.7940 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6371 - accuracy: 0.6695 - val_loss: 0.5683 - val_accuracy: 0.7940 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6364 - accuracy: 0.6697 - val_loss: 0.5671 - val_accuracy: 0.7940 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6357 - accuracy: 0.6695 - val_loss: 0.5658 - val_accuracy: 0.7980 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6351 - accuracy: 0.6691 - val_loss: 0.5645 - val_accuracy: 0.7980 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6345 - accuracy: 0.6686 - val_loss: 0.5632 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6338 - accuracy: 0.6686 - val_loss: 0.5620 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6332 - accuracy: 0.6680 - val_loss: 0.5608 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6326 - accuracy: 0.6679 - val_loss: 0.5596 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6320 - accuracy: 0.6679 - val_loss: 0.5583 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6314 - accuracy: 0.6679 - val_loss: 0.5571 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6308 - accuracy: 0.6680 - val_loss: 0.5559 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6302 - accuracy: 0.6679 - val_loss: 0.5547 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6296 - accuracy: 0.6681 - val_loss: 0.5535 - val_accuracy: 0.7960 - 35ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6290 - accuracy: 0.6680 - val_loss: 0.5523 - val_accuracy: 0.7940 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6285 - accuracy: 0.6687 - val_loss: 0.5512 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6279 - accuracy: 0.6694 - val_loss: 0.5500 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6274 - accuracy: 0.6701 - val_loss: 0.5488 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6268 - accuracy: 0.6704 - val_loss: 0.5477 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6263 - accuracy: 0.6704 - val_loss: 0.5466 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6258 - accuracy: 0.6708 - val_loss: 0.5455 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6253 - accuracy: 0.6714 - val_loss: 0.5443 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6248 - accuracy: 0.6720 - val_loss: 0.5432 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6244 - accuracy: 0.6710 - val_loss: 0.5421 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6239 - accuracy: 0.6712 - val_loss: 0.5409 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6234 - accuracy: 0.6716 - val_loss: 0.5398 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6230 - accuracy: 0.6714 - val_loss: 0.5387 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6226 - accuracy: 0.6716 - val_loss: 0.5376 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6221 - accuracy: 0.6721 - val_loss: 0.5365 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6217 - accuracy: 0.6718 - val_loss: 0.5354 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6213 - accuracy: 0.6720 - val_loss: 0.5343 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6208 - accuracy: 0.6722 - val_loss: 0.5332 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6204 - accuracy: 0.6724 - val_loss: 0.5322 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6200 - accuracy: 0.6724 - val_loss: 0.5312 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6197 - accuracy: 0.6724 - val_loss: 0.5302 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6193 - accuracy: 0.6721 - val_loss: 0.5292 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6189 - accuracy: 0.6720 - val_loss: 0.5283 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6185 - accuracy: 0.6720 - val_loss: 0.5273 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6181 - accuracy: 0.6724 - val_loss: 0.5264 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6178 - accuracy: 0.6724 - val_loss: 0.5254 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6174 - accuracy: 0.6725 - val_loss: 0.5245 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6171 - accuracy: 0.6721 - val_loss: 0.5236 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6167 - accuracy: 0.6722 - val_loss: 0.5227 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6164 - accuracy: 0.6720 - val_loss: 0.5218 - val_accuracy: 0.8080 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6161 - accuracy: 0.6722 - val_loss: 0.5209 - val_accuracy: 0.8080 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6158 - accuracy: 0.6720 - val_loss: 0.5200 - val_accuracy: 0.8080 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6154 - accuracy: 0.6719 - val_loss: 0.5192 - val_accuracy: 0.8080 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6151 - accuracy: 0.6724 - val_loss: 0.5183 - val_accuracy: 0.8080 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6148 - accuracy: 0.6722 - val_loss: 0.5175 - val_accuracy: 0.8080 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6145 - accuracy: 0.6722 - val_loss: 0.5167 - val_accuracy: 0.8100 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6142 - accuracy: 0.6721 - val_loss: 0.5158 - val_accuracy: 0.8080 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6139 - accuracy: 0.6722 - val_loss: 0.5150 - val_accuracy: 0.8080 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6137 - accuracy: 0.6722 - val_loss: 0.5142 - val_accuracy: 0.8080 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6134 - accuracy: 0.6721 - val_loss: 0.5135 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6131 - accuracy: 0.6724 - val_loss: 0.5127 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6128 - accuracy: 0.6726 - val_loss: 0.5120 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6126 - accuracy: 0.6731 - val_loss: 0.5112 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6123 - accuracy: 0.6730 - val_loss: 0.5105 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6121 - accuracy: 0.6729 - val_loss: 0.5098 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6118 - accuracy: 0.6731 - val_loss: 0.5091 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6116 - accuracy: 0.6727 - val_loss: 0.5084 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6113 - accuracy: 0.6733 - val_loss: 0.5078 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6111 - accuracy: 0.6736 - val_loss: 0.5071 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6109 - accuracy: 0.6739 - val_loss: 0.5065 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6106 - accuracy: 0.6735 - val_loss: 0.5058 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6104 - accuracy: 0.6735 - val_loss: 0.5051 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6102 - accuracy: 0.6734 - val_loss: 0.5045 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6100 - accuracy: 0.6733 - val_loss: 0.5038 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6098 - accuracy: 0.6731 - val_loss: 0.5032 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6096 - accuracy: 0.6731 - val_loss: 0.5026 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6094 - accuracy: 0.6734 - val_loss: 0.5020 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6092 - accuracy: 0.6731 - val_loss: 0.5014 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6090 - accuracy: 0.6731 - val_loss: 0.5008 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6088 - accuracy: 0.6735 - val_loss: 0.5002 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6086 - accuracy: 0.6734 - val_loss: 0.4996 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6084 - accuracy: 0.6733 - val_loss: 0.4991 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6082 - accuracy: 0.6734 - val_loss: 0.4985 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6080 - accuracy: 0.6730 - val_loss: 0.4979 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6078 - accuracy: 0.6727 - val_loss: 0.4974 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6076 - accuracy: 0.6726 - val_loss: 0.4968 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6074 - accuracy: 0.6726 - val_loss: 0.4964 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6073 - accuracy: 0.6731 - val_loss: 0.4958 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6071 - accuracy: 0.6735 - val_loss: 0.4954 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6069 - accuracy: 0.6737 - val_loss: 0.4949 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6068 - accuracy: 0.6737 - val_loss: 0.4944 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6066 - accuracy: 0.6740 - val_loss: 0.4939 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6064 - accuracy: 0.6740 - val_loss: 0.4935 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6063 - accuracy: 0.6740 - val_loss: 0.4930 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6061 - accuracy: 0.6741 - val_loss: 0.4925 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6060 - accuracy: 0.6744 - val_loss: 0.4920 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6058 - accuracy: 0.6747 - val_loss: 0.4916 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6057 - accuracy: 0.6752 - val_loss: 0.4912 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6055 - accuracy: 0.6752 - val_loss: 0.4908 - val_accuracy: 0.8060 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6054 - accuracy: 0.6752 - val_loss: 0.4903 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6052 - accuracy: 0.6759 - val_loss: 0.4899 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6051 - accuracy: 0.6759 - val_loss: 0.4895 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6049 - accuracy: 0.6758 - val_loss: 0.4891 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6048 - accuracy: 0.6759 - val_loss: 0.4888 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6046 - accuracy: 0.6759 - val_loss: 0.4884 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6045 - accuracy: 0.6761 - val_loss: 0.4880 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6043 - accuracy: 0.6761 - val_loss: 0.4876 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6042 - accuracy: 0.6762 - val_loss: 0.4872 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6040 - accuracy: 0.6765 - val_loss: 0.4868 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6039 - accuracy: 0.6768 - val_loss: 0.4865 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6038 - accuracy: 0.6770 - val_loss: 0.4861 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6036 - accuracy: 0.6771 - val_loss: 0.4857 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6035 - accuracy: 0.6771 - val_loss: 0.4854 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6034 - accuracy: 0.6774 - val_loss: 0.4851 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6032 - accuracy: 0.6775 - val_loss: 0.4847 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6031 - accuracy: 0.6773 - val_loss: 0.4844 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6030 - accuracy: 0.6775 - val_loss: 0.4841 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6029 - accuracy: 0.6774 - val_loss: 0.4837 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6027 - accuracy: 0.6776 - val_loss: 0.4834 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6026 - accuracy: 0.6779 - val_loss: 0.4831 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6025 - accuracy: 0.6779 - val_loss: 0.4828 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6024 - accuracy: 0.6777 - val_loss: 0.4825 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6022 - accuracy: 0.6775 - val_loss: 0.4822 - val_accuracy: 0.8000 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6021 - accuracy: 0.6776 - val_loss: 0.4818 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6020 - accuracy: 0.6780 - val_loss: 0.4815 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6019 - accuracy: 0.6781 - val_loss: 0.4813 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6018 - accuracy: 0.6784 - val_loss: 0.4810 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6017 - accuracy: 0.6784 - val_loss: 0.4807 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6016 - accuracy: 0.6783 - val_loss: 0.4804 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6014 - accuracy: 0.6781 - val_loss: 0.4801 - val_accuracy: 0.8000 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6013 - accuracy: 0.6780 - val_loss: 0.4799 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6012 - accuracy: 0.6776 - val_loss: 0.4796 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6011 - accuracy: 0.6777 - val_loss: 0.4793 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6011 - accuracy: 0.6783 - val_loss: 0.4790 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6010 - accuracy: 0.6785 - val_loss: 0.4788 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6009 - accuracy: 0.6791 - val_loss: 0.4785 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6008 - accuracy: 0.6794 - val_loss: 0.4782 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6007 - accuracy: 0.6794 - val_loss: 0.4779 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6006 - accuracy: 0.6794 - val_loss: 0.4777 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6005 - accuracy: 0.6795 - val_loss: 0.4774 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6004 - accuracy: 0.6793 - val_loss: 0.4772 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6003 - accuracy: 0.6793 - val_loss: 0.4770 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6002 - accuracy: 0.6791 - val_loss: 0.4767 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6002 - accuracy: 0.6791 - val_loss: 0.4765 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6001 - accuracy: 0.6793 - val_loss: 0.4762 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6000 - accuracy: 0.6793 - val_loss: 0.4759 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5999 - accuracy: 0.6794 - val_loss: 0.4756 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5998 - accuracy: 0.6794 - val_loss: 0.4754 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5998 - accuracy: 0.6794 - val_loss: 0.4750 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5997 - accuracy: 0.6795 - val_loss: 0.4748 - val_accuracy: 0.8000 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5996 - accuracy: 0.6798 - val_loss: 0.4746 - val_accuracy: 0.8000 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5995 - accuracy: 0.6799 - val_loss: 0.4743 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5995 - accuracy: 0.6804 - val_loss: 0.4741 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5994 - accuracy: 0.6802 - val_loss: 0.4739 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5993 - accuracy: 0.6805 - val_loss: 0.4736 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5993 - accuracy: 0.6805 - val_loss: 0.4735 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5992 - accuracy: 0.6806 - val_loss: 0.4733 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5991 - accuracy: 0.6809 - val_loss: 0.4731 - val_accuracy: 0.8020 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5991 - accuracy: 0.6809 - val_loss: 0.4730 - val_accuracy: 0.8020 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5990 - accuracy: 0.6804 - val_loss: 0.4728 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5989 - accuracy: 0.6809 - val_loss: 0.4727 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5988 - accuracy: 0.6806 - val_loss: 0.4725 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5988 - accuracy: 0.6809 - val_loss: 0.4724 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5987 - accuracy: 0.6810 - val_loss: 0.4722 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5987 - accuracy: 0.6811 - val_loss: 0.4721 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5986 - accuracy: 0.6810 - val_loss: 0.4719 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5985 - accuracy: 0.6810 - val_loss: 0.4718 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5985 - accuracy: 0.6811 - val_loss: 0.4717 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5984 - accuracy: 0.6815 - val_loss: 0.4715 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5983 - accuracy: 0.6812 - val_loss: 0.4714 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5983 - accuracy: 0.6814 - val_loss: 0.4713 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5982 - accuracy: 0.6812 - val_loss: 0.4712 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5982 - accuracy: 0.6814 - val_loss: 0.4710 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5981 - accuracy: 0.6812 - val_loss: 0.4709 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5980 - accuracy: 0.6814 - val_loss: 0.4708 - val_accuracy: 0.8040 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5980 - accuracy: 0.6814 - val_loss: 0.4707 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5979 - accuracy: 0.6816 - val_loss: 0.4706 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5978 - accuracy: 0.6820 - val_loss: 0.4704 - val_accuracy: 0.8040 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5978 - accuracy: 0.6817 - val_loss: 0.4703 - val_accuracy: 0.8040 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5977 - accuracy: 0.6817 - val_loss: 0.4701 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5977 - accuracy: 0.6817 - val_loss: 0.4700 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5976 - accuracy: 0.6820 - val_loss: 0.4699 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5976 - accuracy: 0.6824 - val_loss: 0.4698 - val_accuracy: 0.8060 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5975 - accuracy: 0.6825 - val_loss: 0.4697 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5975 - accuracy: 0.6827 - val_loss: 0.4695 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5974 - accuracy: 0.6827 - val_loss: 0.4694 - val_accuracy: 0.8060 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5974 - accuracy: 0.6833 - val_loss: 0.4693 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5973 - accuracy: 0.6833 - val_loss: 0.4692 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5972 - accuracy: 0.6839 - val_loss: 0.4692 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5972 - accuracy: 0.6837 - val_loss: 0.4691 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5971 - accuracy: 0.6837 - val_loss: 0.4689 - val_accuracy: 0.8060 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5971 - accuracy: 0.6836 - val_loss: 0.4688 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5970 - accuracy: 0.6837 - val_loss: 0.4687 - val_accuracy: 0.8060 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5970 - accuracy: 0.6841 - val_loss: 0.4686 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5969 - accuracy: 0.6841 - val_loss: 0.4685 - val_accuracy: 0.8060 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5969 - accuracy: 0.6844 - val_loss: 0.4684 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5968 - accuracy: 0.6848 - val_loss: 0.4683 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5968 - accuracy: 0.6851 - val_loss: 0.4682 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5967 - accuracy: 0.6850 - val_loss: 0.4681 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5967 - accuracy: 0.6848 - val_loss: 0.4680 - val_accuracy: 0.8040 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5966 - accuracy: 0.6850 - val_loss: 0.4679 - val_accuracy: 0.8040 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5965 - accuracy: 0.6852 - val_loss: 0.4678 - val_accuracy: 0.8040 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5965 - accuracy: 0.6852 - val_loss: 0.4677 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5964 - accuracy: 0.6854 - val_loss: 0.4676 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5964 - accuracy: 0.6855 - val_loss: 0.4675 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5963 - accuracy: 0.6859 - val_loss: 0.4674 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5963 - accuracy: 0.6858 - val_loss: 0.4673 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5962 - accuracy: 0.6856 - val_loss: 0.4673 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5962 - accuracy: 0.6858 - val_loss: 0.4672 - val_accuracy: 0.8000 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5961 - accuracy: 0.6859 - val_loss: 0.4671 - val_accuracy: 0.8000 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5961 - accuracy: 0.6861 - val_loss: 0.4670 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5960 - accuracy: 0.6864 - val_loss: 0.4670 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5960 - accuracy: 0.6862 - val_loss: 0.4669 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5959 - accuracy: 0.6865 - val_loss: 0.4668 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5959 - accuracy: 0.6870 - val_loss: 0.4668 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5958 - accuracy: 0.6871 - val_loss: 0.4667 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5958 - accuracy: 0.6871 - val_loss: 0.4667 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5957 - accuracy: 0.6870 - val_loss: 0.4666 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5957 - accuracy: 0.6869 - val_loss: 0.4665 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5956 - accuracy: 0.6874 - val_loss: 0.4665 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5955 - accuracy: 0.6874 - val_loss: 0.4664 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5955 - accuracy: 0.6875 - val_loss: 0.4663 - val_accuracy: 0.8020 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5955 - accuracy: 0.6875 - val_loss: 0.4663 - val_accuracy: 0.8020 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5954 - accuracy: 0.6874 - val_loss: 0.4662 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5954 - accuracy: 0.6875 - val_loss: 0.4662 - val_accuracy: 0.8020 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5953 - accuracy: 0.6879 - val_loss: 0.4661 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5953 - accuracy: 0.6875 - val_loss: 0.4660 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5952 - accuracy: 0.6877 - val_loss: 0.4660 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5952 - accuracy: 0.6879 - val_loss: 0.4659 - val_accuracy: 0.8000 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5951 - accuracy: 0.6883 - val_loss: 0.4658 - val_accuracy: 0.7980 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5951 - accuracy: 0.6881 - val_loss: 0.4657 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5950 - accuracy: 0.6881 - val_loss: 0.4657 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5950 - accuracy: 0.6879 - val_loss: 0.4656 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5949 - accuracy: 0.6883 - val_loss: 0.4656 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5949 - accuracy: 0.6885 - val_loss: 0.4655 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5949 - accuracy: 0.6888 - val_loss: 0.4654 - val_accuracy: 0.8000 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5948 - accuracy: 0.6888 - val_loss: 0.4653 - val_accuracy: 0.7980 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5948 - accuracy: 0.6886 - val_loss: 0.4652 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5947 - accuracy: 0.6888 - val_loss: 0.4652 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5947 - accuracy: 0.6885 - val_loss: 0.4650 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5946 - accuracy: 0.6885 - val_loss: 0.4650 - val_accuracy: 0.7960 - 35ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5946 - accuracy: 0.6886 - val_loss: 0.4649 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5945 - accuracy: 0.6888 - val_loss: 0.4648 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5945 - accuracy: 0.6890 - val_loss: 0.4648 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5944 - accuracy: 0.6889 - val_loss: 0.4647 - val_accuracy: 0.7960 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5944 - accuracy: 0.6888 - val_loss: 0.4646 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5943 - accuracy: 0.6889 - val_loss: 0.4645 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5943 - accuracy: 0.6886 - val_loss: 0.4645 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5942 - accuracy: 0.6890 - val_loss: 0.4644 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5942 - accuracy: 0.6894 - val_loss: 0.4643 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5941 - accuracy: 0.6895 - val_loss: 0.4643 - val_accuracy: 0.7960 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5941 - accuracy: 0.6896 - val_loss: 0.4642 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5940 - accuracy: 0.6901 - val_loss: 0.4642 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5940 - accuracy: 0.6898 - val_loss: 0.4641 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5939 - accuracy: 0.6902 - val_loss: 0.4641 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5939 - accuracy: 0.6900 - val_loss: 0.4641 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5938 - accuracy: 0.6901 - val_loss: 0.4640 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5938 - accuracy: 0.6900 - val_loss: 0.4640 - val_accuracy: 0.7960 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.5937 - accuracy: 0.6898 - val_loss: 0.4640 - val_accuracy: 0.7960 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.4640 - accuracy: 0.7960 - 19ms/epoch - 1ms/step
# 0.46395665407180786

# %%
train_logits = model.predict(
    X_train,
    batch_size=256,
    verbose=0
)

# Calculate one loss value per sample using the corrupted labels
per_sample_loss_fn = CategoricalCrossentropy(
    from_logits=True,
    reduction=tf.keras.losses.Reduction.NONE
)

training_losses = per_sample_loss_fn(
    y_train,
    train_logits
).numpy()

print(training_losses.shape)
print(pd.Series(training_losses).describe())
# Out:
# (8000,)
# count    8000.000000
# mean        0.593407
# std         0.413068
# min         0.044127
# 25%         0.253436
# 50%         0.499202
# 75%         0.789173
# max         3.434240
# dtype: float64

# %%
noise_loss_df = pd.DataFrame({
    "Train_ID": train_ids_original,
    "Clean_Label": train_df["clean_label"].to_numpy(),
    "Noisy_Label": train_df["noisy_label"].to_numpy(),
    "is_noisy": train_df["is_noisy"].to_numpy(),
    "Training_Loss": training_losses
})

print(noise_loss_df.head())
print(
    noise_loss_df.groupby("is_noisy")[
        "Training_Loss"
    ].describe()
)
# Out:
#    Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss
# 0         1            1            1         0       0.253589
# 1         2            1            1         0       0.807421
# 2         3            1            1         0       0.552101
# 3         4            1            1         0       0.253502
# 4         5            1            1         0       0.253445
#            count      mean       std       min       25%       50%       75%  \
# is_noisy
# 0         6400.0  0.459934  0.281842  0.044127  0.248116  0.253655  0.624083
# 1         1600.0  1.127308  0.423234  0.138350  0.730693  1.495888  1.514790
#
#                max
# is_noisy
# 0         3.434240
# 1         1.963551

# %%
noise_loss_df.to_csv(
    "Noise_GroundTruth_and_TrainingLoss.csv",
    index=False
)

# %%
train_df.to_csv(
    "NoisyLabel_TrainingData.csv",
    index=False
)

test_df.to_csv(
    "Clean_TestData.csv",
    index=False
)

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(128))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(128), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
# WARNING:tensorflow:From /rds/bear-apps/2022a/EL8-ice/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /rds/bear-apps/2022a/EL8-ice/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2026-08-01 14:09:53.702343: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0xc060230
#       Train_ID     Score
# 0            1  0.016287
# 1            2 -0.185965
# 2            3  0.193638
# 3            4  0.017229
# 4            5  0.015795
# ...        ...       ...
# 7995      8496  0.017473
# 7996      8497 -0.061271
# 7997      8498  0.016287
# 7998      8499  0.019080
# 7999      8500 -0.311264
#
# [8000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(512), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID     Score
# 0            1 -0.011053
# 1            2 -0.011350
# 2            3 -0.027200
# 3            4 -0.011054
# 4            5 -0.011053
# ...        ...       ...
# 7995      8496 -0.011058
# 7996      8497  0.030230
# 7997      8498 -0.011050
# 7998      8499  0.025206
# 7999      8500  0.008917
#
# [8000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("NoisyLabel_TracIn_Scores.csv",index = False)
df_sorted.to_csv("NoisyLabel_FOIF_Scores.csv",index = False)
