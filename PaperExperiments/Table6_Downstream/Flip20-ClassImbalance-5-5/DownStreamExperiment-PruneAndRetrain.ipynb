# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 15)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -0.318733   5.396442   1.414061   3.356327   2.364601   2.342864
# 1      3.344966   2.424859   5.095402   1.836602  -0.599445   0.611780
# 2      2.667142  -2.090442  -1.641394  -2.687489   0.013207   5.190774
# 3      1.916675  -2.365890  -1.452175  -1.875552  -0.113632   3.494301
# 4     -0.025394   4.375837   1.255440   1.625592  -1.183051   4.534315
# ...         ...        ...        ...        ...        ...        ...
# 7995  -2.313881   1.600642   0.915895   1.690314  -1.885480   0.811767
# 7996  -0.220535   0.361194  -1.581270  -1.457011   3.655984   2.179526
# 7997  -1.744727   0.652012  -0.121031   1.655096   2.296067   0.245165
# 7998  -1.806808  -0.704839   1.698431  -3.602001   0.844647   1.772143
# 7999   3.773403  -1.464346  -2.196749  -0.057284   0.037428   1.036493
#
#       feature_7  feature_8  feature_9  feature_10  label     id  clean_label  \
# 0      0.207598   0.973267   1.528003   -0.050004      1  12161            1
# 1      0.224191  -4.641378  -3.116159   -7.442811      1   5633            1
# 2      1.226277  -2.141567  -0.120532   -1.262692      1  10987            1
# 3      0.652624  -1.462022  -0.360879   -3.728113      1   4264            1
# 4      5.316918  -1.431300  -1.442111   -4.787368      1   8390            1
# ...         ...        ...        ...         ...    ...    ...          ...
# 7995   0.867926  -1.535044   0.259993   -1.019489      1   9284            1
# 7996  -3.086690  -3.591024  -2.216679   -0.555296      0   2511            1
# 7997   6.624843  -1.861098   0.109599    0.741079      1   6327            1
# 7998  -0.625979  -2.597843   1.162316    0.382934      0  12979            0
# 7999   5.025687  -1.033595  -2.782696   -3.326021      1  10432            1
#
#       is_noisy  noisy_label
# 0            0            1
# 1            0            1
# 2            0            1
# 3            0            1
# 4            0            1
# ...        ...          ...
# 7995         0            1
# 7996         1            0
# 7997         0            1
# 7998         0            0
# 7999         0            1
#
# [8000 rows x 15 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0        12161            1            1         0       0.237024    0.170257
# 1         5633            1            1         0       0.148631    0.211974
# 2        10987            1            1         0       0.311004    0.284697
# 3         4264            1            1         0       0.249344    0.156308
# 4         8390            1            1         0       0.197998    0.238378
# ...        ...          ...          ...       ...            ...         ...
# 7995      9284            1            1         0       0.474866    0.136529
# 7996      2511            1            0         1       1.185760   -0.467609
# 7997      6327            1            1         0       0.529301    0.395694
# 7998     12979            0            0         0       0.201204    0.135739
# 7999     10432            1            1         0       0.168573    0.195293
#
#       TracIn_Score
# 0         0.011375
# 1         0.009850
# 2         0.033239
# 3         0.022526
# 4         0.013124
# ...            ...
# 7995      0.007369
# 7996     -0.049873
# 7997      0.012444
# 7998      0.007760
# 7999      0.021048
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0        12161            1            1         0       0.237024    0.170257
# 1         5633            1            1         0       0.148631    0.211974
# 2        10987            1            1         0       0.311004    0.284697
# 3         4264            1            1         0       0.249344    0.156308
# 4         8390            1            1         0       0.197998    0.238378
# ...        ...          ...          ...       ...            ...         ...
# 7995      9284            1            1         0       0.474866    0.136529
# 7996      2511            1            0         1       1.185760   -0.467609
# 7997      6327            1            1         0       0.529301    0.395694
# 7998     12979            0            0         0       0.201204    0.135739
# 7999     10432            1            1         0       0.168573    0.195293
#
#       TracIn_Score  Random_Score
# 0         0.011375      0.773956
# 1         0.009850      0.438878
# 2         0.033239      0.858598
# 3         0.022526      0.697368
# 4         0.013124      0.094177
# ...            ...           ...
# 7995      0.007369      0.339107
# 7996     -0.049873      0.135326
# 7997      0.012444      0.479135
# 7998      0.007760      0.232246
# 7999      0.021048      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.30
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.3
# Removed samples: 2400
# Remaining samples: 5600

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 1402
# Noisy fraction among removed: 0.5841666666666666

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (5600, 11)
# (5600, 2)

# %%
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 22/22 - 1s - loss: 0.9739 - accuracy: 0.4296 - val_loss: 0.7924 - val_accuracy: 0.4560 - 577ms/epoch - 26ms/step
# 22/22 - 0s - loss: 0.7207 - accuracy: 0.5141 - val_loss: 0.6508 - val_accuracy: 0.5580 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.5929 - accuracy: 0.6682 - val_loss: 0.5870 - val_accuracy: 0.6960 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.5314 - accuracy: 0.7536 - val_loss: 0.5508 - val_accuracy: 0.7240 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.4922 - accuracy: 0.7900 - val_loss: 0.5246 - val_accuracy: 0.7420 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.4607 - accuracy: 0.8173 - val_loss: 0.5021 - val_accuracy: 0.7620 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.4324 - accuracy: 0.8404 - val_loss: 0.4815 - val_accuracy: 0.7780 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.4057 - accuracy: 0.8577 - val_loss: 0.4622 - val_accuracy: 0.7880 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.3800 - accuracy: 0.8763 - val_loss: 0.4437 - val_accuracy: 0.8080 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.3552 - accuracy: 0.8920 - val_loss: 0.4263 - val_accuracy: 0.8080 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.3317 - accuracy: 0.9038 - val_loss: 0.4102 - val_accuracy: 0.8160 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.3095 - accuracy: 0.9109 - val_loss: 0.3952 - val_accuracy: 0.8340 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.2888 - accuracy: 0.9187 - val_loss: 0.3819 - val_accuracy: 0.8440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.2697 - accuracy: 0.9264 - val_loss: 0.3700 - val_accuracy: 0.8500 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.2523 - accuracy: 0.9320 - val_loss: 0.3597 - val_accuracy: 0.8480 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.2366 - accuracy: 0.9346 - val_loss: 0.3509 - val_accuracy: 0.8540 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.2225 - accuracy: 0.9380 - val_loss: 0.3434 - val_accuracy: 0.8580 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.2098 - accuracy: 0.9409 - val_loss: 0.3371 - val_accuracy: 0.8620 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1984 - accuracy: 0.9438 - val_loss: 0.3319 - val_accuracy: 0.8620 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1883 - accuracy: 0.9452 - val_loss: 0.3278 - val_accuracy: 0.8640 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1791 - accuracy: 0.9479 - val_loss: 0.3244 - val_accuracy: 0.8660 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1709 - accuracy: 0.9486 - val_loss: 0.3218 - val_accuracy: 0.8680 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1634 - accuracy: 0.9514 - val_loss: 0.3194 - val_accuracy: 0.8680 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1566 - accuracy: 0.9530 - val_loss: 0.3174 - val_accuracy: 0.8640 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1504 - accuracy: 0.9541 - val_loss: 0.3159 - val_accuracy: 0.8640 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1446 - accuracy: 0.9554 - val_loss: 0.3147 - val_accuracy: 0.8660 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1394 - accuracy: 0.9564 - val_loss: 0.3136 - val_accuracy: 0.8660 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1346 - accuracy: 0.9582 - val_loss: 0.3128 - val_accuracy: 0.8660 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1301 - accuracy: 0.9591 - val_loss: 0.3123 - val_accuracy: 0.8700 - 66ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1260 - accuracy: 0.9605 - val_loss: 0.3120 - val_accuracy: 0.8700 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1221 - accuracy: 0.9627 - val_loss: 0.3119 - val_accuracy: 0.8720 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1185 - accuracy: 0.9636 - val_loss: 0.3119 - val_accuracy: 0.8720 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.1151 - accuracy: 0.9648 - val_loss: 0.3120 - val_accuracy: 0.8760 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1120 - accuracy: 0.9654 - val_loss: 0.3121 - val_accuracy: 0.8740 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1090 - accuracy: 0.9661 - val_loss: 0.3123 - val_accuracy: 0.8740 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1062 - accuracy: 0.9670 - val_loss: 0.3125 - val_accuracy: 0.8740 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1035 - accuracy: 0.9682 - val_loss: 0.3127 - val_accuracy: 0.8760 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1010 - accuracy: 0.9689 - val_loss: 0.3131 - val_accuracy: 0.8760 - 67ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0986 - accuracy: 0.9698 - val_loss: 0.3134 - val_accuracy: 0.8760 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0964 - accuracy: 0.9704 - val_loss: 0.3139 - val_accuracy: 0.8780 - 69ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0942 - accuracy: 0.9707 - val_loss: 0.3144 - val_accuracy: 0.8820 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0921 - accuracy: 0.9707 - val_loss: 0.3149 - val_accuracy: 0.8820 - 69ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0902 - accuracy: 0.9716 - val_loss: 0.3155 - val_accuracy: 0.8820 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0883 - accuracy: 0.9725 - val_loss: 0.3160 - val_accuracy: 0.8840 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0865 - accuracy: 0.9729 - val_loss: 0.3165 - val_accuracy: 0.8840 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0848 - accuracy: 0.9730 - val_loss: 0.3171 - val_accuracy: 0.8840 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0832 - accuracy: 0.9737 - val_loss: 0.3177 - val_accuracy: 0.8860 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0816 - accuracy: 0.9745 - val_loss: 0.3182 - val_accuracy: 0.8860 - 73ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0801 - accuracy: 0.9750 - val_loss: 0.3188 - val_accuracy: 0.8860 - 46ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0786 - accuracy: 0.9759 - val_loss: 0.3194 - val_accuracy: 0.8860 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0772 - accuracy: 0.9761 - val_loss: 0.3200 - val_accuracy: 0.8880 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0758 - accuracy: 0.9764 - val_loss: 0.3206 - val_accuracy: 0.8880 - 73ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0746 - accuracy: 0.9775 - val_loss: 0.3211 - val_accuracy: 0.8880 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0733 - accuracy: 0.9782 - val_loss: 0.3217 - val_accuracy: 0.8900 - 91ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0721 - accuracy: 0.9782 - val_loss: 0.3222 - val_accuracy: 0.8900 - 87ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0709 - accuracy: 0.9784 - val_loss: 0.3228 - val_accuracy: 0.8920 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0698 - accuracy: 0.9796 - val_loss: 0.3234 - val_accuracy: 0.8920 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0687 - accuracy: 0.9800 - val_loss: 0.3241 - val_accuracy: 0.8920 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0676 - accuracy: 0.9807 - val_loss: 0.3247 - val_accuracy: 0.8940 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0666 - accuracy: 0.9811 - val_loss: 0.3252 - val_accuracy: 0.8940 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0656 - accuracy: 0.9814 - val_loss: 0.3258 - val_accuracy: 0.8940 - 77ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0646 - accuracy: 0.9820 - val_loss: 0.3264 - val_accuracy: 0.8940 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0637 - accuracy: 0.9821 - val_loss: 0.3269 - val_accuracy: 0.8960 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0628 - accuracy: 0.9823 - val_loss: 0.3275 - val_accuracy: 0.8960 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0619 - accuracy: 0.9827 - val_loss: 0.3279 - val_accuracy: 0.8960 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0611 - accuracy: 0.9829 - val_loss: 0.3283 - val_accuracy: 0.8960 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0603 - accuracy: 0.9834 - val_loss: 0.3287 - val_accuracy: 0.8960 - 45ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0595 - accuracy: 0.9839 - val_loss: 0.3291 - val_accuracy: 0.8960 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0588 - accuracy: 0.9843 - val_loss: 0.3295 - val_accuracy: 0.8960 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0581 - accuracy: 0.9845 - val_loss: 0.3300 - val_accuracy: 0.8960 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0574 - accuracy: 0.9846 - val_loss: 0.3304 - val_accuracy: 0.8980 - 45ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0567 - accuracy: 0.9848 - val_loss: 0.3309 - val_accuracy: 0.8980 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0560 - accuracy: 0.9848 - val_loss: 0.3315 - val_accuracy: 0.8980 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0553 - accuracy: 0.9848 - val_loss: 0.3323 - val_accuracy: 0.8980 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0547 - accuracy: 0.9848 - val_loss: 0.3333 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0540 - accuracy: 0.9848 - val_loss: 0.3341 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0534 - accuracy: 0.9854 - val_loss: 0.3347 - val_accuracy: 0.8980 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0528 - accuracy: 0.9854 - val_loss: 0.3353 - val_accuracy: 0.8980 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0522 - accuracy: 0.9854 - val_loss: 0.3360 - val_accuracy: 0.8980 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0516 - accuracy: 0.9854 - val_loss: 0.3366 - val_accuracy: 0.8980 - 72ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0511 - accuracy: 0.9857 - val_loss: 0.3373 - val_accuracy: 0.8980 - 65ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0506 - accuracy: 0.9857 - val_loss: 0.3381 - val_accuracy: 0.8980 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0500 - accuracy: 0.9857 - val_loss: 0.3388 - val_accuracy: 0.8960 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0495 - accuracy: 0.9861 - val_loss: 0.3394 - val_accuracy: 0.8960 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0490 - accuracy: 0.9861 - val_loss: 0.3401 - val_accuracy: 0.8960 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0485 - accuracy: 0.9866 - val_loss: 0.3407 - val_accuracy: 0.8960 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0481 - accuracy: 0.9871 - val_loss: 0.3415 - val_accuracy: 0.8960 - 68ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0476 - accuracy: 0.9875 - val_loss: 0.3422 - val_accuracy: 0.8960 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0472 - accuracy: 0.9875 - val_loss: 0.3430 - val_accuracy: 0.8960 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0467 - accuracy: 0.9877 - val_loss: 0.3439 - val_accuracy: 0.8960 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0463 - accuracy: 0.9877 - val_loss: 0.3448 - val_accuracy: 0.8960 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0459 - accuracy: 0.9877 - val_loss: 0.3456 - val_accuracy: 0.8940 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0455 - accuracy: 0.9877 - val_loss: 0.3464 - val_accuracy: 0.8940 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0451 - accuracy: 0.9877 - val_loss: 0.3471 - val_accuracy: 0.8940 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0447 - accuracy: 0.9880 - val_loss: 0.3480 - val_accuracy: 0.8940 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0443 - accuracy: 0.9879 - val_loss: 0.3487 - val_accuracy: 0.8940 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0439 - accuracy: 0.9879 - val_loss: 0.3494 - val_accuracy: 0.8940 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0436 - accuracy: 0.9879 - val_loss: 0.3500 - val_accuracy: 0.8940 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0432 - accuracy: 0.9880 - val_loss: 0.3508 - val_accuracy: 0.8940 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0429 - accuracy: 0.9882 - val_loss: 0.3515 - val_accuracy: 0.8940 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0425 - accuracy: 0.9882 - val_loss: 0.3523 - val_accuracy: 0.8940 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0422 - accuracy: 0.9882 - val_loss: 0.3531 - val_accuracy: 0.8940 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0419 - accuracy: 0.9886 - val_loss: 0.3538 - val_accuracy: 0.8940 - 70ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0416 - accuracy: 0.9886 - val_loss: 0.3544 - val_accuracy: 0.8940 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0413 - accuracy: 0.9886 - val_loss: 0.3550 - val_accuracy: 0.8940 - 65ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0410 - accuracy: 0.9886 - val_loss: 0.3557 - val_accuracy: 0.8960 - 67ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0407 - accuracy: 0.9886 - val_loss: 0.3563 - val_accuracy: 0.8960 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0404 - accuracy: 0.9889 - val_loss: 0.3570 - val_accuracy: 0.8960 - 65ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0401 - accuracy: 0.9889 - val_loss: 0.3576 - val_accuracy: 0.8960 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0398 - accuracy: 0.9889 - val_loss: 0.3584 - val_accuracy: 0.8960 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0395 - accuracy: 0.9891 - val_loss: 0.3590 - val_accuracy: 0.8960 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0393 - accuracy: 0.9891 - val_loss: 0.3597 - val_accuracy: 0.8960 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0390 - accuracy: 0.9889 - val_loss: 0.3604 - val_accuracy: 0.8980 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.3611 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.3618 - val_accuracy: 0.8980 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0382 - accuracy: 0.9891 - val_loss: 0.3625 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0380 - accuracy: 0.9887 - val_loss: 0.3631 - val_accuracy: 0.8980 - 71ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0377 - accuracy: 0.9891 - val_loss: 0.3638 - val_accuracy: 0.8980 - 71ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0375 - accuracy: 0.9895 - val_loss: 0.3645 - val_accuracy: 0.8980 - 73ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0373 - accuracy: 0.9893 - val_loss: 0.3651 - val_accuracy: 0.8980 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0371 - accuracy: 0.9893 - val_loss: 0.3659 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0368 - accuracy: 0.9893 - val_loss: 0.3667 - val_accuracy: 0.8980 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0366 - accuracy: 0.9895 - val_loss: 0.3675 - val_accuracy: 0.8980 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0364 - accuracy: 0.9896 - val_loss: 0.3683 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0362 - accuracy: 0.9896 - val_loss: 0.3690 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0360 - accuracy: 0.9896 - val_loss: 0.3698 - val_accuracy: 0.8980 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0358 - accuracy: 0.9896 - val_loss: 0.3705 - val_accuracy: 0.8980 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0356 - accuracy: 0.9896 - val_loss: 0.3711 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0354 - accuracy: 0.9895 - val_loss: 0.3716 - val_accuracy: 0.8980 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0352 - accuracy: 0.9896 - val_loss: 0.3721 - val_accuracy: 0.8980 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0350 - accuracy: 0.9896 - val_loss: 0.3727 - val_accuracy: 0.8980 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0348 - accuracy: 0.9898 - val_loss: 0.3733 - val_accuracy: 0.8980 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0346 - accuracy: 0.9898 - val_loss: 0.3739 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0344 - accuracy: 0.9900 - val_loss: 0.3744 - val_accuracy: 0.8980 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0343 - accuracy: 0.9902 - val_loss: 0.3750 - val_accuracy: 0.8980 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0341 - accuracy: 0.9902 - val_loss: 0.3758 - val_accuracy: 0.8980 - 66ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0339 - accuracy: 0.9905 - val_loss: 0.3765 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0337 - accuracy: 0.9905 - val_loss: 0.3771 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0336 - accuracy: 0.9905 - val_loss: 0.3778 - val_accuracy: 0.8960 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0334 - accuracy: 0.9905 - val_loss: 0.3783 - val_accuracy: 0.8960 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0333 - accuracy: 0.9905 - val_loss: 0.3790 - val_accuracy: 0.8960 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0331 - accuracy: 0.9905 - val_loss: 0.3796 - val_accuracy: 0.8960 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0329 - accuracy: 0.9905 - val_loss: 0.3801 - val_accuracy: 0.8960 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0328 - accuracy: 0.9907 - val_loss: 0.3807 - val_accuracy: 0.8960 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0326 - accuracy: 0.9907 - val_loss: 0.3813 - val_accuracy: 0.8960 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0325 - accuracy: 0.9907 - val_loss: 0.3818 - val_accuracy: 0.8960 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0323 - accuracy: 0.9907 - val_loss: 0.3824 - val_accuracy: 0.8960 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0322 - accuracy: 0.9907 - val_loss: 0.3831 - val_accuracy: 0.8960 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.3837 - val_accuracy: 0.8960 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.3842 - val_accuracy: 0.8960 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0318 - accuracy: 0.9905 - val_loss: 0.3847 - val_accuracy: 0.8960 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0316 - accuracy: 0.9905 - val_loss: 0.3853 - val_accuracy: 0.8960 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.3858 - val_accuracy: 0.8960 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0314 - accuracy: 0.9907 - val_loss: 0.3862 - val_accuracy: 0.8960 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.3868 - val_accuracy: 0.8980 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0311 - accuracy: 0.9907 - val_loss: 0.3872 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0310 - accuracy: 0.9907 - val_loss: 0.3875 - val_accuracy: 0.8980 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0309 - accuracy: 0.9907 - val_loss: 0.3879 - val_accuracy: 0.8980 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0307 - accuracy: 0.9907 - val_loss: 0.3884 - val_accuracy: 0.8980 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0306 - accuracy: 0.9909 - val_loss: 0.3889 - val_accuracy: 0.8980 - 69ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0305 - accuracy: 0.9909 - val_loss: 0.3894 - val_accuracy: 0.8980 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0304 - accuracy: 0.9911 - val_loss: 0.3898 - val_accuracy: 0.8980 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0302 - accuracy: 0.9912 - val_loss: 0.3903 - val_accuracy: 0.8980 - 64ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0301 - accuracy: 0.9912 - val_loss: 0.3910 - val_accuracy: 0.8980 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0300 - accuracy: 0.9912 - val_loss: 0.3914 - val_accuracy: 0.8980 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0299 - accuracy: 0.9912 - val_loss: 0.3919 - val_accuracy: 0.8980 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.3925 - val_accuracy: 0.8980 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.3930 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0295 - accuracy: 0.9912 - val_loss: 0.3934 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0294 - accuracy: 0.9914 - val_loss: 0.3938 - val_accuracy: 0.8980 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0293 - accuracy: 0.9914 - val_loss: 0.3943 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0292 - accuracy: 0.9914 - val_loss: 0.3948 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0291 - accuracy: 0.9914 - val_loss: 0.3953 - val_accuracy: 0.8980 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0290 - accuracy: 0.9914 - val_loss: 0.3957 - val_accuracy: 0.8980 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0289 - accuracy: 0.9914 - val_loss: 0.3963 - val_accuracy: 0.8980 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.3968 - val_accuracy: 0.8980 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0287 - accuracy: 0.9914 - val_loss: 0.3972 - val_accuracy: 0.8980 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0286 - accuracy: 0.9914 - val_loss: 0.3976 - val_accuracy: 0.8980 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0285 - accuracy: 0.9914 - val_loss: 0.3980 - val_accuracy: 0.8980 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0284 - accuracy: 0.9914 - val_loss: 0.3986 - val_accuracy: 0.8980 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0283 - accuracy: 0.9914 - val_loss: 0.3991 - val_accuracy: 0.8980 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0282 - accuracy: 0.9914 - val_loss: 0.3995 - val_accuracy: 0.8980 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0281 - accuracy: 0.9916 - val_loss: 0.4000 - val_accuracy: 0.8980 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.4004 - val_accuracy: 0.8980 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0279 - accuracy: 0.9916 - val_loss: 0.4010 - val_accuracy: 0.8980 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.4016 - val_accuracy: 0.8960 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0277 - accuracy: 0.9918 - val_loss: 0.4020 - val_accuracy: 0.8960 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.4024 - val_accuracy: 0.8960 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0275 - accuracy: 0.9920 - val_loss: 0.4029 - val_accuracy: 0.8960 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0275 - accuracy: 0.9920 - val_loss: 0.4034 - val_accuracy: 0.8960 - 42ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0274 - accuracy: 0.9920 - val_loss: 0.4038 - val_accuracy: 0.8960 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0273 - accuracy: 0.9920 - val_loss: 0.4043 - val_accuracy: 0.8960 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0272 - accuracy: 0.9920 - val_loss: 0.4048 - val_accuracy: 0.8960 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0271 - accuracy: 0.9920 - val_loss: 0.4052 - val_accuracy: 0.8960 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0270 - accuracy: 0.9920 - val_loss: 0.4056 - val_accuracy: 0.8960 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0269 - accuracy: 0.9920 - val_loss: 0.4060 - val_accuracy: 0.8960 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0268 - accuracy: 0.9920 - val_loss: 0.4064 - val_accuracy: 0.8960 - 42ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.4070 - val_accuracy: 0.8960 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.4074 - val_accuracy: 0.8960 - 45ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0266 - accuracy: 0.9923 - val_loss: 0.4078 - val_accuracy: 0.8960 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0265 - accuracy: 0.9923 - val_loss: 0.4083 - val_accuracy: 0.8960 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0264 - accuracy: 0.9923 - val_loss: 0.4090 - val_accuracy: 0.8960 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0264 - accuracy: 0.9923 - val_loss: 0.4094 - val_accuracy: 0.8960 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0263 - accuracy: 0.9923 - val_loss: 0.4100 - val_accuracy: 0.8960 - 93ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.4105 - val_accuracy: 0.8980 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.4109 - val_accuracy: 0.8980 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.4115 - val_accuracy: 0.8980 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.4120 - val_accuracy: 0.8980 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.4124 - val_accuracy: 0.9000 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.4128 - val_accuracy: 0.9000 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0258 - accuracy: 0.9923 - val_loss: 0.4133 - val_accuracy: 0.9000 - 46ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0257 - accuracy: 0.9925 - val_loss: 0.4138 - val_accuracy: 0.9000 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.4143 - val_accuracy: 0.9000 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.4149 - val_accuracy: 0.9000 - 72ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.4154 - val_accuracy: 0.9000 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0254 - accuracy: 0.9925 - val_loss: 0.4159 - val_accuracy: 0.9000 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0254 - accuracy: 0.9925 - val_loss: 0.4165 - val_accuracy: 0.9000 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0253 - accuracy: 0.9925 - val_loss: 0.4170 - val_accuracy: 0.9000 - 71ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.4175 - val_accuracy: 0.9000 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0252 - accuracy: 0.9923 - val_loss: 0.4180 - val_accuracy: 0.9000 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0251 - accuracy: 0.9923 - val_loss: 0.4185 - val_accuracy: 0.9000 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.4191 - val_accuracy: 0.9000 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.4195 - val_accuracy: 0.9000 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.4200 - val_accuracy: 0.9000 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.4205 - val_accuracy: 0.9000 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.4209 - val_accuracy: 0.9000 - 91ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0247 - accuracy: 0.9925 - val_loss: 0.4213 - val_accuracy: 0.9000 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.4217 - val_accuracy: 0.9000 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.4222 - val_accuracy: 0.9000 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.4226 - val_accuracy: 0.9000 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0244 - accuracy: 0.9925 - val_loss: 0.4230 - val_accuracy: 0.9000 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0244 - accuracy: 0.9925 - val_loss: 0.4235 - val_accuracy: 0.9000 - 43ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.4239 - val_accuracy: 0.9000 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.4244 - val_accuracy: 0.9000 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0242 - accuracy: 0.9925 - val_loss: 0.4248 - val_accuracy: 0.9000 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.4252 - val_accuracy: 0.9000 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.4258 - val_accuracy: 0.9020 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.4262 - val_accuracy: 0.9020 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0240 - accuracy: 0.9930 - val_loss: 0.4266 - val_accuracy: 0.9040 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0239 - accuracy: 0.9930 - val_loss: 0.4271 - val_accuracy: 0.9040 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0239 - accuracy: 0.9930 - val_loss: 0.4277 - val_accuracy: 0.9040 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.4282 - val_accuracy: 0.9040 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.4285 - val_accuracy: 0.9040 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.4290 - val_accuracy: 0.9040 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0236 - accuracy: 0.9930 - val_loss: 0.4294 - val_accuracy: 0.9040 - 78ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0236 - accuracy: 0.9930 - val_loss: 0.4299 - val_accuracy: 0.9040 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.4303 - val_accuracy: 0.9040 - 71ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.4307 - val_accuracy: 0.9040 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0234 - accuracy: 0.9930 - val_loss: 0.4312 - val_accuracy: 0.9040 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0234 - accuracy: 0.9930 - val_loss: 0.4317 - val_accuracy: 0.9040 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0233 - accuracy: 0.9930 - val_loss: 0.4323 - val_accuracy: 0.9040 - 64ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0233 - accuracy: 0.9930 - val_loss: 0.4327 - val_accuracy: 0.9040 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0232 - accuracy: 0.9932 - val_loss: 0.4332 - val_accuracy: 0.9040 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.4337 - val_accuracy: 0.9040 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.4342 - val_accuracy: 0.9040 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.4347 - val_accuracy: 0.9040 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.4351 - val_accuracy: 0.9040 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.4356 - val_accuracy: 0.9040 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.4362 - val_accuracy: 0.9040 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0228 - accuracy: 0.9932 - val_loss: 0.4366 - val_accuracy: 0.9040 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0228 - accuracy: 0.9932 - val_loss: 0.4370 - val_accuracy: 0.9040 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0227 - accuracy: 0.9932 - val_loss: 0.4375 - val_accuracy: 0.9040 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0227 - accuracy: 0.9932 - val_loss: 0.4378 - val_accuracy: 0.9040 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.4383 - val_accuracy: 0.9040 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0226 - accuracy: 0.9934 - val_loss: 0.4388 - val_accuracy: 0.9040 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0226 - accuracy: 0.9934 - val_loss: 0.4393 - val_accuracy: 0.9040 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0225 - accuracy: 0.9936 - val_loss: 0.4398 - val_accuracy: 0.9040 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.4402 - val_accuracy: 0.9040 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.4407 - val_accuracy: 0.9040 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.4414 - val_accuracy: 0.9040 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.4418 - val_accuracy: 0.9040 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.4423 - val_accuracy: 0.9040 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.4429 - val_accuracy: 0.9040 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.4432 - val_accuracy: 0.9020 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0221 - accuracy: 0.9939 - val_loss: 0.4437 - val_accuracy: 0.9020 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0221 - accuracy: 0.9939 - val_loss: 0.4443 - val_accuracy: 0.9020 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.4447 - val_accuracy: 0.9020 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.4452 - val_accuracy: 0.9020 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.4456 - val_accuracy: 0.9020 - 88ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0219 - accuracy: 0.9939 - val_loss: 0.4460 - val_accuracy: 0.9020 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0219 - accuracy: 0.9939 - val_loss: 0.4465 - val_accuracy: 0.9020 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0218 - accuracy: 0.9939 - val_loss: 0.4471 - val_accuracy: 0.9020 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0218 - accuracy: 0.9939 - val_loss: 0.4475 - val_accuracy: 0.9020 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.4480 - val_accuracy: 0.9020 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.4485 - val_accuracy: 0.9020 - 68ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0216 - accuracy: 0.9939 - val_loss: 0.4489 - val_accuracy: 0.9020 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0216 - accuracy: 0.9939 - val_loss: 0.4493 - val_accuracy: 0.9020 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0216 - accuracy: 0.9939 - val_loss: 0.4498 - val_accuracy: 0.9020 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0215 - accuracy: 0.9941 - val_loss: 0.4503 - val_accuracy: 0.9020 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0215 - accuracy: 0.9941 - val_loss: 0.4507 - val_accuracy: 0.9020 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0214 - accuracy: 0.9941 - val_loss: 0.4513 - val_accuracy: 0.9020 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0214 - accuracy: 0.9941 - val_loss: 0.4517 - val_accuracy: 0.9020 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0214 - accuracy: 0.9941 - val_loss: 0.4521 - val_accuracy: 0.9020 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.4525 - val_accuracy: 0.9020 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.4529 - val_accuracy: 0.9020 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.4535 - val_accuracy: 0.9020 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.4539 - val_accuracy: 0.9020 - 66ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.4545 - val_accuracy: 0.9020 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.4549 - val_accuracy: 0.9020 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.4554 - val_accuracy: 0.9020 - 56ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.4554 - accuracy: 0.9020 - 27ms/epoch - 2ms/step
# 0.4554139971733093

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
