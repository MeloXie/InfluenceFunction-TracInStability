# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2026-08-01 14:40:05.278427: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2.11.0

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# ERROR:absl:cannot import name 'builder' from 'google.protobuf.internal' (/rds/bear-apps/2022a/EL8-ice/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# Traceback (most recent call last):
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/__init__.py", line 79, in <module>
#     from tensorflow_datasets import rlds  # pylint: disable=g-bad-import-order
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/rlds/__init__.py", line 21, in <module>
#     from tensorflow_datasets.rlds import envlogger_reader
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/rlds/envlogger_reader.py", line 21, in <module>
#     from tensorflow_datasets.core.utils.lazy_imports_utils import tree
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/__init__.py", line 21, in <module>
#     from tensorflow_datasets.core import community
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/community/__init__.py", line 19, in <module>
#     from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/community/huggingface_wrapper.py", line 32, in <module>
#     from tensorflow_datasets.core import dataset_builder
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py", line 162, in <module>
#     class DatasetBuilder(registered.RegisteredDataset):
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/etils/epy/lazy_imports_utils.py", line 123, in __getattr__
#     return getattr(self._module, name)
#   File "/rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/functools.py", line 981, in __get__
#     val = self.func(instance)
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/etils/epy/lazy_imports_utils.py", line 84, in _module
#     module = importlib.import_module(self.module_name)
#   File "/rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/registered.py", line 36, in <module>
#     import tensorflow_datasets.core.logging as _tfds_logging
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/logging/__init__.py", line 29, in <module>
#     from tensorflow_datasets.core.logging import logging_logger
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/logging/logging_logger.py", line 21, in <module>
#     from tensorflow_datasets.core import decode
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/decode/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.decode.partial_decode import PartialDecoding
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/decode/partial_decode.py", line 21, in <module>
#     from tensorflow_datasets.core import features as features_lib
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/__init__.py", line 22, in <module>
#     from tensorflow_datasets.core.features.audio_feature import Audio
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/audio_feature.py", line 33, in <module>
#     from tensorflow_datasets.core.features import feature as feature_lib
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/features/feature.py", line 36, in <module>
#     from tensorflow_datasets.core.proto import feature_pb2
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/proto/__init__.py", line 18, in <module>
#     from tensorflow_datasets.core.proto import dataset_info_generated_pb2 as dataset_info_pb2  # pylint: disable=line-too-long
#   File "/rds/homes/t/txx400/.local/lib/python3.10/site-packages/tensorflow_datasets/core/proto/dataset_info_generated_pb2.py", line 25, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/rds/bear-apps/2022a/EL8-ice/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
total_size = 8500
test_size = 500
n_features=10
seed=42
sep= 1.5
std0 = 1.0          
std1_dense = 0.0001   
std1_sparse = 10.0

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
n_per_class = total_size // 2

# %%
big_size = n_per_class // 2
small_size = n_per_class - big_size

# %%
c0 = np.zeros(n_features)
c0[0] = -sep

c1 = np.zeros(n_features)
c1[0] = sep

# %%
X0_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c0],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed
)

X0_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c0],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 1
)

X1_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c1],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed + 2
)

X1_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c1],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 3
)

# %%
X = np.vstack([X0_dense, X0_sparse, X1_dense, X1_sparse])
y = np.hstack([
    np.zeros(big_size, dtype=int),
    np.zeros(small_size, dtype=int),
    np.ones(big_size, dtype=int),
    np.ones(small_size, dtype=int),
])

# %%
cluster_id = (
    (["0_dense"] * big_size) +
    (["0_sparse"] * small_size) +
    (["1_dense"] * big_size) +
    (["1_sparse"] * small_size)
)
rng = np.random.RandomState(seed)
idx = rng.permutation(X.shape[0])
X = X[idx]; y = y[idx]
cluster_id = np.array(cluster_id, dtype=object)[idx]

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
df["cluster_id"] = cluster_id 
print(df)
print(df["label"].value_counts())
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.500041  -0.000005   0.000084  -0.000046  -0.000010  -0.000293
# 1    -12.078473 -10.257015  -6.183391   8.016973 -12.545224  -6.689937
# 2     -4.858578   8.165048  -6.197105 -13.567885 -23.248130   6.757672
# 3      1.499986  -0.000041  -0.000142   0.000004   0.000034   0.000063
# 4      1.499727  -0.000123  -0.000116   0.000064  -0.000050  -0.000136
# ...         ...        ...        ...        ...        ...        ...
# 8495   1.500042   0.000159   0.000083  -0.000102   0.000112   0.000005
# 8496   1.499917  -0.000040  -0.000288  -0.000033  -0.000056   0.000047
# 8497   1.499949  -0.000062  -0.000151   0.000249  -0.000125  -0.000103
# 8498  -1.499988   0.000121   0.000158   0.000008  -0.000032   0.000007
# 8499  -2.051885 -14.026055   3.858365   4.279559  -7.014501   5.336282
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id
# 0     -0.000251  -0.000077  -0.000049    0.000178      1     1    1_dense
# 1     10.183697  -3.046789  12.012060   -9.157625      1     2   1_sparse
# 2      7.704527  13.806519   3.962867   10.793499      1     3   1_sparse
# 3     -0.000096  -0.000078   0.000020    0.000111      1     4    1_dense
# 4     -0.000284  -0.000057   0.000048   -0.000069      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 8495   0.000322  -0.000252  -0.000074    0.000085      1  8496    1_dense
# 8496   0.000108  -0.000017   0.000043   -0.000099      1  8497    1_dense
# 8497   0.000070  -0.000194   0.000054   -0.000205      1  8498    1_dense
# 8498  -0.000009  -0.000166   0.000155    0.000025      0  8499    0_dense
# 8499  12.052829 -21.279629  15.016274   -2.004951      1  8500   1_sparse
#
# [8500 rows x 13 columns]
# 1    4250
# 0    4250
# Name: label, dtype: int64

# %%
print(df["cluster_id"].value_counts())
# Out:
# 1_dense     2125
# 1_sparse    2125
# 0_sparse    2125
# 0_dense     2125
# Name: cluster_id, dtype: int64

# %%
n0 = test_size //2
n1_big = (test_size - n0) // 2
n1_small = test_size - n0 - n1_big
n0,n1_big,n1_small
# Out:
# (250, 125, 125)

# %%
g = df.groupby("cluster_id", group_keys=False)
test_df = pd.concat([
    g.get_group("0_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("0_sparse").sample(n=n1_small, random_state=seed, replace=False),
    g.get_group("1_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("1_sparse").sample(n=n1_small, random_state=seed, replace=False)
]).sample(frac=1, random_state=seed)

train_df = df.drop(test_df.index).reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df["clean_label"] = train_df["label"].copy()

# Randomly select 20% of the training samples
noise_ratio = 0.20
noise_seed = 42

rng = np.random.default_rng(noise_seed)

n_noisy = int(len(train_df) * noise_ratio)

noisy_positions = rng.choice(
    len(train_df),
    size=n_noisy,
    replace=False
)

# Indicator showing which samples were corrupted
train_df["is_noisy"] = 0
train_df.loc[train_df.index[noisy_positions], "is_noisy"] = 1

# Flip the binary labels: 0 -> 1 and 1 -> 0
train_df.loc[
    train_df.index[noisy_positions],
    "label"
] = 1 - train_df.loc[
    train_df.index[noisy_positions],
    "label"
]

# Save a clearer name for the labels used during training
train_df["noisy_label"] = train_df["label"]

print("Number of training samples:", len(train_df))
print("Number of flipped labels:", train_df["is_noisy"].sum())
print("Noise ratio:", train_df["is_noisy"].mean())

print(
    train_df[
        ["id", "clean_label", "noisy_label", "is_noisy"]
    ].head()
)
# Out:
# Number of training samples: 8000
# Number of flipped labels: 1600
# Noise ratio: 0.2
#    id  clean_label  noisy_label  is_noisy
# 0   1            1            1         0
# 1   2            1            1         0
# 2   3            1            1         0
# 3   4            1            1         0
# 4   5            1            1         0

# %%
# Feature columns used by the model
selected_features = [
    col for col in train_df.columns
    if col.startswith("feature_")
]

# Preserve IDs separately
train_ids_original = train_df["id"].to_numpy()

# Scale IDs only for the influence pipeline
IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

# Model features
X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

# Append the ID column, as required by your existing influence code
X_train = np.hstack([
    X_train_features,
    IDs
])

# Use the corrupted labels for training
y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (8000, 11)
# (8000, 2)

# %%
# X_train = train_df.drop(columns=["label"])
# y_train = train_df["label"]
# IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
# IDs = IDs  / 1e10

# X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
# X_train = np.hstack((X_train, IDs))
# y_train = to_categorical(y_train.values,num_classes=2)

# print(X_train)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
# Out:
# 2026-08-01 14:40:14.502589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38477 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:31:00.0, compute capability: 8.0

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
initial_model = tf.keras.models.clone_model(model)
initial_model.set_weights(model.get_weights())
model_list.append(InfluenceModel(initial_model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(512), epochs=1, validation_data=test_ds.batch(512), verbose=2)
  checkpoint_model = tf.keras.models.clone_model(model)
  checkpoint_model.set_weights(model.get_weights())
  model_list.append(InfluenceModel(checkpoint_model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 16/16 - 2s - loss: 0.8384 - accuracy: 0.5059 - val_loss: 0.7932 - val_accuracy: 0.5160 - 2s/epoch - 95ms/step
# 2026-08-01 14:40:16.256505: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 16/16 - 0s - loss: 0.8105 - accuracy: 0.5069 - val_loss: 0.7616 - val_accuracy: 0.5120 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7850 - accuracy: 0.5064 - val_loss: 0.7420 - val_accuracy: 0.5160 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7665 - accuracy: 0.5052 - val_loss: 0.7289 - val_accuracy: 0.5120 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7530 - accuracy: 0.5051 - val_loss: 0.7195 - val_accuracy: 0.5180 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7427 - accuracy: 0.5247 - val_loss: 0.7123 - val_accuracy: 0.5180 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7346 - accuracy: 0.5817 - val_loss: 0.7067 - val_accuracy: 0.7700 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7279 - accuracy: 0.6298 - val_loss: 0.7022 - val_accuracy: 0.7680 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7224 - accuracy: 0.6574 - val_loss: 0.6984 - val_accuracy: 0.7660 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7176 - accuracy: 0.6569 - val_loss: 0.6953 - val_accuracy: 0.7620 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7136 - accuracy: 0.6571 - val_loss: 0.6925 - val_accuracy: 0.7640 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7102 - accuracy: 0.6570 - val_loss: 0.6901 - val_accuracy: 0.7660 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7071 - accuracy: 0.6576 - val_loss: 0.6879 - val_accuracy: 0.7600 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7045 - accuracy: 0.6576 - val_loss: 0.6860 - val_accuracy: 0.7620 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7021 - accuracy: 0.6580 - val_loss: 0.6843 - val_accuracy: 0.7600 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.7000 - accuracy: 0.6580 - val_loss: 0.6827 - val_accuracy: 0.7620 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6982 - accuracy: 0.6594 - val_loss: 0.6812 - val_accuracy: 0.7620 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6965 - accuracy: 0.6601 - val_loss: 0.6798 - val_accuracy: 0.7620 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6950 - accuracy: 0.6595 - val_loss: 0.6786 - val_accuracy: 0.7640 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6936 - accuracy: 0.6595 - val_loss: 0.6773 - val_accuracy: 0.7620 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6923 - accuracy: 0.6599 - val_loss: 0.6762 - val_accuracy: 0.7600 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6912 - accuracy: 0.6599 - val_loss: 0.6752 - val_accuracy: 0.7600 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6901 - accuracy: 0.6594 - val_loss: 0.6741 - val_accuracy: 0.7640 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6891 - accuracy: 0.6587 - val_loss: 0.6732 - val_accuracy: 0.7640 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6882 - accuracy: 0.6587 - val_loss: 0.6723 - val_accuracy: 0.7660 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6874 - accuracy: 0.6587 - val_loss: 0.6715 - val_accuracy: 0.7620 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6866 - accuracy: 0.6584 - val_loss: 0.6706 - val_accuracy: 0.7580 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6859 - accuracy: 0.6585 - val_loss: 0.6698 - val_accuracy: 0.7580 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.
- val_accuracy: 0.7780 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6072 - accuracy: 0.6654 - val_loss: 0.4979 - val_accuracy: 0.7740 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6071 - accuracy: 0.6650 - val_loss: 0.4974 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6070 - accuracy: 0.6655 - val_loss: 0.4971 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6069 - accuracy: 0.6659 - val_loss: 0.4967 - val_accuracy: 0.7760 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6068 - accuracy: 0.6656 - val_loss: 0.4963 - val_accuracy: 0.7760 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6067 - accuracy: 0.6659 - val_loss: 0.4959 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6066 - accuracy: 0.6660 - val_loss: 0.4956 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6065 - accuracy: 0.6662 - val_loss: 0.4952 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6064 - accuracy: 0.6664 - val_loss: 0.4948 - val_accuracy: 0.7760 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6063 - accuracy: 0.6661 - val_loss: 0.4946 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6062 - accuracy: 0.6656 - val_loss: 0.4942 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6061 - accuracy: 0.6656 - val_loss: 0.4939 - val_accuracy: 0.7780 - 31ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6060 - accuracy: 0.6658 - val_loss: 0.4936 - val_accuracy: 0.7780 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6059 - accuracy: 0.6660 - val_loss: 0.4932 - val_accuracy: 0.7780 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6058 - accuracy: 0.6660 - val_loss: 0.4930 - val_accuracy: 0.7780 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6057 - accuracy: 0.6656 - val_loss: 0.4926 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6056 - accuracy: 0.6658 - val_loss: 0.4923 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6055 - accuracy: 0.6661 - val_loss: 0.4919 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6054 - accuracy: 0.6661 - val_loss: 0.4916 - val_accuracy: 0.7760 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6053 - accuracy: 0.6660 - val_loss: 0.4913 - val_accuracy: 0.7760 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6052 - accuracy: 0.6659 - val_loss: 0.4909 - val_accuracy: 0.7740 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6051 - accuracy: 0.6661 - val_loss: 0.4907 - val_accuracy: 0.7740 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6050 - accuracy: 0.6668 - val_loss: 0.4903 - val_accuracy: 0.7740 - 34ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6049 - accuracy: 0.6669 - val_loss: 0.4900 - val_accuracy: 0.7740 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6048 - accuracy: 0.6669 - val_loss: 0.4896 - val_accuracy: 0.7720 - 33ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.6047 - accuracy: 0.6668 - val_loss: 0.4894 - val_accuracy: 0.7720 - 32ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.4894 - accuracy: 0.7720 - 19ms/epoch - 1ms/step
# 0.48937201499938965

# %%
train_logits = model.predict(
    X_train,
    batch_size=256,
    verbose=0
)

# Calculate one loss value per sample using the corrupted labels
per_sample_loss_fn = CategoricalCrossentropy(
    from_logits=True,
    reduction=tf.keras.losses.Reduction.NONE
)

training_losses = per_sample_loss_fn(
    y_train,
    train_logits
).numpy()

print(training_losses.shape)
print(pd.Series(training_losses).describe())
# Out:
# (8000,)
# count    8000.000000
# mean        0.603610
# std         0.371134
# min         0.033836
# 25%         0.287610
# 50%         0.536961
# 75%         0.780758
# max         3.947754
# dtype: float64

# %%
noise_loss_df = pd.DataFrame({
    "Train_ID": train_ids_original,
    "Clean_Label": train_df["clean_label"].to_numpy(),
    "Noisy_Label": train_df["noisy_label"].to_numpy(),
    "is_noisy": train_df["is_noisy"].to_numpy(),
    "Training_Loss": training_losses
})

print(noise_loss_df.head())
print(
    noise_loss_df.groupby("is_noisy")[
        "Training_Loss"
    ].describe()
)
# Out:
#    Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss
# 0         1            1            1         0       0.273689
# 1         2            1            1         0       0.727169
# 2         3            1            1         0       0.592320
# 3         4            1            1         0       0.273689
# 4         5            1            1         0       0.273689
#            count      mean       std       min       25%       50%       75%  \
# is_noisy
# 0         6400.0  0.488891  0.265076  0.033836  0.273689  0.287649  0.673098
# 1         1600.0  1.062455  0.380158  0.141933  0.705728  1.386400  1.429488
#
#                max
# is_noisy
# 0         3.947754
# 1         2.023956

# %%
noise_loss_df.to_csv(
    "Noise_GroundTruth_and_TrainingLoss.csv",
    index=False
)

# %%
train_df.to_csv(
    "NoisyLabel_TrainingData.csv",
    index=False
)

test_df.to_csv(
    "Clean_TestData.csv",
    index=False
)

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(128))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(128), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
# WARNING:tensorflow:From /rds/bear-apps/2022a/EL8-ice/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /rds/bear-apps/2022a/EL8-ice/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2026-08-01 14:40:46.748207: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x296332d0
#       Train_ID     Score
# 0            1  0.003412
# 1            2 -0.084138
# 2            3  0.199801
# 3            4  0.003222
# 4            5  0.003412
# ...        ...       ...
# 7995      8496  0.003412
# 7996      8497 -0.011566
# 7997      8498  0.003412
# 7998      8499 -0.004709
# 7999      8500 -0.379223
#
# [8000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(512), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID     Score
# 0            1 -0.013200
# 1            2 -0.019431
# 2            3 -0.036715
# 3            4 -0.013200
# 4            5 -0.013200
# ...        ...       ...
# 7995      8496 -0.013201
# 7996      8497  0.028023
# 7997      8498 -0.013200
# 7998      8499  0.025522
# 7999      8500 -0.006264
#
# [8000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("NoisyLabel_TracIn_Scores.csv",index = False)
df_sorted.to_csv("NoisyLabel_FOIF_Scores.csv",index = False)
