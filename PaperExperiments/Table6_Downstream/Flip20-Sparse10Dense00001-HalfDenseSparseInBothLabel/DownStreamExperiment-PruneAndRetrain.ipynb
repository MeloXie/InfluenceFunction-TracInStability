# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 16)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.500041  -0.000005   0.000084  -0.000046  -0.000010  -0.000293
# 1    -12.078473 -10.257015  -6.183391   8.016973 -12.545224  -6.689937
# 2     -4.858578   8.165048  -6.197105 -13.567885 -23.248130   6.757672
# 3      1.499986  -0.000041  -0.000142   0.000004   0.000034   0.000063
# 4      1.499727  -0.000123  -0.000116   0.000064  -0.000050  -0.000136
# ...         ...        ...        ...        ...        ...        ...
# 7995   1.500042   0.000159   0.000083  -0.000102   0.000112   0.000005
# 7996   1.499917  -0.000040  -0.000288  -0.000033  -0.000056   0.000047
# 7997   1.499949  -0.000062  -0.000151   0.000249  -0.000125  -0.000103
# 7998  -1.499988   0.000121   0.000158   0.000008  -0.000032   0.000007
# 7999  -2.051885 -14.026055   3.858365   4.279559  -7.014501   5.336282
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id  \
# 0     -0.000251  -0.000077  -0.000049    0.000178      1     1    1_dense
# 1     10.183697  -3.046789  12.012060   -9.157625      1     2   1_sparse
# 2      7.704527  13.806519   3.962867   10.793499      1     3   1_sparse
# 3     -0.000096  -0.000078   0.000020    0.000111      1     4    1_dense
# 4     -0.000284  -0.000057   0.000048   -0.000069      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 7995   0.000322  -0.000252  -0.000074    0.000085      1  8496    1_dense
# 7996   0.000108  -0.000017   0.000043   -0.000099      0  8497    1_dense
# 7997   0.000070  -0.000194   0.000054   -0.000205      1  8498    1_dense
# 7998  -0.000009  -0.000166   0.000155    0.000025      0  8499    0_dense
# 7999  12.052829 -21.279629  15.016274   -2.004951      1  8500   1_sparse
#
#       clean_label  is_noisy  noisy_label
# 0               1         0            1
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               1         0            1
# ...           ...       ...          ...
# 7995            1         0            1
# 7996            1         1            0
# 7997            1         0            1
# 7998            0         0            0
# 7999            1         0            1
#
# [8000 rows x 16 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.273689    0.003412
# 1            2            1            1         0       0.727169   -0.084138
# 2            3            1            1         0       0.592320    0.199801
# 3            4            1            1         0       0.273689    0.003222
# 4            5            1            1         0       0.273689    0.003412
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.273583    0.003412
# 7996      8497            1            0         1       1.429826   -0.011566
# 7997      8498            1            1         0       0.273583    0.003412
# 7998      8499            0            0         0       0.287831   -0.004709
# 7999      8500            1            1         0       0.812987   -0.379223
#
#       TracIn_Score
# 0        -0.013200
# 1        -0.019431
# 2        -0.036715
# 3        -0.013200
# 4        -0.013200
# ...            ...
# 7995     -0.013201
# 7996      0.028023
# 7997     -0.013200
# 7998      0.025522
# 7999     -0.006264
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.273689    0.003412
# 1            2            1            1         0       0.727169   -0.084138
# 2            3            1            1         0       0.592320    0.199801
# 3            4            1            1         0       0.273689    0.003222
# 4            5            1            1         0       0.273689    0.003412
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.273583    0.003412
# 7996      8497            1            0         1       1.429826   -0.011566
# 7997      8498            1            1         0       0.273583    0.003412
# 7998      8499            0            0         0       0.287831   -0.004709
# 7999      8500            1            1         0       0.812987   -0.379223
#
#       TracIn_Score  Random_Score
# 0        -0.013200      0.773956
# 1        -0.019431      0.438878
# 2        -0.036715      0.858598
# 3        -0.013200      0.697368
# 4        -0.013200      0.094177
# ...            ...           ...
# 7995     -0.013201      0.339107
# 7996      0.028023      0.135326
# 7997     -0.013200      0.479135
# 7998      0.025522      0.232246
# 7999     -0.006264      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.20
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.2
# Removed samples: 1600
# Remaining samples: 6400

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 659
# Noisy fraction among removed: 0.411875

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (6400, 11)
# (6400, 2)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(512), epochs=1, validation_data=test_ds.batch(512), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 13/13 - 1s - loss: 0.7815 - accuracy: 0.5039 - val_loss: 0.8039 - val_accuracy: 0.5100 - 726ms/epoch - 56ms/step
# 13/13 - 0s - loss: 0.7442 - accuracy: 0.5116 - val_loss: 0.7720 - val_accuracy: 0.5180 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.7082 - accuracy: 0.5192 - val_loss: 0.7587 - val_accuracy: 0.5260 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6826 - accuracy: 0.6748 - val_loss: 0.7531 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6652 - accuracy: 0.7812 - val_loss: 0.7508 - val_accuracy: 0.7680 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6538 - accuracy: 0.7862 - val_loss: 0.7497 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6453 - accuracy: 0.7623 - val_loss: 0.7487 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6384 - accuracy: 0.7102 - val_loss: 0.7474 - val_accuracy: 0.5840 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6325 - accuracy: 0.7117 - val_loss: 0.7460 - val_accuracy: 0.5320 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6274 - accuracy: 0.6550 - val_loss: 0.7445 - val_accuracy: 0.5220 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6229 - accuracy: 0.6569 - val_loss: 0.7431 - val_accuracy: 0.5280 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6189 - accuracy: 0.6159 - val_loss: 0.7416 - val_accuracy: 0.5280 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6152 - accuracy: 0.6162 - val_loss: 0.7403 - val_accuracy: 0.5280 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6118 - accuracy: 0.6169 - val_loss: 0.7389 - val_accuracy: 0.5260 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6086 - accuracy: 0.6177 - val_loss: 0.7376 - val_accuracy: 0.5240 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6056 - accuracy: 0.6177 - val_loss: 0.7364 - val_accuracy: 0.5240 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6028 - accuracy: 0.6192 - val_loss: 0.7352 - val_accuracy: 0.5220 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.6001 - accuracy: 0.6197 - val_loss: 0.7343 - val_accuracy: 0.5220 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5976 - accuracy: 0.6203 - val_loss: 0.7332 - val_accuracy: 0.5240 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5951 - accuracy: 0.6209 - val_loss: 0.7322 - val_accuracy: 0.5260 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5926 - accuracy: 0.6223 - val_loss: 0.7313 - val_accuracy: 0.5260 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5903 - accuracy: 0.6219 - val_loss: 0.7303 - val_accuracy: 0.5240 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5880 - accuracy: 0.6225 - val_loss: 0.7295 - val_accuracy: 0.5240 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5858 - accuracy: 0.6225 - val_loss: 0.7288 - val_accuracy: 0.5260 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5837 - accuracy: 0.6367 - val_loss: 0.7280 - val_accuracy: 0.5260 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5816 - accuracy: 0.6380 - val_loss: 0.7275 - val_accuracy: 0.5260 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5795 - accuracy: 0.6516 - val_loss: 0.7269 - val_accuracy: 0.5260 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5775 - accuracy: 0.6662 - val_loss: 0.7263 - val_accuracy: 0.5260 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5755 - accuracy: 0.6667 - val_loss: 0.7258 - val_accuracy: 0.5260 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5735 - accuracy: 0.6817 - val_loss: 0.7253 - val_accuracy: 0.5260 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5715 - accuracy: 0.6975 - val_loss: 0.7248 - val_accuracy: 0.5240 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5696 - accuracy: 0.7053 - val_loss: 0.7243 - val_accuracy: 0.5240 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5677 - accuracy: 0.7053 - val_loss: 0.7240 - val_accuracy: 0.5240 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5658 - accuracy: 0.7056 - val_loss: 0.7235 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5640 - accuracy: 0.7348 - val_loss: 0.7232 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5622 - accuracy: 0.7356 - val_loss: 0.7229 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5604 - accuracy: 0.7362 - val_loss: 0.7227 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5586 - accuracy: 0.7500 - val_loss: 0.7224 - val_accuracy: 0.7740 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5568 - accuracy: 0.7658 - val_loss: 0.7222 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5551 - accuracy: 0.7663 - val_loss: 0.7222 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5532 - accuracy: 0.7667 - val_loss: 0.7220 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5514 - accuracy: 0.7672 - val_loss: 0.7219 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5495 - accuracy: 0.7670 - val_loss: 0.7218 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5474 - accuracy: 0.7852 - val_loss: 0.7212 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5447 - accuracy: 0.7855 - val_loss: 0.7197 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5414 - accuracy: 0.7862 - val_loss: 0.7182 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5378 - accuracy: 0.8020 - val_loss: 0.7164 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5341 - accuracy: 0.8019 - val_loss: 0.7147 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5304 - accuracy: 0.8016 - val_loss: 0.7132 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5268 - accuracy: 0.8012 - val_loss: 0.7118 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5232 - accuracy: 0.8142 - val_loss: 0.7104 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5195 - accuracy: 0.8142 - val_loss: 0.7093 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5159 - accuracy: 0.8138 - val_loss: 0.7081 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5124 - accuracy: 0.8142 - val_loss: 0.7071 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5093 - accuracy: 0.8145 - val_loss: 0.7069 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5067 - accuracy: 0.8148 - val_loss: 0.7075 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5044 - accuracy: 0.8145 - val_loss: 0.7076 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.5021 - accuracy: 0.8142 - val_loss: 0.7079 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4998 - accuracy: 0.8142 - val_loss: 0.7084 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4976 - accuracy: 0.8142 - val_loss: 0.7090 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4954 - accuracy: 0.8141 - val_loss: 0.7095 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4931 - accuracy: 0.8147 - val_loss: 0.7102 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4910 - accuracy: 0.8148 - val_loss: 0.7107 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4888 - accuracy: 0.8153 - val_loss: 0.7115 - val_accuracy: 0.7680 - 26ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4867 - accuracy: 0.8152 - val_loss: 0.7121 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4845 - accuracy: 0.8152 - val_loss: 0.7128 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4824 - accuracy: 0.8156 - val_loss: 0.7137 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4803 - accuracy: 0.8159 - val_loss: 0.7146 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4783 - accuracy: 0.8159 - val_loss: 0.7155 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4763 - accuracy: 0.8159 - val_loss: 0.7164 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4743 - accuracy: 0.8158 - val_loss: 0.7173 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4723 - accuracy: 0.8158 - val_loss: 0.7183 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4703 - accuracy: 0.8159 - val_loss: 0.7192 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4684 - accuracy: 0.8158 - val_loss: 0.7199 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4664 - accuracy: 0.8156 - val_loss: 0.7208 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4645 - accuracy: 0.8153 - val_loss: 0.7217 - val_accuracy: 0.7800 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4627 - accuracy: 0.8164 - val_loss: 0.7226 - val_accuracy: 0.7800 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4608 - accuracy: 0.8163 - val_loss: 0.7233 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4589 - accuracy: 0.8163 - val_loss: 0.7243 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4571 - accuracy: 0.8161 - val_loss: 0.7252 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4553 - accuracy: 0.8163 - val_loss: 0.7261 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4535 - accuracy: 0.8166 - val_loss: 0.7271 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4518 - accuracy: 0.8163 - val_loss: 0.7282 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4501 - accuracy: 0.8169 - val_loss: 0.7293 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4484 - accuracy: 0.8164 - val_loss: 0.7304 - val_accuracy: 0.7820 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4468 - accuracy: 0.8167 - val_loss: 0.7315 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4452 - accuracy: 0.8170 - val_loss: 0.7327 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4436 - accuracy: 0.8173 - val_loss: 0.7337 - val_accuracy: 0.7840 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4420 - accuracy: 0.8175 - val_loss: 0.7349 - val_accuracy: 0.7840 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4405 - accuracy: 0.8172 - val_loss: 0.7360 - val_accuracy: 0.7820 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4390 - accuracy: 0.8172 - val_loss: 0.7371 - val_accuracy: 0.7800 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4375 - accuracy: 0.8175 - val_loss: 0.7383 - val_accuracy: 0.7800 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4360 - accuracy: 0.8173 - val_loss: 0.7395 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4346 - accuracy: 0.8178 - val_loss: 0.7407 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4332 - accuracy: 0.8178 - val_loss: 0.7418 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4319 - accuracy: 0.8178 - val_loss: 0.7429 - val_accuracy: 0.7780 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4305 - accuracy: 0.8181 - val_loss: 0.7439 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4292 - accuracy: 0.8184 - val_loss: 0.7450 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4280 - accuracy: 0.8191 - val_loss: 0.7461 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4267 - accuracy: 0.8192 - val_loss: 0.7470 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4255 - accuracy: 0.8189 - val_loss: 0.7481 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4243 - accuracy: 0.8188 - val_loss: 0.7490 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4232 - accuracy: 0.8183 - val_loss: 0.7501 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4221 - accuracy: 0.8183 - val_loss: 0.7511 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4210 - accuracy: 0.8184 - val_loss: 0.7520 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4199 - accuracy: 0.8183 - val_loss: 0.7531 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4189 - accuracy: 0.8181 - val_loss: 0.7543 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4179 - accuracy: 0.8184 - val_loss: 0.7553 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4169 - accuracy: 0.8184 - val_loss: 0.7564 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4160 - accuracy: 0.8183 - val_loss: 0.7573 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4150 - accuracy: 0.8183 - val_loss: 0.7584 - val_accuracy: 0.7760 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4141 - accuracy: 0.8184 - val_loss: 0.7595 - val_accuracy: 0.7780 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4132 - accuracy: 0.8189 - val_loss: 0.7604 - val_accuracy: 0.7780 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4124 - accuracy: 0.8191 - val_loss: 0.7614 - val_accuracy: 0.7780 - 33ms/epoch - 3ms/step
# 13/13 - 0s - loss: 0.4115 - accuracy: 0.8189 - val_loss: 0.7625 - val_accuracy: 0.7760 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4107 - accuracy: 0.8192 - val_loss: 0.7633 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4098 - accuracy: 0.8188 - val_loss: 0.7643 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4090 - accuracy: 0.8188 - val_loss: 0.7652 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4082 - accuracy: 0.8192 - val_loss: 0.7662 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4075 - accuracy: 0.8191 - val_loss: 0.7670 - val_accuracy: 0.7740 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4067 - accuracy: 0.8192 - val_loss: 0.7678 - val_accuracy: 0.7740 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4060 - accuracy: 0.8194 - val_loss: 0.7687 - val_accuracy: 0.7740 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4052 - accuracy: 0.8191 - val_loss: 0.7696 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4045 - accuracy: 0.8189 - val_loss: 0.7705 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4038 - accuracy: 0.8192 - val_loss: 0.7712 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4031 - accuracy: 0.8191 - val_loss: 0.7721 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4025 - accuracy: 0.8195 - val_loss: 0.7728 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4018 - accuracy: 0.8198 - val_loss: 0.7737 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4011 - accuracy: 0.8200 - val_loss: 0.7743 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.4005 - accuracy: 0.8194 - val_loss: 0.7753 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3999 - accuracy: 0.8189 - val_loss: 0.7763 - val_accuracy: 0.7720 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3993 - accuracy: 0.8195 - val_loss: 0.7772 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3988 - accuracy: 0.8202 - val_loss: 0.7779 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3982 - accuracy: 0.8198 - val_loss: 0.7788 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3976 - accuracy: 0.8202 - val_loss: 0.7796 - val_accuracy: 0.7700 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3971 - accuracy: 0.8202 - val_loss: 0.7806 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3966 - accuracy: 0.8205 - val_loss: 0.7816 - val_accuracy: 0.7680 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3960 - accuracy: 0.8209 - val_loss: 0.7824 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3955 - accuracy: 0.8211 - val_loss: 0.7832 - val_accuracy: 0.7680 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3950 - accuracy: 0.8211 - val_loss: 0.7840 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3945 - accuracy: 0.8211 - val_loss: 0.7847 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3940 - accuracy: 0.8213 - val_loss: 0.7854 - val_accuracy: 0.7700 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3935 - accuracy: 0.8219 - val_loss: 0.7862 - val_accuracy: 0.7700 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3930 - accuracy: 0.8222 - val_loss: 0.7869 - val_accuracy: 0.7680 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3925 - accuracy: 0.8219 - val_loss: 0.7875 - val_accuracy: 0.7680 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3921 - accuracy: 0.8219 - val_loss: 0.7884 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3916 - accuracy: 0.8217 - val_loss: 0.7891 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3912 - accuracy: 0.8219 - val_loss: 0.7900 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3908 - accuracy: 0.8220 - val_loss: 0.7909 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3905 - accuracy: 0.8213 - val_loss: 0.7919 - val_accuracy: 0.7680 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3901 - accuracy: 0.8211 - val_loss: 0.7925 - val_accuracy: 0.7660 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3898 - accuracy: 0.8213 - val_loss: 0.7933 - val_accuracy: 0.7660 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3894 - accuracy: 0.8216 - val_loss: 0.7940 - val_accuracy: 0.7660 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3891 - accuracy: 0.8216 - val_loss: 0.7947 - val_accuracy: 0.7660 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3887 - accuracy: 0.8216 - val_loss: 0.7952 - val_accuracy: 0.7660 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3884 - accuracy: 0.8214 - val_loss: 0.7959 - val_accuracy: 0.7660 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3881 - accuracy: 0.8214 - val_loss: 0.7965 - val_accuracy: 0.7660 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3878 - accuracy: 0.8219 - val_loss: 0.7972 - val_accuracy: 0.7660 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3874 - accuracy: 0.8220 - val_loss: 0.7975 - val_accuracy: 0.7660 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3871 - accuracy: 0.8223 - val_loss: 0.7981 - val_accuracy: 0.7660 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3868 - accuracy: 0.8222 - val_loss: 0.7986 - val_accuracy: 0.7640 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3865 - accuracy: 0.8219 - val_loss: 0.7989 - val_accuracy: 0.7640 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3862 - accuracy: 0.8220 - val_loss: 0.7993 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3859 - accuracy: 0.8217 - val_loss: 0.7996 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3856 - accuracy: 0.8217 - val_loss: 0.8001 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3854 - accuracy: 0.8220 - val_loss: 0.8003 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3851 - accuracy: 0.8220 - val_loss: 0.8007 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3848 - accuracy: 0.8225 - val_loss: 0.8011 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3845 - accuracy: 0.8227 - val_loss: 0.8016 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3843 - accuracy: 0.8231 - val_loss: 0.8018 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3840 - accuracy: 0.8233 - val_loss: 0.8022 - val_accuracy: 0.7600 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3838 - accuracy: 0.8231 - val_loss: 0.8026 - val_accuracy: 0.7600 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3835 - accuracy: 0.8228 - val_loss: 0.8030 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3833 - accuracy: 0.8228 - val_loss: 0.8034 - val_accuracy: 0.7580 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3830 - accuracy: 0.8233 - val_loss: 0.8037 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3828 - accuracy: 0.8233 - val_loss: 0.8040 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3826 - accuracy: 0.8236 - val_loss: 0.8044 - val_accuracy: 0.7580 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3824 - accuracy: 0.8238 - val_loss: 0.8049 - val_accuracy: 0.7580 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3821 - accuracy: 0.8236 - val_loss: 0.8053 - val_accuracy: 0.7580 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3819 - accuracy: 0.8238 - val_loss: 0.8058 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3817 - accuracy: 0.8238 - val_loss: 0.8062 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3814 - accuracy: 0.8234 - val_loss: 0.8067 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3812 - accuracy: 0.8233 - val_loss: 0.8072 - val_accuracy: 0.7560 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3810 - accuracy: 0.8233 - val_loss: 0.8077 - val_accuracy: 0.7560 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3807 - accuracy: 0.8234 - val_loss: 0.8080 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3805 - accuracy: 0.8233 - val_loss: 0.8084 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3803 - accuracy: 0.8236 - val_loss: 0.8088 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3801 - accuracy: 0.8239 - val_loss: 0.8092 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3799 - accuracy: 0.8241 - val_loss: 0.8096 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3797 - accuracy: 0.8242 - val_loss: 0.8100 - val_accuracy: 0.7560 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3795 - accuracy: 0.8241 - val_loss: 0.8102 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3793 - accuracy: 0.8241 - val_loss: 0.8105 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3791 - accuracy: 0.8242 - val_loss: 0.8108 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3789 - accuracy: 0.8242 - val_loss: 0.8109 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3788 - accuracy: 0.8244 - val_loss: 0.8110 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3786 - accuracy: 0.8245 - val_loss: 0.8113 - val_accuracy: 0.7540 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3784 - accuracy: 0.8250 - val_loss: 0.8115 - val_accuracy: 0.7540 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3782 - accuracy: 0.8252 - val_loss: 0.8118 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3780 - accuracy: 0.8252 - val_loss: 0.8122 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3779 - accuracy: 0.8259 - val_loss: 0.8122 - val_accuracy: 0.7540 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3777 - accuracy: 0.8259 - val_loss: 0.8126 - val_accuracy: 0.7520 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3775 - accuracy: 0.8261 - val_loss: 0.8128 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3774 - accuracy: 0.8261 - val_loss: 0.8131 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3772 - accuracy: 0.8258 - val_loss: 0.8131 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3771 - accuracy: 0.8261 - val_loss: 0.8135 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3769 - accuracy: 0.8259 - val_loss: 0.8135 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3768 - accuracy: 0.8259 - val_loss: 0.8138 - val_accuracy: 0.7520 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3766 - accuracy: 0.8261 - val_loss: 0.8140 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3765 - accuracy: 0.8264 - val_loss: 0.8143 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3763 - accuracy: 0.8264 - val_loss: 0.8142 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3762 - accuracy: 0.8267 - val_loss: 0.8144 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3760 - accuracy: 0.8267 - val_loss: 0.8147 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3759 - accuracy: 0.8269 - val_loss: 0.8150 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3758 - accuracy: 0.8270 - val_loss: 0.8150 - val_accuracy: 0.7560 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3756 - accuracy: 0.8270 - val_loss: 0.8152 - val_accuracy: 0.7560 - 30ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3755 - accuracy: 0.8272 - val_loss: 0.8154 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3753 - accuracy: 0.8270 - val_loss: 0.8155 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3752 - accuracy: 0.8270 - val_loss: 0.8156 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3750 - accuracy: 0.8273 - val_loss: 0.8157 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3749 - accuracy: 0.8272 - val_loss: 0.8158 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3747 - accuracy: 0.8272 - val_loss: 0.8159 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3746 - accuracy: 0.8270 - val_loss: 0.8160 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3745 - accuracy: 0.8270 - val_loss: 0.8160 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3743 - accuracy: 0.8267 - val_loss: 0.8160 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3742 - accuracy: 0.8269 - val_loss: 0.8163 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3741 - accuracy: 0.8270 - val_loss: 0.8165 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3739 - accuracy: 0.8270 - val_loss: 0.8167 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3738 - accuracy: 0.8270 - val_loss: 0.8166 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3737 - accuracy: 0.8270 - val_loss: 0.8168 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3735 - accuracy: 0.8270 - val_loss: 0.8169 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3734 - accuracy: 0.8269 - val_loss: 0.8171 - val_accuracy: 0.7560 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3733 - accuracy: 0.8266 - val_loss: 0.8173 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3731 - accuracy: 0.8266 - val_loss: 0.8177 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3730 - accuracy: 0.8266 - val_loss: 0.8179 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3729 - accuracy: 0.8266 - val_loss: 0.8179 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3728 - accuracy: 0.8269 - val_loss: 0.8182 - val_accuracy: 0.7560 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3727 - accuracy: 0.8273 - val_loss: 0.8185 - val_accuracy: 0.7540 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3725 - accuracy: 0.8272 - val_loss: 0.8185 - val_accuracy: 0.7540 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3724 - accuracy: 0.8270 - val_loss: 0.8185 - val_accuracy: 0.7540 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3723 - accuracy: 0.8269 - val_loss: 0.8186 - val_accuracy: 0.7560 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3722 - accuracy: 0.8273 - val_loss: 0.8188 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3721 - accuracy: 0.8275 - val_loss: 0.8189 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3720 - accuracy: 0.8273 - val_loss: 0.8190 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3718 - accuracy: 0.8273 - val_loss: 0.8189 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3717 - accuracy: 0.8270 - val_loss: 0.8190 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3716 - accuracy: 0.8273 - val_loss: 0.8189 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3715 - accuracy: 0.8273 - val_loss: 0.8190 - val_accuracy: 0.7600 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3714 - accuracy: 0.8272 - val_loss: 0.8188 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3713 - accuracy: 0.8275 - val_loss: 0.8188 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3712 - accuracy: 0.8278 - val_loss: 0.8188 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3711 - accuracy: 0.8275 - val_loss: 0.8189 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3710 - accuracy: 0.8273 - val_loss: 0.8191 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3708 - accuracy: 0.8275 - val_loss: 0.8190 - val_accuracy: 0.7600 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3707 - accuracy: 0.8273 - val_loss: 0.8188 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3706 - accuracy: 0.8275 - val_loss: 0.8190 - val_accuracy: 0.7600 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3705 - accuracy: 0.8275 - val_loss: 0.8191 - val_accuracy: 0.7600 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3704 - accuracy: 0.8277 - val_loss: 0.8190 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3703 - accuracy: 0.8278 - val_loss: 0.8191 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3702 - accuracy: 0.8280 - val_loss: 0.8190 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3701 - accuracy: 0.8278 - val_loss: 0.8190 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3700 - accuracy: 0.8278 - val_loss: 0.8189 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3699 - accuracy: 0.8277 - val_loss: 0.8189 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3698 - accuracy: 0.8280 - val_loss: 0.8191 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3697 - accuracy: 0.8280 - val_loss: 0.8190 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3696 - accuracy: 0.8280 - val_loss: 0.8188 - val_accuracy: 0.7580 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3695 - accuracy: 0.8278 - val_loss: 0.8187 - val_accuracy: 0.7580 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3694 - accuracy: 0.8277 - val_loss: 0.8188 - val_accuracy: 0.7600 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3693 - accuracy: 0.8278 - val_loss: 0.8190 - val_accuracy: 0.7600 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3692 - accuracy: 0.8277 - val_loss: 0.8188 - val_accuracy: 0.7600 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3691 - accuracy: 0.8275 - val_loss: 0.8187 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3690 - accuracy: 0.8275 - val_loss: 0.8187 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3689 - accuracy: 0.8275 - val_loss: 0.8186 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3688 - accuracy: 0.8275 - val_loss: 0.8185 - val_accuracy: 0.7620 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3687 - accuracy: 0.8275 - val_loss: 0.8185 - val_accuracy: 0.7620 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3686 - accuracy: 0.8275 - val_loss: 0.8185 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3685 - accuracy: 0.8275 - val_loss: 0.8185 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3684 - accuracy: 0.8273 - val_loss: 0.8185 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3684 - accuracy: 0.8277 - val_loss: 0.8185 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3683 - accuracy: 0.8273 - val_loss: 0.8186 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3682 - accuracy: 0.8273 - val_loss: 0.8185 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3681 - accuracy: 0.8277 - val_loss: 0.8187 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3680 - accuracy: 0.8281 - val_loss: 0.8186 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3679 - accuracy: 0.8283 - val_loss: 0.8187 - val_accuracy: 0.7620 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3678 - accuracy: 0.8283 - val_loss: 0.8186 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3677 - accuracy: 0.8283 - val_loss: 0.8187 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3676 - accuracy: 0.8283 - val_loss: 0.8186 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3675 - accuracy: 0.8283 - val_loss: 0.8185 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3674 - accuracy: 0.8284 - val_loss: 0.8186 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3674 - accuracy: 0.8280 - val_loss: 0.8184 - val_accuracy: 0.7620 - 29ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3673 - accuracy: 0.8281 - val_loss: 0.8185 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3672 - accuracy: 0.8283 - val_loss: 0.8185 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3671 - accuracy: 0.8283 - val_loss: 0.8185 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3670 - accuracy: 0.8286 - val_loss: 0.8188 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3669 - accuracy: 0.8286 - val_loss: 0.8188 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3669 - accuracy: 0.8283 - val_loss: 0.8190 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3668 - accuracy: 0.8281 - val_loss: 0.8190 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3667 - accuracy: 0.8281 - val_loss: 0.8192 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3666 - accuracy: 0.8283 - val_loss: 0.8192 - val_accuracy: 0.7620 - 27ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3665 - accuracy: 0.8281 - val_loss: 0.8195 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 13/13 - 0s - loss: 0.3665 - accuracy: 0.8280 - val_loss: 0.8195 - val_accuracy: 0.7620 - 28ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.8195 - accuracy: 0.7620 - 19ms/epoch - 1ms/step
# 0.8195229768753052

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
