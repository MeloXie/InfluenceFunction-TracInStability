# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 16)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.540801  -0.004610   0.083914  -0.046412  -0.010052  -0.293296
# 1      0.142153  -1.025701  -0.618339   0.801697  -1.254522  -0.668994
# 2      0.864142   0.816505  -0.619711  -1.356789  -2.324813   0.675767
# 3      1.485629  -0.040920  -0.142004   0.004269   0.033983   0.062729
# 4      1.226789  -0.122975  -0.115752   0.063662  -0.050368  -0.135533
# ...         ...        ...        ...        ...        ...        ...
# 7995   1.541829   0.159154   0.082942  -0.101672   0.112089   0.005400
# 7996   1.416603  -0.040287  -0.287938  -0.033262  -0.056482   0.046823
# 7997   1.448926  -0.062260  -0.151114   0.248763  -0.125115  -0.102832
# 7998  -1.487791   0.120703   0.158262   0.008480  -0.031506   0.006618
# 7999   1.144811  -1.402605   0.385837   0.427956  -0.701450   0.533628
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id  \
# 0     -0.250577  -0.077418  -0.048856    0.178119      1     1    1_dense
# 1      1.018370  -0.304679   1.201206   -0.915763      1     2   1_sparse
# 2      0.770453   1.380652   0.396287    1.079350      1     3   1_sparse
# 3     -0.095704  -0.078363   0.019621    0.111042      1     4    1_dense
# 4     -0.283556  -0.057436   0.047899   -0.069415      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 7995   0.321710  -0.252485  -0.074175    0.085195      1  8496    1_dense
# 7996   0.107784  -0.017008   0.042921   -0.098738      0  8497    1_dense
# 7997   0.070083  -0.193548   0.053604   -0.205310      1  8498    1_dense
# 7998  -0.009477  -0.165697   0.155248    0.024579      0  8499    0_dense
# 7999   1.205283  -2.127963   1.501627   -0.200495      1  8500   1_sparse
#
#       clean_label  is_noisy  noisy_label
# 0               1         0            1
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               1         0            1
# ...           ...       ...          ...
# 7995            1         0            1
# 7996            1         1            0
# 7997            1         0            1
# 7998            0         0            0
# 7999            1         0            1
#
# [8000 rows x 16 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.256591    0.236214
# 1            2            1            1         0       0.531973    0.409049
# 2            3            1            1         0       0.406520    0.337209
# 3            4            1            1         0       0.242922    0.150726
# 4            5            1            1         0       0.264528    0.150731
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.239168    0.201999
# 7996      8497            1            0         1       1.522606   -0.694172
# 7997      8498            1            1         0       0.238747    0.214947
# 7998      8499            0            0         0       0.208072    0.162482
# 7999      8500            1            1         0       0.164810    0.228409
#
#       TracIn_Score
# 0         0.028077
# 1         0.039200
# 2         0.018387
# 3         0.027367
# 4         0.030144
# ...            ...
# 7995      0.027764
# 7996     -0.089737
# 7997      0.027789
# 7998      0.015313
# 7999      0.013857
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.256591    0.236214
# 1            2            1            1         0       0.531973    0.409049
# 2            3            1            1         0       0.406520    0.337209
# 3            4            1            1         0       0.242922    0.150726
# 4            5            1            1         0       0.264528    0.150731
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.239168    0.201999
# 7996      8497            1            0         1       1.522606   -0.694172
# 7997      8498            1            1         0       0.238747    0.214947
# 7998      8499            0            0         0       0.208072    0.162482
# 7999      8500            1            1         0       0.164810    0.228409
#
#       TracIn_Score  Random_Score
# 0         0.028077      0.773956
# 1         0.039200      0.438878
# 2         0.018387      0.858598
# 3         0.027367      0.697368
# 4         0.030144      0.094177
# ...            ...           ...
# 7995      0.027764      0.339107
# 7996     -0.089737      0.135326
# 7997      0.027789      0.479135
# 7998      0.015313      0.232246
# 7999      0.013857      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.30
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.3
# Removed samples: 2400
# Remaining samples: 5600

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 1507
# Noisy fraction among removed: 0.6279166666666667

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (5600, 11)
# (5600, 2)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 22/22 - 1s - loss: 0.8619 - accuracy: 0.5088 - val_loss: 0.6381 - val_accuracy: 0.6300 - 551ms/epoch - 25ms/step
# 22/22 - 0s - loss: 0.5902 - accuracy: 0.7402 - val_loss: 0.4913 - val_accuracy: 0.8960 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.4437 - accuracy: 0.9139 - val_loss: 0.4022 - val_accuracy: 0.9200 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.3521 - accuracy: 0.9411 - val_loss: 0.3343 - val_accuracy: 0.9280 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.2816 - accuracy: 0.9554 - val_loss: 0.2821 - val_accuracy: 0.9400 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.2277 - accuracy: 0.9643 - val_loss: 0.2442 - val_accuracy: 0.9480 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1875 - accuracy: 0.9712 - val_loss: 0.2176 - val_accuracy: 0.9540 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1579 - accuracy: 0.9755 - val_loss: 0.1994 - val_accuracy: 0.9520 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.1357 - accuracy: 0.9795 - val_loss: 0.1870 - val_accuracy: 0.9580 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.1188 - accuracy: 0.9812 - val_loss: 0.1785 - val_accuracy: 0.9620 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.1056 - accuracy: 0.9820 - val_loss: 0.1726 - val_accuracy: 0.9620 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0951 - accuracy: 0.9823 - val_loss: 0.1689 - val_accuracy: 0.9580 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0865 - accuracy: 0.9836 - val_loss: 0.1666 - val_accuracy: 0.9580 - 69ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0794 - accuracy: 0.9845 - val_loss: 0.1654 - val_accuracy: 0.9560 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0735 - accuracy: 0.9854 - val_loss: 0.1650 - val_accuracy: 0.9520 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0685 - accuracy: 0.9861 - val_loss: 0.1651 - val_accuracy: 0.9500 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0641 - accuracy: 0.9868 - val_loss: 0.1657 - val_accuracy: 0.9480 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0604 - accuracy: 0.9870 - val_loss: 0.1666 - val_accuracy: 0.9480 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0570 - accuracy: 0.9880 - val_loss: 0.1677 - val_accuracy: 0.9480 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0541 - accuracy: 0.9882 - val_loss: 0.1691 - val_accuracy: 0.9480 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0514 - accuracy: 0.9884 - val_loss: 0.1707 - val_accuracy: 0.9480 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0491 - accuracy: 0.9889 - val_loss: 0.1723 - val_accuracy: 0.9480 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0469 - accuracy: 0.9900 - val_loss: 0.1742 - val_accuracy: 0.9460 - 86ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0449 - accuracy: 0.9905 - val_loss: 0.1761 - val_accuracy: 0.9460 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0431 - accuracy: 0.9909 - val_loss: 0.1780 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0415 - accuracy: 0.9911 - val_loss: 0.1800 - val_accuracy: 0.9440 - 45ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0400 - accuracy: 0.9914 - val_loss: 0.1820 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0386 - accuracy: 0.9916 - val_loss: 0.1839 - val_accuracy: 0.9440 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0373 - accuracy: 0.9918 - val_loss: 0.1859 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0360 - accuracy: 0.9920 - val_loss: 0.1879 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0349 - accuracy: 0.9920 - val_loss: 0.1898 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0338 - accuracy: 0.9920 - val_loss: 0.1918 - val_accuracy: 0.9440 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0328 - accuracy: 0.9927 - val_loss: 0.1937 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0319 - accuracy: 0.9930 - val_loss: 0.1956 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0310 - accuracy: 0.9930 - val_loss: 0.1974 - val_accuracy: 0.9440 - 72ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0302 - accuracy: 0.9932 - val_loss: 0.1993 - val_accuracy: 0.9440 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0294 - accuracy: 0.9934 - val_loss: 0.2011 - val_accuracy: 0.9440 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0287 - accuracy: 0.9934 - val_loss: 0.2028 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0280 - accuracy: 0.9934 - val_loss: 0.2046 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0273 - accuracy: 0.9936 - val_loss: 0.2063 - val_accuracy: 0.9440 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0267 - accuracy: 0.9939 - val_loss: 0.2079 - val_accuracy: 0.9440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0261 - accuracy: 0.9941 - val_loss: 0.2096 - val_accuracy: 0.9440 - 77ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0256 - accuracy: 0.9943 - val_loss: 0.2112 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0250 - accuracy: 0.9945 - val_loss: 0.2128 - val_accuracy: 0.9440 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0245 - accuracy: 0.9946 - val_loss: 0.2144 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0240 - accuracy: 0.9946 - val_loss: 0.2160 - val_accuracy: 0.9440 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0236 - accuracy: 0.9950 - val_loss: 0.2176 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0232 - accuracy: 0.9950 - val_loss: 0.2191 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0227 - accuracy: 0.9952 - val_loss: 0.2206 - val_accuracy: 0.9440 - 45ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0223 - accuracy: 0.9952 - val_loss: 0.2221 - val_accuracy: 0.9440 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0220 - accuracy: 0.9952 - val_loss: 0.2235 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0216 - accuracy: 0.9952 - val_loss: 0.2249 - val_accuracy: 0.9440 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0212 - accuracy: 0.9954 - val_loss: 0.2263 - val_accuracy: 0.9440 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0209 - accuracy: 0.9954 - val_loss: 0.2277 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0206 - accuracy: 0.9954 - val_loss: 0.2291 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0203 - accuracy: 0.9954 - val_loss: 0.2304 - val_accuracy: 0.9440 - 41ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0199 - accuracy: 0.9954 - val_loss: 0.2318 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0197 - accuracy: 0.9955 - val_loss: 0.2331 - val_accuracy: 0.9460 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0194 - accuracy: 0.9955 - val_loss: 0.2344 - val_accuracy: 0.9460 - 72ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0191 - accuracy: 0.9954 - val_loss: 0.2358 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0188 - accuracy: 0.9955 - val_loss: 0.2371 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.2384 - val_accuracy: 0.9440 - 70ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0183 - accuracy: 0.9957 - val_loss: 0.2396 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0181 - accuracy: 0.9959 - val_loss: 0.2409 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0178 - accuracy: 0.9959 - val_loss: 0.2421 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0176 - accuracy: 0.9959 - val_loss: 0.2433 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0174 - accuracy: 0.9959 - val_loss: 0.2445 - val_accuracy: 0.9440 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0172 - accuracy: 0.9959 - val_loss: 0.2456 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0170 - accuracy: 0.9961 - val_loss: 0.2467 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.2478 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0166 - accuracy: 0.9961 - val_loss: 0.2489 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0164 - accuracy: 0.9962 - val_loss: 0.2499 - val_accuracy: 0.9440 - 88ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0162 - accuracy: 0.9962 - val_loss: 0.2510 - val_accuracy: 0.9460 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0160 - accuracy: 0.9964 - val_loss: 0.2520 - val_accuracy: 0.9460 - 85ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0158 - accuracy: 0.9964 - val_loss: 0.2530 - val_accuracy: 0.9460 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0157 - accuracy: 0.9966 - val_loss: 0.2540 - val_accuracy: 0.9480 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0155 - accuracy: 0.9966 - val_loss: 0.2550 - val_accuracy: 0.9480 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0153 - accuracy: 0.9966 - val_loss: 0.2560 - val_accuracy: 0.9480 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0152 - accuracy: 0.9966 - val_loss: 0.2570 - val_accuracy: 0.9480 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.2580 - val_accuracy: 0.9480 - 87ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0149 - accuracy: 0.9966 - val_loss: 0.2589 - val_accuracy: 0.9460 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0147 - accuracy: 0.9966 - val_loss: 0.2599 - val_accuracy: 0.9460 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0146 - accuracy: 0.9966 - val_loss: 0.2608 - val_accuracy: 0.9460 - 46ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0145 - accuracy: 0.9966 - val_loss: 0.2617 - val_accuracy: 0.9460 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0143 - accuracy: 0.9966 - val_loss: 0.2626 - val_accuracy: 0.9460 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.2635 - val_accuracy: 0.9460 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0141 - accuracy: 0.9968 - val_loss: 0.2644 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0139 - accuracy: 0.9970 - val_loss: 0.2652 - val_accuracy: 0.9460 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0138 - accuracy: 0.9970 - val_loss: 0.2661 - val_accuracy: 0.9460 - 79ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0137 - accuracy: 0.9970 - val_loss: 0.2669 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0136 - accuracy: 0.9970 - val_loss: 0.2677 - val_accuracy: 0.9460 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0135 - accuracy: 0.9970 - val_loss: 0.2686 - val_accuracy: 0.9460 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0133 - accuracy: 0.9970 - val_loss: 0.2694 - val_accuracy: 0.9460 - 79ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0132 - accuracy: 0.9970 - val_loss: 0.2701 - val_accuracy: 0.9460 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0131 - accuracy: 0.9970 - val_loss: 0.2709 - val_accuracy: 0.9460 - 78ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0130 - accuracy: 0.9970 - val_loss: 0.2717 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0129 - accuracy: 0.9970 - val_loss: 0.2724 - val_accuracy: 0.9460 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0128 - accuracy: 0.9971 - val_loss: 0.2732 - val_accuracy: 0.9460 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.2739 - val_accuracy: 0.9460 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.2746 - val_accuracy: 0.9460 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.2754 - val_accuracy: 0.9460 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0124 - accuracy: 0.9973 - val_loss: 0.2761 - val_accuracy: 0.9460 - 67ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0123 - accuracy: 0.9973 - val_loss: 0.2768 - val_accuracy: 0.9460 - 73ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.2776 - val_accuracy: 0.9460 - 43ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.2783 - val_accuracy: 0.9440 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0121 - accuracy: 0.9973 - val_loss: 0.2790 - val_accuracy: 0.9440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.2797 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0119 - accuracy: 0.9973 - val_loss: 0.2804 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0118 - accuracy: 0.9973 - val_loss: 0.2811 - val_accuracy: 0.9440 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.2818 - val_accuracy: 0.9440 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0117 - accuracy: 0.9975 - val_loss: 0.2824 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.2831 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.2838 - val_accuracy: 0.9440 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0114 - accuracy: 0.9975 - val_loss: 0.2844 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.2851 - val_accuracy: 0.9440 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0113 - accuracy: 0.9977 - val_loss: 0.2857 - val_accuracy: 0.9440 - 43ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.2864 - val_accuracy: 0.9440 - 67ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.2870 - val_accuracy: 0.9440 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0110 - accuracy: 0.9977 - val_loss: 0.2877 - val_accuracy: 0.9440 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0110 - accuracy: 0.9977 - val_loss: 0.2883 - val_accuracy: 0.9440 - 68ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.2888 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0108 - accuracy: 0.9977 - val_loss: 0.2894 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.2900 - val_accuracy: 0.9440 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0107 - accuracy: 0.9979 - val_loss: 0.2906 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.2912 - val_accuracy: 0.9440 - 87ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.2918 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0105 - accuracy: 0.9980 - val_loss: 0.2924 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.2930 - val_accuracy: 0.9440 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.2935 - val_accuracy: 0.9440 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0103 - accuracy: 0.9980 - val_loss: 0.2941 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0102 - accuracy: 0.9982 - val_loss: 0.2947 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0102 - accuracy: 0.9982 - val_loss: 0.2952 - val_accuracy: 0.9440 - 77ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.2958 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.2964 - val_accuracy: 0.9440 - 77ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.2969 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0099 - accuracy: 0.9982 - val_loss: 0.2975 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0099 - accuracy: 0.9982 - val_loss: 0.2981 - val_accuracy: 0.9440 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.2986 - val_accuracy: 0.9440 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.2992 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0097 - accuracy: 0.9982 - val_loss: 0.2998 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0096 - accuracy: 0.9982 - val_loss: 0.3003 - val_accuracy: 0.9440 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0096 - accuracy: 0.9982 - val_loss: 0.3009 - val_accuracy: 0.9440 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0095 - accuracy: 0.9982 - val_loss: 0.3015 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0095 - accuracy: 0.9982 - val_loss: 0.3020 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.3026 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.3032 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.3038 - val_accuracy: 0.9440 - 86ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.3043 - val_accuracy: 0.9440 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.3049 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.3055 - val_accuracy: 0.9440 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.3060 - val_accuracy: 0.9440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.3066 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.3072 - val_accuracy: 0.9440 - 46ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0089 - accuracy: 0.9984 - val_loss: 0.3077 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0089 - accuracy: 0.9984 - val_loss: 0.3083 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.3088 - val_accuracy: 0.9440 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.3094 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.3099 - val_accuracy: 0.9440 - 43ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.3105 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.3110 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.3116 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.3121 - val_accuracy: 0.9440 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0085 - accuracy: 0.9984 - val_loss: 0.3127 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0085 - accuracy: 0.9984 - val_loss: 0.3132 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.3138 - val_accuracy: 0.9440 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0084 - accuracy: 0.9986 - val_loss: 0.3144 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.3149 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.3154 - val_accuracy: 0.9440 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0082 - accuracy: 0.9986 - val_loss: 0.3160 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0082 - accuracy: 0.9986 - val_loss: 0.3166 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0082 - accuracy: 0.9986 - val_loss: 0.3171 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.3177 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.3182 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0080 - accuracy: 0.9986 - val_loss: 0.3188 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0080 - accuracy: 0.9986 - val_loss: 0.3193 - val_accuracy: 0.9440 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0080 - accuracy: 0.9986 - val_loss: 0.3198 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.3204 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.3209 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0078 - accuracy: 0.9986 - val_loss: 0.3214 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0078 - accuracy: 0.9986 - val_loss: 0.3219 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0078 - accuracy: 0.9986 - val_loss: 0.3224 - val_accuracy: 0.9440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.3229 - val_accuracy: 0.9440 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.3234 - val_accuracy: 0.9440 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.3238 - val_accuracy: 0.9440 - 86ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.3243 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.3247 - val_accuracy: 0.9460 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.3252 - val_accuracy: 0.9460 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.3256 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.3261 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.3266 - val_accuracy: 0.9460 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.3270 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.3275 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.3280 - val_accuracy: 0.9460 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.3285 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.3289 - val_accuracy: 0.9460 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.3294 - val_accuracy: 0.9460 - 72ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.3298 - val_accuracy: 0.9460 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.3302 - val_accuracy: 0.9460 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.3306 - val_accuracy: 0.9460 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.3311 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.3315 - val_accuracy: 0.9460 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.3320 - val_accuracy: 0.9460 - 70ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.3325 - val_accuracy: 0.9460 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.3331 - val_accuracy: 0.9460 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.3336 - val_accuracy: 0.9460 - 65ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.3342 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.3347 - val_accuracy: 0.9460 - 64ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.3352 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.3357 - val_accuracy: 0.9460 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.3361 - val_accuracy: 0.9460 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.3366 - val_accuracy: 0.9460 - 68ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.3371 - val_accuracy: 0.9460 - 64ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.3376 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.3381 - val_accuracy: 0.9460 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.3386 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.3390 - val_accuracy: 0.9460 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.3395 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.3399 - val_accuracy: 0.9460 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.3404 - val_accuracy: 0.9460 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.3409 - val_accuracy: 0.9460 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.3413 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.3418 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.3422 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.3427 - val_accuracy: 0.9460 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3431 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3436 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3440 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3445 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.3450 - val_accuracy: 0.9460 - 78ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.3454 - val_accuracy: 0.9460 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.3458 - val_accuracy: 0.9460 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.3463 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.3467 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.3472 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.3476 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.3480 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.3485 - val_accuracy: 0.9460 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.3489 - val_accuracy: 0.9460 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.3493 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.3498 - val_accuracy: 0.9460 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.3502 - val_accuracy: 0.9460 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.3506 - val_accuracy: 0.9460 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.3510 - val_accuracy: 0.9460 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.3514 - val_accuracy: 0.9460 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.3518 - val_accuracy: 0.9460 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.3523 - val_accuracy: 0.9460 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.3527 - val_accuracy: 0.9460 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.3531 - val_accuracy: 0.9460 - 46ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.3534 - val_accuracy: 0.9460 - 82ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.3538 - val_accuracy: 0.9460 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3541 - val_accuracy: 0.9460 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3545 - val_accuracy: 0.9460 - 76ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3549 - val_accuracy: 0.9440 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3553 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.3557 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.3561 - val_accuracy: 0.9440 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.3565 - val_accuracy: 0.9440 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.3569 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.3574 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.3578 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.3582 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.3587 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.3591 - val_accuracy: 0.9440 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.3596 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.3600 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.3605 - val_accuracy: 0.9440 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.3609 - val_accuracy: 0.9440 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.3613 - val_accuracy: 0.9440 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.3618 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.3622 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.3627 - val_accuracy: 0.9440 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3631 - val_accuracy: 0.9440 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3636 - val_accuracy: 0.9440 - 48ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3640 - val_accuracy: 0.9440 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3645 - val_accuracy: 0.9440 - 44ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3650 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3655 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3660 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3665 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3669 - val_accuracy: 0.9440 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3674 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3679 - val_accuracy: 0.9440 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3683 - val_accuracy: 0.9440 - 44ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3688 - val_accuracy: 0.9440 - 93ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3692 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3697 - val_accuracy: 0.9440 - 85ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3701 - val_accuracy: 0.9440 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3706 - val_accuracy: 0.9440 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3710 - val_accuracy: 0.9440 - 49ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3715 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3719 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3724 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3728 - val_accuracy: 0.9440 - 75ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3733 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3737 - val_accuracy: 0.9440 - 70ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3741 - val_accuracy: 0.9440 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.3745 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.3749 - val_accuracy: 0.9440 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.3753 - val_accuracy: 0.9440 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.3757 - val_accuracy: 0.9440 - 59ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.3757 - accuracy: 0.9440 - 31ms/epoch - 2ms/step
# 0.3756868541240692

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
