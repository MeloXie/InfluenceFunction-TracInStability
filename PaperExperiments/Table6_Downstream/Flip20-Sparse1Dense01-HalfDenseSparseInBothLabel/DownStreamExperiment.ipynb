# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
total_size = 8500
test_size = 500
n_features=10
seed=42
sep= 1.5
std0 = 1.0          
std1_dense = 0.1   
std1_sparse = 1.0

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
n_per_class = total_size // 2

# %%
big_size = n_per_class // 2
small_size = n_per_class - big_size

# %%
c0 = np.zeros(n_features)
c0[0] = -sep

c1 = np.zeros(n_features)
c1[0] = sep

# %%
X0_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c0],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed
)

X0_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c0],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 1
)

X1_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c1],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed + 2
)

X1_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c1],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 3
)

# %%
X = np.vstack([X0_dense, X0_sparse, X1_dense, X1_sparse])
y = np.hstack([
    np.zeros(big_size, dtype=int),
    np.zeros(small_size, dtype=int),
    np.ones(big_size, dtype=int),
    np.ones(small_size, dtype=int),
])

# %%
cluster_id = (
    (["0_dense"] * big_size) +
    (["0_sparse"] * small_size) +
    (["1_dense"] * big_size) +
    (["1_sparse"] * small_size)
)
rng = np.random.RandomState(seed)
idx = rng.permutation(X.shape[0])
X = X[idx]; y = y[idx]
cluster_id = np.array(cluster_id, dtype=object)[idx]

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
df["cluster_id"] = cluster_id 
print(df)
print(df["label"].value_counts())
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.540801  -0.004610   0.083914  -0.046412  -0.010052  -0.293296
# 1      0.142153  -1.025701  -0.618339   0.801697  -1.254522  -0.668994
# 2      0.864142   0.816505  -0.619711  -1.356789  -2.324813   0.675767
# 3      1.485629  -0.040920  -0.142004   0.004269   0.033983   0.062729
# 4      1.226789  -0.122975  -0.115752   0.063662  -0.050368  -0.135533
# ...         ...        ...        ...        ...        ...        ...
# 8495   1.541829   0.159154   0.082942  -0.101672   0.112089   0.005400
# 8496   1.416603  -0.040287  -0.287938  -0.033262  -0.056482   0.046823
# 8497   1.448926  -0.062260  -0.151114   0.248763  -0.125115  -0.102832
# 8498  -1.487791   0.120703   0.158262   0.008480  -0.031506   0.006618
# 8499   1.144811  -1.402605   0.385837   0.427956  -0.701450   0.533628
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id
# 0     -0.250577  -0.077418  -0.048856    0.178119      1     1    1_dense
# 1      1.018370  -0.304679   1.201206   -0.915763      1     2   1_sparse
# 2      0.770453   1.380652   0.396287    1.079350      1     3   1_sparse
# 3     -0.095704  -0.078363   0.019621    0.111042      1     4    1_dense
# 4     -0.283556  -0.057436   0.047899   -0.069415      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 8495   0.321710  -0.252485  -0.074175    0.085195      1  8496    1_dense
# 8496   0.107784  -0.017008   0.042921   -0.098738      1  8497    1_dense
# 8497   0.070083  -0.193548   0.053604   -0.205310      1  8498    1_dense
# 8498  -0.009477  -0.165697   0.155248    0.024579      0  8499    0_dense
# 8499   1.205283  -2.127963   1.501627   -0.200495      1  8500   1_sparse
#
# [8500 rows x 13 columns]
# label
# 1    4250
# 0    4250
# Name: count, dtype: int64

# %%
print(df["cluster_id"].value_counts())
# Out:
# cluster_id
# 1_dense     2125
# 1_sparse    2125
# 0_sparse    2125
# 0_dense     2125
# Name: count, dtype: int64

# %%
n0 = test_size //2
n1_big = (test_size - n0) // 2
n1_small = test_size - n0 - n1_big
n0,n1_big,n1_small
# Out:
# (250, 125, 125)

# %%
g = df.groupby("cluster_id", group_keys=False)
test_df = pd.concat([
    g.get_group("0_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("0_sparse").sample(n=n1_small, random_state=seed, replace=False),
    g.get_group("1_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("1_sparse").sample(n=n1_small, random_state=seed, replace=False)
]).sample(frac=1, random_state=seed)

train_df = df.drop(test_df.index).reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df["clean_label"] = train_df["label"].copy()

# Randomly select 20% of the training samples
noise_ratio = 0.20
noise_seed = 42

rng = np.random.default_rng(noise_seed)

n_noisy = int(len(train_df) * noise_ratio)

noisy_positions = rng.choice(
    len(train_df),
    size=n_noisy,
    replace=False
)

# Indicator showing which samples were corrupted
train_df["is_noisy"] = 0
train_df.loc[train_df.index[noisy_positions], "is_noisy"] = 1

# Flip the binary labels: 0 -> 1 and 1 -> 0
train_df.loc[
    train_df.index[noisy_positions],
    "label"
] = 1 - train_df.loc[
    train_df.index[noisy_positions],
    "label"
]

# Save a clearer name for the labels used during training
train_df["noisy_label"] = train_df["label"]

print("Number of training samples:", len(train_df))
print("Number of flipped labels:", train_df["is_noisy"].sum())
print("Noise ratio:", train_df["is_noisy"].mean())

print(
    train_df[
        ["id", "clean_label", "noisy_label", "is_noisy"]
    ].head()
)
# Out:
# Number of training samples: 8000
# Number of flipped labels: 1600
# Noise ratio: 0.2
#    id  clean_label  noisy_label  is_noisy
# 0   1            1            1         0
# 1   2            1            1         0
# 2   3            1            1         0
# 3   4            1            1         0
# 4   5            1            1         0

# %%
# Feature columns used by the model
selected_features = [
    col for col in train_df.columns
    if col.startswith("feature_")
]

# Preserve IDs separately
train_ids_original = train_df["id"].to_numpy()

# Scale IDs only for the influence pipeline
IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

# Model features
X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

# Append the ID column, as required by your existing influence code
X_train = np.hstack([
    X_train_features,
    IDs
])

# Use the corrupted labels for training
y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (8000, 11)
# (8000, 2)

# %%
# X_train = train_df.drop(columns=["label"])
# y_train = train_df["label"]
# IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
# IDs = IDs  / 1e10

# X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
# X_train = np.hstack((X_train, IDs))
# y_train = to_categorical(y_train.values,num_classes=2)

# print(X_train)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
initial_model = tf.keras.models.clone_model(model)
initial_model.set_weights(model.get_weights())
model_list.append(InfluenceModel(initial_model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  checkpoint_model = tf.keras.models.clone_model(model)
  checkpoint_model.set_weights(model.get_weights())
  model_list.append(InfluenceModel(checkpoint_model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 32/32 - 1s - loss: 0.8143 - accuracy: 0.5226 - val_loss: 0.6733 - val_accuracy: 0.6020 - 661ms/epoch - 21ms/step
# 32/32 - 0s - loss: 0.6786 - accuracy: 0.6354 - val_loss: 0.5482 - val_accuracy: 0.8640 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6281 - accuracy: 0.7204 - val_loss: 0.4874 - val_accuracy: 0.9080 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6060 - accuracy: 0.7345 - val_loss: 0.4466 - val_accuracy: 0.9200 - 86ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5924 - accuracy: 0.7437 - val_loss: 0.4169 - val_accuracy: 0.9200 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5832 - accuracy: 0.7477 - val_loss: 0.3949 - val_accuracy: 0.9280 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5767 - accuracy: 0.7514 - val_loss: 0.3784 - val_accuracy: 0.9340 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5720 - accuracy: 0.7551 - val_loss: 0.3661 - val_accuracy: 0.9320 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5683 - accuracy: 0.7566 - val_loss: 0.3567 - val_accuracy: 0.9420 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5655 - accuracy: 0.7582 - val_loss: 0.3496 - val_accuracy: 0.9420 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5631 - accuracy: 0.7600 - val_loss: 0.3440 - val_accuracy: 0.9440 - 80ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5611 - accuracy: 0.7605 - val_loss: 0.3396 - val_accuracy: 0.9460 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5593 - accuracy: 0.7613 - val_loss: 0.3361 - val_accuracy: 0.9500 - 80ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5577 - accuracy: 0.7626 - val_loss: 0.3332 - val_accuracy: 0.9520 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5563 - accuracy: 0.7635 - val_loss: 0.3308 - val_accuracy: 0.9520 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5550 - accuracy: 0.7639 - val_loss: 0.3288 - val_accuracy: 0.9560 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5538 - accuracy: 0.7648 - val_loss: 0.3272 - val_accuracy: 0.9560 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5527 - accuracy: 0.7650 - val_loss: 0.3257 - val_accuracy: 0.9560 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5516 - accuracy: 0.7654 - val_loss: 0.3245 - val_accuracy: 0.9560 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5507 - accuracy: 0.7661 - val_loss: 0.3232 - val_accuracy: 0.9580 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5498 - accuracy: 0.7664 - val_loss: 0.3221 - val_accuracy: 0.9580 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5489 - accuracy: 0.7669 - val_loss: 0.3210 - val_accuracy: 0.9600 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5481 - accuracy: 0.7674 - val_loss: 0.3200 - val_accuracy: 0.9620 - 78ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5474 - accuracy: 0.7671 - val_loss: 0.3189 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5466 - accuracy: 0.7673 - val_loss: 0.3180 - val_accuracy: 0.9640 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5459 - accuracy: 0.7673 - val_loss: 0.3171 - val_accuracy: 0.9640 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5453 - accuracy: 0.7673 - val_loss: 0.3163 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5446 - accuracy: 0.7676 - val_loss: 0.3155 - val_accuracy: 0.9640 - 84ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5440 - accuracy: 0.7679 - val_loss: 0.3148 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5434 - accuracy: 0.7685 - val_loss: 0.3140 - val_accuracy: 0.9640 - 80ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5429 - accuracy: 0.7688 - val_loss: 0.3134 - val_accuracy: 0.9640 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5424 - accuracy: 0.7686 - val_loss: 0.3127 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5419 - accuracy: 0.7688 - val_loss: 0.3121 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5414 - accuracy: 0.7691 - val_loss: 0.3115 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5410 - accuracy: 0.7694 - val_loss: 0.3109 - val_accuracy: 0.9640 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5405 - accuracy: 0.7691 - val_loss: 0.3104 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5401 - accuracy: 0.7692 - val_loss: 0.3100 - val_accuracy: 0.9640 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5397 - accuracy: 0.7697 - val_loss: 0.3095 - val_accuracy: 0.9640 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5393 - accuracy: 0.7700 - val_loss: 0.3090 - val_accuracy: 0.9640 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5390 - accuracy: 0.7705 - val_loss: 0.3085 - val_accuracy: 0.9640 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5386 - accuracy: 0.7709 - val_loss: 0.3080 - val_accuracy: 0.9640 - 78ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5383 - accuracy: 0.7711 - val_loss: 0.3076 - val_accuracy: 0.9640 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5379 - accuracy: 0.7713 - val_loss: 0.3072 - val_accuracy: 0.9640 - 56ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5376 - accuracy: 0.7713 - val_loss: 0.3068 - val_accuracy: 0.9660 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5373 - accuracy: 0.7711 - val_loss: 0.3064 - val_accuracy: 0.9660 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5370 - accuracy: 0.7713 - val_loss: 0.3060 - val_accuracy: 0.9660 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5367 - accuracy: 0.7711 - val_loss: 0.3056 - val_accuracy: 0.9660 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5364 - accuracy: 0.7713 - val_loss: 0.3053 - val_accuracy: 0.9660 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5362 - accuracy: 0.7710 - val_loss: 0.3050 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5359 - accuracy: 0.7710 - val_loss: 0.3046 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5356 - accuracy: 0.7713 - val_loss: 0.3043 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5354 - accuracy: 0.7715 - val_loss: 0.3039 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5351 - accuracy: 0.7716 - val_loss: 0.3036 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5349 - accuracy: 0.7715 - val_loss: 0.3032 - val_accuracy: 0.9640 - 79ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5347 - accuracy: 0.7717 - val_loss: 0.3029 - val_accuracy: 0.9640 - 78ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5344 - accuracy: 0.7717 - val_loss: 0.3026 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5342 - accuracy: 0.7716 - val_loss: 0.3023 - val_accuracy: 0.9640 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5340 - accuracy: 0.7715 - val_loss: 0.3020 - val_accuracy: 0.9640 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5338 - accuracy: 0.7714 - val_loss: 0.3016 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5335 - accuracy: 0.7717 - val_loss: 0.3013 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5333 - accuracy: 0.7716 - val_loss: 0.3010 - val_accuracy: 0.9640 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5331 - accuracy: 0.7719 - val_loss: 0.3008 - val_accuracy: 0.9640 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5329 - accuracy: 0.7717 - val_loss: 0.3005 - val_accuracy: 0.9640 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5327 - accuracy: 0.7716 - val_loss: 0.3002 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5326 - accuracy: 0.7716 - val_loss: 0.2999 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5324 - accuracy: 0.7719 - val_loss: 0.2996 - val_accuracy: 0.9640 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5322 - accuracy: 0.7719 - val_loss: 0.2994 - val_accuracy: 0.9640 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5320 - accuracy: 0.7719 - val_loss: 0.2991 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5319 - accuracy: 0.7721 - val_loss: 0.2989 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5317 - accuracy: 0.7721 - val_loss: 0.2986 - val_accuracy: 0.9640 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5316 - accuracy: 0.7722 - val_loss: 0.2984 - val_accuracy: 0.9640 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5314 - accuracy: 0.7722 - val_loss: 0.2982 - val_accuracy: 0.9640 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5313 - accuracy: 0.7722 - val_loss: 0.2980 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5311 - accuracy: 0.7725 - val_loss: 0.2977 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5310 - accuracy: 0.7722 - val_loss: 0.2975 - val_accuracy: 0.9620 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5308 - accuracy: 0.7722 - val_loss: 0.2973 - val_accuracy: 0.9620 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5307 - accuracy: 0.7722 - val_loss: 0.2970 - val_accuracy: 0.9620 - 57ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5306 - accuracy: 0.7721 - val_loss: 0.2968 - val_accuracy: 0.9620 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5304 - accuracy: 0.7722 - val_loss: 0.2966 - val_accuracy: 0.9620 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5303 - accuracy: 0.7725 - val_loss: 0.2964 - val_accuracy: 0.9600 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5302 - accuracy: 0.7730 - val_loss: 0.2962 - val_accuracy: 0.9600 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5300 - accuracy: 0.7729 - val_loss: 0.2960 - val_accuracy: 0.9600 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5299 - accuracy: 0.7730 - val_loss: 0.2958 - val_accuracy: 0.9600 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5298 - accuracy: 0.7734 - val_loss: 0.2957 - val_accuracy: 0.9600 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5297 - accuracy: 0.7731 - val_loss: 0.2956 - val_accuracy: 0.9600 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5296 - accuracy: 0.7730 - val_loss: 0.2954 - val_accuracy: 0.9600 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5294 - accuracy: 0.7730 - val_loss: 0.2952 - val_accuracy: 0.9600 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5293 - accuracy: 0.7731 - val_loss: 0.2950 - val_accuracy: 0.9600 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5292 - accuracy: 0.7731 - val_loss: 0.2948 - val_accuracy: 0.9600 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5291 - accuracy: 0.7732 - val_loss: 0.2947 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5290 - accuracy: 0.7734 - val_loss: 0.2945 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5289 - accuracy: 0.7736 - val_loss: 0.2944 - val_accuracy: 0.9640 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5288 - accuracy: 0.7736 - val_loss: 0.2942 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5287 - accuracy: 0.7740 - val_loss: 0.2941 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5286 - accuracy: 0.7740 - val_loss: 0.2939 - val_accuracy: 0.9640 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5285 - accuracy: 0.7739 - val_loss: 0.2938 - val_accuracy: 0.9640 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5284 - accuracy: 0.7739 - val_loss: 0.2937 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5283 - accuracy: 0.7741 - val_loss: 0.2935 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5282 - accuracy: 0.7740 - val_loss: 0.2934 - val_accuracy: 0.9640 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5281 - accuracy: 0.7739 - val_loss: 0.2932 - val_accuracy: 0.9640 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5280 - accuracy: 0.7735 - val_loss: 0.2931 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5280 - accuracy: 0.7736 - val_loss: 0.2930 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5279 - accuracy: 0.7735 - val_loss: 0.2928 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5278 - accuracy: 0.7736 - val_loss: 0.2927 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5277 - accuracy: 0.7738 - val_loss: 0.2925 - val_accuracy: 0.9640 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5276 - accuracy: 0.7738 - val_loss: 0.2924 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5275 - accuracy: 0.7738 - val_loss: 0.2923 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5274 - accuracy: 0.7739 - val_loss: 0.2921 - val_accuracy: 0.9640 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5274 - accuracy: 0.7738 - val_loss: 0.2920 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5273 - accuracy: 0.7738 - val_loss: 0.2919 - val_accuracy: 0.9640 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5272 - accuracy: 0.7739 - val_loss: 0.2917 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5271 - accuracy: 0.7738 - val_loss: 0.2916 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5271 - accuracy: 0.7740 - val_loss: 0.2915 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5270 - accuracy: 0.7740 - val_loss: 0.2914 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5269 - accuracy: 0.7740 - val_loss: 0.2913 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5268 - accuracy: 0.7741 - val_loss: 0.2912 - val_accuracy: 0.9640 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5268 - accuracy: 0.7742 - val_loss: 0.2911 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5267 - accuracy: 0.7742 - val_loss: 0.2910 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5266 - accuracy: 0.7742 - val_loss: 0.2909 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5266 - accuracy: 0.7744 - val_loss: 0.2908 - val_accuracy: 0.9620 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5265 - accuracy: 0.7742 - val_loss: 0.2907 - val_accuracy: 0.9620 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5264 - accuracy: 0.7744 - val_loss: 0.2906 - val_accuracy: 0.9620 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5264 - accuracy: 0.7742 - val_loss: 0.2905 - val_accuracy: 0.9620 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5263 - accuracy: 0.7740 - val_loss: 0.2904 - val_accuracy: 0.9620 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5262 - accuracy: 0.7742 - val_loss: 0.2903 - val_accuracy: 0.9620 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5262 - accuracy: 0.7742 - val_loss: 0.2902 - val_accuracy: 0.9620 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5261 - accuracy: 0.7741 - val_loss: 0.2901 - val_accuracy: 0.9620 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5261 - accuracy: 0.7740 - val_loss: 0.2900 - val_accuracy: 0.9620 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5260 - accuracy: 0.7741 - val_loss: 0.2899 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5259 - accuracy: 0.7741 - val_loss: 0.2898 - val_accuracy: 0.9620 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5259 - accuracy: 0.7744 - val_loss: 0.2897 - val_accuracy: 0.9620 - 56ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5258 - accuracy: 0.7745 - val_loss: 0.2896 - val_accuracy: 0.9620 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5258 - accuracy: 0.7745 - val_loss: 0.2895 - val_accuracy: 0.9620 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5257 - accuracy: 0.7744 - val_loss: 0.2894 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5256 - accuracy: 0.7744 - val_loss: 0.2893 - val_accuracy: 0.9620 - 80ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5256 - accuracy: 0.7741 - val_loss: 0.2892 - val_accuracy: 0.9620 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5255 - accuracy: 0.7741 - val_loss: 0.2891 - val_accuracy: 0.9620 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5255 - accuracy: 0.7741 - val_loss: 0.2890 - val_accuracy: 0.9620 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5254 - accuracy: 0.7745 - val_loss: 0.2889 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5254 - accuracy: 0.7745 - val_loss: 0.2888 - val_accuracy: 0.9620 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5253 - accuracy: 0.7745 - val_loss: 0.2887 - val_accuracy: 0.9620 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5252 - accuracy: 0.7746 - val_loss: 0.2886 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5252 - accuracy: 0.7747 - val_loss: 0.2885 - val_accuracy: 0.9620 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5251 - accuracy: 0.7749 - val_loss: 0.2884 - val_accuracy: 0.9620 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5251 - accuracy: 0.7749 - val_loss: 0.2883 - val_accuracy: 0.9620 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5250 - accuracy: 0.7751 - val_loss: 0.2882 - val_accuracy: 0.9620 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5250 - accuracy: 0.7750 - val_loss: 0.2880 - val_accuracy: 0.9620 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5249 - accuracy: 0.7745 - val_loss: 0.2879 - val_accuracy: 0.9620 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5249 - accuracy: 0.7747 - val_loss: 0.2878 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5248 - accuracy: 0.7747 - val_loss: 0.2877 - val_accuracy: 0.9620 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5248 - accuracy: 0.7747 - val_loss: 0.2876 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5247 - accuracy: 0.7749 - val_loss: 0.2875 - val_accuracy: 0.9620 - 102ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5247 - accuracy: 0.7750 - val_loss: 0.2874 - val_accuracy: 0.9620 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5246 - accuracy: 0.7751 - val_loss: 0.2874 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5246 - accuracy: 0.7751 - val_loss: 0.2873 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5245 - accuracy: 0.7750 - val_loss: 0.2872 - val_accuracy: 0.9620 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5245 - accuracy: 0.7750 - val_loss: 0.2871 - val_accuracy: 0.9620 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5244 - accuracy: 0.7750 - val_loss: 0.2871 - val_accuracy: 0.9620 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5244 - accuracy: 0.7750 - val_loss: 0.2870 - val_accuracy: 0.9620 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5243 - accuracy: 0.7750 - val_loss: 0.2869 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5243 - accuracy: 0.7749 - val_loss: 0.2869 - val_accuracy: 0.9620 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5242 - accuracy: 0.7750 - val_loss: 0.2868 - val_accuracy: 0.9620 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5242 - accuracy: 0.7750 - val_loss: 0.2867 - val_accuracy: 0.9620 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5241 - accuracy: 0.7749 - val_loss: 0.2867 - val_accuracy: 0.9620 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5241 - accuracy: 0.7749 - val_loss: 0.2866 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5240 - accuracy: 0.7750 - val_loss: 0.2865 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5240 - accuracy: 0.7750 - val_loss: 0.2865 - val_accuracy: 0.9620 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5239 - accuracy: 0.7751 - val_loss: 0.2864 - val_accuracy: 0.9620 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5239 - accuracy: 0.7751 - val_loss: 0.2863 - val_accuracy: 0.9620 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5238 - accuracy: 0.7751 - val_loss: 0.2862 - val_accuracy: 0.9620 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5238 - accuracy: 0.7751 - val_loss: 0.2862 - val_accuracy: 0.9620 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5237 - accuracy: 0.7751 - val_loss: 0.2861 - val_accuracy: 0.9620 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5237 - accuracy: 0.7754 - val_loss: 0.2860 - val_accuracy: 0.9640 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5237 - accuracy: 0.7755 - val_loss: 0.2860 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5236 - accuracy: 0.7755 - val_loss: 0.2859 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5236 - accuracy: 0.7755 - val_loss: 0.2858 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5235 - accuracy: 0.7755 - val_loss: 0.2857 - val_accuracy: 0.9640 - 101ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5235 - accuracy: 0.7755 - val_loss: 0.2857 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5234 - accuracy: 0.7756 - val_loss: 0.2856 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5234 - accuracy: 0.7757 - val_loss: 0.2856 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5234 - accuracy: 0.7757 - val_loss: 0.2855 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5233 - accuracy: 0.7757 - val_loss: 0.2854 - val_accuracy: 0.9640 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5233 - accuracy: 0.7756 - val_loss: 0.2854 - val_accuracy: 0.9640 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5232 - accuracy: 0.7757 - val_loss: 0.2853 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5232 - accuracy: 0.7759 - val_loss: 0.2852 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5231 - accuracy: 0.7759 - val_loss: 0.2852 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5231 - accuracy: 0.7760 - val_loss: 0.2851 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5231 - accuracy: 0.7763 - val_loss: 0.2850 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5230 - accuracy: 0.7760 - val_loss: 0.2850 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5230 - accuracy: 0.7760 - val_loss: 0.2849 - val_accuracy: 0.9640 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5229 - accuracy: 0.7761 - val_loss: 0.2848 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5229 - accuracy: 0.7760 - val_loss: 0.2848 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5229 - accuracy: 0.7760 - val_loss: 0.2847 - val_accuracy: 0.9640 - 114ms/epoch - 4ms/step
# 32/32 - 0s - loss: 0.5228 - accuracy: 0.7760 - val_loss: 0.2846 - val_accuracy: 0.9640 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5228 - accuracy: 0.7760 - val_loss: 0.2846 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5227 - accuracy: 0.7760 - val_loss: 0.2845 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5227 - accuracy: 0.7759 - val_loss: 0.2845 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5227 - accuracy: 0.7759 - val_loss: 0.2844 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5226 - accuracy: 0.7759 - val_loss: 0.2843 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5226 - accuracy: 0.7760 - val_loss: 0.2843 - val_accuracy: 0.9640 - 57ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5226 - accuracy: 0.7761 - val_loss: 0.2842 - val_accuracy: 0.9640 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5225 - accuracy: 0.7761 - val_loss: 0.2841 - val_accuracy: 0.9640 - 79ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5225 - accuracy: 0.7760 - val_loss: 0.2841 - val_accuracy: 0.9640 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5224 - accuracy: 0.7760 - val_loss: 0.2840 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5224 - accuracy: 0.7757 - val_loss: 0.2840 - val_accuracy: 0.9640 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5224 - accuracy: 0.7757 - val_loss: 0.2839 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5223 - accuracy: 0.7757 - val_loss: 0.2839 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5223 - accuracy: 0.7757 - val_loss: 0.2838 - val_accuracy: 0.9640 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5223 - accuracy: 0.7757 - val_loss: 0.2838 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5222 - accuracy: 0.7757 - val_loss: 0.2837 - val_accuracy: 0.9640 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5222 - accuracy: 0.7757 - val_loss: 0.2837 - val_accuracy: 0.9640 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5222 - accuracy: 0.7760 - val_loss: 0.2836 - val_accuracy: 0.9640 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5221 - accuracy: 0.7760 - val_loss: 0.2836 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5221 - accuracy: 0.7760 - val_loss: 0.2836 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5221 - accuracy: 0.7761 - val_loss: 0.2835 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5220 - accuracy: 0.7761 - val_loss: 0.2835 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5220 - accuracy: 0.7761 - val_loss: 0.2835 - val_accuracy: 0.9640 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5220 - accuracy: 0.7761 - val_loss: 0.2834 - val_accuracy: 0.9640 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5219 - accuracy: 0.7761 - val_loss: 0.2834 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5219 - accuracy: 0.7761 - val_loss: 0.2834 - val_accuracy: 0.9640 - 58ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5219 - accuracy: 0.7761 - val_loss: 0.2834 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5219 - accuracy: 0.7763 - val_loss: 0.2833 - val_accuracy: 0.9640 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5218 - accuracy: 0.7764 - val_loss: 0.2833 - val_accuracy: 0.9640 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5218 - accuracy: 0.7764 - val_loss: 0.2832 - val_accuracy: 0.9640 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5218 - accuracy: 0.7763 - val_loss: 0.2832 - val_accuracy: 0.9640 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5217 - accuracy: 0.7764 - val_loss: 0.2831 - val_accuracy: 0.9640 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5217 - accuracy: 0.7761 - val_loss: 0.2831 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5217 - accuracy: 0.7761 - val_loss: 0.2831 - val_accuracy: 0.9640 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5216 - accuracy: 0.7760 - val_loss: 0.2831 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5216 - accuracy: 0.7760 - val_loss: 0.2830 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5216 - accuracy: 0.7761 - val_loss: 0.2830 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5216 - accuracy: 0.7760 - val_loss: 0.2830 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5215 - accuracy: 0.7760 - val_loss: 0.2829 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5215 - accuracy: 0.7760 - val_loss: 0.2829 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5215 - accuracy: 0.7760 - val_loss: 0.2828 - val_accuracy: 0.9640 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5214 - accuracy: 0.7760 - val_loss: 0.2828 - val_accuracy: 0.9640 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5214 - accuracy: 0.7760 - val_loss: 0.2828 - val_accuracy: 0.9640 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5214 - accuracy: 0.7760 - val_loss: 0.2827 - val_accuracy: 0.9640 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5214 - accuracy: 0.7760 - val_loss: 0.2827 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5213 - accuracy: 0.7763 - val_loss: 0.2826 - val_accuracy: 0.9640 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5213 - accuracy: 0.7763 - val_loss: 0.2826 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5213 - accuracy: 0.7761 - val_loss: 0.2825 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5213 - accuracy: 0.7761 - val_loss: 0.2825 - val_accuracy: 0.9640 - 56ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5212 - accuracy: 0.7761 - val_loss: 0.2825 - val_accuracy: 0.9640 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5212 - accuracy: 0.7763 - val_loss: 0.2825 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5212 - accuracy: 0.7764 - val_loss: 0.2824 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5212 - accuracy: 0.7764 - val_loss: 0.2824 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5211 - accuracy: 0.7765 - val_loss: 0.2824 - val_accuracy: 0.9640 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5211 - accuracy: 0.7765 - val_loss: 0.2824 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5211 - accuracy: 0.7765 - val_loss: 0.2823 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5211 - accuracy: 0.7765 - val_loss: 0.2823 - val_accuracy: 0.9640 - 52ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5210 - accuracy: 0.7766 - val_loss: 0.2823 - val_accuracy: 0.9640 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5210 - accuracy: 0.7765 - val_loss: 0.2823 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5210 - accuracy: 0.7766 - val_loss: 0.2822 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5210 - accuracy: 0.7766 - val_loss: 0.2822 - val_accuracy: 0.9640 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5209 - accuracy: 0.7768 - val_loss: 0.2821 - val_accuracy: 0.9640 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5209 - accuracy: 0.7769 - val_loss: 0.2821 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5209 - accuracy: 0.7768 - val_loss: 0.2821 - val_accuracy: 0.9640 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5209 - accuracy: 0.7766 - val_loss: 0.2820 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5208 - accuracy: 0.7766 - val_loss: 0.2820 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5208 - accuracy: 0.7765 - val_loss: 0.2819 - val_accuracy: 0.9640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5208 - accuracy: 0.7765 - val_loss: 0.2819 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5208 - accuracy: 0.7765 - val_loss: 0.2819 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5207 - accuracy: 0.7765 - val_loss: 0.2819 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5207 - accuracy: 0.7766 - val_loss: 0.2818 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5207 - accuracy: 0.7766 - val_loss: 0.2818 - val_accuracy: 0.9640 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5207 - accuracy: 0.7766 - val_loss: 0.2817 - val_accuracy: 0.9640 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5206 - accuracy: 0.7766 - val_loss: 0.2817 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5206 - accuracy: 0.7769 - val_loss: 0.2817 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5206 - accuracy: 0.7768 - val_loss: 0.2816 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5206 - accuracy: 0.7768 - val_loss: 0.2816 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5205 - accuracy: 0.7769 - val_loss: 0.2816 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5205 - accuracy: 0.7766 - val_loss: 0.2815 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5205 - accuracy: 0.7766 - val_loss: 0.2815 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5205 - accuracy: 0.7766 - val_loss: 0.2815 - val_accuracy: 0.9640 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5204 - accuracy: 0.7765 - val_loss: 0.2815 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5204 - accuracy: 0.7766 - val_loss: 0.2815 - val_accuracy: 0.9640 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5204 - accuracy: 0.7766 - val_loss: 0.2814 - val_accuracy: 0.9640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5204 - accuracy: 0.7766 - val_loss: 0.2814 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5203 - accuracy: 0.7766 - val_loss: 0.2814 - val_accuracy: 0.9640 - 78ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5203 - accuracy: 0.7766 - val_loss: 0.2813 - val_accuracy: 0.9640 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5203 - accuracy: 0.7766 - val_loss: 0.2813 - val_accuracy: 0.9640 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5203 - accuracy: 0.7768 - val_loss: 0.2813 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5202 - accuracy: 0.7769 - val_loss: 0.2812 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5202 - accuracy: 0.7770 - val_loss: 0.2813 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5202 - accuracy: 0.7770 - val_loss: 0.2812 - val_accuracy: 0.9640 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5202 - accuracy: 0.7770 - val_loss: 0.2812 - val_accuracy: 0.9640 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5202 - accuracy: 0.7771 - val_loss: 0.2811 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5201 - accuracy: 0.7770 - val_loss: 0.2811 - val_accuracy: 0.9640 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5201 - accuracy: 0.7769 - val_loss: 0.2811 - val_accuracy: 0.9640 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5201 - accuracy: 0.7768 - val_loss: 0.2810 - val_accuracy: 0.9640 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5201 - accuracy: 0.7769 - val_loss: 0.2810 - val_accuracy: 0.9640 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7768 - val_loss: 0.2809 - val_accuracy: 0.9640 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7768 - val_loss: 0.2809 - val_accuracy: 0.9640 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7768 - val_loss: 0.2809 - val_accuracy: 0.9640 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7768 - val_loss: 0.2808 - val_accuracy: 0.9640 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7768 - val_loss: 0.2808 - val_accuracy: 0.9640 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5199 - accuracy: 0.7768 - val_loss: 0.2808 - val_accuracy: 0.9640 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5199 - accuracy: 0.7768 - val_loss: 0.2807 - val_accuracy: 0.9640 - 321ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.5199 - accuracy: 0.7768 - val_loss: 0.2807 - val_accuracy: 0.9640 - 97ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.2807 - accuracy: 0.9640 - 31ms/epoch - 2ms/step
# 0.2806760370731354

# %%
train_logits = model.predict(
    X_train,
    batch_size=256,
    verbose=0
)

# Calculate one loss value per sample using the corrupted labels
per_sample_loss_fn = CategoricalCrossentropy(
    from_logits=True,
    reduction=tf.keras.losses.Reduction.NONE
)

training_losses = per_sample_loss_fn(
    y_train,
    train_logits
).numpy()

print(training_losses.shape)
print(pd.Series(training_losses).describe())
# Out:
# (8000,)
# count    8000.000000
# mean        0.519221
# std         0.530602
# min         0.016073
# 25%         0.209555
# 50%         0.246898
# 75%         0.536740
# max         2.904394
# dtype: float64

# %%
noise_loss_df = pd.DataFrame({
    "Train_ID": train_ids_original,
    "Clean_Label": train_df["clean_label"].to_numpy(),
    "Noisy_Label": train_df["noisy_label"].to_numpy(),
    "is_noisy": train_df["is_noisy"].to_numpy(),
    "Training_Loss": training_losses
})

print(noise_loss_df.head())
print(
    noise_loss_df.groupby("is_noisy")[
        "Training_Loss"
    ].describe()
)
# Out:
#    Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss
# 0         1            1            1         0       0.256591
# 1         2            1            1         0       0.531973
# 2         3            1            1         0       0.406520
# 3         4            1            1         0       0.242922
# 4         5            1            1         0       0.264528
#            count      mean       std       min       25%       50%       75%  \
# is_noisy
# 0         6400.0  0.279721  0.177918  0.016073  0.203125  0.235317  0.266505
# 1         1600.0  1.477221  0.365780  0.215512  1.376510  1.549061  1.672437
#
#                max
# is_noisy
# 0         2.000767
# 1         2.904394

# %%
noise_loss_df.to_csv(
    "Noise_GroundTruth_and_TrainingLoss.csv",
    index=False
)

# %%
train_df.to_csv(
    "NoisyLabel_TrainingData.csv",
    index=False
)

test_df.to_csv(
    "Clean_TestData.csv",
    index=False
)

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
#       Train_ID     Score
# 0            1  0.236214
# 1            2  0.409049
# 2            3  0.337209
# 3            4  0.150726
# 4            5  0.150731
# ...        ...       ...
# 7995      8496  0.201999
# 7996      8497 -0.694172
# 7997      8498  0.214947
# 7998      8499  0.162482
# 7999      8500  0.228409
#
# [8000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID     Score
# 0            1  0.028077
# 1            2  0.039200
# 2            3  0.018387
# 3            4  0.027367
# 4            5  0.030144
# ...        ...       ...
# 7995      8496  0.027764
# 7996      8497 -0.089737
# 7997      8498  0.027789
# 7998      8499  0.015313
# 7999      8500  0.013857
#
# [8000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("NoisyLabel_TracIn_Scores.csv",index = False)
df_sorted.to_csv("NoisyLabel_FOIF_Scores.csv",index = False)
