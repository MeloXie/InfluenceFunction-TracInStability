# %% [markdown]
# ## This is the code to train the model and acquire influence and loss for Sensitivity to Outliers Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 16000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is almost the same code as the base code. Please refer to the base code for more detailed explanation.** The differences here are: 1. Train_sizes are limited to 5 choices. 2. The loss of the training points are stored as a file for later analysis.

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> Store the Loss Lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last three block3 to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.metrics import pairwise_distances
from sklearn.manifold import MDS
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# Train_Size: 1000, 2000, 4000, 8000, 16000

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 16000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **If you just want to use our setting to test, the only thing you need to change here is the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to multi-verify the experiement results.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
train_pool = 16000
test_size = 500
train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
n_features=160
seed=42
sep = 5

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
total_samples = train_pool + test_size

X, y = make_classification(n_samples=total_samples,
                           n_features=n_features,
                           n_informative=n_features,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           class_sep=sep,
                           random_state=seed)

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
print(df)
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1       4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2      -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3       1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4       2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
# ...          ...        ...        ...        ...        ...        ...
# 16495  -6.716227  -3.941982   6.511306  -1.178930 -10.376654  -9.079567
# 16496   4.277247 -15.312607  10.519820  -0.178716  -3.619789 -10.264994
# 16497  -8.898158   2.233196  -6.868816  -1.021291   9.341948  15.122732
# 16498  -3.610179 -17.301590   2.750310   6.510539  -0.240444  -2.099331
# 16499 -17.536142   5.698689   9.265016   3.931781   6.659502  10.521925
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_153  \
# 0       8.887783  -4.063796  21.086774   -1.520991  ...     7.819484
# 1      -2.525553   9.558629   7.793142    4.989492  ...     0.182679
# 2     -17.248069   6.155376   3.674610    8.811081  ...     7.133064
# 3     -16.208869   2.459683  20.384366   11.957595  ...     6.951633
# 4     -16.237140  15.315085  12.821372   -1.751887  ...     4.459658
# ...          ...        ...        ...         ...  ...          ...
# 16495  -4.641685   2.222042  -7.869077  -12.255666  ...    -4.546759
# 16496  -0.316307  -5.902208  -1.288590    4.576726  ...    -7.428876
# 16497   1.245836  -3.054652  -0.862010    1.089771  ...     1.037077
# 16498   6.536393   4.578611  -8.949377  -16.968405  ...    -2.097471
# 16499  -1.995124   5.285654  -2.441093   13.462665  ...    21.396240
#
#        feature_154  feature_155  feature_156  feature_157  feature_158  \
# 0        -8.721757    -0.265044   -12.609638    20.374691    -1.570831
# 1        -0.204365     0.888607     3.551630     2.569427    -6.208564
# 2        16.611964    -3.646307    -7.176389     6.705201    -2.310830
# 3         2.328660     6.681308     1.769797    -4.039115    -5.922587
# 4         5.218489    12.759107   -13.026580    22.496523    -9.348923
# ...            ...          ...          ...          ...          ...
# 16495    -4.050163    -9.094683    17.398139    -9.798232   -11.915061
# 16496     6.799153     7.235603    -4.089953    13.648382    -6.782679
# 16497     0.432403    10.715410     7.253302     0.726265     6.259256
# 16498     7.160379   -14.985227    22.886270     0.205933     2.049345
# 16499    11.098062    19.261285     9.649843    -5.213003     3.549000
#
#        feature_159  feature_160  label     id
# 0         1.681914   -12.080108      0      1
# 1        15.227281   -11.197154      0      2
# 2         6.484147     6.494745      0      3
# 3         1.982110   -11.342025      0      4
# 4        -1.507289    -2.109601      0      5
# ...            ...          ...    ...    ...
# 16495    -9.204892    -0.940133      1  16496
# 16496     5.975577    -0.858158      0  16497
# 16497     9.247954     7.098226      0  16498
# 16498    -1.669219    -4.507195      1  16499
# 16499     1.238540    10.778987      0  16500
#
# [16500 rows x 162 columns]

# %%
df_train_pool = df.iloc[:train_pool].reset_index(drop=True)
df_test = df.iloc[train_pool:].reset_index(drop=True)

# %%
print(df_train_pool.head())
print(df_test.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0 -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1   4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2  -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3   1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4   2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   8.887783  -4.063796  21.086774   -1.520991  ...     7.819484    -8.721757
# 1  -2.525553   9.558629   7.793142    4.989492  ...     0.182679    -0.204365
# 2 -17.248069   6.155376   3.674610    8.811081  ...     7.133064    16.611964
# 3 -16.208869   2.459683  20.384366   11.957595  ...     6.951633     2.328660
# 4 -16.237140  15.315085  12.821372   -1.751887  ...     4.459658     5.218489
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -0.265044   -12.609638    20.374691    -1.570831     1.681914
# 1     0.888607     3.551630     2.569427    -6.208564    15.227281
# 2    -3.646307    -7.176389     6.705201    -2.310830     6.484147
# 3     6.681308     1.769797    -4.039115    -5.922587     1.982110
# 4    12.759107   -13.026580    22.496523    -9.348923    -1.507289
#
#    feature_160  label  id
# 0   -12.080108      0   1
# 1   -11.197154      0   2
# 2     6.494745      0   3
# 3   -11.342025      0   4
# 4    -2.109601      0   5
#
# [5 rows x 162 columns]
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   8.186701   1.756976  -3.511353  13.659343   5.483705 -10.949900
# 1  14.967977  -5.722160   3.950408 -13.784702  11.335362 -18.859072
# 2  -9.988432  -4.055041  -0.115356  11.196465 -16.064963  -8.859267
# 3 -11.848951  -2.649319   4.776790  -4.132250  17.601257  16.474988
# 4   5.367084   7.090506  -8.492735   7.735160   6.893680   4.421945
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   2.760068 -10.072462  11.672101   13.301910  ...    -1.642295    -5.284690
# 1 -11.031748   3.485709   5.296748   -4.241424  ...     4.449477     9.646840
# 2 -10.954191  -9.738694   1.515229    6.760216  ...   -15.213665     3.202685
# 3   2.001569  15.994439  12.516982   12.461262  ...    -1.251628    26.544205
# 4  -8.181725  -5.288708   1.554211   -3.996913  ...    10.820747    -3.109014
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -6.683406    -4.249138     2.145855     4.493905     1.603028
# 1     4.716637     0.493215    16.669589     0.114925     2.073456
# 2     3.373245    11.608862   -16.135474    -5.296019   -11.790634
# 3    14.547684     3.009137    -3.386921    -5.009036    -3.927385
# 4     8.360912    11.710584     2.666601     3.784130     3.617174
#
#    feature_160  label     id
# 0    13.536012      1  16001
# 1    -9.846196      0  16002
# 2    -3.989249      1  16003
# 3     8.479217      0  16004
# 4     5.204375      1  16005
#
# [5 rows x 162 columns]

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %%
features_to_test = 10
selected_features = [f'feature_{i+1}' for i in range(features_to_test)]

nested_train_dfs = [df_train_pool.iloc[:size].reset_index(drop=True) for size in train_sizes]
nested_train_dfs = [df[ selected_features + ['label', 'id'] ].copy()for df in nested_train_dfs]

df_test = df_test[ selected_features + ['label', 'id'] ].copy()

core_1000_ids = nested_train_dfs[0]['id'].tolist()

# %% [markdown]
# Again, change here if you wish to change the number of train size

# %%
train_df = nested_train_dfs[9]

# %%
train_df["label"].value_counts()
# Out:
# label
# 1    5025
# 0    4975
# Name: count, dtype: int64

# %%
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]
IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
X_train = np.hstack((X_train, IDs))
y_train = to_categorical(y_train.values,num_classes=2)

print(X_train.shape)
# Out:
# (10000, 11)

# %%
test_df = df_test
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
# Out:
# (500, 11)

# %%
test_df["label"].value_counts()
# Out:
# label
# 0    255
# 1    245
# Name: count, dtype: int64

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %%
train_df[["id", "label"]].rename(
    columns={"id": "Train_ID"}
).to_csv(
    "train_labels.csv",
    index=False
)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.
#
# **The only difference here is the loss for the training samples are stored and this shall be saved in a file later**

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 32/32 - 1s - loss: 0.8722 - accuracy: 0.4755 - val_loss: 0.7693 - val_accuracy: 0.5060 - 726ms/epoch - 23ms/step
# 32/32 - 0s - loss: 0.6965 - accuracy: 0.5872 - val_loss: 0.6412 - val_accuracy: 0.6560 - 80ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.6102 - accuracy: 0.6896 - val_loss: 0.5764 - val_accuracy: 0.7500 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5588 - accuracy: 0.7464 - val_loss: 0.5309 - val_accuracy: 0.7920 - 51ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5200 - accuracy: 0.7805 - val_loss: 0.4944 - val_accuracy: 0.8120 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.4882 - accuracy: 0.8026 - val_loss: 0.4642 - val_accuracy: 0.8260 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.4611 - accuracy: 0.8166 - val_loss: 0.4382 - val_accuracy: 0.8360 - 50ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.4379 - accuracy: 0.8296 - val_loss: 0.4162 - val_accuracy: 0.8500 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.4182 - accuracy: 0.8397 - val_loss: 0.3976 - val_accuracy: 0.8580 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.4016 - accuracy: 0.8466 - val_loss: 0.3820 - val_accuracy: 0.8680 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3875 - accuracy: 0.8514 - val_loss: 0.3683 - val_accuracy: 0.8720 - 52ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3754 - accuracy: 0.8561 - val_loss: 0.3565 - val_accuracy: 0.8760 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3650 - accuracy: 0.8597 - val_loss: 0.3464 - val_accuracy: 0.8840 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.3559 - accuracy: 0.8629 - val_loss: 0.3375 - val_accuracy: 0.8900 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3479 - accuracy: 0.8662 - val_loss: 0.3296 - val_accuracy: 0.8860 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3408 - accuracy: 0.8683 - val_loss: 0.3223 - val_accuracy: 0.8900 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.3344 - accuracy: 0.8715 - val_loss: 0.3157 - val_accuracy: 0.8920 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.3286 - accuracy: 0.8745 - val_loss: 0.3096 - val_accuracy: 0.8920 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3234 - accuracy: 0.8763 - val_loss: 0.3041 - val_accuracy: 0.8900 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3185 - accuracy: 0.8779 - val_loss: 0.2989 - val_accuracy: 0.8920 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3141 - accuracy: 0.8804 - val_loss: 0.2941 - val_accuracy: 0.8940 - 101ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.3098 - accuracy: 0.8810 - val_loss: 0.2896 - val_accuracy: 0.8940 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3059 - accuracy: 0.8817 - val_loss: 0.2854 - val_accuracy: 0.8980 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.3021 - accuracy: 0.8832 - val_loss: 0.2814 - val_accuracy: 0.9000 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2986 - accuracy: 0.8845 - val_loss: 0.2776 - val_accuracy: 0.9020 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2952 - accuracy: 0.8860 - val_loss: 0.2739 - val_accuracy: 0.9020 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2920 - accuracy: 0.8870 - val_loss: 0.2704 - val_accuracy: 0.9020 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2889 - accuracy: 0.8880 - val_loss: 0.2670 - val_accuracy: 0.9020 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2860 - accuracy: 0.8899 - val_loss: 0.2637 - val_accuracy: 0.9060 - 52ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2832 - accuracy: 0.8915 - val_loss: 0.2606 - val_accuracy: 0.9060 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2805 - accuracy: 0.8919 - val_loss: 0.2575 - val_accuracy: 0.9060 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2780 - accuracy: 0.8931 - val_loss: 0.2545 - val_accuracy: 0.9100 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2755 - accuracy: 0.8934 - val_loss: 0.2516 - val_accuracy: 0.9100 - 81ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2731 - accuracy: 0.8947 - val_loss: 0.2487 - val_accuracy: 0.9100 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2708 - accuracy: 0.8949 - val_loss: 0.2461 - val_accuracy: 0.9100 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2686 - accuracy: 0.8953 - val_loss: 0.2436 - val_accuracy: 0.9080 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2665 - accuracy: 0.8963 - val_loss: 0.2411 - val_accuracy: 0.9100 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2645 - accuracy: 0.8961 - val_loss: 0.2388 - val_accuracy: 0.9080 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2625 - accuracy: 0.8965 - val_loss: 0.2365 - val_accuracy: 0.9100 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2607 - accuracy: 0.8969 - val_loss: 0.2343 - val_accuracy: 0.9100 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2589 - accuracy: 0.8974 - val_loss: 0.2322 - val_accuracy: 0.9100 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2573 - accuracy: 0.8979 - val_loss: 0.2301 - val_accuracy: 0.9120 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2557 - accuracy: 0.8985 - val_loss: 0.2282 - val_accuracy: 0.9120 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2542 - accuracy: 0.8988 - val_loss: 0.2263 - val_accuracy: 0.9120 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2528 - accuracy: 0.8991 - val_loss: 0.2245 - val_accuracy: 0.9140 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2514 - accuracy: 0.8994 - val_loss: 0.2228 - val_accuracy: 0.9120 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2501 - accuracy: 0.8992 - val_loss: 0.2212 - val_accuracy: 0.9120 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2489 - accuracy: 0.8999 - val_loss: 0.2197 - val_accuracy: 0.9120 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2477 - accuracy: 0.9006 - val_loss: 0.2182 - val_accuracy: 0.9140 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2467 - accuracy: 0.9014 - val_loss: 0.2169 - val_accuracy: 0.9160 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2456 - accuracy: 0.9020 - val_loss: 0.2155 - val_accuracy: 0.9160 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2446 - accuracy: 0.9022 - val_loss: 0.2143 - val_accuracy: 0.9160 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2437 - accuracy: 0.9029 - val_loss: 0.2130 - val_accuracy: 0.9160 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2428 - accuracy: 0.9036 - val_loss: 0.2119 - val_accuracy: 0.9160 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2420 - accuracy: 0.9041 - val_loss: 0.2108 - val_accuracy: 0.9160 - 86ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2412 - accuracy: 0.9036 - val_loss: 0.2098 - val_accuracy: 0.9160 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2405 - accuracy: 0.9039 - val_loss: 0.2089 - val_accuracy: 0.9180 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2398 - accuracy: 0.9039 - val_loss: 0.2080 - val_accuracy: 0.9180 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2391 - accuracy: 0.9040 - val_loss: 0.2072 - val_accuracy: 0.9180 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2385 - accuracy: 0.9045 - val_loss: 0.2064 - val_accuracy: 0.9180 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2379 - accuracy: 0.9045 - val_loss: 0.2057 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2373 - accuracy: 0.9049 - val_loss: 0.2050 - val_accuracy: 0.9220 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2368 - accuracy: 0.9054 - val_loss: 0.2043 - val_accuracy: 0.9220 - 85ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2363 - accuracy: 0.9059 - val_loss: 0.2037 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2358 - accuracy: 0.9062 - val_loss: 0.2031 - val_accuracy: 0.9220 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2353 - accuracy: 0.9069 - val_loss: 0.2025 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2349 - accuracy: 0.9066 - val_loss: 0.2020 - val_accuracy: 0.9220 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2345 - accuracy: 0.9066 - val_loss: 0.2015 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2341 - accuracy: 0.9069 - val_loss: 0.2010 - val_accuracy: 0.9220 - 58ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2337 - accuracy: 0.9070 - val_loss: 0.2006 - val_accuracy: 0.9220 - 52ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2333 - accuracy: 0.9074 - val_loss: 0.2001 - val_accuracy: 0.9220 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2330 - accuracy: 0.9071 - val_loss: 0.1997 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2326 - accuracy: 0.9074 - val_loss: 0.1993 - val_accuracy: 0.9200 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2323 - accuracy: 0.9075 - val_loss: 0.1989 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2320 - accuracy: 0.9085 - val_loss: 0.1986 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2317 - accuracy: 0.9085 - val_loss: 0.1982 - val_accuracy: 0.9220 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2314 - accuracy: 0.9086 - val_loss: 0.1979 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2311 - accuracy: 0.9086 - val_loss: 0.1976 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2308 - accuracy: 0.9089 - val_loss: 0.1973 - val_accuracy: 0.9220 - 102ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2306 - accuracy: 0.9089 - val_loss: 0.1970 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2303 - accuracy: 0.9094 - val_loss: 0.1967 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2300 - accuracy: 0.9096 - val_loss: 0.1964 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2298 - accuracy: 0.9096 - val_loss: 0.1961 - val_accuracy: 0.9240 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2295 - accuracy: 0.9097 - val_loss: 0.1958 - val_accuracy: 0.9240 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2293 - accuracy: 0.9096 - val_loss: 0.1956 - val_accuracy: 0.9240 - 81ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2291 - accuracy: 0.9097 - val_loss: 0.1954 - val_accuracy: 0.9240 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2289 - accuracy: 0.9097 - val_loss: 0.1952 - val_accuracy: 0.9220 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2286 - accuracy: 0.9099 - val_loss: 0.1950 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2284 - accuracy: 0.9097 - val_loss: 0.1948 - val_accuracy: 0.9220 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2282 - accuracy: 0.9100 - val_loss: 0.1946 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2280 - accuracy: 0.9101 - val_loss: 0.1945 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2278 - accuracy: 0.9103 - val_loss: 0.1943 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2277 - accuracy: 0.9104 - val_loss: 0.1942 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2275 - accuracy: 0.9105 - val_loss: 0.1940 - val_accuracy: 0.9220 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2273 - accuracy: 0.9107 - val_loss: 0.1939 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2271 - accuracy: 0.9109 - val_loss: 0.1937 - val_accuracy: 0.9200 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2269 - accuracy: 0.9106 - val_loss: 0.1935 - val_accuracy: 0.9200 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2267 - accuracy: 0.9105 - val_loss: 0.1933 - val_accuracy: 0.9200 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2266 - accuracy: 0.9104 - val_loss: 0.1932 - val_accuracy: 0.9200 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2264 - accuracy: 0.9104 - val_loss: 0.1930 - val_accuracy: 0.9200 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2262 - accuracy: 0.9106 - val_loss: 0.1928 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2261 - accuracy: 0.9107 - val_loss: 0.1927 - val_accuracy: 0.9200 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2259 - accuracy: 0.9106 - val_loss: 0.1926 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2258 - accuracy: 0.9109 - val_loss: 0.1924 - val_accuracy: 0.9200 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2256 - accuracy: 0.9110 - val_loss: 0.1923 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2255 - accuracy: 0.9110 - val_loss: 0.1922 - val_accuracy: 0.9200 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2254 - accuracy: 0.9110 - val_loss: 0.1921 - val_accuracy: 0.9220 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2252 - accuracy: 0.9112 - val_loss: 0.1920 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2251 - accuracy: 0.9115 - val_loss: 0.1919 - val_accuracy: 0.9220 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2250 - accuracy: 0.9115 - val_loss: 0.1918 - val_accuracy: 0.9220 - 53ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2248 - accuracy: 0.9112 - val_loss: 0.1917 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2247 - accuracy: 0.9111 - val_loss: 0.1916 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2246 - accuracy: 0.9114 - val_loss: 0.1915 - val_accuracy: 0.9220 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2245 - accuracy: 0.9114 - val_loss: 0.1914 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2243 - accuracy: 0.9115 - val_loss: 0.1913 - val_accuracy: 0.9200 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2242 - accuracy: 0.9115 - val_loss: 0.1913 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2241 - accuracy: 0.9112 - val_loss: 0.1912 - val_accuracy: 0.9200 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2240 - accuracy: 0.9116 - val_loss: 0.1911 - val_accuracy: 0.9200 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2239 - accuracy: 0.9119 - val_loss: 0.1910 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2237 - accuracy: 0.9116 - val_loss: 0.1910 - val_accuracy: 0.9200 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2236 - accuracy: 0.9118 - val_loss: 0.1909 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2235 - accuracy: 0.9118 - val_loss: 0.1909 - val_accuracy: 0.9200 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2234 - accuracy: 0.9119 - val_loss: 0.1908 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2233 - accuracy: 0.9119 - val_loss: 0.1908 - val_accuracy: 0.9200 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2232 - accuracy: 0.9118 - val_loss: 0.1907 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2231 - accuracy: 0.9120 - val_loss: 0.1907 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2230 - accuracy: 0.9121 - val_loss: 0.1906 - val_accuracy: 0.9220 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2229 - accuracy: 0.9121 - val_loss: 0.1906 - val_accuracy: 0.9220 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2228 - accuracy: 0.9120 - val_loss: 0.1905 - val_accuracy: 0.9220 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2227 - accuracy: 0.9121 - val_loss: 0.1905 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2226 - accuracy: 0.9120 - val_loss: 0.1905 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2225 - accuracy: 0.9121 - val_loss: 0.1904 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2224 - accuracy: 0.9122 - val_loss: 0.1904 - val_accuracy: 0.9220 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2223 - accuracy: 0.9124 - val_loss: 0.1903 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2222 - accuracy: 0.9125 - val_loss: 0.1903 - val_accuracy: 0.9220 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2221 - accuracy: 0.9126 - val_loss: 0.1903 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2220 - accuracy: 0.9126 - val_loss: 0.1902 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2220 - accuracy: 0.9126 - val_loss: 0.1901 - val_accuracy: 0.9220 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2219 - accuracy: 0.9126 - val_loss: 0.1901 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2218 - accuracy: 0.9126 - val_loss: 0.1900 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2217 - accuracy: 0.9126 - val_loss: 0.1900 - val_accuracy: 0.9220 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2216 - accuracy: 0.9128 - val_loss: 0.1899 - val_accuracy: 0.9220 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2216 - accuracy: 0.9128 - val_loss: 0.1899 - val_accuracy: 0.9240 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2215 - accuracy: 0.9130 - val_loss: 0.1899 - val_accuracy: 0.9240 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2214 - accuracy: 0.9131 - val_loss: 0.1898 - val_accuracy: 0.9240 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2213 - accuracy: 0.9131 - val_loss: 0.1898 - val_accuracy: 0.9240 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2213 - accuracy: 0.9131 - val_loss: 0.1897 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2212 - accuracy: 0.9131 - val_loss: 0.1897 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2211 - accuracy: 0.9130 - val_loss: 0.1897 - val_accuracy: 0.9240 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2210 - accuracy: 0.9131 - val_loss: 0.1897 - val_accuracy: 0.9240 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2210 - accuracy: 0.9133 - val_loss: 0.1896 - val_accuracy: 0.9240 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2209 - accuracy: 0.9130 - val_loss: 0.1896 - val_accuracy: 0.9240 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2208 - accuracy: 0.9129 - val_loss: 0.1896 - val_accuracy: 0.9240 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2207 - accuracy: 0.9128 - val_loss: 0.1896 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2207 - accuracy: 0.9128 - val_loss: 0.1895 - val_accuracy: 0.9240 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2206 - accuracy: 0.9129 - val_loss: 0.1895 - val_accuracy: 0.9240 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2205 - accuracy: 0.9130 - val_loss: 0.1895 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2205 - accuracy: 0.9130 - val_loss: 0.1895 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2204 - accuracy: 0.9130 - val_loss: 0.1895 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2203 - accuracy: 0.9130 - val_loss: 0.1895 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2203 - accuracy: 0.9130 - val_loss: 0.1895 - val_accuracy: 0.9240 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2202 - accuracy: 0.9131 - val_loss: 0.1895 - val_accuracy: 0.9240 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2202 - accuracy: 0.9133 - val_loss: 0.1895 - val_accuracy: 0.9240 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2201 - accuracy: 0.9133 - val_loss: 0.1895 - val_accuracy: 0.9240 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2200 - accuracy: 0.9133 - val_loss: 0.1894 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2200 - accuracy: 0.9133 - val_loss: 0.1894 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2199 - accuracy: 0.9135 - val_loss: 0.1894 - val_accuracy: 0.9240 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2198 - accuracy: 0.9135 - val_loss: 0.1894 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2198 - accuracy: 0.9135 - val_loss: 0.1894 - val_accuracy: 0.9240 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2197 - accuracy: 0.9135 - val_loss: 0.1893 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2196 - accuracy: 0.9135 - val_loss: 0.1894 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2196 - accuracy: 0.9134 - val_loss: 0.1893 - val_accuracy: 0.9240 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2195 - accuracy: 0.9134 - val_loss: 0.1893 - val_accuracy: 0.9240 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2195 - accuracy: 0.9135 - val_loss: 0.1893 - val_accuracy: 0.9240 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2194 - accuracy: 0.9136 - val_loss: 0.1894 - val_accuracy: 0.9240 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2193 - accuracy: 0.9137 - val_loss: 0.1894 - val_accuracy: 0.9240 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2193 - accuracy: 0.9141 - val_loss: 0.1893 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2192 - accuracy: 0.9141 - val_loss: 0.1894 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2191 - accuracy: 0.9143 - val_loss: 0.1893 - val_accuracy: 0.9240 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2191 - accuracy: 0.9145 - val_loss: 0.1893 - val_accuracy: 0.9240 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2190 - accuracy: 0.9147 - val_loss: 0.1893 - val_accuracy: 0.9240 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2189 - accuracy: 0.9147 - val_loss: 0.1893 - val_accuracy: 0.9240 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2189 - accuracy: 0.9149 - val_loss: 0.1893 - val_accuracy: 0.9240 - 54ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2188 - accuracy: 0.9149 - val_loss: 0.1893 - val_accuracy: 0.9220 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2187 - accuracy: 0.9149 - val_loss: 0.1893 - val_accuracy: 0.9220 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2187 - accuracy: 0.9149 - val_loss: 0.1893 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2186 - accuracy: 0.9150 - val_loss: 0.1892 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2186 - accuracy: 0.9149 - val_loss: 0.1892 - val_accuracy: 0.9220 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2185 - accuracy: 0.9149 - val_loss: 0.1892 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2184 - accuracy: 0.9151 - val_loss: 0.1892 - val_accuracy: 0.9220 - 86ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2184 - accuracy: 0.9151 - val_loss: 0.1892 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2183 - accuracy: 0.9151 - val_loss: 0.1892 - val_accuracy: 0.9220 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2183 - accuracy: 0.9151 - val_loss: 0.1891 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2182 - accuracy: 0.9151 - val_loss: 0.1891 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2181 - accuracy: 0.9150 - val_loss: 0.1891 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2181 - accuracy: 0.9151 - val_loss: 0.1891 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2180 - accuracy: 0.9149 - val_loss: 0.1890 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2180 - accuracy: 0.9150 - val_loss: 0.1890 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2179 - accuracy: 0.9150 - val_loss: 0.1890 - val_accuracy: 0.9220 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2179 - accuracy: 0.9150 - val_loss: 0.1889 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2178 - accuracy: 0.9149 - val_loss: 0.1889 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2177 - accuracy: 0.9147 - val_loss: 0.1889 - val_accuracy: 0.9220 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2177 - accuracy: 0.9150 - val_loss: 0.1889 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2176 - accuracy: 0.9150 - val_loss: 0.1889 - val_accuracy: 0.9220 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2176 - accuracy: 0.9149 - val_loss: 0.1889 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2175 - accuracy: 0.9147 - val_loss: 0.1889 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2175 - accuracy: 0.9147 - val_loss: 0.1888 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2174 - accuracy: 0.9147 - val_loss: 0.1889 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2174 - accuracy: 0.9147 - val_loss: 0.1888 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2173 - accuracy: 0.9147 - val_loss: 0.1888 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2172 - accuracy: 0.9147 - val_loss: 0.1888 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2172 - accuracy: 0.9146 - val_loss: 0.1888 - val_accuracy: 0.9220 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2171 - accuracy: 0.9146 - val_loss: 0.1888 - val_accuracy: 0.9220 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2171 - accuracy: 0.9146 - val_loss: 0.1888 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2170 - accuracy: 0.9146 - val_loss: 0.1887 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2170 - accuracy: 0.9146 - val_loss: 0.1887 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2169 - accuracy: 0.9147 - val_loss: 0.1887 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2169 - accuracy: 0.9147 - val_loss: 0.1887 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2168 - accuracy: 0.9147 - val_loss: 0.1887 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2168 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2167 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2167 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2166 - accuracy: 0.9147 - val_loss: 0.1887 - val_accuracy: 0.9220 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2166 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2166 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2165 - accuracy: 0.9150 - val_loss: 0.1887 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2165 - accuracy: 0.9149 - val_loss: 0.1887 - val_accuracy: 0.9220 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2164 - accuracy: 0.9151 - val_loss: 0.1887 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2164 - accuracy: 0.9153 - val_loss: 0.1887 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2163 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2163 - accuracy: 0.9150 - val_loss: 0.1886 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2162 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2162 - accuracy: 0.9151 - val_loss: 0.1886 - val_accuracy: 0.9220 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2162 - accuracy: 0.9150 - val_loss: 0.1885 - val_accuracy: 0.9220 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2161 - accuracy: 0.9151 - val_loss: 0.1886 - val_accuracy: 0.9220 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2161 - accuracy: 0.9151 - val_loss: 0.1886 - val_accuracy: 0.9220 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2160 - accuracy: 0.9151 - val_loss: 0.1886 - val_accuracy: 0.9220 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2160 - accuracy: 0.9151 - val_loss: 0.1886 - val_accuracy: 0.9220 - 83ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2160 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2159 - accuracy: 0.9154 - val_loss: 0.1886 - val_accuracy: 0.9220 - 57ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2159 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2158 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2158 - accuracy: 0.9153 - val_loss: 0.1886 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2158 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2157 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2157 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2157 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2156 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2156 - accuracy: 0.9153 - val_loss: 0.1885 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2156 - accuracy: 0.9154 - val_loss: 0.1884 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2155 - accuracy: 0.9154 - val_loss: 0.1884 - val_accuracy: 0.9220 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2155 - accuracy: 0.9154 - val_loss: 0.1884 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2154 - accuracy: 0.9154 - val_loss: 0.1884 - val_accuracy: 0.9220 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2154 - accuracy: 0.9154 - val_loss: 0.1884 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2154 - accuracy: 0.9153 - val_loss: 0.1883 - val_accuracy: 0.9220 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2153 - accuracy: 0.9154 - val_loss: 0.1883 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2153 - accuracy: 0.9155 - val_loss: 0.1883 - val_accuracy: 0.9220 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2153 - accuracy: 0.9156 - val_loss: 0.1883 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2152 - accuracy: 0.9156 - val_loss: 0.1883 - val_accuracy: 0.9220 - 55ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2152 - accuracy: 0.9156 - val_loss: 0.1883 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2152 - accuracy: 0.9158 - val_loss: 0.1883 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2151 - accuracy: 0.9159 - val_loss: 0.1882 - val_accuracy: 0.9220 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2151 - accuracy: 0.9160 - val_loss: 0.1882 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2151 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2150 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 49ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2150 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2150 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2149 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2149 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2148 - accuracy: 0.9161 - val_loss: 0.1882 - val_accuracy: 0.9220 - 58ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2148 - accuracy: 0.9162 - val_loss: 0.1881 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2148 - accuracy: 0.9162 - val_loss: 0.1881 - val_accuracy: 0.9220 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2147 - accuracy: 0.9164 - val_loss: 0.1881 - val_accuracy: 0.9220 - 50ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2147 - accuracy: 0.9164 - val_loss: 0.1881 - val_accuracy: 0.9220 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2147 - accuracy: 0.9165 - val_loss: 0.1881 - val_accuracy: 0.9200 - 83ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2146 - accuracy: 0.9165 - val_loss: 0.1880 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2146 - accuracy: 0.9165 - val_loss: 0.1880 - val_accuracy: 0.9200 - 53ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2146 - accuracy: 0.9164 - val_loss: 0.1880 - val_accuracy: 0.9200 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2145 - accuracy: 0.9164 - val_loss: 0.1880 - val_accuracy: 0.9200 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2145 - accuracy: 0.9165 - val_loss: 0.1879 - val_accuracy: 0.9200 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2145 - accuracy: 0.9161 - val_loss: 0.1879 - val_accuracy: 0.9200 - 54ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2144 - accuracy: 0.9162 - val_loss: 0.1879 - val_accuracy: 0.9200 - 79ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2144 - accuracy: 0.9164 - val_loss: 0.1878 - val_accuracy: 0.9200 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2144 - accuracy: 0.9164 - val_loss: 0.1878 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2143 - accuracy: 0.9162 - val_loss: 0.1878 - val_accuracy: 0.9200 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2143 - accuracy: 0.9164 - val_loss: 0.1877 - val_accuracy: 0.9200 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2143 - accuracy: 0.9165 - val_loss: 0.1877 - val_accuracy: 0.9200 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2142 - accuracy: 0.9165 - val_loss: 0.1876 - val_accuracy: 0.9200 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2142 - accuracy: 0.9165 - val_loss: 0.1876 - val_accuracy: 0.9200 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2142 - accuracy: 0.9164 - val_loss: 0.1875 - val_accuracy: 0.9200 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2141 - accuracy: 0.9165 - val_loss: 0.1875 - val_accuracy: 0.9200 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2141 - accuracy: 0.9165 - val_loss: 0.1875 - val_accuracy: 0.9200 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2141 - accuracy: 0.9162 - val_loss: 0.1875 - val_accuracy: 0.9200 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2140 - accuracy: 0.9165 - val_loss: 0.1874 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2140 - accuracy: 0.9165 - val_loss: 0.1874 - val_accuracy: 0.9200 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2140 - accuracy: 0.9165 - val_loss: 0.1874 - val_accuracy: 0.9200 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2139 - accuracy: 0.9165 - val_loss: 0.1874 - val_accuracy: 0.9200 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.2139 - accuracy: 0.9166 - val_loss: 0.1873 - val_accuracy: 0.9200 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.2139 - accuracy: 0.9168 - val_loss: 0.1873 - val_accuracy: 0.9200 - 47ms/epoch - 1ms/step
# 32/32 - 0s - loss: 0.2138 - accuracy: 0.9168 - val_loss: 0.1873 - val_accuracy: 0.9200 - 63ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.1873 - accuracy: 0.9200 - 30ms/epoch - 2ms/step
# 0.18729345500469208

# %% [markdown]
# 2. Store the loss for each training sample here. Important for this experiment

# %%
train_loss_values = unreduced_loss_fn(y_train, model.predict(X_train)).numpy()
# Out:
# 250/250 [==============================] - 0s 788us/step

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC. One Loss list.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
#       Train_ID     Score
# 0            1  0.001775
# 1            2  0.014391
# 2            3  0.004921
# 3            4  0.002940
# 4            5  0.002280
# ...        ...       ...
# 7995      7996  0.006449
# 7996      7997 -0.012514
# 7997      7998  0.012489
# 7998      7999  0.031524
# 7999      8000  0.009550
#
# [8000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID     Score
# 0            1  0.000462
# 1            2  0.000076
# 2            3  0.000013
# 3            4  0.000010
# 4            5  0.000009
# ...        ...       ...
# 7995      7996  0.000025
# 7996      7997 -0.001110
# 7997      7998  0.000121
# 7998      7999  0.000283
# 7999      8000 -0.000002
#
# [8000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing. Also, we store the previous loss list here.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("TC_Train_Set_1.csv",index = False)
df_sorted.to_csv("IF_Train_Set_1.csv",index = False)

# %%
df_train_loss = pd.DataFrame({
    'Train_ID': train_ids,
    'Loss': train_loss_values
}).sort_values('Loss', ascending=False).reset_index(drop=True)
print(df_train_loss)
# Out:
#       Train_ID          Loss
# 0         2957  7.434403e+00
# 1         6972  6.442560e+00
# 2         6845  6.327017e+00
# 3          382  6.120854e+00
# 4         6627  6.005379e+00
# ...        ...           ...
# 7995      2528  1.871568e-05
# 7996      1943  1.716599e-05
# 7997      4419  1.561629e-05
# 7998      1524  1.537788e-05
# 7999      3372  8.344646e-07
#
# [8000 rows x 2 columns]

# %%
df_train_loss.to_csv("Train_Loss_Train_Set_1.csv",index = False)
