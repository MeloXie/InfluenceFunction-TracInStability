# %% [markdown]
# ## This is the code to train the model and acquire influence and loss for Sensitivity to Outliers Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 16000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is almost the same code as the base code. Please refer to the base code for more detailed explanation.** The differences here are: 1. Train_sizes are limited to 5 choices. 2. The loss of the training points are stored as a file for later analysis.

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> Store the Loss Lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last three block3 to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.metrics import pairwise_distances
from sklearn.manifold import MDS
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# Train_Size: 1000, 2000, 4000, 8000, 16000

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 16000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **If you just want to use our setting to test, the only thing you need to change here is the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to multi-verify the experiement results.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
train_pool = 16000
test_size = 500
train_sizes=[1000, 2000, 4000, 8000, 16000]
n_features=160
seed=42
sep = 5

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
total_samples = train_pool + test_size

X, y = make_classification(n_samples=total_samples,
                           n_features=n_features,
                           n_informative=n_features,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           class_sep=sep,
                           random_state=seed)

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
print(df)
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1       4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2      -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3       1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4       2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
# ...          ...        ...        ...        ...        ...        ...
# 16495  -6.716227  -3.941982   6.511306  -1.178930 -10.376654  -9.079567
# 16496   4.277247 -15.312607  10.519820  -0.178716  -3.619789 -10.264994
# 16497  -8.898158   2.233196  -6.868816  -1.021291   9.341948  15.122732
# 16498  -3.610179 -17.301590   2.750310   6.510539  -0.240444  -2.099331
# 16499 -17.536142   5.698689   9.265016   3.931781   6.659502  10.521925
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_153  \
# 0       8.887783  -4.063796  21.086774   -1.520991  ...     7.819484
# 1      -2.525553   9.558629   7.793142    4.989492  ...     0.182679
# 2     -17.248069   6.155376   3.674610    8.811081  ...     7.133064
# 3     -16.208869   2.459683  20.384366   11.957595  ...     6.951633
# 4     -16.237140  15.315085  12.821372   -1.751887  ...     4.459658
# ...          ...        ...        ...         ...  ...          ...
# 16495  -4.641685   2.222042  -7.869077  -12.255666  ...    -4.546759
# 16496  -0.316307  -5.902208  -1.288590    4.576726  ...    -7.428876
# 16497   1.245836  -3.054652  -0.862010    1.089771  ...     1.037077
# 16498   6.536393   4.578611  -8.949377  -16.968405  ...    -2.097471
# 16499  -1.995124   5.285654  -2.441093   13.462665  ...    21.396240
#
#        feature_154  feature_155  feature_156  feature_157  feature_158  \
# 0        -8.721757    -0.265044   -12.609638    20.374691    -1.570831
# 1        -0.204365     0.888607     3.551630     2.569427    -6.208564
# 2        16.611964    -3.646307    -7.176389     6.705201    -2.310830
# 3         2.328660     6.681308     1.769797    -4.039115    -5.922587
# 4         5.218489    12.759107   -13.026580    22.496523    -9.348923
# ...            ...          ...          ...          ...          ...
# 16495    -4.050163    -9.094683    17.398139    -9.798232   -11.915061
# 16496     6.799153     7.235603    -4.089953    13.648382    -6.782679
# 16497     0.432403    10.715410     7.253302     0.726265     6.259256
# 16498     7.160379   -14.985227    22.886270     0.205933     2.049345
# 16499    11.098062    19.261285     9.649843    -5.213003     3.549000
#
#        feature_159  feature_160  label     id
# 0         1.681914   -12.080108      0      1
# 1        15.227281   -11.197154      0      2
# 2         6.484147     6.494745      0      3
# 3         1.982110   -11.342025      0      4
# 4        -1.507289    -2.109601      0      5
# ...            ...          ...    ...    ...
# 16495    -9.204892    -0.940133      1  16496
# 16496     5.975577    -0.858158      0  16497
# 16497     9.247954     7.098226      0  16498
# 16498    -1.669219    -4.507195      1  16499
# 16499     1.238540    10.778987      0  16500
#
# [16500 rows x 162 columns]

# %%
df_train_pool = df.iloc[:train_pool].reset_index(drop=True)
df_test = df.iloc[train_pool:].reset_index(drop=True)

# %%
print(df_train_pool.head())
print(df_test.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0 -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1   4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2  -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3   1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4   2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   8.887783  -4.063796  21.086774   -1.520991  ...     7.819484    -8.721757
# 1  -2.525553   9.558629   7.793142    4.989492  ...     0.182679    -0.204365
# 2 -17.248069   6.155376   3.674610    8.811081  ...     7.133064    16.611964
# 3 -16.208869   2.459683  20.384366   11.957595  ...     6.951633     2.328660
# 4 -16.237140  15.315085  12.821372   -1.751887  ...     4.459658     5.218489
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -0.265044   -12.609638    20.374691    -1.570831     1.681914
# 1     0.888607     3.551630     2.569427    -6.208564    15.227281
# 2    -3.646307    -7.176389     6.705201    -2.310830     6.484147
# 3     6.681308     1.769797    -4.039115    -5.922587     1.982110
# 4    12.759107   -13.026580    22.496523    -9.348923    -1.507289
#
#    feature_160  label  id
# 0   -12.080108      0   1
# 1   -11.197154      0   2
# 2     6.494745      0   3
# 3   -11.342025      0   4
# 4    -2.109601      0   5
#
# [5 rows x 162 columns]
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   8.186701   1.756976  -3.511353  13.659343   5.483705 -10.949900
# 1  14.967977  -5.722160   3.950408 -13.784702  11.335362 -18.859072
# 2  -9.988432  -4.055041  -0.115356  11.196465 -16.064963  -8.859267
# 3 -11.848951  -2.649319   4.776790  -4.132250  17.601257  16.474988
# 4   5.367084   7.090506  -8.492735   7.735160   6.893680   4.421945
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   2.760068 -10.072462  11.672101   13.301910  ...    -1.642295    -5.284690
# 1 -11.031748   3.485709   5.296748   -4.241424  ...     4.449477     9.646840
# 2 -10.954191  -9.738694   1.515229    6.760216  ...   -15.213665     3.202685
# 3   2.001569  15.994439  12.516982   12.461262  ...    -1.251628    26.544205
# 4  -8.181725  -5.288708   1.554211   -3.996913  ...    10.820747    -3.109014
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -6.683406    -4.249138     2.145855     4.493905     1.603028
# 1     4.716637     0.493215    16.669589     0.114925     2.073456
# 2     3.373245    11.608862   -16.135474    -5.296019   -11.790634
# 3    14.547684     3.009137    -3.386921    -5.009036    -3.927385
# 4     8.360912    11.710584     2.666601     3.784130     3.617174
#
#    feature_160  label     id
# 0    13.536012      1  16001
# 1    -9.846196      0  16002
# 2    -3.989249      1  16003
# 3     8.479217      0  16004
# 4     5.204375      1  16005
#
# [5 rows x 162 columns]

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %%
features_to_test = 10
selected_features = [f'feature_{i+1}' for i in range(features_to_test)]

nested_train_dfs = [df_train_pool.iloc[:size].reset_index(drop=True) for size in train_sizes]
nested_train_dfs = [df[ selected_features + ['label', 'id'] ].copy()for df in nested_train_dfs]

df_test = df_test[ selected_features + ['label', 'id'] ].copy()

core_1000_ids = nested_train_dfs[0]['id'].tolist()

# %% [markdown]
# Again, change here if you wish to change the number of train size

# %%
train_df = nested_train_dfs[4]

# %%
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]
IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
X_train = np.hstack((X_train, IDs))
y_train = to_categorical(y_train.values,num_classes=2)

print(X_train)
# Out:
# [[-1.1782908e+01 -8.1327267e+00  1.6152943e+01 ...  2.1086775e+01
#   -1.5209914e+00  1.0000000e-10]
#  [ 4.3370576e+00 -3.3224895e+00 -5.7607651e+00 ...  7.7931418e+00
#    4.9894924e+00  2.0000000e-10]
#  [-6.1624880e+00  1.0509963e+01  8.3503752e+00 ...  3.6746099e+00
#    8.8110809e+00  3.0000000e-10]
#  ...
#  [ 4.5180626e+00 -1.9904240e+01  1.3106934e+00 ...  1.1083531e+00
#    4.4679608e+00  1.5998000e-06]
#  [-6.8096948e+00 -3.0447917e+00 -2.7435186e+00 ... -5.0655752e-01
#   -7.7083702e+00  1.5999000e-06]
#  [-3.0826135e+00  5.1090604e-01  2.3374403e+00 ...  4.3270829e-01
#   -1.8326107e+00  1.6000000e-06]]

# %%
test_df = df_test
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test)
# Out:
# [[ 8.1867008e+00  1.7569758e+00 -3.5113528e+00 ...  1.1672101e+01
#    1.3301909e+01  1.6000999e-06]
#  [ 1.4967977e+01 -5.7221599e+00  3.9504085e+00 ...  5.2967482e+00
#   -4.2414246e+00  1.6002000e-06]
#  [-9.9884319e+00 -4.0550404e+00 -1.1535553e-01 ...  1.5152292e+00
#    6.7602162e+00  1.6003000e-06]
#  ...
#  [-8.8981581e+00  2.2331958e+00 -6.8688164e+00 ... -8.6201030e-01
#    1.0897712e+00  1.6498000e-06]
#  [-3.6101794e+00 -1.7301590e+01  2.7503097e+00 ... -8.9493771e+00
#   -1.6968405e+01  1.6499000e-06]
#  [-1.7536142e+01  5.6986890e+00  9.2650166e+00 ... -2.4410927e+00
#    1.3462665e+01  1.6499999e-06]]

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.
#
# **The only difference here is the loss for the training samples are stored and this shall be saved in a file later**

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 63/63 - 1s - loss: 0.7822 - accuracy: 0.5369 - val_loss: 0.6465 - val_accuracy: 0.6500 - 856ms/epoch - 14ms/step
# 63/63 - 0s - loss: 0.5857 - accuracy: 0.7158 - val_loss: 0.5324 - val_accuracy: 0.7800 - 379ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.5055 - accuracy: 0.7885 - val_loss: 0.4655 - val_accuracy: 0.8180 - 590ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.4512 - accuracy: 0.8209 - val_loss: 0.4176 - val_accuracy: 0.8520 - 370ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.4118 - accuracy: 0.8399 - val_loss: 0.3835 - val_accuracy: 0.8680 - 761ms/epoch - 12ms/step
# 63/63 - 1s - loss: 0.3832 - accuracy: 0.8516 - val_loss: 0.3579 - val_accuracy: 0.8700 - 545ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.3619 - accuracy: 0.8608 - val_loss: 0.3388 - val_accuracy: 0.8760 - 398ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.3454 - accuracy: 0.8674 - val_loss: 0.3237 - val_accuracy: 0.8820 - 587ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.3323 - accuracy: 0.8715 - val_loss: 0.3110 - val_accuracy: 0.8920 - 348ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.3215 - accuracy: 0.8752 - val_loss: 0.3003 - val_accuracy: 0.8920 - 588ms/epoch - 9ms/step
# 63/63 - 1s - loss: 0.3124 - accuracy: 0.8788 - val_loss: 0.2911 - val_accuracy: 0.8920 - 727ms/epoch - 12ms/step
# 63/63 - 1s - loss: 0.3045 - accuracy: 0.8826 - val_loss: 0.2828 - val_accuracy: 0.9000 - 502ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2973 - accuracy: 0.8856 - val_loss: 0.2753 - val_accuracy: 0.9020 - 359ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2908 - accuracy: 0.8877 - val_loss: 0.2685 - val_accuracy: 0.9000 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2850 - accuracy: 0.8896 - val_loss: 0.2621 - val_accuracy: 0.9020 - 482ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2796 - accuracy: 0.8905 - val_loss: 0.2560 - val_accuracy: 0.9040 - 334ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2747 - accuracy: 0.8923 - val_loss: 0.2502 - val_accuracy: 0.9040 - 345ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2702 - accuracy: 0.8947 - val_loss: 0.2449 - val_accuracy: 0.9040 - 344ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2661 - accuracy: 0.8957 - val_loss: 0.2401 - val_accuracy: 0.9080 - 349ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2623 - accuracy: 0.8969 - val_loss: 0.2357 - val_accuracy: 0.9080 - 350ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2589 - accuracy: 0.8980 - val_loss: 0.2318 - val_accuracy: 0.9140 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2560 - accuracy: 0.8988 - val_loss: 0.2282 - val_accuracy: 0.9160 - 350ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2533 - accuracy: 0.8990 - val_loss: 0.2247 - val_accuracy: 0.9160 - 366ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2509 - accuracy: 0.8996 - val_loss: 0.2217 - val_accuracy: 0.9160 - 410ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2487 - accuracy: 0.8998 - val_loss: 0.2188 - val_accuracy: 0.9160 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2468 - accuracy: 0.9004 - val_loss: 0.2163 - val_accuracy: 0.9140 - 393ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2450 - accuracy: 0.9009 - val_loss: 0.2139 - val_accuracy: 0.9140 - 365ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2435 - accuracy: 0.9017 - val_loss: 0.2119 - val_accuracy: 0.9160 - 373ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2421 - accuracy: 0.9018 - val_loss: 0.2100 - val_accuracy: 0.9160 - 367ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2409 - accuracy: 0.9025 - val_loss: 0.2083 - val_accuracy: 0.9180 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2398 - accuracy: 0.9029 - val_loss: 0.2068 - val_accuracy: 0.9180 - 351ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2388 - accuracy: 0.9036 - val_loss: 0.2054 - val_accuracy: 0.9180 - 383ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2379 - accuracy: 0.9041 - val_loss: 0.2040 - val_accuracy: 0.9200 - 341ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2371 - accuracy: 0.9044 - val_loss: 0.2028 - val_accuracy: 0.9200 - 406ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2363 - accuracy: 0.9048 - val_loss: 0.2018 - val_accuracy: 0.9200 - 426ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2356 - accuracy: 0.9053 - val_loss: 0.2007 - val_accuracy: 0.9200 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2350 - accuracy: 0.9055 - val_loss: 0.1998 - val_accuracy: 0.9200 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2344 - accuracy: 0.9058 - val_loss: 0.1991 - val_accuracy: 0.9220 - 458ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2338 - accuracy: 0.9061 - val_loss: 0.1984 - val_accuracy: 0.9220 - 357ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2333 - accuracy: 0.9064 - val_loss: 0.1977 - val_accuracy: 0.9240 - 345ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2328 - accuracy: 0.9065 - val_loss: 0.1971 - val_accuracy: 0.9220 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2324 - accuracy: 0.9069 - val_loss: 0.1964 - val_accuracy: 0.9220 - 360ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2319 - accuracy: 0.9068 - val_loss: 0.1959 - val_accuracy: 0.9240 - 363ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2315 - accuracy: 0.9070 - val_loss: 0.1953 - val_accuracy: 0.9240 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2312 - accuracy: 0.9071 - val_loss: 0.1949 - val_accuracy: 0.9240 - 376ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2308 - accuracy: 0.9072 - val_loss: 0.1945 - val_accuracy: 0.9240 - 363ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2305 - accuracy: 0.9074 - val_loss: 0.1941 - val_accuracy: 0.9240 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2302 - accuracy: 0.9072 - val_loss: 0.1937 - val_accuracy: 0.9240 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2299 - accuracy: 0.9074 - val_loss: 0.1935 - val_accuracy: 0.9240 - 394ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2296 - accuracy: 0.9072 - val_loss: 0.1932 - val_accuracy: 0.9240 - 356ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2294 - accuracy: 0.9073 - val_loss: 0.1929 - val_accuracy: 0.9240 - 368ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2291 - accuracy: 0.9078 - val_loss: 0.1926 - val_accuracy: 0.9240 - 354ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2288 - accuracy: 0.9079 - val_loss: 0.1923 - val_accuracy: 0.9260 - 373ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2286 - accuracy: 0.9083 - val_loss: 0.1920 - val_accuracy: 0.9280 - 438ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2284 - accuracy: 0.9084 - val_loss: 0.1918 - val_accuracy: 0.9280 - 440ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2282 - accuracy: 0.9086 - val_loss: 0.1916 - val_accuracy: 0.9280 - 417ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2280 - accuracy: 0.9088 - val_loss: 0.1913 - val_accuracy: 0.9280 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2278 - accuracy: 0.9090 - val_loss: 0.1911 - val_accuracy: 0.9260 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2276 - accuracy: 0.9089 - val_loss: 0.1909 - val_accuracy: 0.9260 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2274 - accuracy: 0.9087 - val_loss: 0.1907 - val_accuracy: 0.9260 - 451ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2272 - accuracy: 0.9088 - val_loss: 0.1905 - val_accuracy: 0.9260 - 404ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2271 - accuracy: 0.9090 - val_loss: 0.1904 - val_accuracy: 0.9260 - 337ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2269 - accuracy: 0.9089 - val_loss: 0.1902 - val_accuracy: 0.9240 - 389ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2267 - accuracy: 0.9089 - val_loss: 0.1900 - val_accuracy: 0.9240 - 449ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2266 - accuracy: 0.9091 - val_loss: 0.1899 - val_accuracy: 0.9240 - 381ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2264 - accuracy: 0.9094 - val_loss: 0.1898 - val_accuracy: 0.9240 - 357ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2263 - accuracy: 0.9095 - val_loss: 0.1896 - val_accuracy: 0.9240 - 393ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2261 - accuracy: 0.9096 - val_loss: 0.1894 - val_accuracy: 0.9240 - 383ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2260 - accuracy: 0.9096 - val_loss: 0.1893 - val_accuracy: 0.9240 - 396ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2258 - accuracy: 0.9097 - val_loss: 0.1892 - val_accuracy: 0.9240 - 335ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2257 - accuracy: 0.9095 - val_loss: 0.1890 - val_accuracy: 0.9260 - 345ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2255 - accuracy: 0.9095 - val_loss: 0.1889 - val_accuracy: 0.9260 - 347ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2254 - accuracy: 0.9095 - val_loss: 0.1887 - val_accuracy: 0.9260 - 418ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2253 - accuracy: 0.9095 - val_loss: 0.1886 - val_accuracy: 0.9260 - 495ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2251 - accuracy: 0.9095 - val_loss: 0.1884 - val_accuracy: 0.9260 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2250 - accuracy: 0.9096 - val_loss: 0.1883 - val_accuracy: 0.9260 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2249 - accuracy: 0.9095 - val_loss: 0.1882 - val_accuracy: 0.9260 - 398ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2247 - accuracy: 0.9095 - val_loss: 0.1881 - val_accuracy: 0.9260 - 349ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2246 - accuracy: 0.9097 - val_loss: 0.1880 - val_accuracy: 0.9280 - 343ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2245 - accuracy: 0.9097 - val_loss: 0.1878 - val_accuracy: 0.9280 - 383ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2244 - accuracy: 0.9097 - val_loss: 0.1877 - val_accuracy: 0.9280 - 381ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2243 - accuracy: 0.9097 - val_loss: 0.1877 - val_accuracy: 0.9280 - 343ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2242 - accuracy: 0.9096 - val_loss: 0.1876 - val_accuracy: 0.9280 - 373ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2241 - accuracy: 0.9097 - val_loss: 0.1875 - val_accuracy: 0.9280 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2239 - accuracy: 0.9098 - val_loss: 0.1874 - val_accuracy: 0.9280 - 401ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2238 - accuracy: 0.9100 - val_loss: 0.1873 - val_accuracy: 0.9280 - 382ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2237 - accuracy: 0.9101 - val_loss: 0.1872 - val_accuracy: 0.9280 - 375ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2236 - accuracy: 0.9101 - val_loss: 0.1871 - val_accuracy: 0.9280 - 463ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2235 - accuracy: 0.9103 - val_loss: 0.1870 - val_accuracy: 0.9280 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2234 - accuracy: 0.9103 - val_loss: 0.1869 - val_accuracy: 0.9280 - 389ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2233 - accuracy: 0.9103 - val_loss: 0.1868 - val_accuracy: 0.9280 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2232 - accuracy: 0.9103 - val_loss: 0.1867 - val_accuracy: 0.9280 - 450ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2232 - accuracy: 0.9103 - val_loss: 0.1866 - val_accuracy: 0.9280 - 382ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2231 - accuracy: 0.9103 - val_loss: 0.1865 - val_accuracy: 0.9280 - 359ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2230 - accuracy: 0.9104 - val_loss: 0.1863 - val_accuracy: 0.9280 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2229 - accuracy: 0.9105 - val_loss: 0.1863 - val_accuracy: 0.9280 - 358ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2228 - accuracy: 0.9106 - val_loss: 0.1862 - val_accuracy: 0.9280 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2227 - accuracy: 0.9107 - val_loss: 0.1862 - val_accuracy: 0.9280 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2226 - accuracy: 0.9107 - val_loss: 0.1861 - val_accuracy: 0.9280 - 352ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2226 - accuracy: 0.9106 - val_loss: 0.1860 - val_accuracy: 0.9280 - 396ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2225 - accuracy: 0.9103 - val_loss: 0.1860 - val_accuracy: 0.9280 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2224 - accuracy: 0.9104 - val_loss: 0.1859 - val_accuracy: 0.9280 - 365ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2223 - accuracy: 0.9104 - val_loss: 0.1858 - val_accuracy: 0.9280 - 371ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2222 - accuracy: 0.9105 - val_loss: 0.1858 - val_accuracy: 0.9280 - 357ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2222 - accuracy: 0.9106 - val_loss: 0.1857 - val_accuracy: 0.9280 - 393ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2221 - accuracy: 0.9107 - val_loss: 0.1856 - val_accuracy: 0.9280 - 369ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2220 - accuracy: 0.9107 - val_loss: 0.1856 - val_accuracy: 0.9280 - 402ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2219 - accuracy: 0.9107 - val_loss: 0.1855 - val_accuracy: 0.9280 - 395ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2219 - accuracy: 0.9107 - val_loss: 0.1855 - val_accuracy: 0.9280 - 389ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2218 - accuracy: 0.9107 - val_loss: 0.1854 - val_accuracy: 0.9280 - 411ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2217 - accuracy: 0.9109 - val_loss: 0.1853 - val_accuracy: 0.9280 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2216 - accuracy: 0.9107 - val_loss: 0.1852 - val_accuracy: 0.9280 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2216 - accuracy: 0.9107 - val_loss: 0.1852 - val_accuracy: 0.9280 - 359ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2215 - accuracy: 0.9110 - val_loss: 0.1851 - val_accuracy: 0.9260 - 358ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2214 - accuracy: 0.9111 - val_loss: 0.1850 - val_accuracy: 0.9260 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2213 - accuracy: 0.9112 - val_loss: 0.1850 - val_accuracy: 0.9260 - 354ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2213 - accuracy: 0.9112 - val_loss: 0.1849 - val_accuracy: 0.9260 - 489ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2212 - accuracy: 0.9113 - val_loss: 0.1849 - val_accuracy: 0.9260 - 349ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2211 - accuracy: 0.9113 - val_loss: 0.1848 - val_accuracy: 0.9260 - 444ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2211 - accuracy: 0.9114 - val_loss: 0.1848 - val_accuracy: 0.9260 - 352ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2210 - accuracy: 0.9114 - val_loss: 0.1847 - val_accuracy: 0.9260 - 405ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2210 - accuracy: 0.9115 - val_loss: 0.1847 - val_accuracy: 0.9240 - 380ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2209 - accuracy: 0.9111 - val_loss: 0.1846 - val_accuracy: 0.9240 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2208 - accuracy: 0.9113 - val_loss: 0.1846 - val_accuracy: 0.9240 - 395ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2208 - accuracy: 0.9114 - val_loss: 0.1845 - val_accuracy: 0.9260 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2207 - accuracy: 0.9115 - val_loss: 0.1845 - val_accuracy: 0.9260 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2206 - accuracy: 0.9114 - val_loss: 0.1845 - val_accuracy: 0.9260 - 346ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2206 - accuracy: 0.9114 - val_loss: 0.1845 - val_accuracy: 0.9260 - 365ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2205 - accuracy: 0.9113 - val_loss: 0.1845 - val_accuracy: 0.9260 - 355ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2205 - accuracy: 0.9113 - val_loss: 0.1844 - val_accuracy: 0.9260 - 418ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2204 - accuracy: 0.9113 - val_loss: 0.1843 - val_accuracy: 0.9260 - 344ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2204 - accuracy: 0.9114 - val_loss: 0.1843 - val_accuracy: 0.9260 - 380ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2203 - accuracy: 0.9116 - val_loss: 0.1842 - val_accuracy: 0.9260 - 385ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2202 - accuracy: 0.9117 - val_loss: 0.1842 - val_accuracy: 0.9240 - 373ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2202 - accuracy: 0.9118 - val_loss: 0.1841 - val_accuracy: 0.9240 - 380ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2201 - accuracy: 0.9118 - val_loss: 0.1841 - val_accuracy: 0.9240 - 369ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2201 - accuracy: 0.9118 - val_loss: 0.1841 - val_accuracy: 0.9240 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2200 - accuracy: 0.9118 - val_loss: 0.1840 - val_accuracy: 0.9240 - 363ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2200 - accuracy: 0.9118 - val_loss: 0.1840 - val_accuracy: 0.9240 - 381ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2199 - accuracy: 0.9118 - val_loss: 0.1840 - val_accuracy: 0.9240 - 359ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2199 - accuracy: 0.9119 - val_loss: 0.1839 - val_accuracy: 0.9240 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2198 - accuracy: 0.9118 - val_loss: 0.1838 - val_accuracy: 0.9240 - 410ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2198 - accuracy: 0.9119 - val_loss: 0.1838 - val_accuracy: 0.9240 - 370ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2197 - accuracy: 0.9120 - val_loss: 0.1837 - val_accuracy: 0.9240 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2197 - accuracy: 0.9121 - val_loss: 0.1837 - val_accuracy: 0.9240 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2196 - accuracy: 0.9121 - val_loss: 0.1836 - val_accuracy: 0.9240 - 387ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2196 - accuracy: 0.9122 - val_loss: 0.1836 - val_accuracy: 0.9240 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2195 - accuracy: 0.9122 - val_loss: 0.1835 - val_accuracy: 0.9240 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2195 - accuracy: 0.9122 - val_loss: 0.1835 - val_accuracy: 0.9240 - 354ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2194 - accuracy: 0.9123 - val_loss: 0.1835 - val_accuracy: 0.9240 - 463ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2194 - accuracy: 0.9123 - val_loss: 0.1834 - val_accuracy: 0.9240 - 384ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2193 - accuracy: 0.9122 - val_loss: 0.1834 - val_accuracy: 0.9260 - 360ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2193 - accuracy: 0.9121 - val_loss: 0.1833 - val_accuracy: 0.9260 - 349ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2192 - accuracy: 0.9121 - val_loss: 0.1833 - val_accuracy: 0.9260 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2192 - accuracy: 0.9121 - val_loss: 0.1833 - val_accuracy: 0.9260 - 373ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2192 - accuracy: 0.9121 - val_loss: 0.1832 - val_accuracy: 0.9260 - 354ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2191 - accuracy: 0.9121 - val_loss: 0.1832 - val_accuracy: 0.9260 - 358ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2191 - accuracy: 0.9122 - val_loss: 0.1832 - val_accuracy: 0.9260 - 416ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2190 - accuracy: 0.9124 - val_loss: 0.1832 - val_accuracy: 0.9260 - 355ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2190 - accuracy: 0.9125 - val_loss: 0.1832 - val_accuracy: 0.9260 - 370ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2189 - accuracy: 0.9126 - val_loss: 0.1831 - val_accuracy: 0.9260 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2189 - accuracy: 0.9126 - val_loss: 0.1831 - val_accuracy: 0.9260 - 364ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2189 - accuracy: 0.9126 - val_loss: 0.1830 - val_accuracy: 0.9260 - 378ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2188 - accuracy: 0.9128 - val_loss: 0.1830 - val_accuracy: 0.9260 - 392ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2188 - accuracy: 0.9126 - val_loss: 0.1830 - val_accuracy: 0.9260 - 422ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2187 - accuracy: 0.9126 - val_loss: 0.1829 - val_accuracy: 0.9260 - 345ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2187 - accuracy: 0.9127 - val_loss: 0.1829 - val_accuracy: 0.9260 - 369ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2187 - accuracy: 0.9128 - val_loss: 0.1828 - val_accuracy: 0.9260 - 359ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2186 - accuracy: 0.9127 - val_loss: 0.1828 - val_accuracy: 0.9260 - 375ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2186 - accuracy: 0.9127 - val_loss: 0.1827 - val_accuracy: 0.9260 - 374ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2185 - accuracy: 0.9126 - val_loss: 0.1827 - val_accuracy: 0.9260 - 344ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2185 - accuracy: 0.9126 - val_loss: 0.1827 - val_accuracy: 0.9260 - 379ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2185 - accuracy: 0.9126 - val_loss: 0.1826 - val_accuracy: 0.9260 - 391ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2184 - accuracy: 0.9126 - val_loss: 0.1826 - val_accuracy: 0.9260 - 440ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2184 - accuracy: 0.9127 - val_loss: 0.1826 - val_accuracy: 0.9240 - 392ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2183 - accuracy: 0.9128 - val_loss: 0.1825 - val_accuracy: 0.9240 - 367ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2183 - accuracy: 0.9128 - val_loss: 0.1825 - val_accuracy: 0.9260 - 395ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2183 - accuracy: 0.9128 - val_loss: 0.1825 - val_accuracy: 0.9260 - 362ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2182 - accuracy: 0.9129 - val_loss: 0.1824 - val_accuracy: 0.9260 - 351ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2182 - accuracy: 0.9129 - val_loss: 0.1824 - val_accuracy: 0.9260 - 353ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2182 - accuracy: 0.9131 - val_loss: 0.1824 - val_accuracy: 0.9280 - 539ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2181 - accuracy: 0.9130 - val_loss: 0.1823 - val_accuracy: 0.9300 - 293ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2181 - accuracy: 0.9131 - val_loss: 0.1823 - val_accuracy: 0.9300 - 430ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2181 - accuracy: 0.9129 - val_loss: 0.1823 - val_accuracy: 0.9300 - 346ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2180 - accuracy: 0.9131 - val_loss: 0.1823 - val_accuracy: 0.9300 - 366ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2180 - accuracy: 0.9131 - val_loss: 0.1822 - val_accuracy: 0.9300 - 341ms/epoch - 5ms/step
# 63/63 - 1s - loss: 0.2180 - accuracy: 0.9131 - val_loss: 0.1822 - val_accuracy: 0.9300 - 577ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2179 - accuracy: 0.9131 - val_loss: 0.1822 - val_accuracy: 0.9300 - 462ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2179 - accuracy: 0.9131 - val_loss: 0.1822 - val_accuracy: 0.9300 - 435ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2178 - accuracy: 0.9133 - val_loss: 0.1821 - val_accuracy: 0.9300 - 486ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2178 - accuracy: 0.9133 - val_loss: 0.1821 - val_accuracy: 0.9300 - 609ms/epoch - 10ms/step
# 63/63 - 0s - loss: 0.2178 - accuracy: 0.9132 - val_loss: 0.1820 - val_accuracy: 0.9300 - 466ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2177 - accuracy: 0.9133 - val_loss: 0.1820 - val_accuracy: 0.9300 - 429ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2177 - accuracy: 0.9132 - val_loss: 0.1819 - val_accuracy: 0.9300 - 473ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2177 - accuracy: 0.9133 - val_loss: 0.1819 - val_accuracy: 0.9300 - 549ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2176 - accuracy: 0.9131 - val_loss: 0.1818 - val_accuracy: 0.9300 - 414ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2176 - accuracy: 0.9133 - val_loss: 0.1818 - val_accuracy: 0.9300 - 414ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2176 - accuracy: 0.9133 - val_loss: 0.1818 - val_accuracy: 0.9300 - 425ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2176 - accuracy: 0.9132 - val_loss: 0.1817 - val_accuracy: 0.9300 - 428ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2175 - accuracy: 0.9134 - val_loss: 0.1817 - val_accuracy: 0.9300 - 438ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2175 - accuracy: 0.9134 - val_loss: 0.1816 - val_accuracy: 0.9300 - 462ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2175 - accuracy: 0.9135 - val_loss: 0.1816 - val_accuracy: 0.9300 - 418ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2174 - accuracy: 0.9134 - val_loss: 0.1816 - val_accuracy: 0.9300 - 457ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2174 - accuracy: 0.9135 - val_loss: 0.1815 - val_accuracy: 0.9300 - 457ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2174 - accuracy: 0.9135 - val_loss: 0.1815 - val_accuracy: 0.9300 - 472ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2173 - accuracy: 0.9135 - val_loss: 0.1815 - val_accuracy: 0.9300 - 487ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2173 - accuracy: 0.9136 - val_loss: 0.1814 - val_accuracy: 0.9300 - 520ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2173 - accuracy: 0.9136 - val_loss: 0.1814 - val_accuracy: 0.9300 - 413ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2172 - accuracy: 0.9136 - val_loss: 0.1814 - val_accuracy: 0.9320 - 400ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2172 - accuracy: 0.9137 - val_loss: 0.1813 - val_accuracy: 0.9300 - 450ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2172 - accuracy: 0.9137 - val_loss: 0.1812 - val_accuracy: 0.9300 - 555ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2172 - accuracy: 0.9137 - val_loss: 0.1812 - val_accuracy: 0.9300 - 444ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2171 - accuracy: 0.9137 - val_loss: 0.1812 - val_accuracy: 0.9300 - 346ms/epoch - 5ms/step
# 63/63 - 0s - loss: 0.2171 - accuracy: 0.9137 - val_loss: 0.1811 - val_accuracy: 0.9280 - 487ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2171 - accuracy: 0.9137 - val_loss: 0.1811 - val_accuracy: 0.9280 - 372ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2170 - accuracy: 0.9138 - val_loss: 0.1811 - val_accuracy: 0.9280 - 349ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2170 - accuracy: 0.9137 - val_loss: 0.1810 - val_accuracy: 0.9280 - 435ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2170 - accuracy: 0.9137 - val_loss: 0.1810 - val_accuracy: 0.9280 - 474ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2170 - accuracy: 0.9138 - val_loss: 0.1809 - val_accuracy: 0.9280 - 391ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2169 - accuracy: 0.9137 - val_loss: 0.1809 - val_accuracy: 0.9280 - 376ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2169 - accuracy: 0.9137 - val_loss: 0.1808 - val_accuracy: 0.9280 - 500ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2169 - accuracy: 0.9137 - val_loss: 0.1808 - val_accuracy: 0.9280 - 429ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2169 - accuracy: 0.9137 - val_loss: 0.1808 - val_accuracy: 0.9280 - 461ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2168 - accuracy: 0.9139 - val_loss: 0.1808 - val_accuracy: 0.9280 - 381ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2168 - accuracy: 0.9139 - val_loss: 0.1807 - val_accuracy: 0.9280 - 422ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2168 - accuracy: 0.9139 - val_loss: 0.1807 - val_accuracy: 0.9280 - 548ms/epoch - 9ms/step
# 63/63 - 1s - loss: 0.2168 - accuracy: 0.9140 - val_loss: 0.1806 - val_accuracy: 0.9280 - 509ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2167 - accuracy: 0.9141 - val_loss: 0.1806 - val_accuracy: 0.9280 - 394ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2167 - accuracy: 0.9140 - val_loss: 0.1806 - val_accuracy: 0.9280 - 520ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2167 - accuracy: 0.9140 - val_loss: 0.1805 - val_accuracy: 0.9280 - 384ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2167 - accuracy: 0.9141 - val_loss: 0.1805 - val_accuracy: 0.9280 - 472ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2166 - accuracy: 0.9140 - val_loss: 0.1805 - val_accuracy: 0.9280 - 491ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2166 - accuracy: 0.9141 - val_loss: 0.1804 - val_accuracy: 0.9280 - 421ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2166 - accuracy: 0.9141 - val_loss: 0.1804 - val_accuracy: 0.9280 - 501ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2166 - accuracy: 0.9141 - val_loss: 0.1803 - val_accuracy: 0.9280 - 411ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2165 - accuracy: 0.9143 - val_loss: 0.1803 - val_accuracy: 0.9280 - 596ms/epoch - 9ms/step
# 63/63 - 1s - loss: 0.2165 - accuracy: 0.9143 - val_loss: 0.1802 - val_accuracy: 0.9280 - 614ms/epoch - 10ms/step
# 63/63 - 0s - loss: 0.2165 - accuracy: 0.9143 - val_loss: 0.1802 - val_accuracy: 0.9280 - 423ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2165 - accuracy: 0.9143 - val_loss: 0.1802 - val_accuracy: 0.9280 - 396ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2164 - accuracy: 0.9142 - val_loss: 0.1801 - val_accuracy: 0.9280 - 509ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2164 - accuracy: 0.9143 - val_loss: 0.1801 - val_accuracy: 0.9280 - 507ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2164 - accuracy: 0.9143 - val_loss: 0.1801 - val_accuracy: 0.9280 - 490ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2164 - accuracy: 0.9143 - val_loss: 0.1800 - val_accuracy: 0.9280 - 432ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2164 - accuracy: 0.9143 - val_loss: 0.1800 - val_accuracy: 0.9280 - 488ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2163 - accuracy: 0.9143 - val_loss: 0.1799 - val_accuracy: 0.9280 - 554ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2163 - accuracy: 0.9144 - val_loss: 0.1799 - val_accuracy: 0.9280 - 429ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2163 - accuracy: 0.9145 - val_loss: 0.1799 - val_accuracy: 0.9280 - 559ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2163 - accuracy: 0.9144 - val_loss: 0.1798 - val_accuracy: 0.9280 - 495ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2162 - accuracy: 0.9145 - val_loss: 0.1798 - val_accuracy: 0.9280 - 512ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2162 - accuracy: 0.9144 - val_loss: 0.1798 - val_accuracy: 0.9280 - 485ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2162 - accuracy: 0.9144 - val_loss: 0.1797 - val_accuracy: 0.9280 - 490ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2162 - accuracy: 0.9144 - val_loss: 0.1797 - val_accuracy: 0.9280 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2162 - accuracy: 0.9144 - val_loss: 0.1797 - val_accuracy: 0.9280 - 415ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2161 - accuracy: 0.9144 - val_loss: 0.1797 - val_accuracy: 0.9280 - 402ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2161 - accuracy: 0.9144 - val_loss: 0.1797 - val_accuracy: 0.9280 - 550ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2161 - accuracy: 0.9144 - val_loss: 0.1796 - val_accuracy: 0.9280 - 440ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2161 - accuracy: 0.9146 - val_loss: 0.1796 - val_accuracy: 0.9280 - 682ms/epoch - 11ms/step
# 63/63 - 0s - loss: 0.2161 - accuracy: 0.9145 - val_loss: 0.1796 - val_accuracy: 0.9280 - 417ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2160 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9280 - 512ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2160 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9280 - 633ms/epoch - 10ms/step
# 63/63 - 1s - loss: 0.2160 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9260 - 608ms/epoch - 10ms/step
# 63/63 - 0s - loss: 0.2160 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9260 - 459ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2160 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9260 - 399ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2159 - accuracy: 0.9147 - val_loss: 0.1795 - val_accuracy: 0.9260 - 441ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2159 - accuracy: 0.9148 - val_loss: 0.1794 - val_accuracy: 0.9280 - 529ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2159 - accuracy: 0.9147 - val_loss: 0.1794 - val_accuracy: 0.9280 - 466ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2159 - accuracy: 0.9147 - val_loss: 0.1794 - val_accuracy: 0.9260 - 561ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2159 - accuracy: 0.9147 - val_loss: 0.1794 - val_accuracy: 0.9260 - 426ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2158 - accuracy: 0.9147 - val_loss: 0.1794 - val_accuracy: 0.9260 - 554ms/epoch - 9ms/step
# 63/63 - 1s - loss: 0.2158 - accuracy: 0.9146 - val_loss: 0.1794 - val_accuracy: 0.9280 - 655ms/epoch - 10ms/step
# 63/63 - 0s - loss: 0.2158 - accuracy: 0.9148 - val_loss: 0.1794 - val_accuracy: 0.9280 - 489ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2158 - accuracy: 0.9149 - val_loss: 0.1794 - val_accuracy: 0.9280 - 460ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2158 - accuracy: 0.9149 - val_loss: 0.1794 - val_accuracy: 0.9280 - 399ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2158 - accuracy: 0.9149 - val_loss: 0.1794 - val_accuracy: 0.9280 - 481ms/epoch - 8ms/step
# 63/63 - 1s - loss: 0.2157 - accuracy: 0.9150 - val_loss: 0.1794 - val_accuracy: 0.9280 - 544ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2157 - accuracy: 0.9151 - val_loss: 0.1793 - val_accuracy: 0.9280 - 490ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2157 - accuracy: 0.9151 - val_loss: 0.1793 - val_accuracy: 0.9280 - 406ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2157 - accuracy: 0.9150 - val_loss: 0.1793 - val_accuracy: 0.9280 - 377ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2157 - accuracy: 0.9150 - val_loss: 0.1793 - val_accuracy: 0.9280 - 453ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2156 - accuracy: 0.9151 - val_loss: 0.1792 - val_accuracy: 0.9280 - 610ms/epoch - 10ms/step
# 63/63 - 0s - loss: 0.2156 - accuracy: 0.9150 - val_loss: 0.1792 - val_accuracy: 0.9280 - 395ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2156 - accuracy: 0.9150 - val_loss: 0.1792 - val_accuracy: 0.9280 - 490ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2156 - accuracy: 0.9150 - val_loss: 0.1792 - val_accuracy: 0.9280 - 443ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2156 - accuracy: 0.9150 - val_loss: 0.1792 - val_accuracy: 0.9280 - 398ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2155 - accuracy: 0.9150 - val_loss: 0.1791 - val_accuracy: 0.9300 - 452ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2155 - accuracy: 0.9149 - val_loss: 0.1791 - val_accuracy: 0.9300 - 468ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2155 - accuracy: 0.9149 - val_loss: 0.1791 - val_accuracy: 0.9300 - 406ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2155 - accuracy: 0.9151 - val_loss: 0.1790 - val_accuracy: 0.9300 - 366ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2155 - accuracy: 0.9151 - val_loss: 0.1790 - val_accuracy: 0.9320 - 821ms/epoch - 13ms/step
# 63/63 - 0s - loss: 0.2154 - accuracy: 0.9151 - val_loss: 0.1790 - val_accuracy: 0.9320 - 442ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2154 - accuracy: 0.9151 - val_loss: 0.1789 - val_accuracy: 0.9320 - 350ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2154 - accuracy: 0.9151 - val_loss: 0.1789 - val_accuracy: 0.9320 - 748ms/epoch - 12ms/step
# 63/63 - 1s - loss: 0.2154 - accuracy: 0.9151 - val_loss: 0.1789 - val_accuracy: 0.9320 - 535ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2154 - accuracy: 0.9150 - val_loss: 0.1788 - val_accuracy: 0.9320 - 429ms/epoch - 7ms/step
# 63/63 - 0s - loss: 0.2154 - accuracy: 0.9149 - val_loss: 0.1788 - val_accuracy: 0.9320 - 414ms/epoch - 7ms/step
# 63/63 - 1s - loss: 0.2153 - accuracy: 0.9149 - val_loss: 0.1788 - val_accuracy: 0.9320 - 501ms/epoch - 8ms/step
# 63/63 - 0s - loss: 0.2153 - accuracy: 0.9148 - val_loss: 0.1788 - val_accuracy: 0.9320 - 348ms/epoch - 6ms/step
# 63/63 - 0s - loss: 0.2153 - accuracy: 0.9149 - val_loss: 0.1787 - val_accuracy: 0.9340 - 348ms/epoch - 6ms/step
# 63/63 - 1s - loss: 0.2153 - accuracy: 0.9148 - val_loss: 0.1787 - val_accuracy: 0.9340 - 558ms/epoch - 9ms/step
# 63/63 - 0s - loss: 0.2153 - accuracy: 0.9149 - val_loss: 0.1787 - val_accuracy: 0.9340 - 391ms/epoch - 6ms/step
# 16/16 - 0s - loss: 0.1787 - accuracy: 0.9340 - 75ms/epoch - 5ms/step
# 0.17870891094207764

# %% [markdown]
# 2. Store the loss for each training sample here. Important for this experiment

# %%
train_loss_values = unreduced_loss_fn(y_train, model.predict(X_train)).numpy()
# Out:
# 500/500 [==============================] - 1s 2ms/step

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC. One Loss list.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function ExactIHVP._compute_inv_hessian at 0x00000220D4728700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#        Train_ID     Score
# 0             1  0.044570
# 1             2  0.017578
# 2             3  0.004415
# 3             4  0.001811
# 4             5  0.001456
# ...         ...       ...
# 15995     15996  0.014304
# 15996     15997  0.002266
# 15997     15998  0.002202
# 15998     15999  0.008679
# 15999     16000  0.025855
#
# [16000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#        Train_ID     Score
# 0             1  0.000468
# 1             2  0.000112
# 2             3  0.000013
# 3             4  0.000008
# 4             5  0.000008
# ...         ...       ...
# 15995     15996  0.000107
# 15996     15997  0.000009
# 15997     15998  0.000008
# 15998     15999 -0.000001
# 15999     16000  0.000251
#
# [16000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing. Also, we store the previous loss list here.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("TC_Train_Set_5.csv",index = False)
df_sorted.to_csv("IF_Train_Set_5.csv",index = False)

# %%
df_train_loss = pd.DataFrame({
    'Train_ID': train_ids,
    'Loss': train_loss_values
}).sort_values('Loss', ascending=False).reset_index(drop=True)
print(df_train_loss)
# Out:
#        Train_ID      Loss
# 0          6972  7.204785
# 1          2957  6.317614
# 2          6845  6.046388
# 3         10931  5.822237
# 4          6296  5.725292
# ...         ...       ...
# 15995      1374  0.000029
# 15996      5547  0.000022
# 15997      3372  0.000021
# 15998     14420  0.000016
# 15999     12608  0.000007
#
# [16000 rows x 2 columns]

# %%
df_train_loss.to_csv("Train_Loss_Train_Set_5.csv",index = False)
