# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 16)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.504080  -0.000461   0.008391  -0.004641  -0.001005  -0.029330
# 1     -2.573542  -3.077104  -1.855017   2.405092  -3.763567  -2.006981
# 2     -0.407573   2.449514  -1.859132  -4.070366  -6.974439   2.027302
# 3      1.498563  -0.004092  -0.014200   0.000427   0.003398   0.006273
# 4      1.472679  -0.012297  -0.011575   0.006366  -0.005037  -0.013553
# ...         ...        ...        ...        ...        ...        ...
# 7995   1.504183   0.015915   0.008294  -0.010167   0.011209   0.000540
# 7996   1.491660  -0.004029  -0.028794  -0.003326  -0.005648   0.004682
# 7997   1.494893  -0.006226  -0.015111   0.024876  -0.012512  -0.010283
# 7998  -1.498779   0.012070   0.015826   0.000848  -0.003151   0.000662
# 7999   0.434434  -4.207816   1.157510   1.283868  -2.104350   1.600885
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id  \
# 0     -0.025058  -0.007742  -0.004886    0.017812      1     1    1_dense
# 1      3.055109  -0.914037   3.603618   -2.747288      1     2   1_sparse
# 2      2.311358   4.141956   1.188860    3.238050      1     3   1_sparse
# 3     -0.009570  -0.007836   0.001962    0.011104      1     4    1_dense
# 4     -0.028356  -0.005744   0.004790   -0.006941      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 7995   0.032171  -0.025249  -0.007417    0.008520      1  8496    1_dense
# 7996   0.010778  -0.001701   0.004292   -0.009874      0  8497    1_dense
# 7997   0.007008  -0.019355   0.005360   -0.020531      1  8498    1_dense
# 7998  -0.000948  -0.016570   0.015525    0.002458      0  8499    0_dense
# 7999   3.615849  -6.383889   4.504882   -0.601485      1  8500   1_sparse
#
#       clean_label  is_noisy  noisy_label
# 0               1         0            1
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               1         0            1
# ...           ...       ...          ...
# 7995            1         0            1
# 7996            1         1            0
# 7997            1         0            1
# 7998            0         0            0
# 7999            1         0            1
#
# [8000 rows x 16 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.255569    0.163209
# 1            2            1            1         0       0.688969    0.171920
# 2            3            1            1         0       0.971147   -0.103400
# 3            4            1            1         0       0.255532    0.163094
# 4            5            1            1         0       0.256884    0.167286
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.256298    0.165468
# 7996      8497            1            0         1       1.489454   -0.560176
# 7997      8498            1            1         0       0.255532    0.163094
# 7998      8499            0            0         0       0.230375    0.109717
# 7999      8500            1            1         0       0.473821    0.147292
#
#       TracIn_Score
# 0         0.006703
# 1        -0.030974
# 2        -0.003956
# 3         0.006685
# 4         0.006703
# ...            ...
# 7995      0.006678
# 7996     -0.021928
# 7997      0.006677
# 7998      0.018781
# 7999     -0.021889
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.255569    0.163209
# 1            2            1            1         0       0.688969    0.171920
# 2            3            1            1         0       0.971147   -0.103400
# 3            4            1            1         0       0.255532    0.163094
# 4            5            1            1         0       0.256884    0.167286
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.256298    0.165468
# 7996      8497            1            0         1       1.489454   -0.560176
# 7997      8498            1            1         0       0.255532    0.163094
# 7998      8499            0            0         0       0.230375    0.109717
# 7999      8500            1            1         0       0.473821    0.147292
#
#       TracIn_Score  Random_Score
# 0         0.006703      0.773956
# 1        -0.030974      0.438878
# 2        -0.003956      0.858598
# 3         0.006685      0.697368
# 4         0.006703      0.094177
# ...            ...           ...
# 7995      0.006678      0.339107
# 7996     -0.021928      0.135326
# 7997      0.006677      0.479135
# 7998      0.018781      0.232246
# 7999     -0.021889      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.20
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.2
# Removed samples: 1600
# Remaining samples: 6400

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 1102
# Noisy fraction among removed: 0.68875

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (6400, 11)
# (6400, 2)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 25/25 - 1s - loss: 0.7986 - accuracy: 0.5336 - val_loss: 0.7720 - val_accuracy: 0.5240 - 762ms/epoch - 30ms/step
# 25/25 - 0s - loss: 0.7214 - accuracy: 0.5800 - val_loss: 0.7107 - val_accuracy: 0.7960 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.6610 - accuracy: 0.7908 - val_loss: 0.6741 - val_accuracy: 0.8140 - 72ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.6182 - accuracy: 0.8238 - val_loss: 0.6441 - val_accuracy: 0.8140 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.5828 - accuracy: 0.8306 - val_loss: 0.6202 - val_accuracy: 0.8000 - 51ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.5535 - accuracy: 0.8369 - val_loss: 0.6015 - val_accuracy: 0.8020 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.5293 - accuracy: 0.8419 - val_loss: 0.5876 - val_accuracy: 0.8080 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.5088 - accuracy: 0.8458 - val_loss: 0.5772 - val_accuracy: 0.8120 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.4912 - accuracy: 0.8475 - val_loss: 0.5692 - val_accuracy: 0.8140 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4758 - accuracy: 0.8503 - val_loss: 0.5630 - val_accuracy: 0.8200 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4620 - accuracy: 0.8525 - val_loss: 0.5578 - val_accuracy: 0.8260 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4498 - accuracy: 0.8553 - val_loss: 0.5536 - val_accuracy: 0.8280 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4388 - accuracy: 0.8583 - val_loss: 0.5502 - val_accuracy: 0.8300 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4289 - accuracy: 0.8612 - val_loss: 0.5472 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.4199 - accuracy: 0.8616 - val_loss: 0.5445 - val_accuracy: 0.8280 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.4115 - accuracy: 0.8630 - val_loss: 0.5420 - val_accuracy: 0.8280 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4038 - accuracy: 0.8630 - val_loss: 0.5398 - val_accuracy: 0.8300 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3967 - accuracy: 0.8636 - val_loss: 0.5378 - val_accuracy: 0.8300 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3900 - accuracy: 0.8639 - val_loss: 0.5363 - val_accuracy: 0.8260 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3838 - accuracy: 0.8658 - val_loss: 0.5350 - val_accuracy: 0.8280 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3781 - accuracy: 0.8672 - val_loss: 0.5339 - val_accuracy: 0.8280 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3727 - accuracy: 0.8681 - val_loss: 0.5328 - val_accuracy: 0.8320 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3677 - accuracy: 0.8673 - val_loss: 0.5318 - val_accuracy: 0.8320 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3630 - accuracy: 0.8684 - val_loss: 0.5306 - val_accuracy: 0.8320 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3586 - accuracy: 0.8691 - val_loss: 0.5294 - val_accuracy: 0.8340 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3545 - accuracy: 0.8697 - val_loss: 0.5283 - val_accuracy: 0.8340 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3505 - accuracy: 0.8709 - val_loss: 0.5273 - val_accuracy: 0.8320 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3468 - accuracy: 0.8717 - val_loss: 0.5263 - val_accuracy: 0.8340 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3433 - accuracy: 0.8723 - val_loss: 0.5252 - val_accuracy: 0.8340 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.3400 - accuracy: 0.8731 - val_loss: 0.5243 - val_accuracy: 0.8340 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3368 - accuracy: 0.8734 - val_loss: 0.5236 - val_accuracy: 0.8340 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3338 - accuracy: 0.8736 - val_loss: 0.5227 - val_accuracy: 0.8320 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3310 - accuracy: 0.8731 - val_loss: 0.5218 - val_accuracy: 0.8300 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3282 - accuracy: 0.8730 - val_loss: 0.5210 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3256 - accuracy: 0.8739 - val_loss: 0.5201 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3231 - accuracy: 0.8742 - val_loss: 0.5194 - val_accuracy: 0.8280 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3208 - accuracy: 0.8736 - val_loss: 0.5188 - val_accuracy: 0.8260 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.3185 - accuracy: 0.8736 - val_loss: 0.5182 - val_accuracy: 0.8240 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3164 - accuracy: 0.8742 - val_loss: 0.5176 - val_accuracy: 0.8240 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3143 - accuracy: 0.8744 - val_loss: 0.5170 - val_accuracy: 0.8240 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3123 - accuracy: 0.8747 - val_loss: 0.5165 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3105 - accuracy: 0.8750 - val_loss: 0.5161 - val_accuracy: 0.8260 - 52ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3087 - accuracy: 0.8755 - val_loss: 0.5158 - val_accuracy: 0.8240 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3070 - accuracy: 0.8758 - val_loss: 0.5155 - val_accuracy: 0.8260 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3053 - accuracy: 0.8766 - val_loss: 0.5152 - val_accuracy: 0.8260 - 75ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3037 - accuracy: 0.8759 - val_loss: 0.5150 - val_accuracy: 0.8260 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3022 - accuracy: 0.8769 - val_loss: 0.5148 - val_accuracy: 0.8260 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3007 - accuracy: 0.8769 - val_loss: 0.5145 - val_accuracy: 0.8260 - 46ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2993 - accuracy: 0.8766 - val_loss: 0.5143 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2980 - accuracy: 0.8766 - val_loss: 0.5141 - val_accuracy: 0.8260 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2967 - accuracy: 0.8773 - val_loss: 0.5139 - val_accuracy: 0.8260 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2954 - accuracy: 0.8780 - val_loss: 0.5137 - val_accuracy: 0.8260 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2942 - accuracy: 0.8780 - val_loss: 0.5135 - val_accuracy: 0.8280 - 78ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2930 - accuracy: 0.8780 - val_loss: 0.5133 - val_accuracy: 0.8280 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2919 - accuracy: 0.8780 - val_loss: 0.5130 - val_accuracy: 0.8260 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2907 - accuracy: 0.8784 - val_loss: 0.5129 - val_accuracy: 0.8260 - 74ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2897 - accuracy: 0.8783 - val_loss: 0.5127 - val_accuracy: 0.8260 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2887 - accuracy: 0.8775 - val_loss: 0.5126 - val_accuracy: 0.8260 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2877 - accuracy: 0.8780 - val_loss: 0.5124 - val_accuracy: 0.8260 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2867 - accuracy: 0.8786 - val_loss: 0.5123 - val_accuracy: 0.8260 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2857 - accuracy: 0.8791 - val_loss: 0.5121 - val_accuracy: 0.8260 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2848 - accuracy: 0.8794 - val_loss: 0.5120 - val_accuracy: 0.8240 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2839 - accuracy: 0.8792 - val_loss: 0.5119 - val_accuracy: 0.8240 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2831 - accuracy: 0.8794 - val_loss: 0.5118 - val_accuracy: 0.8240 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2823 - accuracy: 0.8789 - val_loss: 0.5118 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2815 - accuracy: 0.8789 - val_loss: 0.5118 - val_accuracy: 0.8240 - 86ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2807 - accuracy: 0.8789 - val_loss: 0.5119 - val_accuracy: 0.8240 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2799 - accuracy: 0.8789 - val_loss: 0.5120 - val_accuracy: 0.8220 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2792 - accuracy: 0.8795 - val_loss: 0.5121 - val_accuracy: 0.8220 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2785 - accuracy: 0.8795 - val_loss: 0.5122 - val_accuracy: 0.8220 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2778 - accuracy: 0.8791 - val_loss: 0.5123 - val_accuracy: 0.8220 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2771 - accuracy: 0.8794 - val_loss: 0.5124 - val_accuracy: 0.8220 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2764 - accuracy: 0.8792 - val_loss: 0.5124 - val_accuracy: 0.8220 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2758 - accuracy: 0.8795 - val_loss: 0.5124 - val_accuracy: 0.8220 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2752 - accuracy: 0.8795 - val_loss: 0.5125 - val_accuracy: 0.8220 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2746 - accuracy: 0.8792 - val_loss: 0.5125 - val_accuracy: 0.8220 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2740 - accuracy: 0.8794 - val_loss: 0.5125 - val_accuracy: 0.8240 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2734 - accuracy: 0.8791 - val_loss: 0.5125 - val_accuracy: 0.8240 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2729 - accuracy: 0.8797 - val_loss: 0.5124 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2723 - accuracy: 0.8795 - val_loss: 0.5125 - val_accuracy: 0.8240 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2718 - accuracy: 0.8794 - val_loss: 0.5126 - val_accuracy: 0.8240 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2713 - accuracy: 0.8794 - val_loss: 0.5126 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2708 - accuracy: 0.8792 - val_loss: 0.5126 - val_accuracy: 0.8240 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2703 - accuracy: 0.8789 - val_loss: 0.5125 - val_accuracy: 0.8240 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2698 - accuracy: 0.8788 - val_loss: 0.5125 - val_accuracy: 0.8240 - 50ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2693 - accuracy: 0.8788 - val_loss: 0.5124 - val_accuracy: 0.8240 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2689 - accuracy: 0.8786 - val_loss: 0.5124 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2684 - accuracy: 0.8784 - val_loss: 0.5123 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2680 - accuracy: 0.8786 - val_loss: 0.5123 - val_accuracy: 0.8240 - 52ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2675 - accuracy: 0.8786 - val_loss: 0.5123 - val_accuracy: 0.8240 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2671 - accuracy: 0.8786 - val_loss: 0.5124 - val_accuracy: 0.8260 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2667 - accuracy: 0.8791 - val_loss: 0.5122 - val_accuracy: 0.8260 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2662 - accuracy: 0.8794 - val_loss: 0.5121 - val_accuracy: 0.8260 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2658 - accuracy: 0.8797 - val_loss: 0.5121 - val_accuracy: 0.8260 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2654 - accuracy: 0.8794 - val_loss: 0.5120 - val_accuracy: 0.8260 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2650 - accuracy: 0.8794 - val_loss: 0.5120 - val_accuracy: 0.8280 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2646 - accuracy: 0.8795 - val_loss: 0.5119 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2642 - accuracy: 0.8795 - val_loss: 0.5117 - val_accuracy: 0.8300 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2638 - accuracy: 0.8795 - val_loss: 0.5116 - val_accuracy: 0.8300 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2635 - accuracy: 0.8797 - val_loss: 0.5115 - val_accuracy: 0.8300 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2631 - accuracy: 0.8800 - val_loss: 0.5114 - val_accuracy: 0.8300 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2627 - accuracy: 0.8809 - val_loss: 0.5113 - val_accuracy: 0.8300 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2624 - accuracy: 0.8809 - val_loss: 0.5113 - val_accuracy: 0.8320 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2620 - accuracy: 0.8813 - val_loss: 0.5113 - val_accuracy: 0.8320 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2617 - accuracy: 0.8816 - val_loss: 0.5113 - val_accuracy: 0.8320 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2613 - accuracy: 0.8817 - val_loss: 0.5112 - val_accuracy: 0.8320 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2610 - accuracy: 0.8816 - val_loss: 0.5112 - val_accuracy: 0.8320 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2607 - accuracy: 0.8817 - val_loss: 0.5113 - val_accuracy: 0.8320 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2603 - accuracy: 0.8817 - val_loss: 0.5111 - val_accuracy: 0.8320 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2600 - accuracy: 0.8817 - val_loss: 0.5111 - val_accuracy: 0.8320 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2597 - accuracy: 0.8816 - val_loss: 0.5110 - val_accuracy: 0.8320 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2594 - accuracy: 0.8817 - val_loss: 0.5110 - val_accuracy: 0.8320 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2591 - accuracy: 0.8822 - val_loss: 0.5111 - val_accuracy: 0.8320 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2588 - accuracy: 0.8825 - val_loss: 0.5110 - val_accuracy: 0.8320 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2585 - accuracy: 0.8823 - val_loss: 0.5110 - val_accuracy: 0.8320 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2582 - accuracy: 0.8825 - val_loss: 0.5110 - val_accuracy: 0.8320 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2579 - accuracy: 0.8825 - val_loss: 0.5111 - val_accuracy: 0.8340 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2576 - accuracy: 0.8823 - val_loss: 0.5113 - val_accuracy: 0.8340 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2573 - accuracy: 0.8822 - val_loss: 0.5113 - val_accuracy: 0.8340 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2571 - accuracy: 0.8822 - val_loss: 0.5114 - val_accuracy: 0.8340 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2568 - accuracy: 0.8819 - val_loss: 0.5115 - val_accuracy: 0.8340 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2565 - accuracy: 0.8822 - val_loss: 0.5116 - val_accuracy: 0.8340 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2563 - accuracy: 0.8822 - val_loss: 0.5117 - val_accuracy: 0.8340 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2560 - accuracy: 0.8828 - val_loss: 0.5119 - val_accuracy: 0.8340 - 79ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2558 - accuracy: 0.8828 - val_loss: 0.5121 - val_accuracy: 0.8340 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2556 - accuracy: 0.8827 - val_loss: 0.5122 - val_accuracy: 0.8340 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2553 - accuracy: 0.8827 - val_loss: 0.5124 - val_accuracy: 0.8320 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2551 - accuracy: 0.8827 - val_loss: 0.5125 - val_accuracy: 0.8320 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2549 - accuracy: 0.8827 - val_loss: 0.5127 - val_accuracy: 0.8320 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2546 - accuracy: 0.8828 - val_loss: 0.5128 - val_accuracy: 0.8320 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2544 - accuracy: 0.8828 - val_loss: 0.5130 - val_accuracy: 0.8340 - 51ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2542 - accuracy: 0.8828 - val_loss: 0.5131 - val_accuracy: 0.8340 - 76ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2540 - accuracy: 0.8833 - val_loss: 0.5132 - val_accuracy: 0.8340 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2538 - accuracy: 0.8833 - val_loss: 0.5134 - val_accuracy: 0.8340 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2535 - accuracy: 0.8828 - val_loss: 0.5135 - val_accuracy: 0.8340 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2533 - accuracy: 0.8828 - val_loss: 0.5137 - val_accuracy: 0.8340 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2531 - accuracy: 0.8827 - val_loss: 0.5138 - val_accuracy: 0.8360 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2529 - accuracy: 0.8827 - val_loss: 0.5140 - val_accuracy: 0.8360 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2527 - accuracy: 0.8827 - val_loss: 0.5141 - val_accuracy: 0.8360 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2525 - accuracy: 0.8828 - val_loss: 0.5142 - val_accuracy: 0.8360 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2523 - accuracy: 0.8828 - val_loss: 0.5143 - val_accuracy: 0.8360 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2521 - accuracy: 0.8830 - val_loss: 0.5143 - val_accuracy: 0.8360 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2520 - accuracy: 0.8830 - val_loss: 0.5143 - val_accuracy: 0.8360 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2518 - accuracy: 0.8830 - val_loss: 0.5144 - val_accuracy: 0.8360 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2516 - accuracy: 0.8833 - val_loss: 0.5144 - val_accuracy: 0.8360 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2514 - accuracy: 0.8831 - val_loss: 0.5145 - val_accuracy: 0.8340 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2512 - accuracy: 0.8833 - val_loss: 0.5146 - val_accuracy: 0.8340 - 78ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2510 - accuracy: 0.8833 - val_loss: 0.5146 - val_accuracy: 0.8340 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2508 - accuracy: 0.8834 - val_loss: 0.5147 - val_accuracy: 0.8340 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2506 - accuracy: 0.8836 - val_loss: 0.5148 - val_accuracy: 0.8340 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2505 - accuracy: 0.8836 - val_loss: 0.5148 - val_accuracy: 0.8340 - 46ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2503 - accuracy: 0.8838 - val_loss: 0.5148 - val_accuracy: 0.8340 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2501 - accuracy: 0.8841 - val_loss: 0.5149 - val_accuracy: 0.8340 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2499 - accuracy: 0.8841 - val_loss: 0.5149 - val_accuracy: 0.8340 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2497 - accuracy: 0.8839 - val_loss: 0.5148 - val_accuracy: 0.8340 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2495 - accuracy: 0.8839 - val_loss: 0.5149 - val_accuracy: 0.8320 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2494 - accuracy: 0.8838 - val_loss: 0.5148 - val_accuracy: 0.8320 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2492 - accuracy: 0.8838 - val_loss: 0.5149 - val_accuracy: 0.8320 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2490 - accuracy: 0.8834 - val_loss: 0.5148 - val_accuracy: 0.8320 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2488 - accuracy: 0.8833 - val_loss: 0.5147 - val_accuracy: 0.8320 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2487 - accuracy: 0.8836 - val_loss: 0.5147 - val_accuracy: 0.8300 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2485 - accuracy: 0.8834 - val_loss: 0.5146 - val_accuracy: 0.8300 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2483 - accuracy: 0.8833 - val_loss: 0.5145 - val_accuracy: 0.8300 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2482 - accuracy: 0.8833 - val_loss: 0.5145 - val_accuracy: 0.8300 - 67ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2480 - accuracy: 0.8831 - val_loss: 0.5145 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2479 - accuracy: 0.8831 - val_loss: 0.5144 - val_accuracy: 0.8300 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2477 - accuracy: 0.8834 - val_loss: 0.5143 - val_accuracy: 0.8300 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2475 - accuracy: 0.8833 - val_loss: 0.5143 - val_accuracy: 0.8300 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2474 - accuracy: 0.8834 - val_loss: 0.5142 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2472 - accuracy: 0.8833 - val_loss: 0.5142 - val_accuracy: 0.8300 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2471 - accuracy: 0.8831 - val_loss: 0.5141 - val_accuracy: 0.8300 - 77ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2469 - accuracy: 0.8834 - val_loss: 0.5142 - val_accuracy: 0.8280 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2468 - accuracy: 0.8833 - val_loss: 0.5141 - val_accuracy: 0.8280 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2467 - accuracy: 0.8831 - val_loss: 0.5141 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2465 - accuracy: 0.8833 - val_loss: 0.5140 - val_accuracy: 0.8280 - 73ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2464 - accuracy: 0.8834 - val_loss: 0.5141 - val_accuracy: 0.8300 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2462 - accuracy: 0.8839 - val_loss: 0.5141 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2461 - accuracy: 0.8839 - val_loss: 0.5142 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2459 - accuracy: 0.8839 - val_loss: 0.5142 - val_accuracy: 0.8300 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2458 - accuracy: 0.8841 - val_loss: 0.5141 - val_accuracy: 0.8300 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2457 - accuracy: 0.8839 - val_loss: 0.5140 - val_accuracy: 0.8300 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2455 - accuracy: 0.8836 - val_loss: 0.5141 - val_accuracy: 0.8300 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2454 - accuracy: 0.8839 - val_loss: 0.5141 - val_accuracy: 0.8300 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2453 - accuracy: 0.8839 - val_loss: 0.5142 - val_accuracy: 0.8300 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2451 - accuracy: 0.8842 - val_loss: 0.5143 - val_accuracy: 0.8300 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2450 - accuracy: 0.8842 - val_loss: 0.5142 - val_accuracy: 0.8300 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2449 - accuracy: 0.8844 - val_loss: 0.5143 - val_accuracy: 0.8300 - 78ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2448 - accuracy: 0.8847 - val_loss: 0.5144 - val_accuracy: 0.8280 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2446 - accuracy: 0.8848 - val_loss: 0.5145 - val_accuracy: 0.8280 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2445 - accuracy: 0.8850 - val_loss: 0.5145 - val_accuracy: 0.8280 - 76ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2444 - accuracy: 0.8850 - val_loss: 0.5146 - val_accuracy: 0.8280 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2443 - accuracy: 0.8850 - val_loss: 0.5147 - val_accuracy: 0.8280 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2441 - accuracy: 0.8850 - val_loss: 0.5149 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2440 - accuracy: 0.8853 - val_loss: 0.5152 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2439 - accuracy: 0.8852 - val_loss: 0.5154 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2438 - accuracy: 0.8853 - val_loss: 0.5156 - val_accuracy: 0.8280 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2437 - accuracy: 0.8853 - val_loss: 0.5157 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2435 - accuracy: 0.8853 - val_loss: 0.5158 - val_accuracy: 0.8280 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2434 - accuracy: 0.8855 - val_loss: 0.5159 - val_accuracy: 0.8280 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2433 - accuracy: 0.8856 - val_loss: 0.5160 - val_accuracy: 0.8280 - 46ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2432 - accuracy: 0.8858 - val_loss: 0.5160 - val_accuracy: 0.8280 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2431 - accuracy: 0.8856 - val_loss: 0.5160 - val_accuracy: 0.8280 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2430 - accuracy: 0.8858 - val_loss: 0.5160 - val_accuracy: 0.8280 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2429 - accuracy: 0.8856 - val_loss: 0.5159 - val_accuracy: 0.8280 - 76ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2427 - accuracy: 0.8855 - val_loss: 0.5160 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2426 - accuracy: 0.8855 - val_loss: 0.5161 - val_accuracy: 0.8280 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2425 - accuracy: 0.8856 - val_loss: 0.5162 - val_accuracy: 0.8280 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2424 - accuracy: 0.8859 - val_loss: 0.5163 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2422 - accuracy: 0.8859 - val_loss: 0.5163 - val_accuracy: 0.8280 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2421 - accuracy: 0.8856 - val_loss: 0.5164 - val_accuracy: 0.8280 - 86ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2420 - accuracy: 0.8859 - val_loss: 0.5164 - val_accuracy: 0.8280 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2419 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8280 - 79ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2417 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8280 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2416 - accuracy: 0.8850 - val_loss: 0.5164 - val_accuracy: 0.8280 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2415 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8260 - 77ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2414 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8260 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2412 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8260 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2411 - accuracy: 0.8852 - val_loss: 0.5164 - val_accuracy: 0.8260 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2410 - accuracy: 0.8853 - val_loss: 0.5164 - val_accuracy: 0.8260 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2409 - accuracy: 0.8856 - val_loss: 0.5163 - val_accuracy: 0.8260 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2408 - accuracy: 0.8855 - val_loss: 0.5163 - val_accuracy: 0.8260 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2407 - accuracy: 0.8858 - val_loss: 0.5162 - val_accuracy: 0.8260 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2405 - accuracy: 0.8858 - val_loss: 0.5160 - val_accuracy: 0.8240 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2404 - accuracy: 0.8856 - val_loss: 0.5159 - val_accuracy: 0.8240 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2403 - accuracy: 0.8855 - val_loss: 0.5157 - val_accuracy: 0.8240 - 72ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2402 - accuracy: 0.8855 - val_loss: 0.5155 - val_accuracy: 0.8240 - 86ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2401 - accuracy: 0.8855 - val_loss: 0.5153 - val_accuracy: 0.8240 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2400 - accuracy: 0.8853 - val_loss: 0.5152 - val_accuracy: 0.8240 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2398 - accuracy: 0.8853 - val_loss: 0.5151 - val_accuracy: 0.8240 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2397 - accuracy: 0.8855 - val_loss: 0.5149 - val_accuracy: 0.8240 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2396 - accuracy: 0.8858 - val_loss: 0.5146 - val_accuracy: 0.8220 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2395 - accuracy: 0.8861 - val_loss: 0.5145 - val_accuracy: 0.8220 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2393 - accuracy: 0.8861 - val_loss: 0.5145 - val_accuracy: 0.8220 - 78ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2392 - accuracy: 0.8859 - val_loss: 0.5145 - val_accuracy: 0.8220 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2391 - accuracy: 0.8856 - val_loss: 0.5145 - val_accuracy: 0.8200 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2390 - accuracy: 0.8853 - val_loss: 0.5145 - val_accuracy: 0.8200 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2389 - accuracy: 0.8853 - val_loss: 0.5145 - val_accuracy: 0.8200 - 51ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2388 - accuracy: 0.8853 - val_loss: 0.5145 - val_accuracy: 0.8200 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2386 - accuracy: 0.8856 - val_loss: 0.5146 - val_accuracy: 0.8200 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2385 - accuracy: 0.8856 - val_loss: 0.5147 - val_accuracy: 0.8220 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2384 - accuracy: 0.8859 - val_loss: 0.5147 - val_accuracy: 0.8220 - 93ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2383 - accuracy: 0.8859 - val_loss: 0.5147 - val_accuracy: 0.8220 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2382 - accuracy: 0.8858 - val_loss: 0.5148 - val_accuracy: 0.8220 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2381 - accuracy: 0.8852 - val_loss: 0.5149 - val_accuracy: 0.8220 - 67ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2380 - accuracy: 0.8853 - val_loss: 0.5149 - val_accuracy: 0.8220 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2379 - accuracy: 0.8853 - val_loss: 0.5150 - val_accuracy: 0.8220 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2378 - accuracy: 0.8858 - val_loss: 0.5150 - val_accuracy: 0.8220 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2377 - accuracy: 0.8858 - val_loss: 0.5150 - val_accuracy: 0.8220 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2376 - accuracy: 0.8858 - val_loss: 0.5151 - val_accuracy: 0.8220 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2375 - accuracy: 0.8856 - val_loss: 0.5152 - val_accuracy: 0.8220 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2374 - accuracy: 0.8858 - val_loss: 0.5153 - val_accuracy: 0.8220 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2373 - accuracy: 0.8861 - val_loss: 0.5155 - val_accuracy: 0.8220 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2372 - accuracy: 0.8861 - val_loss: 0.5156 - val_accuracy: 0.8220 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2371 - accuracy: 0.8861 - val_loss: 0.5156 - val_accuracy: 0.8220 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2371 - accuracy: 0.8861 - val_loss: 0.5157 - val_accuracy: 0.8220 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2370 - accuracy: 0.8861 - val_loss: 0.5158 - val_accuracy: 0.8220 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2369 - accuracy: 0.8859 - val_loss: 0.5158 - val_accuracy: 0.8220 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2368 - accuracy: 0.8859 - val_loss: 0.5158 - val_accuracy: 0.8220 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2367 - accuracy: 0.8861 - val_loss: 0.5158 - val_accuracy: 0.8220 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2366 - accuracy: 0.8861 - val_loss: 0.5160 - val_accuracy: 0.8220 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2365 - accuracy: 0.8863 - val_loss: 0.5160 - val_accuracy: 0.8220 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2364 - accuracy: 0.8861 - val_loss: 0.5160 - val_accuracy: 0.8220 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2363 - accuracy: 0.8861 - val_loss: 0.5161 - val_accuracy: 0.8220 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2362 - accuracy: 0.8863 - val_loss: 0.5161 - val_accuracy: 0.8220 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2362 - accuracy: 0.8863 - val_loss: 0.5161 - val_accuracy: 0.8220 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2361 - accuracy: 0.8864 - val_loss: 0.5161 - val_accuracy: 0.8240 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2360 - accuracy: 0.8866 - val_loss: 0.5162 - val_accuracy: 0.8240 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2359 - accuracy: 0.8866 - val_loss: 0.5162 - val_accuracy: 0.8240 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2358 - accuracy: 0.8867 - val_loss: 0.5163 - val_accuracy: 0.8240 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2357 - accuracy: 0.8867 - val_loss: 0.5164 - val_accuracy: 0.8240 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2356 - accuracy: 0.8866 - val_loss: 0.5164 - val_accuracy: 0.8240 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2355 - accuracy: 0.8866 - val_loss: 0.5165 - val_accuracy: 0.8240 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2355 - accuracy: 0.8866 - val_loss: 0.5165 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2354 - accuracy: 0.8864 - val_loss: 0.5165 - val_accuracy: 0.8240 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2353 - accuracy: 0.8866 - val_loss: 0.5166 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2352 - accuracy: 0.8870 - val_loss: 0.5166 - val_accuracy: 0.8240 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2351 - accuracy: 0.8869 - val_loss: 0.5167 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2351 - accuracy: 0.8866 - val_loss: 0.5167 - val_accuracy: 0.8240 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2350 - accuracy: 0.8866 - val_loss: 0.5167 - val_accuracy: 0.8240 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2349 - accuracy: 0.8867 - val_loss: 0.5167 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2348 - accuracy: 0.8866 - val_loss: 0.5168 - val_accuracy: 0.8240 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2348 - accuracy: 0.8866 - val_loss: 0.5169 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2347 - accuracy: 0.8866 - val_loss: 0.5169 - val_accuracy: 0.8240 - 77ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2346 - accuracy: 0.8867 - val_loss: 0.5170 - val_accuracy: 0.8240 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2345 - accuracy: 0.8866 - val_loss: 0.5170 - val_accuracy: 0.8260 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2345 - accuracy: 0.8867 - val_loss: 0.5170 - val_accuracy: 0.8260 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2344 - accuracy: 0.8867 - val_loss: 0.5170 - val_accuracy: 0.8260 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2343 - accuracy: 0.8870 - val_loss: 0.5170 - val_accuracy: 0.8260 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2342 - accuracy: 0.8872 - val_loss: 0.5170 - val_accuracy: 0.8240 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2341 - accuracy: 0.8873 - val_loss: 0.5171 - val_accuracy: 0.8240 - 50ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2341 - accuracy: 0.8872 - val_loss: 0.5170 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2340 - accuracy: 0.8873 - val_loss: 0.5170 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2339 - accuracy: 0.8870 - val_loss: 0.5171 - val_accuracy: 0.8240 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2339 - accuracy: 0.8870 - val_loss: 0.5171 - val_accuracy: 0.8240 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2338 - accuracy: 0.8869 - val_loss: 0.5172 - val_accuracy: 0.8240 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2337 - accuracy: 0.8869 - val_loss: 0.5172 - val_accuracy: 0.8260 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2336 - accuracy: 0.8869 - val_loss: 0.5172 - val_accuracy: 0.8280 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2336 - accuracy: 0.8870 - val_loss: 0.5172 - val_accuracy: 0.8280 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2335 - accuracy: 0.8869 - val_loss: 0.5173 - val_accuracy: 0.8280 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2334 - accuracy: 0.8867 - val_loss: 0.5174 - val_accuracy: 0.8280 - 84ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.5174 - accuracy: 0.8280 - 29ms/epoch - 2ms/step
# 0.5174261927604675

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
