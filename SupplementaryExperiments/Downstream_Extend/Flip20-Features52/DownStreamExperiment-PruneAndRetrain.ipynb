# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 57)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -1.542923   2.947225   0.959419  -4.395205  -1.431741   1.939100
# 1     -2.521719  -2.689454   1.094643  -1.436749   6.080163  -1.356511
# 2      1.244477  -1.247769  -1.303517  -2.528068  -0.017037   2.762006
# 3      0.127356   2.841254   1.349793   0.405480  -0.140788   1.266193
# 4     -1.472171  -2.553477   1.029830   2.241359   1.358712   1.175452
# ...         ...        ...        ...        ...        ...        ...
# 7995  -6.329526  -3.406216  -2.799390  -1.034668   0.193200  -0.445982
# 7996  -0.842317  -1.796848  -0.847455   0.290313  -1.111715   2.241778
# 7997  -0.797864  -0.033538   0.111429  -0.144002  -0.018739   0.105129
# 7998  -1.170100  -2.263628   2.179277   0.276304  -2.013152   1.107240
# 7999   5.047530   0.848630   0.805674   1.241202  -1.222169  -1.830039
#
#       feature_7  feature_8  feature_9  feature_10  ...  feature_48  \
# 0     -0.194749  -2.570256  -4.340923   -0.555221  ...   -1.959670
# 1      1.943488  -2.596218  -1.325415    3.206086  ...   -0.566298
# 2      1.721536  -2.614666   2.227024   -0.212853  ...   -0.236819
# 3      0.973642  -0.967218   0.295457    0.047215  ...   -0.591571
# 4     -2.276574   0.730642   2.942305    1.150730  ...    1.353872
# ...         ...        ...        ...         ...  ...         ...
# 7995   0.061278  -0.187923   3.845442    1.560356  ...   -0.285662
# 7996  -2.925443   0.926865   1.199213   -0.314028  ...   -1.436003
# 7997   1.920124   5.079731  -2.499243    0.980655  ...   -1.539477
# 7998  -1.221108   0.488968   3.485159    3.221060  ...    0.479204
# 7999  -0.899922   3.429811   0.390903    3.840027  ...   -2.848113
#
#       feature_49  feature_50  feature_51  feature_52  label    id  \
# 0      -1.328186    0.196861    0.738467    0.171368      0     1
# 1       0.099651   -0.503476   -1.550663    0.068563      1     2
# 2      -0.485364    0.081874    2.314659   -1.867265      1     3
# 3       0.547097   -0.202193   -0.217681    1.098777      1     4
# 4      -0.114540    1.237816   -1.594428   -0.599375      0     5
# ...          ...         ...         ...         ...    ...   ...
# 7995   -0.140862   -0.739106    0.594273    1.076213      0  7996
# 7996    0.221133    0.821009   -1.198877    0.165275      1  7997
# 7997   -0.376490    1.173453    1.314604    0.360082      0  7998
# 7998   -0.730967    0.229680    0.961258   -0.959144      0  7999
# 7999    0.508410   -0.414804   -0.365487   -1.982037      0  8000
#
#       clean_label  is_noisy  noisy_label
# 0               0         0            0
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               0         0            0
# ...           ...       ...          ...
# 7995            0         0            0
# 7996            0         1            1
# 7997            0         0            0
# 7998            0         0            0
# 7999            0         0            0
#
# [8000 rows x 57 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            0            0         0       0.082718    0.162673
# 1            2            1            1         0       0.141169    0.193420
# 2            3            1            1         0       0.304665    0.245969
# 3            4            1            1         0       0.599408    0.231110
# 4            5            0            0         0       0.315456    0.204313
# ...        ...          ...          ...       ...            ...         ...
# 7995      7996            0            0         0       0.160876    0.323826
# 7996      7997            0            1         1       0.454101    0.227448
# 7997      7998            0            0         0       0.304615    0.318565
# 7998      7999            0            0         0       0.159375    0.256325
# 7999      8000            0            0         0       0.082865    0.130082
#
#       TracIn_Score
# 0         0.006024
# 1         0.015964
# 2         0.001933
# 3         0.018973
# 4         0.012374
# ...            ...
# 7995      0.003643
# 7996     -0.014449
# 7997      0.016202
# 7998     -0.001396
# 7999      0.014265
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            0            0         0       0.082718    0.162673
# 1            2            1            1         0       0.141169    0.193420
# 2            3            1            1         0       0.304665    0.245969
# 3            4            1            1         0       0.599408    0.231110
# 4            5            0            0         0       0.315456    0.204313
# ...        ...          ...          ...       ...            ...         ...
# 7995      7996            0            0         0       0.160876    0.323826
# 7996      7997            0            1         1       0.454101    0.227448
# 7997      7998            0            0         0       0.304615    0.318565
# 7998      7999            0            0         0       0.159375    0.256325
# 7999      8000            0            0         0       0.082865    0.130082
#
#       TracIn_Score  Random_Score
# 0         0.006024      0.773956
# 1         0.015964      0.438878
# 2         0.001933      0.858598
# 3         0.018973      0.697368
# 4         0.012374      0.094177
# ...            ...           ...
# 7995      0.003643      0.339107
# 7996     -0.014449      0.135326
# 7997      0.016202      0.479135
# 7998     -0.001396      0.232246
# 7999      0.014265      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.30
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.3
# Removed samples: 2400
# Remaining samples: 5600

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 1099
# Noisy fraction among removed: 0.4579166666666667

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (5600, 53)
# (5600, 2)

# %%
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 53)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 22/22 - 1s - loss: 0.9241 - accuracy: 0.5154 - val_loss: 0.8620 - val_accuracy: 0.4940 - 581ms/epoch - 26ms/step
# 22/22 - 0s - loss: 0.7810 - accuracy: 0.5462 - val_loss: 0.7736 - val_accuracy: 0.5160 - 52ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.6870 - accuracy: 0.5995 - val_loss: 0.7214 - val_accuracy: 0.5600 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.6318 - accuracy: 0.6491 - val_loss: 0.6887 - val_accuracy: 0.5940 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.5939 - accuracy: 0.6871 - val_loss: 0.6650 - val_accuracy: 0.6160 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.5640 - accuracy: 0.7132 - val_loss: 0.6466 - val_accuracy: 0.6300 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.5381 - accuracy: 0.7386 - val_loss: 0.6313 - val_accuracy: 0.6420 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.5145 - accuracy: 0.7568 - val_loss: 0.6182 - val_accuracy: 0.6540 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.4923 - accuracy: 0.7736 - val_loss: 0.6065 - val_accuracy: 0.6680 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.4712 - accuracy: 0.7877 - val_loss: 0.5960 - val_accuracy: 0.6720 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.4511 - accuracy: 0.8002 - val_loss: 0.5868 - val_accuracy: 0.6820 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.
ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0806 - accuracy: 0.9707 - val_loss: 0.8837 - val_accuracy: 0.7660 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0805 - accuracy: 0.9709 - val_loss: 0.8849 - val_accuracy: 0.7680 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0803 - accuracy: 0.9707 - val_loss: 0.8861 - val_accuracy: 0.7680 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0801 - accuracy: 0.9707 - val_loss: 0.8872 - val_accuracy: 0.7680 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0800 - accuracy: 0.9707 - val_loss: 0.8884 - val_accuracy: 0.7700 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0798 - accuracy: 0.9709 - val_loss: 0.8897 - val_accuracy: 0.7700 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0797 - accuracy: 0.9709 - val_loss: 0.8905 - val_accuracy: 0.7700 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0795 - accuracy: 0.9709 - val_loss: 0.8920 - val_accuracy: 0.7700 - 89ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0793 - accuracy: 0.9711 - val_loss: 0.8929 - val_accuracy: 0.7700 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0792 - accuracy: 0.9709 - val_loss: 0.8941 - val_accuracy: 0.7700 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0790 - accuracy: 0.9709 - val_loss: 0.8953 - val_accuracy: 0.7700 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0789 - accuracy: 0.9711 - val_loss: 0.8963 - val_accuracy: 0.7700 - 64ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0787 - accuracy: 0.9709 - val_loss: 0.8975 - val_accuracy: 0.7700 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0785 - accuracy: 0.9709 - val_loss: 0.8986 - val_accuracy: 0.7700 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0784 - accuracy: 0.9709 - val_loss: 0.8997 - val_accuracy: 0.7700 - 56ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0782 - accuracy: 0.9712 - val_loss: 0.9008 - val_accuracy: 0.7700 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0781 - accuracy: 0.9712 - val_loss: 0.9020 - val_accuracy: 0.7700 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0779 - accuracy: 0.9712 - val_loss: 0.9029 - val_accuracy: 0.7700 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0778 - accuracy: 0.9712 - val_loss: 0.9042 - val_accuracy: 0.7700 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0776 - accuracy: 0.9712 - val_loss: 0.9051 - val_accuracy: 0.7700 - 84ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0775 - accuracy: 0.9718 - val_loss: 0.9067 - val_accuracy: 0.7700 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0773 - accuracy: 0.9712 - val_loss: 0.9074 - val_accuracy: 0.7700 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0772 - accuracy: 0.9716 - val_loss: 0.9087 - val_accuracy: 0.7700 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0770 - accuracy: 0.9716 - val_loss: 0.9098 - val_accuracy: 0.7700 - 53ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0769 - accuracy: 0.9720 - val_loss: 0.9110 - val_accuracy: 0.7700 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0767 - accuracy: 0.9716 - val_loss: 0.9119 - val_accuracy: 0.7700 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0766 - accuracy: 0.9718 - val_loss: 0.9132 - val_accuracy: 0.7700 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0764 - accuracy: 0.9720 - val_loss: 0.9140 - val_accuracy: 0.7700 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0763 - accuracy: 0.9720 - val_loss: 0.9157 - val_accuracy: 0.7700 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0761 - accuracy: 0.9721 - val_loss: 0.9163 - val_accuracy: 0.7700 - 62ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0760 - accuracy: 0.9723 - val_loss: 0.9176 - val_accuracy: 0.7700 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0758 - accuracy: 0.9727 - val_loss: 0.9185 - val_accuracy: 0.7700 - 71ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0757 - accuracy: 0.9725 - val_loss: 0.9195 - val_accuracy: 0.7700 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0755 - accuracy: 0.9727 - val_loss: 0.9205 - val_accuracy: 0.7700 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0754 - accuracy: 0.9730 - val_loss: 0.9219 - val_accuracy: 0.7700 - 80ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0752 - accuracy: 0.9730 - val_loss: 0.9227 - val_accuracy: 0.7700 - 81ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0751 - accuracy: 0.9730 - val_loss: 0.9239 - val_accuracy: 0.7700 - 55ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0749 - accuracy: 0.9730 - val_loss: 0.9249 - val_accuracy: 0.7700 - 61ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0748 - accuracy: 0.9730 - val_loss: 0.9262 - val_accuracy: 0.7700 - 90ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0747 - accuracy: 0.9730 - val_loss: 0.9269 - val_accuracy: 0.7700 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0745 - accuracy: 0.9732 - val_loss: 0.9281 - val_accuracy: 0.7700 - 55ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0744 - accuracy: 0.9732 - val_loss: 0.9292 - val_accuracy: 0.7720 - 47ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0742 - accuracy: 0.9734 - val_loss: 0.9304 - val_accuracy: 0.7720 - 74ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0741 - accuracy: 0.9736 - val_loss: 0.9314 - val_accuracy: 0.7720 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0740 - accuracy: 0.9734 - val_loss: 0.9327 - val_accuracy: 0.7720 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0738 - accuracy: 0.9736 - val_loss: 0.9339 - val_accuracy: 0.7720 - 63ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0737 - accuracy: 0.9736 - val_loss: 0.9352 - val_accuracy: 0.7720 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0735 - accuracy: 0.9736 - val_loss: 0.9358 - val_accuracy: 0.7720 - 88ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0734 - accuracy: 0.9736 - val_loss: 0.9373 - val_accuracy: 0.7720 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0733 - accuracy: 0.9739 - val_loss: 0.9377 - val_accuracy: 0.7720 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0731 - accuracy: 0.9739 - val_loss: 0.9393 - val_accuracy: 0.7720 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0730 - accuracy: 0.9741 - val_loss: 0.9403 - val_accuracy: 0.7720 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0728 - accuracy: 0.9743 - val_loss: 0.9414 - val_accuracy: 0.7720 - 51ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0727 - accuracy: 0.9743 - val_loss: 0.9424 - val_accuracy: 0.7720 - 67ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0726 - accuracy: 0.9743 - val_loss: 0.9433 - val_accuracy: 0.7720 - 83ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0724 - accuracy: 0.9741 - val_loss: 0.9446 - val_accuracy: 0.7720 - 60ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0723 - accuracy: 0.9745 - val_loss: 0.9456 - val_accuracy: 0.7720 - 87ms/epoch - 4ms/step
# 22/22 - 0s - loss: 0.0721 - accuracy: 0.9745 - val_loss: 0.9465 - val_accuracy: 0.7720 - 54ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0720 - accuracy: 0.9748 - val_loss: 0.9479 - val_accuracy: 0.7720 - 58ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0719 - accuracy: 0.9750 - val_loss: 0.9487 - val_accuracy: 0.7720 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0717 - accuracy: 0.9748 - val_loss: 0.9496 - val_accuracy: 0.7720 - 50ms/epoch - 2ms/step
# 22/22 - 0s - loss: 0.0716 - accuracy: 0.9748 - val_loss: 0.9504 - val_accuracy: 0.7720 - 59ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0714 - accuracy: 0.9750 - val_loss: 0.9516 - val_accuracy: 0.7720 - 57ms/epoch - 3ms/step
# 22/22 - 0s - loss: 0.0713 - accuracy: 0.9748 - val_loss: 0.9529 - val_accuracy: 0.7720 - 62ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.9529 - accuracy: 0.7720 - 30ms/epoch - 2ms/step
# 0.9529251456260681

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
