# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %%
train_df_full = pd.read_csv("NoisyLabel_TrainingData.csv")
test_df = pd.read_csv("Clean_TestData.csv")

groundtruth = pd.read_csv("Noise_GroundTruth_and_TrainingLoss.csv")

foif_df = (
    pd.read_csv("NoisyLabel_FOIF_Scores.csv")
    .rename(columns={"Score": "FOIF_Score"})
)

tracin_df = (
    pd.read_csv("NoisyLabel_TracIn_Scores.csv")
    .rename(columns={"Score": "TracIn_Score"})
)

ranking_df = (
    groundtruth
    .merge(
        foif_df[["Train_ID", "FOIF_Score"]],
        on="Train_ID"
    )
    .merge(
        tracin_df[["Train_ID", "TracIn_Score"]],
        on="Train_ID"
    )
)

print(train_df_full.shape)
print(ranking_df.shape)
# Out:
# (8000, 16)
# (8000, 7)

# %%
print(train_df_full.head)
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.520401  -0.002305   0.041957  -0.023206  -0.005026  -0.146648
# 1     -1.215695  -2.051403  -1.236678   1.603395  -2.509045  -1.337987
# 2      0.228284   1.633010  -1.239421  -2.713577  -4.649626   1.351534
# 3      1.492814  -0.020460  -0.071002   0.002134   0.016991   0.031364
# 4      1.363394  -0.061487  -0.057876   0.031831  -0.025184  -0.067767
# ...         ...        ...        ...        ...        ...        ...
# 7995   1.520914   0.079577   0.041471  -0.050836   0.056044   0.002700
# 7996   1.458301  -0.020143  -0.143969  -0.016631  -0.028241   0.023412
# 7997   1.474463  -0.031130  -0.075557   0.124382  -0.062558  -0.051416
# 7998  -1.493895   0.060351   0.079131   0.004240  -0.015753   0.003309
# 7999   0.789623  -2.805211   0.771673   0.855912  -1.402900   1.067256
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id  \
# 0     -0.125289  -0.038709  -0.024428    0.089059      1     1    1_dense
# 1      2.036739  -0.609358   2.402412   -1.831525      1     2   1_sparse
# 2      1.540905   2.761304   0.792573    2.158700      1     3   1_sparse
# 3     -0.047852  -0.039181   0.009810    0.055521      1     4    1_dense
# 4     -0.141778  -0.028718   0.023950   -0.034707      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 7995   0.160855  -0.126243  -0.037087    0.042598      1  8496    1_dense
# 7996   0.053892  -0.008504   0.021460   -0.049369      0  8497    1_dense
# 7997   0.035041  -0.096774   0.026802   -0.102655      1  8498    1_dense
# 7998  -0.004739  -0.082848   0.077624    0.012289      0  8499    0_dense
# 7999   2.410566  -4.255926   3.003255   -0.400990      1  8500   1_sparse
#
#       clean_label  is_noisy  noisy_label
# 0               1         0            1
# 1               1         0            1
# 2               1         0            1
# 3               1         0            1
# 4               1         0            1
# ...           ...       ...          ...
# 7995            1         0            1
# 7996            1         1            0
# 7997            1         0            1
# 7998            0         0            0
# 7999            1         0            1
#
# [8000 rows x 16 columns]>
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.253127    0.244800
# 1            2            1            1         0       0.726266   -0.040638
# 2            3            1            1         0       0.701762    0.027229
# 3            4            1            1         0       0.250296    0.241008
# 4            5            1            1         0       0.252989    0.240168
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.249516    0.227912
# 7996      8497            1            0         1       1.506393   -0.791891
# 7997      8498            1            1         0       0.250336    0.224438
# 7998      8499            0            0         0       0.224250    0.164666
# 7999      8500            1            1         0       0.319284    0.318000
#
#       TracIn_Score
# 0         0.006162
# 1        -0.013262
# 2        -0.010094
# 3         0.005963
# 4         0.005228
# ...            ...
# 7995      0.005383
# 7996     -0.014270
# 7997      0.005413
# 7998      0.028937
# 7999      0.005826
#
# [8000 rows x 7 columns]>

# %%
random_baseline_seed = 42

rng = np.random.default_rng(random_baseline_seed)

ranking_df["Random_Score"] = rng.random(len(ranking_df))
print(ranking_df.head)
# Out:
# <bound method NDFrame.head of       Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss  FOIF_Score  \
# 0            1            1            1         0       0.253127    0.244800
# 1            2            1            1         0       0.726266   -0.040638
# 2            3            1            1         0       0.701762    0.027229
# 3            4            1            1         0       0.250296    0.241008
# 4            5            1            1         0       0.252989    0.240168
# ...        ...          ...          ...       ...            ...         ...
# 7995      8496            1            1         0       0.249516    0.227912
# 7996      8497            1            0         1       1.506393   -0.791891
# 7997      8498            1            1         0       0.250336    0.224438
# 7998      8499            0            0         0       0.224250    0.164666
# 7999      8500            1            1         0       0.319284    0.318000
#
#       TracIn_Score  Random_Score
# 0         0.006162      0.773956
# 1        -0.013262      0.438878
# 2        -0.010094      0.858598
# 3         0.005963      0.697368
# 4         0.005228      0.094177
# ...            ...           ...
# 7995      0.005383      0.339107
# 7996     -0.014270      0.135326
# 7997      0.005413      0.479135
# 7998      0.028937      0.232246
# 7999      0.005826      0.952072
#
# [8000 rows x 8 columns]>

# %%
# Change Here
method = "TracIn"
remove_fraction = 0.20
random_seed = 42

# %%
def select_ids_to_remove(
    ranking_df,
    method,
    remove_fraction,
    random_seed=42
):
    n_remove = int(len(ranking_df) * remove_fraction)

    if method == "Random":
        return (
            ranking_df
            .nsmallest(n_remove, "Random_Score")
            ["Train_ID"]
            .to_numpy()
        )

    if method == "Training Loss":
        return (
            ranking_df
            .nlargest(n_remove, "Training_Loss")["Train_ID"]
            .to_numpy()
        )

    if method == "FOIF":
        return (
            ranking_df
            .nsmallest(n_remove, "FOIF_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "TracIn":
        return (
            ranking_df
            .nsmallest(n_remove, "TracIn_Score")["Train_ID"]
            .to_numpy()
        )

    if method == "No Pruning":
        return np.array([], dtype=ranking_df["Train_ID"].dtype)

    raise ValueError(f"Unknown method: {method}")

# %%
remove_ids = select_ids_to_remove(
    ranking_df=ranking_df,
    method=method,
    remove_fraction=remove_fraction,
    random_seed=random_seed
)

train_df = (
    train_df_full[
        ~train_df_full["id"].isin(remove_ids)
    ]
    .copy()
    .reset_index(drop=True)
)

print("Method:", method)
print("Removal rate:", remove_fraction)
print("Removed samples:", len(remove_ids))
print("Remaining samples:", len(train_df))
# Out:
# Method: TracIn
# Removal rate: 0.2
# Removed samples: 1600
# Remaining samples: 6400

# %%
removed_info = ranking_df[
    ranking_df["Train_ID"].isin(remove_ids)
]

print(
    "Noisy samples among removed:",
    int(removed_info["is_noisy"].sum())
)

print(
    "Noisy fraction among removed:",
    removed_info["is_noisy"].mean()
)
# Out:
# Noisy samples among removed: 1122
# Noisy fraction among removed: 0.70125

# %%
selected_features = sorted(
    [
        col for col in train_df.columns
        if col.startswith("feature_")
    ],
    key=lambda col: int(col.split("_")[1])
)

train_ids_original = train_df["id"].to_numpy()

IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

X_train = np.hstack([
    X_train_features,
    IDs
])

y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (6400, 11)
# (6400, 2)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 25/25 - 1s - loss: 0.8039 - accuracy: 0.5494 - val_loss: 0.7432 - val_accuracy: 0.5460 - 768ms/epoch - 31ms/step
# 25/25 - 0s - loss: 0.6761 - accuracy: 0.6078 - val_loss: 0.6427 - val_accuracy: 0.7960 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.5852 - accuracy: 0.8172 - val_loss: 0.5920 - val_accuracy: 0.8380 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.5353 - accuracy: 0.8505 - val_loss: 0.5575 - val_accuracy: 0.8440 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4980 - accuracy: 0.8617 - val_loss: 0.5308 - val_accuracy: 0.8440 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4674 - accuracy: 0.8684 - val_loss: 0.5090 - val_accuracy: 0.8500 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.4414 - accuracy: 0.8745 - val_loss: 0.4901 - val_accuracy: 0.8460 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.4187 - accuracy: 0.8792 - val_loss: 0.4736 - val_accuracy: 0.8480 - 71ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3986 - accuracy: 0.8830 - val_loss: 0.4600 - val_accuracy: 0.8540 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.3811 - accuracy: 0.8844 - val_loss: 0.4487 - val_accuracy: 0.8620 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3661 - accuracy: 0.8875 - val_loss: 0.4393 - val_accuracy: 0.8660 - 52ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3531 - accuracy: 0.8886 - val_loss: 0.4315 - val_accuracy: 0.8680 - 51ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3417 - accuracy: 0.8889 - val_loss: 0.4250 - val_accuracy: 0.8660 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3317 - accuracy: 0.8894 - val_loss: 0.4196 - val_accuracy: 0.8660 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3227 - accuracy: 0.8909 - val_loss: 0.4151 - val_accuracy: 0.8640 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3147 - accuracy: 0.8925 - val_loss: 0.4113 - val_accuracy: 0.8680 - 73ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.3077 - accuracy: 0.8944 - val_loss: 0.4081 - val_accuracy: 0.8700 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.3014 - accuracy: 0.8953 - val_loss: 0.4055 - val_accuracy: 0.8720 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2958 - accuracy: 0.8955 - val_loss: 0.4034 - val_accuracy: 0.8740 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2908 - accuracy: 0.8967 - val_loss: 0.4017 - val_accuracy: 0.8720 - 44ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2864 - accuracy: 0.8983 - val_loss: 0.4003 - val_accuracy: 0.8720 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2825 - accuracy: 0.8983 - val_loss: 0.3991 - val_accuracy: 0.8720 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2789 - accuracy: 0.8983 - val_loss: 0.3981 - val_accuracy: 0.8720 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2758 - accuracy: 0.8986 - val_loss: 0.3972 - val_accuracy: 0.8720 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2730 - accuracy: 0.8984 - val_loss: 0.3965 - val_accuracy: 0.8720 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2704 - accuracy: 0.8986 - val_loss: 0.3959 - val_accuracy: 0.8720 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2682 - accuracy: 0.8988 - val_loss: 0.3953 - val_accuracy: 0.8700 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2661 - accuracy: 0.8989 - val_loss: 0.3947 - val_accuracy: 0.8700 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2642 - accuracy: 0.8989 - val_loss: 0.3942 - val_accuracy: 0.8700 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2625 - accuracy: 0.8995 - val_loss: 0.3937 - val_accuracy: 0.8720 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2609 - accuracy: 0.8992 - val_loss: 0.3933 - val_accuracy: 0.8700 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2595 - accuracy: 0.8994 - val_loss: 0.3928 - val_accuracy: 0.8700 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2581 - accuracy: 0.8991 - val_loss: 0.3924 - val_accuracy: 0.8700 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2569 - accuracy: 0.8997 - val_loss: 0.3919 - val_accuracy: 0.8700 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2557 - accuracy: 0.8995 - val_loss: 0.3914 - val_accuracy: 0.8680 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2545 - accuracy: 0.8997 - val_loss: 0.3911 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2535 - accuracy: 0.9000 - val_loss: 0.3907 - val_accuracy: 0.8680 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2524 - accuracy: 0.9002 - val_loss: 0.3903 - val_accuracy: 0.8680 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2515 - accuracy: 0.9002 - val_loss: 0.3899 - val_accuracy: 0.8680 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2505 - accuracy: 0.9002 - val_loss: 0.3894 - val_accuracy: 0.8700 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2496 - accuracy: 0.9006 - val_loss: 0.3889 - val_accuracy: 0.8720 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2488 - accuracy: 0.9005 - val_loss: 0.3884 - val_accuracy: 0.8700 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2480 - accuracy: 0.8998 - val_loss: 0.3880 - val_accuracy: 0.8700 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2472 - accuracy: 0.9003 - val_loss: 0.3875 - val_accuracy: 0.8700 - 51ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2465 - accuracy: 0.9006 - val_loss: 0.3871 - val_accuracy: 0.8700 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2457 - accuracy: 0.9008 - val_loss: 0.3866 - val_accuracy: 0.8700 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2451 - accuracy: 0.9008 - val_loss: 0.3863 - val_accuracy: 0.8680 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2444 - accuracy: 0.9011 - val_loss: 0.3858 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2437 - accuracy: 0.9013 - val_loss: 0.3852 - val_accuracy: 0.8660 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2431 - accuracy: 0.9013 - val_loss: 0.3847 - val_accuracy: 0.8660 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2425 - accuracy: 0.9013 - val_loss: 0.3843 - val_accuracy: 0.8660 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2420 - accuracy: 0.9020 - val_loss: 0.3838 - val_accuracy: 0.8660 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2414 - accuracy: 0.9023 - val_loss: 0.3835 - val_accuracy: 0.8660 - 68ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2409 - accuracy: 0.9027 - val_loss: 0.3832 - val_accuracy: 0.8660 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2404 - accuracy: 0.9028 - val_loss: 0.3829 - val_accuracy: 0.8660 - 75ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2399 - accuracy: 0.9030 - val_loss: 0.3826 - val_accuracy: 0.8680 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2394 - accuracy: 0.9033 - val_loss: 0.3823 - val_accuracy: 0.8680 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2390 - accuracy: 0.9031 - val_loss: 0.3820 - val_accuracy: 0.8680 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2385 - accuracy: 0.9033 - val_loss: 0.3816 - val_accuracy: 0.8680 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2381 - accuracy: 0.9031 - val_loss: 0.3810 - val_accuracy: 0.8680 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2376 - accuracy: 0.9030 - val_loss: 0.3805 - val_accuracy: 0.8680 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2372 - accuracy: 0.9031 - val_loss: 0.3801 - val_accuracy: 0.8660 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2368 - accuracy: 0.9030 - val_loss: 0.3797 - val_accuracy: 0.8660 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2364 - accuracy: 0.9028 - val_loss: 0.3793 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2360 - accuracy: 0.9033 - val_loss: 0.3791 - val_accuracy: 0.8700 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2357 - accuracy: 0.9034 - val_loss: 0.3788 - val_accuracy: 0.8700 - 86ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2353 - accuracy: 0.9033 - val_loss: 0.3786 - val_accuracy: 0.8700 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2350 - accuracy: 0.9036 - val_loss: 0.3784 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2346 - accuracy: 0.9041 - val_loss: 0.3781 - val_accuracy: 0.8680 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2343 - accuracy: 0.9042 - val_loss: 0.3778 - val_accuracy: 0.8680 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2340 - accuracy: 0.9048 - val_loss: 0.3776 - val_accuracy: 0.8680 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2337 - accuracy: 0.9050 - val_loss: 0.3773 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2334 - accuracy: 0.9045 - val_loss: 0.3771 - val_accuracy: 0.8680 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2331 - accuracy: 0.9044 - val_loss: 0.3768 - val_accuracy: 0.8680 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2328 - accuracy: 0.9044 - val_loss: 0.3765 - val_accuracy: 0.8680 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2326 - accuracy: 0.9039 - val_loss: 0.3762 - val_accuracy: 0.8680 - 75ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2323 - accuracy: 0.9039 - val_loss: 0.3759 - val_accuracy: 0.8680 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2320 - accuracy: 0.9039 - val_loss: 0.3756 - val_accuracy: 0.8680 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2318 - accuracy: 0.9039 - val_loss: 0.3754 - val_accuracy: 0.8680 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2315 - accuracy: 0.9039 - val_loss: 0.3752 - val_accuracy: 0.8700 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2313 - accuracy: 0.9036 - val_loss: 0.3751 - val_accuracy: 0.8700 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2310 - accuracy: 0.9036 - val_loss: 0.3750 - val_accuracy: 0.8700 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2308 - accuracy: 0.9038 - val_loss: 0.3749 - val_accuracy: 0.8700 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2305 - accuracy: 0.9044 - val_loss: 0.3749 - val_accuracy: 0.8700 - 44ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2303 - accuracy: 0.9041 - val_loss: 0.3749 - val_accuracy: 0.8700 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2301 - accuracy: 0.9041 - val_loss: 0.3749 - val_accuracy: 0.8680 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2299 - accuracy: 0.9039 - val_loss: 0.3749 - val_accuracy: 0.8680 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2296 - accuracy: 0.9042 - val_loss: 0.3749 - val_accuracy: 0.8680 - 79ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2294 - accuracy: 0.9042 - val_loss: 0.3750 - val_accuracy: 0.8680 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2292 - accuracy: 0.9042 - val_loss: 0.3750 - val_accuracy: 0.8680 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2290 - accuracy: 0.9044 - val_loss: 0.3751 - val_accuracy: 0.8660 - 76ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2288 - accuracy: 0.9047 - val_loss: 0.3752 - val_accuracy: 0.8660 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2286 - accuracy: 0.9053 - val_loss: 0.3752 - val_accuracy: 0.8660 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2284 - accuracy: 0.9053 - val_loss: 0.3752 - val_accuracy: 0.8640 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2282 - accuracy: 0.9052 - val_loss: 0.3752 - val_accuracy: 0.8640 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2280 - accuracy: 0.9053 - val_loss: 0.3753 - val_accuracy: 0.8640 - 77ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2278 - accuracy: 0.9056 - val_loss: 0.3753 - val_accuracy: 0.8640 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2276 - accuracy: 0.9053 - val_loss: 0.3754 - val_accuracy: 0.8640 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2275 - accuracy: 0.9053 - val_loss: 0.3754 - val_accuracy: 0.8620 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2273 - accuracy: 0.9056 - val_loss: 0.3754 - val_accuracy: 0.8580 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2271 - accuracy: 0.9058 - val_loss: 0.3754 - val_accuracy: 0.8580 - 73ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2269 - accuracy: 0.9058 - val_loss: 0.3754 - val_accuracy: 0.8580 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2268 - accuracy: 0.9056 - val_loss: 0.3754 - val_accuracy: 0.8580 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2266 - accuracy: 0.9056 - val_loss: 0.3754 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2264 - accuracy: 0.9055 - val_loss: 0.3754 - val_accuracy: 0.8580 - 50ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2263 - accuracy: 0.9052 - val_loss: 0.3754 - val_accuracy: 0.8580 - 88ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2261 - accuracy: 0.9048 - val_loss: 0.3753 - val_accuracy: 0.8580 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2260 - accuracy: 0.9047 - val_loss: 0.3753 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2258 - accuracy: 0.9048 - val_loss: 0.3753 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2257 - accuracy: 0.9050 - val_loss: 0.3754 - val_accuracy: 0.8580 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2256 - accuracy: 0.9052 - val_loss: 0.3754 - val_accuracy: 0.8580 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2254 - accuracy: 0.9052 - val_loss: 0.3754 - val_accuracy: 0.8580 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2253 - accuracy: 0.9055 - val_loss: 0.3754 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2252 - accuracy: 0.9055 - val_loss: 0.3754 - val_accuracy: 0.8580 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2251 - accuracy: 0.9055 - val_loss: 0.3754 - val_accuracy: 0.8600 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2249 - accuracy: 0.9055 - val_loss: 0.3755 - val_accuracy: 0.8600 - 92ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2248 - accuracy: 0.9055 - val_loss: 0.3755 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2247 - accuracy: 0.9055 - val_loss: 0.3756 - val_accuracy: 0.8600 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2246 - accuracy: 0.9055 - val_loss: 0.3756 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2244 - accuracy: 0.9055 - val_loss: 0.3758 - val_accuracy: 0.8600 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2243 - accuracy: 0.9055 - val_loss: 0.3759 - val_accuracy: 0.8600 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2242 - accuracy: 0.9056 - val_loss: 0.3760 - val_accuracy: 0.8600 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2241 - accuracy: 0.9056 - val_loss: 0.3761 - val_accuracy: 0.8600 - 52ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2240 - accuracy: 0.9058 - val_loss: 0.3761 - val_accuracy: 0.8600 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2239 - accuracy: 0.9059 - val_loss: 0.3762 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2238 - accuracy: 0.9061 - val_loss: 0.3763 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2237 - accuracy: 0.9061 - val_loss: 0.3764 - val_accuracy: 0.8600 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2236 - accuracy: 0.9062 - val_loss: 0.3764 - val_accuracy: 0.8600 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2235 - accuracy: 0.9062 - val_loss: 0.3765 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2234 - accuracy: 0.9061 - val_loss: 0.3765 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2233 - accuracy: 0.9061 - val_loss: 0.3766 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2232 - accuracy: 0.9061 - val_loss: 0.3766 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2231 - accuracy: 0.9061 - val_loss: 0.3766 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2230 - accuracy: 0.9058 - val_loss: 0.3767 - val_accuracy: 0.8600 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2229 - accuracy: 0.9059 - val_loss: 0.3768 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2229 - accuracy: 0.9059 - val_loss: 0.3768 - val_accuracy: 0.8600 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2228 - accuracy: 0.9058 - val_loss: 0.3768 - val_accuracy: 0.8600 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2227 - accuracy: 0.9058 - val_loss: 0.3769 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2226 - accuracy: 0.9059 - val_loss: 0.3769 - val_accuracy: 0.8600 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2225 - accuracy: 0.9059 - val_loss: 0.3770 - val_accuracy: 0.8600 - 49ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2224 - accuracy: 0.9059 - val_loss: 0.3771 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2223 - accuracy: 0.9059 - val_loss: 0.3772 - val_accuracy: 0.8600 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2222 - accuracy: 0.9058 - val_loss: 0.3773 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2222 - accuracy: 0.9056 - val_loss: 0.3775 - val_accuracy: 0.8600 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2221 - accuracy: 0.9058 - val_loss: 0.3776 - val_accuracy: 0.8600 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2220 - accuracy: 0.9058 - val_loss: 0.3777 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2219 - accuracy: 0.9059 - val_loss: 0.3777 - val_accuracy: 0.8600 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2218 - accuracy: 0.9059 - val_loss: 0.3778 - val_accuracy: 0.8600 - 67ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2217 - accuracy: 0.9059 - val_loss: 0.3778 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2217 - accuracy: 0.9055 - val_loss: 0.3779 - val_accuracy: 0.8600 - 68ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2216 - accuracy: 0.9058 - val_loss: 0.3780 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2215 - accuracy: 0.9058 - val_loss: 0.3780 - val_accuracy: 0.8600 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2214 - accuracy: 0.9059 - val_loss: 0.3781 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2213 - accuracy: 0.9061 - val_loss: 0.3782 - val_accuracy: 0.8600 - 70ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2213 - accuracy: 0.9066 - val_loss: 0.3784 - val_accuracy: 0.8600 - 69ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2212 - accuracy: 0.9066 - val_loss: 0.3785 - val_accuracy: 0.8600 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2211 - accuracy: 0.9064 - val_loss: 0.3787 - val_accuracy: 0.8600 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2210 - accuracy: 0.9064 - val_loss: 0.3789 - val_accuracy: 0.8600 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2209 - accuracy: 0.9062 - val_loss: 0.3790 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2208 - accuracy: 0.9062 - val_loss: 0.3790 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2208 - accuracy: 0.9064 - val_loss: 0.3791 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2207 - accuracy: 0.9064 - val_loss: 0.3792 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2206 - accuracy: 0.9066 - val_loss: 0.3793 - val_accuracy: 0.8600 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2205 - accuracy: 0.9066 - val_loss: 0.3793 - val_accuracy: 0.8600 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2205 - accuracy: 0.9067 - val_loss: 0.3794 - val_accuracy: 0.8600 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2204 - accuracy: 0.9067 - val_loss: 0.3794 - val_accuracy: 0.8600 - 48ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2203 - accuracy: 0.9067 - val_loss: 0.3795 - val_accuracy: 0.8600 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2202 - accuracy: 0.9069 - val_loss: 0.3795 - val_accuracy: 0.8620 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2202 - accuracy: 0.9070 - val_loss: 0.3796 - val_accuracy: 0.8620 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2201 - accuracy: 0.9070 - val_loss: 0.3797 - val_accuracy: 0.8620 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2200 - accuracy: 0.9070 - val_loss: 0.3799 - val_accuracy: 0.8620 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2199 - accuracy: 0.9070 - val_loss: 0.3800 - val_accuracy: 0.8620 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2199 - accuracy: 0.9072 - val_loss: 0.3800 - val_accuracy: 0.8620 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2198 - accuracy: 0.9073 - val_loss: 0.3801 - val_accuracy: 0.8620 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2197 - accuracy: 0.9073 - val_loss: 0.3802 - val_accuracy: 0.8620 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2196 - accuracy: 0.9077 - val_loss: 0.3803 - val_accuracy: 0.8620 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2195 - accuracy: 0.9077 - val_loss: 0.3803 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2195 - accuracy: 0.9077 - val_loss: 0.3804 - val_accuracy: 0.8620 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2194 - accuracy: 0.9077 - val_loss: 0.3805 - val_accuracy: 0.8620 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2193 - accuracy: 0.9077 - val_loss: 0.3807 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2193 - accuracy: 0.9080 - val_loss: 0.3807 - val_accuracy: 0.8620 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2192 - accuracy: 0.9081 - val_loss: 0.3809 - val_accuracy: 0.8620 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2191 - accuracy: 0.9083 - val_loss: 0.3810 - val_accuracy: 0.8620 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2190 - accuracy: 0.9084 - val_loss: 0.3811 - val_accuracy: 0.8620 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2190 - accuracy: 0.9083 - val_loss: 0.3812 - val_accuracy: 0.8620 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2189 - accuracy: 0.9081 - val_loss: 0.3812 - val_accuracy: 0.8620 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2188 - accuracy: 0.9081 - val_loss: 0.3813 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2188 - accuracy: 0.9084 - val_loss: 0.3815 - val_accuracy: 0.8620 - 46ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2187 - accuracy: 0.9084 - val_loss: 0.3816 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2186 - accuracy: 0.9083 - val_loss: 0.3817 - val_accuracy: 0.8620 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2185 - accuracy: 0.9086 - val_loss: 0.3818 - val_accuracy: 0.8620 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2185 - accuracy: 0.9086 - val_loss: 0.3818 - val_accuracy: 0.8620 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2184 - accuracy: 0.9086 - val_loss: 0.3819 - val_accuracy: 0.8600 - 50ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2183 - accuracy: 0.9086 - val_loss: 0.3820 - val_accuracy: 0.8600 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2182 - accuracy: 0.9084 - val_loss: 0.3821 - val_accuracy: 0.8620 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2182 - accuracy: 0.9086 - val_loss: 0.3821 - val_accuracy: 0.8620 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2181 - accuracy: 0.9086 - val_loss: 0.3822 - val_accuracy: 0.8620 - 68ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2180 - accuracy: 0.9087 - val_loss: 0.3822 - val_accuracy: 0.8620 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2180 - accuracy: 0.9087 - val_loss: 0.3823 - val_accuracy: 0.8620 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2179 - accuracy: 0.9091 - val_loss: 0.3824 - val_accuracy: 0.8620 - 48ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2179 - accuracy: 0.9092 - val_loss: 0.3825 - val_accuracy: 0.8620 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2178 - accuracy: 0.9092 - val_loss: 0.3827 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2177 - accuracy: 0.9094 - val_loss: 0.3827 - val_accuracy: 0.8620 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2177 - accuracy: 0.9095 - val_loss: 0.3829 - val_accuracy: 0.8620 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2176 - accuracy: 0.9094 - val_loss: 0.3830 - val_accuracy: 0.8620 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2175 - accuracy: 0.9097 - val_loss: 0.3831 - val_accuracy: 0.8620 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2175 - accuracy: 0.9100 - val_loss: 0.3831 - val_accuracy: 0.8620 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2174 - accuracy: 0.9095 - val_loss: 0.3833 - val_accuracy: 0.8620 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2174 - accuracy: 0.9098 - val_loss: 0.3834 - val_accuracy: 0.8620 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2173 - accuracy: 0.9102 - val_loss: 0.3834 - val_accuracy: 0.8620 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2172 - accuracy: 0.9102 - val_loss: 0.3835 - val_accuracy: 0.8620 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2172 - accuracy: 0.9103 - val_loss: 0.3836 - val_accuracy: 0.8620 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2171 - accuracy: 0.9103 - val_loss: 0.3837 - val_accuracy: 0.8620 - 74ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2170 - accuracy: 0.9102 - val_loss: 0.3838 - val_accuracy: 0.8620 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2170 - accuracy: 0.9102 - val_loss: 0.3840 - val_accuracy: 0.8600 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2169 - accuracy: 0.9102 - val_loss: 0.3841 - val_accuracy: 0.8580 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2169 - accuracy: 0.9102 - val_loss: 0.3843 - val_accuracy: 0.8580 - 87ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2168 - accuracy: 0.9105 - val_loss: 0.3844 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2168 - accuracy: 0.9106 - val_loss: 0.3845 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2167 - accuracy: 0.9106 - val_loss: 0.3846 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2166 - accuracy: 0.9106 - val_loss: 0.3848 - val_accuracy: 0.8580 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2166 - accuracy: 0.9106 - val_loss: 0.3850 - val_accuracy: 0.8580 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2165 - accuracy: 0.9105 - val_loss: 0.3851 - val_accuracy: 0.8580 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2165 - accuracy: 0.9106 - val_loss: 0.3853 - val_accuracy: 0.8580 - 84ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2164 - accuracy: 0.9103 - val_loss: 0.3854 - val_accuracy: 0.8580 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2164 - accuracy: 0.9105 - val_loss: 0.3856 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2163 - accuracy: 0.9105 - val_loss: 0.3858 - val_accuracy: 0.8580 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2163 - accuracy: 0.9106 - val_loss: 0.3859 - val_accuracy: 0.8580 - 69ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2162 - accuracy: 0.9108 - val_loss: 0.3860 - val_accuracy: 0.8580 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2161 - accuracy: 0.9106 - val_loss: 0.3862 - val_accuracy: 0.8580 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2161 - accuracy: 0.9105 - val_loss: 0.3864 - val_accuracy: 0.8580 - 86ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2160 - accuracy: 0.9105 - val_loss: 0.3865 - val_accuracy: 0.8580 - 57ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2160 - accuracy: 0.9105 - val_loss: 0.3867 - val_accuracy: 0.8580 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2159 - accuracy: 0.9106 - val_loss: 0.3868 - val_accuracy: 0.8580 - 82ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2159 - accuracy: 0.9105 - val_loss: 0.3870 - val_accuracy: 0.8580 - 80ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2158 - accuracy: 0.9103 - val_loss: 0.3872 - val_accuracy: 0.8580 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2157 - accuracy: 0.9105 - val_loss: 0.3873 - val_accuracy: 0.8580 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2157 - accuracy: 0.9103 - val_loss: 0.3875 - val_accuracy: 0.8580 - 67ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2156 - accuracy: 0.9105 - val_loss: 0.3877 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2156 - accuracy: 0.9105 - val_loss: 0.3878 - val_accuracy: 0.8580 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2155 - accuracy: 0.9105 - val_loss: 0.3880 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2155 - accuracy: 0.9103 - val_loss: 0.3880 - val_accuracy: 0.8580 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2154 - accuracy: 0.9106 - val_loss: 0.3882 - val_accuracy: 0.8580 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2153 - accuracy: 0.9106 - val_loss: 0.3883 - val_accuracy: 0.8580 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2153 - accuracy: 0.9106 - val_loss: 0.3885 - val_accuracy: 0.8580 - 54ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2152 - accuracy: 0.9105 - val_loss: 0.3886 - val_accuracy: 0.8580 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2152 - accuracy: 0.9102 - val_loss: 0.3887 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2151 - accuracy: 0.9105 - val_loss: 0.3889 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2150 - accuracy: 0.9106 - val_loss: 0.3890 - val_accuracy: 0.8580 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2150 - accuracy: 0.9106 - val_loss: 0.3892 - val_accuracy: 0.8580 - 45ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2149 - accuracy: 0.9105 - val_loss: 0.3894 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2149 - accuracy: 0.9102 - val_loss: 0.3894 - val_accuracy: 0.8580 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2148 - accuracy: 0.9102 - val_loss: 0.3896 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2148 - accuracy: 0.9102 - val_loss: 0.3898 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2147 - accuracy: 0.9102 - val_loss: 0.3899 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2147 - accuracy: 0.9102 - val_loss: 0.3900 - val_accuracy: 0.8580 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2146 - accuracy: 0.9102 - val_loss: 0.3902 - val_accuracy: 0.8580 - 71ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2146 - accuracy: 0.9103 - val_loss: 0.3905 - val_accuracy: 0.8580 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2145 - accuracy: 0.9102 - val_loss: 0.3906 - val_accuracy: 0.8580 - 85ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2145 - accuracy: 0.9102 - val_loss: 0.3908 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2144 - accuracy: 0.9102 - val_loss: 0.3909 - val_accuracy: 0.8580 - 89ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2144 - accuracy: 0.9103 - val_loss: 0.3911 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2143 - accuracy: 0.9105 - val_loss: 0.3912 - val_accuracy: 0.8580 - 61ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2143 - accuracy: 0.9105 - val_loss: 0.3915 - val_accuracy: 0.8580 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2142 - accuracy: 0.9106 - val_loss: 0.3916 - val_accuracy: 0.8580 - 52ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2142 - accuracy: 0.9106 - val_loss: 0.3919 - val_accuracy: 0.8580 - 65ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2141 - accuracy: 0.9108 - val_loss: 0.3921 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2141 - accuracy: 0.9109 - val_loss: 0.3922 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2140 - accuracy: 0.9109 - val_loss: 0.3924 - val_accuracy: 0.8580 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2140 - accuracy: 0.9108 - val_loss: 0.3926 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2140 - accuracy: 0.9108 - val_loss: 0.3927 - val_accuracy: 0.8580 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2139 - accuracy: 0.9111 - val_loss: 0.3929 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2139 - accuracy: 0.9112 - val_loss: 0.3932 - val_accuracy: 0.8580 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2138 - accuracy: 0.9112 - val_loss: 0.3933 - val_accuracy: 0.8600 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2138 - accuracy: 0.9114 - val_loss: 0.3935 - val_accuracy: 0.8600 - 81ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2137 - accuracy: 0.9112 - val_loss: 0.3937 - val_accuracy: 0.8600 - 63ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2137 - accuracy: 0.9116 - val_loss: 0.3939 - val_accuracy: 0.8600 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2136 - accuracy: 0.9116 - val_loss: 0.3941 - val_accuracy: 0.8600 - 53ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2136 - accuracy: 0.9112 - val_loss: 0.3943 - val_accuracy: 0.8600 - 58ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2136 - accuracy: 0.9114 - val_loss: 0.3946 - val_accuracy: 0.8600 - 90ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2135 - accuracy: 0.9116 - val_loss: 0.3948 - val_accuracy: 0.8600 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2135 - accuracy: 0.9116 - val_loss: 0.3949 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2134 - accuracy: 0.9116 - val_loss: 0.3951 - val_accuracy: 0.8600 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2134 - accuracy: 0.9117 - val_loss: 0.3953 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2133 - accuracy: 0.9117 - val_loss: 0.3954 - val_accuracy: 0.8600 - 56ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2133 - accuracy: 0.9117 - val_loss: 0.3957 - val_accuracy: 0.8600 - 48ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2133 - accuracy: 0.9117 - val_loss: 0.3959 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2132 - accuracy: 0.9117 - val_loss: 0.3960 - val_accuracy: 0.8600 - 79ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2132 - accuracy: 0.9117 - val_loss: 0.3962 - val_accuracy: 0.8600 - 62ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2131 - accuracy: 0.9117 - val_loss: 0.3964 - val_accuracy: 0.8600 - 64ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2131 - accuracy: 0.9119 - val_loss: 0.3966 - val_accuracy: 0.8600 - 59ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2131 - accuracy: 0.9119 - val_loss: 0.3968 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2130 - accuracy: 0.9119 - val_loss: 0.3970 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2130 - accuracy: 0.9120 - val_loss: 0.3971 - val_accuracy: 0.8600 - 55ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2129 - accuracy: 0.9120 - val_loss: 0.3973 - val_accuracy: 0.8600 - 66ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2129 - accuracy: 0.9122 - val_loss: 0.3975 - val_accuracy: 0.8620 - 91ms/epoch - 4ms/step
# 25/25 - 0s - loss: 0.2128 - accuracy: 0.9123 - val_loss: 0.3976 - val_accuracy: 0.8620 - 60ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2128 - accuracy: 0.9123 - val_loss: 0.3978 - val_accuracy: 0.8620 - 83ms/epoch - 3ms/step
# 25/25 - 0s - loss: 0.2128 - accuracy: 0.9122 - val_loss: 0.3979 - val_accuracy: 0.8620 - 47ms/epoch - 2ms/step
# 25/25 - 0s - loss: 0.2127 - accuracy: 0.9122 - val_loss: 0.3980 - val_accuracy: 0.8620 - 48ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.3980 - accuracy: 0.8620 - 30ms/epoch - 2ms/step
# 0.3980499804019928

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.
