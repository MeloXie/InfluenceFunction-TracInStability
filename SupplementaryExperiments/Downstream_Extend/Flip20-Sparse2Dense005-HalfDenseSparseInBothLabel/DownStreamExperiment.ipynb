# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
total_size = 8500
test_size = 500
n_features=10
seed=42
sep= 1.5
std0 = 1.0          
std1_dense = 0.05   
std1_sparse = 2.0

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
n_per_class = total_size // 2

# %%
big_size = n_per_class // 2
small_size = n_per_class - big_size

# %%
c0 = np.zeros(n_features)
c0[0] = -sep

c1 = np.zeros(n_features)
c1[0] = sep

# %%
X0_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c0],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed
)

X0_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c0],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 1
)

X1_dense, _ = make_blobs(
    n_samples=small_size,
    centers=[c1],
    cluster_std=std1_dense,
    n_features=n_features,
    random_state=seed + 2
)

X1_sparse, _ = make_blobs(
    n_samples=big_size,
    centers=[c1],
    cluster_std=std1_sparse,
    n_features=n_features,
    random_state=seed + 3
)

# %%
X = np.vstack([X0_dense, X0_sparse, X1_dense, X1_sparse])
y = np.hstack([
    np.zeros(big_size, dtype=int),
    np.zeros(small_size, dtype=int),
    np.ones(big_size, dtype=int),
    np.ones(small_size, dtype=int),
])

# %%
cluster_id = (
    (["0_dense"] * big_size) +
    (["0_sparse"] * small_size) +
    (["1_dense"] * big_size) +
    (["1_sparse"] * small_size)
)
rng = np.random.RandomState(seed)
idx = rng.permutation(X.shape[0])
X = X[idx]; y = y[idx]
cluster_id = np.array(cluster_id, dtype=object)[idx]

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
df["cluster_id"] = cluster_id 
print(df)
print(df["label"].value_counts())
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      1.520401  -0.002305   0.041957  -0.023206  -0.005026  -0.146648
# 1     -1.215695  -2.051403  -1.236678   1.603395  -2.509045  -1.337987
# 2      0.228284   1.633010  -1.239421  -2.713577  -4.649626   1.351534
# 3      1.492814  -0.020460  -0.071002   0.002134   0.016991   0.031364
# 4      1.363394  -0.061487  -0.057876   0.031831  -0.025184  -0.067767
# ...         ...        ...        ...        ...        ...        ...
# 8495   1.520914   0.079577   0.041471  -0.050836   0.056044   0.002700
# 8496   1.458301  -0.020143  -0.143969  -0.016631  -0.028241   0.023412
# 8497   1.474463  -0.031130  -0.075557   0.124382  -0.062558  -0.051416
# 8498  -1.493895   0.060351   0.079131   0.004240  -0.015753   0.003309
# 8499   0.789623  -2.805211   0.771673   0.855912  -1.402900   1.067256
#
#       feature_7  feature_8  feature_9  feature_10  label    id cluster_id
# 0     -0.125289  -0.038709  -0.024428    0.089059      1     1    1_dense
# 1      2.036739  -0.609358   2.402412   -1.831525      1     2   1_sparse
# 2      1.540905   2.761304   0.792573    2.158700      1     3   1_sparse
# 3     -0.047852  -0.039181   0.009810    0.055521      1     4    1_dense
# 4     -0.141778  -0.028718   0.023950   -0.034707      1     5    1_dense
# ...         ...        ...        ...         ...    ...   ...        ...
# 8495   0.160855  -0.126243  -0.037087    0.042598      1  8496    1_dense
# 8496   0.053892  -0.008504   0.021460   -0.049369      1  8497    1_dense
# 8497   0.035041  -0.096774   0.026802   -0.102655      1  8498    1_dense
# 8498  -0.004739  -0.082848   0.077624    0.012289      0  8499    0_dense
# 8499   2.410566  -4.255926   3.003255   -0.400990      1  8500   1_sparse
#
# [8500 rows x 13 columns]
# label
# 1    4250
# 0    4250
# Name: count, dtype: int64

# %%
print(df["cluster_id"].value_counts())
# Out:
# cluster_id
# 1_dense     2125
# 1_sparse    2125
# 0_sparse    2125
# 0_dense     2125
# Name: count, dtype: int64

# %%
n0 = test_size //2
n1_big = (test_size - n0) // 2
n1_small = test_size - n0 - n1_big
n0,n1_big,n1_small
# Out:
# (250, 125, 125)

# %%
g = df.groupby("cluster_id", group_keys=False)
test_df = pd.concat([
    g.get_group("0_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("0_sparse").sample(n=n1_small, random_state=seed, replace=False),
    g.get_group("1_dense").sample(n=n1_big, random_state=seed, replace=False),
    g.get_group("1_sparse").sample(n=n1_small, random_state=seed, replace=False)
]).sample(frac=1, random_state=seed)

train_df = df.drop(test_df.index).reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df["clean_label"] = train_df["label"].copy()

# Randomly select 20% of the training samples
noise_ratio = 0.20
noise_seed = 42

rng = np.random.default_rng(noise_seed)

n_noisy = int(len(train_df) * noise_ratio)

noisy_positions = rng.choice(
    len(train_df),
    size=n_noisy,
    replace=False
)

# Indicator showing which samples were corrupted
train_df["is_noisy"] = 0
train_df.loc[train_df.index[noisy_positions], "is_noisy"] = 1

# Flip the binary labels: 0 -> 1 and 1 -> 0
train_df.loc[
    train_df.index[noisy_positions],
    "label"
] = 1 - train_df.loc[
    train_df.index[noisy_positions],
    "label"
]

# Save a clearer name for the labels used during training
train_df["noisy_label"] = train_df["label"]

print("Number of training samples:", len(train_df))
print("Number of flipped labels:", train_df["is_noisy"].sum())
print("Noise ratio:", train_df["is_noisy"].mean())

print(
    train_df[
        ["id", "clean_label", "noisy_label", "is_noisy"]
    ].head()
)
# Out:
# Number of training samples: 8000
# Number of flipped labels: 1600
# Noise ratio: 0.2
#    id  clean_label  noisy_label  is_noisy
# 0   1            1            1         0
# 1   2            1            1         0
# 2   3            1            1         0
# 3   4            1            1         0
# 4   5            1            1         0

# %%
# Feature columns used by the model
selected_features = [
    col for col in train_df.columns
    if col.startswith("feature_")
]

# Preserve IDs separately
train_ids_original = train_df["id"].to_numpy()

# Scale IDs only for the influence pipeline
IDs = (
    train_ids_original
    .reshape(-1, 1)
    .astype(np.float32)
    / 1e10
)

# Model features
X_train_features = train_df[
    selected_features
].to_numpy(dtype=np.float32)

# Append the ID column, as required by your existing influence code
X_train = np.hstack([
    X_train_features,
    IDs
])

# Use the corrupted labels for training
y_train_1d = train_df[
    "noisy_label"
].to_numpy(dtype=np.int64)

y_train = to_categorical(
    y_train_1d,
    num_classes=2
)

print(X_train.shape)
print(y_train.shape)
# Out:
# (8000, 11)
# (8000, 2)

# %%
# X_train = train_df.drop(columns=["label"])
# y_train = train_df["label"]
# IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
# IDs = IDs  / 1e10

# X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
# X_train = np.hstack((X_train, IDs))
# y_train = to_categorical(y_train.values,num_classes=2)

# print(X_train)

# %%
X_test = test_df.drop(columns=["label","cluster_id"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test.shape)
print(y_test.shape)
# Out:
# (500, 11)
# (500, 2)

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
initial_model = tf.keras.models.clone_model(model)
initial_model.set_weights(model.get_weights())
model_list.append(InfluenceModel(initial_model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  checkpoint_model = tf.keras.models.clone_model(model)
  checkpoint_model.set_weights(model.get_weights())
  model_list.append(InfluenceModel(checkpoint_model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 32/32 - 1s - loss: 0.8160 - accuracy: 0.5084 - val_loss: 0.7578 - val_accuracy: 0.5360 - 663ms/epoch - 21ms/step
# 32/32 - 0s - loss: 0.7366 - accuracy: 0.5249 - val_loss: 0.6749 - val_accuracy: 0.6860 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.6914 - accuracy: 0.6620 - val_loss: 0.6293 - val_accuracy: 0.8220 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6710 - accuracy: 0.6852 - val_loss: 0.6044 - val_accuracy: 0.8260 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6586 - accuracy: 0.6884 - val_loss: 0.5851 - val_accuracy: 0.8400 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6494 - accuracy: 0.6926 - val_loss: 0.5696 - val_accuracy: 0.8400 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6424 - accuracy: 0.6980 - val_loss: 0.5567 - val_accuracy: 0.8440 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6368 - accuracy: 0.6989 - val_loss: 0.5460 - val_accuracy: 0.8440 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6321 - accuracy: 0.7023 - val_loss: 0.5370 - val_accuracy: 0.8440 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6281 - accuracy: 0.7042 - val_loss: 0.5293 - val_accuracy: 0.8520 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6247 - accuracy: 0.7066 - val_loss: 0.5226 - val_accuracy: 0.8540 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6217 - accuracy: 0.7084 - val_loss: 0.5167 - val_accuracy: 0.8560 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6190 - accuracy: 0.7088 - val_loss: 0.5114 - val_accuracy: 0.8580 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6167 - accuracy: 0.7090 - val_loss: 0.5066 - val_accuracy: 0.8560 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6145 - accuracy: 0.7103 - val_loss: 0.5023 - val_accuracy: 0.8540 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6126 - accuracy: 0.7110 - val_loss: 0.4982 - val_accuracy: 0.8540 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6107 - accuracy: 0.7107 - val_loss: 0.4944 - val_accuracy: 0.8540 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6090 - accuracy: 0.7114 - val_loss: 0.4909 - val_accuracy: 0.8600 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6074 - accuracy: 0.7113 - val_loss: 0.4876 - val_accuracy: 0.8620 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6059 - accuracy: 0.7119 - val_loss: 0.4846 - val_accuracy: 0.8600 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.6045 - accuracy: 0.7116 - val_loss: 0.4817 - val_accuracy: 0.8620 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6032 - accuracy: 0.7128 - val_loss: 0.4790 - val_accuracy: 0.8580 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6020 - accuracy: 0.7131 - val_loss: 0.4765 - val_accuracy: 0.8600 - 79ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.6008 - accuracy: 0.7134 - val_loss: 0.4740 - val_accuracy: 0.8600 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5997 - accuracy: 0.7139 - val_loss: 0.4716 - val_accuracy: 0.8560 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5987 - accuracy: 0.7140 - val_loss: 0.4694 - val_accuracy: 0.8560 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5977 - accuracy: 0.7147 - val_loss: 0.4672 - val_accuracy: 0.8580 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5967 - accuracy: 0.7150 - val_loss: 0.4651 - val_accuracy: 0.8580 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5958 - accuracy: 0.7145 - val_loss: 0.4631 - val_accuracy: 0.8580 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5949 - accuracy: 0.7159 - val_loss: 0.4612 - val_accuracy: 0.8600 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5941 - accuracy: 0.7168 - val_loss: 0.4594 - val_accuracy: 0.8620 - 88ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5933 - accuracy: 0.7168 - val_loss: 0.4577 - val_accuracy: 0.8620 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5925 - accuracy: 0.7175 - val_loss: 0.4560 - val_accuracy: 0.8620 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5918 - accuracy: 0.7170 - val_loss: 0.4544 - val_accuracy: 0.8620 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5911 - accuracy: 0.7168 - val_loss: 0.4528 - val_accuracy: 0.8620 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5904 - accuracy: 0.7178 - val_loss: 0.4514 - val_accuracy: 0.8620 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5897 - accuracy: 0.7178 - val_loss: 0.4499 - val_accuracy: 0.8620 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5891 - accuracy: 0.7175 - val_loss: 0.4486 - val_accuracy: 0.8640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5885 - accuracy: 0.7181 - val_loss: 0.4472 - val_accuracy: 0.8640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5880 - accuracy: 0.7184 - val_loss: 0.4459 - val_accuracy: 0.8640 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5874 - accuracy: 0.7189 - val_loss: 0.4447 - val_accuracy: 0.8640 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5869 - accuracy: 0.7190 - val_loss: 0.4435 - val_accuracy: 0.8640 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5864 - accuracy: 0.7199 - val_loss: 0.4424 - val_accuracy: 0.8640 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5859 - accuracy: 0.7199 - val_loss: 0.4412 - val_accuracy: 0.8680 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5855 - accuracy: 0.7207 - val_loss: 0.4402 - val_accuracy: 0.8700 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5850 - accuracy: 0.7209 - val_loss: 0.4391 - val_accuracy: 0.8700 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5846 - accuracy: 0.7211 - val_loss: 0.4381 - val_accuracy: 0.8700 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5842 - accuracy: 0.7219 - val_loss: 0.4371 - val_accuracy: 0.8700 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5838 - accuracy: 0.7225 - val_loss: 0.4361 - val_accuracy: 0.8700 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5834 - accuracy: 0.7222 - val_loss: 0.4352 - val_accuracy: 0.8700 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5831 - accuracy: 0.7219 - val_loss: 0.4343 - val_accuracy: 0.8700 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5827 - accuracy: 0.7221 - val_loss: 0.4334 - val_accuracy: 0.8720 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5823 - accuracy: 0.7228 - val_loss: 0.4326 - val_accuracy: 0.8740 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5820 - accuracy: 0.7228 - val_loss: 0.4318 - val_accuracy: 0.8740 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5817 - accuracy: 0.7220 - val_loss: 0.4310 - val_accuracy: 0.8720 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5813 - accuracy: 0.7220 - val_loss: 0.4303 - val_accuracy: 0.8700 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5810 - accuracy: 0.7226 - val_loss: 0.4295 - val_accuracy: 0.8700 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5807 - accuracy: 0.7226 - val_loss: 0.4288 - val_accuracy: 0.8720 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5804 - accuracy: 0.7226 - val_loss: 0.4281 - val_accuracy: 0.8720 - 78ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5801 - accuracy: 0.7229 - val_loss: 0.4274 - val_accuracy: 0.8760 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5798 - accuracy: 0.7229 - val_loss: 0.4267 - val_accuracy: 0.8760 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5796 - accuracy: 0.7230 - val_loss: 0.4261 - val_accuracy: 0.8760 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5793 - accuracy: 0.7232 - val_loss: 0.4254 - val_accuracy: 0.8760 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5791 - accuracy: 0.7232 - val_loss: 0.4248 - val_accuracy: 0.8760 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5788 - accuracy: 0.7230 - val_loss: 0.4242 - val_accuracy: 0.8760 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5786 - accuracy: 0.7232 - val_loss: 0.4236 - val_accuracy: 0.8760 - 84ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5783 - accuracy: 0.7235 - val_loss: 0.4230 - val_accuracy: 0.8760 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5781 - accuracy: 0.7234 - val_loss: 0.4225 - val_accuracy: 0.8800 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5779 - accuracy: 0.7234 - val_loss: 0.4219 - val_accuracy: 0.8800 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5776 - accuracy: 0.7231 - val_loss: 0.4214 - val_accuracy: 0.8820 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5774 - accuracy: 0.7232 - val_loss: 0.4209 - val_accuracy: 0.8840 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5772 - accuracy: 0.7237 - val_loss: 0.4203 - val_accuracy: 0.8840 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5770 - accuracy: 0.7239 - val_loss: 0.4198 - val_accuracy: 0.8840 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5768 - accuracy: 0.7240 - val_loss: 0.4193 - val_accuracy: 0.8840 - 84ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5765 - accuracy: 0.7239 - val_loss: 0.4187 - val_accuracy: 0.8840 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5763 - accuracy: 0.7243 - val_loss: 0.4182 - val_accuracy: 0.8840 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5761 - accuracy: 0.7245 - val_loss: 0.4177 - val_accuracy: 0.8840 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5759 - accuracy: 0.7245 - val_loss: 0.4172 - val_accuracy: 0.8840 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5757 - accuracy: 0.7245 - val_loss: 0.4167 - val_accuracy: 0.8820 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5755 - accuracy: 0.7244 - val_loss: 0.4162 - val_accuracy: 0.8840 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5754 - accuracy: 0.7244 - val_loss: 0.4157 - val_accuracy: 0.8840 - 56ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5752 - accuracy: 0.7244 - val_loss: 0.4152 - val_accuracy: 0.8840 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5750 - accuracy: 0.7239 - val_loss: 0.4148 - val_accuracy: 0.8840 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5748 - accuracy: 0.7240 - val_loss: 0.4144 - val_accuracy: 0.8840 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5746 - accuracy: 0.7244 - val_loss: 0.4139 - val_accuracy: 0.8840 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5744 - accuracy: 0.7245 - val_loss: 0.4135 - val_accuracy: 0.8840 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5743 - accuracy: 0.7246 - val_loss: 0.4131 - val_accuracy: 0.8840 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5741 - accuracy: 0.7246 - val_loss: 0.4128 - val_accuracy: 0.8840 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5739 - accuracy: 0.7247 - val_loss: 0.4124 - val_accuracy: 0.8840 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5737 - accuracy: 0.7250 - val_loss: 0.4120 - val_accuracy: 0.8840 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5736 - accuracy: 0.7253 - val_loss: 0.4116 - val_accuracy: 0.8840 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5734 - accuracy: 0.7253 - val_loss: 0.4113 - val_accuracy: 0.8840 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5732 - accuracy: 0.7254 - val_loss: 0.4110 - val_accuracy: 0.8820 - 47ms/epoch - 1ms/step
# 32/32 - 0s - loss: 0.5731 - accuracy: 0.7265 - val_loss: 0.4106 - val_accuracy: 0.8820 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5729 - accuracy: 0.7271 - val_loss: 0.4103 - val_accuracy: 0.8820 - 48ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5727 - accuracy: 0.7272 - val_loss: 0.4100 - val_accuracy: 0.8820 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5726 - accuracy: 0.7275 - val_loss: 0.4097 - val_accuracy: 0.8820 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5724 - accuracy: 0.7278 - val_loss: 0.4094 - val_accuracy: 0.8800 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5722 - accuracy: 0.7272 - val_loss: 0.4091 - val_accuracy: 0.8800 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5721 - accuracy: 0.7274 - val_loss: 0.4088 - val_accuracy: 0.8820 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5719 - accuracy: 0.7272 - val_loss: 0.4085 - val_accuracy: 0.8820 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5718 - accuracy: 0.7276 - val_loss: 0.4083 - val_accuracy: 0.8820 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5716 - accuracy: 0.7276 - val_loss: 0.4080 - val_accuracy: 0.8820 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5715 - accuracy: 0.7272 - val_loss: 0.4077 - val_accuracy: 0.8840 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5713 - accuracy: 0.7276 - val_loss: 0.4075 - val_accuracy: 0.8860 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5712 - accuracy: 0.7279 - val_loss: 0.4073 - val_accuracy: 0.8860 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5711 - accuracy: 0.7280 - val_loss: 0.4070 - val_accuracy: 0.8860 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5709 - accuracy: 0.7278 - val_loss: 0.4068 - val_accuracy: 0.8860 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5708 - accuracy: 0.7276 - val_loss: 0.4066 - val_accuracy: 0.8860 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5706 - accuracy: 0.7276 - val_loss: 0.4064 - val_accuracy: 0.8880 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5705 - accuracy: 0.7278 - val_loss: 0.4061 - val_accuracy: 0.8880 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5704 - accuracy: 0.7276 - val_loss: 0.4059 - val_accuracy: 0.8880 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5703 - accuracy: 0.7276 - val_loss: 0.4057 - val_accuracy: 0.8880 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5701 - accuracy: 0.7278 - val_loss: 0.4054 - val_accuracy: 0.8880 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5700 - accuracy: 0.7279 - val_loss: 0.4052 - val_accuracy: 0.8880 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5699 - accuracy: 0.7278 - val_loss: 0.4050 - val_accuracy: 0.8880 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5698 - accuracy: 0.7275 - val_loss: 0.4048 - val_accuracy: 0.8880 - 52ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5696 - accuracy: 0.7275 - val_loss: 0.4046 - val_accuracy: 0.8880 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5695 - accuracy: 0.7278 - val_loss: 0.4044 - val_accuracy: 0.8880 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5694 - accuracy: 0.7276 - val_loss: 0.4041 - val_accuracy: 0.8880 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5693 - accuracy: 0.7270 - val_loss: 0.4039 - val_accuracy: 0.8880 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5692 - accuracy: 0.7272 - val_loss: 0.4037 - val_accuracy: 0.8880 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5691 - accuracy: 0.7275 - val_loss: 0.4035 - val_accuracy: 0.8880 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5690 - accuracy: 0.7276 - val_loss: 0.4033 - val_accuracy: 0.8900 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5689 - accuracy: 0.7275 - val_loss: 0.4031 - val_accuracy: 0.8900 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5688 - accuracy: 0.7278 - val_loss: 0.4029 - val_accuracy: 0.8900 - 101ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5687 - accuracy: 0.7280 - val_loss: 0.4027 - val_accuracy: 0.8920 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5686 - accuracy: 0.7276 - val_loss: 0.4024 - val_accuracy: 0.8900 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5685 - accuracy: 0.7275 - val_loss: 0.4022 - val_accuracy: 0.8900 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5684 - accuracy: 0.7274 - val_loss: 0.4020 - val_accuracy: 0.8900 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5683 - accuracy: 0.7276 - val_loss: 0.4018 - val_accuracy: 0.8900 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5682 - accuracy: 0.7278 - val_loss: 0.4016 - val_accuracy: 0.8900 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5681 - accuracy: 0.7276 - val_loss: 0.4014 - val_accuracy: 0.8900 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5680 - accuracy: 0.7279 - val_loss: 0.4012 - val_accuracy: 0.8900 - 60ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5679 - accuracy: 0.7279 - val_loss: 0.4010 - val_accuracy: 0.8900 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5678 - accuracy: 0.7278 - val_loss: 0.4008 - val_accuracy: 0.8900 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5677 - accuracy: 0.7283 - val_loss: 0.4006 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5677 - accuracy: 0.7281 - val_loss: 0.4005 - val_accuracy: 0.8920 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5676 - accuracy: 0.7281 - val_loss: 0.4003 - val_accuracy: 0.8920 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5675 - accuracy: 0.7285 - val_loss: 0.4001 - val_accuracy: 0.8920 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5674 - accuracy: 0.7290 - val_loss: 0.4000 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5673 - accuracy: 0.7290 - val_loss: 0.3998 - val_accuracy: 0.8940 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5672 - accuracy: 0.7290 - val_loss: 0.3996 - val_accuracy: 0.8940 - 53ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5672 - accuracy: 0.7291 - val_loss: 0.3995 - val_accuracy: 0.8940 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5671 - accuracy: 0.7291 - val_loss: 0.3993 - val_accuracy: 0.8940 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5670 - accuracy: 0.7291 - val_loss: 0.3992 - val_accuracy: 0.8940 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5669 - accuracy: 0.7296 - val_loss: 0.3990 - val_accuracy: 0.8940 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5668 - accuracy: 0.7296 - val_loss: 0.3989 - val_accuracy: 0.8940 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5668 - accuracy: 0.7296 - val_loss: 0.3987 - val_accuracy: 0.8940 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5667 - accuracy: 0.7296 - val_loss: 0.3985 - val_accuracy: 0.8940 - 51ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5666 - accuracy: 0.7297 - val_loss: 0.3984 - val_accuracy: 0.8940 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5665 - accuracy: 0.7296 - val_loss: 0.3982 - val_accuracy: 0.8940 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5665 - accuracy: 0.7296 - val_loss: 0.3981 - val_accuracy: 0.8940 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5664 - accuracy: 0.7297 - val_loss: 0.3979 - val_accuracy: 0.8940 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5663 - accuracy: 0.7296 - val_loss: 0.3978 - val_accuracy: 0.8940 - 82ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5663 - accuracy: 0.7296 - val_loss: 0.3977 - val_accuracy: 0.8940 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5662 - accuracy: 0.7299 - val_loss: 0.3975 - val_accuracy: 0.8940 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5661 - accuracy: 0.7300 - val_loss: 0.3974 - val_accuracy: 0.8940 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5661 - accuracy: 0.7301 - val_loss: 0.3973 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5660 - accuracy: 0.7301 - val_loss: 0.3971 - val_accuracy: 0.8940 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5659 - accuracy: 0.7304 - val_loss: 0.3970 - val_accuracy: 0.8940 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5659 - accuracy: 0.7303 - val_loss: 0.3968 - val_accuracy: 0.8940 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5658 - accuracy: 0.7303 - val_loss: 0.3967 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5657 - accuracy: 0.7301 - val_loss: 0.3965 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5657 - accuracy: 0.7300 - val_loss: 0.3964 - val_accuracy: 0.8940 - 50ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5656 - accuracy: 0.7301 - val_loss: 0.3962 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5655 - accuracy: 0.7303 - val_loss: 0.3961 - val_accuracy: 0.8940 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5655 - accuracy: 0.7303 - val_loss: 0.3959 - val_accuracy: 0.8940 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5654 - accuracy: 0.7304 - val_loss: 0.3958 - val_accuracy: 0.8940 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5654 - accuracy: 0.7306 - val_loss: 0.3956 - val_accuracy: 0.8940 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5653 - accuracy: 0.7306 - val_loss: 0.3955 - val_accuracy: 0.8940 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5652 - accuracy: 0.7309 - val_loss: 0.3954 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5652 - accuracy: 0.7312 - val_loss: 0.3952 - val_accuracy: 0.8920 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5651 - accuracy: 0.7314 - val_loss: 0.3951 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5651 - accuracy: 0.7312 - val_loss: 0.3950 - val_accuracy: 0.8940 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5650 - accuracy: 0.7314 - val_loss: 0.3949 - val_accuracy: 0.8940 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5650 - accuracy: 0.7315 - val_loss: 0.3947 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5649 - accuracy: 0.7311 - val_loss: 0.3946 - val_accuracy: 0.8940 - 87ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5648 - accuracy: 0.7312 - val_loss: 0.3945 - val_accuracy: 0.8940 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5648 - accuracy: 0.7314 - val_loss: 0.3944 - val_accuracy: 0.8940 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5647 - accuracy: 0.7314 - val_loss: 0.3943 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5647 - accuracy: 0.7315 - val_loss: 0.3941 - val_accuracy: 0.8940 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5646 - accuracy: 0.7315 - val_loss: 0.3940 - val_accuracy: 0.8940 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5646 - accuracy: 0.7316 - val_loss: 0.3939 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5645 - accuracy: 0.7316 - val_loss: 0.3938 - val_accuracy: 0.8940 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5645 - accuracy: 0.7318 - val_loss: 0.3937 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5644 - accuracy: 0.7320 - val_loss: 0.3936 - val_accuracy: 0.8940 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5644 - accuracy: 0.7320 - val_loss: 0.3935 - val_accuracy: 0.8920 - 85ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5643 - accuracy: 0.7320 - val_loss: 0.3934 - val_accuracy: 0.8920 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5643 - accuracy: 0.7318 - val_loss: 0.3933 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5642 - accuracy: 0.7319 - val_loss: 0.3932 - val_accuracy: 0.8940 - 95ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5642 - accuracy: 0.7316 - val_loss: 0.3932 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5641 - accuracy: 0.7318 - val_loss: 0.3931 - val_accuracy: 0.8940 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5641 - accuracy: 0.7320 - val_loss: 0.3930 - val_accuracy: 0.8960 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5640 - accuracy: 0.7320 - val_loss: 0.3929 - val_accuracy: 0.8960 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5640 - accuracy: 0.7318 - val_loss: 0.3928 - val_accuracy: 0.8960 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5639 - accuracy: 0.7316 - val_loss: 0.3927 - val_accuracy: 0.8960 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5639 - accuracy: 0.7316 - val_loss: 0.3926 - val_accuracy: 0.8960 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5638 - accuracy: 0.7316 - val_loss: 0.3925 - val_accuracy: 0.8960 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5638 - accuracy: 0.7316 - val_loss: 0.3924 - val_accuracy: 0.8960 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5637 - accuracy: 0.7318 - val_loss: 0.3924 - val_accuracy: 0.8960 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5637 - accuracy: 0.7319 - val_loss: 0.3923 - val_accuracy: 0.8960 - 82ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5636 - accuracy: 0.7319 - val_loss: 0.3922 - val_accuracy: 0.8960 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5636 - accuracy: 0.7320 - val_loss: 0.3922 - val_accuracy: 0.8980 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5635 - accuracy: 0.7320 - val_loss: 0.3921 - val_accuracy: 0.8980 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5635 - accuracy: 0.7322 - val_loss: 0.3920 - val_accuracy: 0.8980 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5635 - accuracy: 0.7325 - val_loss: 0.3920 - val_accuracy: 0.8980 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5634 - accuracy: 0.7327 - val_loss: 0.3919 - val_accuracy: 0.8980 - 62ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5634 - accuracy: 0.7327 - val_loss: 0.3918 - val_accuracy: 0.8980 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5633 - accuracy: 0.7331 - val_loss: 0.3917 - val_accuracy: 0.8980 - 63ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5633 - accuracy: 0.7333 - val_loss: 0.3917 - val_accuracy: 0.8980 - 89ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5632 - accuracy: 0.7334 - val_loss: 0.3916 - val_accuracy: 0.8960 - 64ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5632 - accuracy: 0.7333 - val_loss: 0.3915 - val_accuracy: 0.8960 - 54ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5632 - accuracy: 0.7333 - val_loss: 0.3914 - val_accuracy: 0.8960 - 100ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5631 - accuracy: 0.7333 - val_loss: 0.3914 - val_accuracy: 0.8960 - 93ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5631 - accuracy: 0.7334 - val_loss: 0.3913 - val_accuracy: 0.8960 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5630 - accuracy: 0.7334 - val_loss: 0.3912 - val_accuracy: 0.8960 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5630 - accuracy: 0.7334 - val_loss: 0.3911 - val_accuracy: 0.8960 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5630 - accuracy: 0.7334 - val_loss: 0.3911 - val_accuracy: 0.8960 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5629 - accuracy: 0.7337 - val_loss: 0.3910 - val_accuracy: 0.8960 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5629 - accuracy: 0.7337 - val_loss: 0.3909 - val_accuracy: 0.8960 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5628 - accuracy: 0.7337 - val_loss: 0.3908 - val_accuracy: 0.8960 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5628 - accuracy: 0.7335 - val_loss: 0.3908 - val_accuracy: 0.8960 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5628 - accuracy: 0.7335 - val_loss: 0.3907 - val_accuracy: 0.8960 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5627 - accuracy: 0.7333 - val_loss: 0.3907 - val_accuracy: 0.8960 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5627 - accuracy: 0.7333 - val_loss: 0.3906 - val_accuracy: 0.8960 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5626 - accuracy: 0.7331 - val_loss: 0.3905 - val_accuracy: 0.8960 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5626 - accuracy: 0.7329 - val_loss: 0.3905 - val_accuracy: 0.8960 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5626 - accuracy: 0.7327 - val_loss: 0.3904 - val_accuracy: 0.8960 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5625 - accuracy: 0.7327 - val_loss: 0.3903 - val_accuracy: 0.8960 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5625 - accuracy: 0.7329 - val_loss: 0.3903 - val_accuracy: 0.8960 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5625 - accuracy: 0.7329 - val_loss: 0.3902 - val_accuracy: 0.8960 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5624 - accuracy: 0.7327 - val_loss: 0.3901 - val_accuracy: 0.8960 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5624 - accuracy: 0.7329 - val_loss: 0.3901 - val_accuracy: 0.8960 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5623 - accuracy: 0.7329 - val_loss: 0.3900 - val_accuracy: 0.8960 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5623 - accuracy: 0.7327 - val_loss: 0.3900 - val_accuracy: 0.8960 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5623 - accuracy: 0.7326 - val_loss: 0.3899 - val_accuracy: 0.8940 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5622 - accuracy: 0.7329 - val_loss: 0.3899 - val_accuracy: 0.8940 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5622 - accuracy: 0.7331 - val_loss: 0.3898 - val_accuracy: 0.8920 - 110ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5622 - accuracy: 0.7334 - val_loss: 0.3897 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5621 - accuracy: 0.7334 - val_loss: 0.3897 - val_accuracy: 0.8920 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5621 - accuracy: 0.7334 - val_loss: 0.3896 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5620 - accuracy: 0.7334 - val_loss: 0.3896 - val_accuracy: 0.8920 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5620 - accuracy: 0.7337 - val_loss: 0.3895 - val_accuracy: 0.8920 - 59ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5620 - accuracy: 0.7340 - val_loss: 0.3895 - val_accuracy: 0.8920 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5619 - accuracy: 0.7340 - val_loss: 0.3894 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5619 - accuracy: 0.7337 - val_loss: 0.3893 - val_accuracy: 0.8920 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5619 - accuracy: 0.7335 - val_loss: 0.3893 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5618 - accuracy: 0.7334 - val_loss: 0.3892 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5618 - accuracy: 0.7335 - val_loss: 0.3891 - val_accuracy: 0.8920 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5618 - accuracy: 0.7335 - val_loss: 0.3891 - val_accuracy: 0.8920 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5617 - accuracy: 0.7336 - val_loss: 0.3890 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5617 - accuracy: 0.7336 - val_loss: 0.3889 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5617 - accuracy: 0.7340 - val_loss: 0.3889 - val_accuracy: 0.8920 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5616 - accuracy: 0.7341 - val_loss: 0.3888 - val_accuracy: 0.8920 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5616 - accuracy: 0.7341 - val_loss: 0.3888 - val_accuracy: 0.8920 - 98ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5616 - accuracy: 0.7343 - val_loss: 0.3887 - val_accuracy: 0.8920 - 58ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5615 - accuracy: 0.7341 - val_loss: 0.3886 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5615 - accuracy: 0.7340 - val_loss: 0.3886 - val_accuracy: 0.8920 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5615 - accuracy: 0.7340 - val_loss: 0.3885 - val_accuracy: 0.8920 - 91ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5614 - accuracy: 0.7339 - val_loss: 0.3885 - val_accuracy: 0.8920 - 92ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5614 - accuracy: 0.7339 - val_loss: 0.3884 - val_accuracy: 0.8920 - 77ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5614 - accuracy: 0.7337 - val_loss: 0.3883 - val_accuracy: 0.8920 - 94ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5613 - accuracy: 0.7339 - val_loss: 0.3883 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5613 - accuracy: 0.7337 - val_loss: 0.3882 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5613 - accuracy: 0.7339 - val_loss: 0.3881 - val_accuracy: 0.8920 - 96ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5612 - accuracy: 0.7339 - val_loss: 0.3881 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5612 - accuracy: 0.7336 - val_loss: 0.3880 - val_accuracy: 0.8920 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5612 - accuracy: 0.7339 - val_loss: 0.3879 - val_accuracy: 0.8920 - 102ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5611 - accuracy: 0.7340 - val_loss: 0.3879 - val_accuracy: 0.8920 - 67ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5611 - accuracy: 0.7340 - val_loss: 0.3878 - val_accuracy: 0.8920 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5611 - accuracy: 0.7341 - val_loss: 0.3878 - val_accuracy: 0.8920 - 101ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5610 - accuracy: 0.7344 - val_loss: 0.3877 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5610 - accuracy: 0.7345 - val_loss: 0.3877 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5610 - accuracy: 0.7344 - val_loss: 0.3876 - val_accuracy: 0.8920 - 71ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5609 - accuracy: 0.7343 - val_loss: 0.3875 - val_accuracy: 0.8920 - 68ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5609 - accuracy: 0.7344 - val_loss: 0.3875 - val_accuracy: 0.8920 - 76ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5609 - accuracy: 0.7344 - val_loss: 0.3875 - val_accuracy: 0.8920 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5609 - accuracy: 0.7343 - val_loss: 0.3874 - val_accuracy: 0.8920 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5608 - accuracy: 0.7343 - val_loss: 0.3874 - val_accuracy: 0.8920 - 97ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5608 - accuracy: 0.7344 - val_loss: 0.3873 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5608 - accuracy: 0.7343 - val_loss: 0.3873 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5607 - accuracy: 0.7341 - val_loss: 0.3872 - val_accuracy: 0.8920 - 69ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5607 - accuracy: 0.7341 - val_loss: 0.3872 - val_accuracy: 0.8920 - 61ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5607 - accuracy: 0.7344 - val_loss: 0.3871 - val_accuracy: 0.8920 - 65ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5607 - accuracy: 0.7344 - val_loss: 0.3871 - val_accuracy: 0.8920 - 66ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5606 - accuracy: 0.7343 - val_loss: 0.3870 - val_accuracy: 0.8920 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5606 - accuracy: 0.7341 - val_loss: 0.3870 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5606 - accuracy: 0.7341 - val_loss: 0.3869 - val_accuracy: 0.8920 - 90ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5606 - accuracy: 0.7341 - val_loss: 0.3868 - val_accuracy: 0.8920 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5605 - accuracy: 0.7341 - val_loss: 0.3868 - val_accuracy: 0.8920 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5605 - accuracy: 0.7345 - val_loss: 0.3867 - val_accuracy: 0.8920 - 70ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5605 - accuracy: 0.7345 - val_loss: 0.3867 - val_accuracy: 0.8920 - 73ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5605 - accuracy: 0.7345 - val_loss: 0.3866 - val_accuracy: 0.8920 - 79ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5604 - accuracy: 0.7344 - val_loss: 0.3866 - val_accuracy: 0.8900 - 74ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5604 - accuracy: 0.7345 - val_loss: 0.3865 - val_accuracy: 0.8900 - 72ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5604 - accuracy: 0.7346 - val_loss: 0.3865 - val_accuracy: 0.8920 - 75ms/epoch - 2ms/step
# 32/32 - 0s - loss: 0.5604 - accuracy: 0.7347 - val_loss: 0.3864 - val_accuracy: 0.8920 - 99ms/epoch - 3ms/step
# 32/32 - 0s - loss: 0.5603 - accuracy: 0.7347 - val_loss: 0.3864 - val_accuracy: 0.8920 - 298ms/epoch - 9ms/step
# 32/32 - 0s - loss: 0.5603 - accuracy: 0.7347 - val_loss: 0.3864 - val_accuracy: 0.8920 - 100ms/epoch - 3ms/step
# 16/16 - 0s - loss: 0.3864 - accuracy: 0.8920 - 31ms/epoch - 2ms/step
# 0.3863571286201477

# %%
train_logits = model.predict(
    X_train,
    batch_size=256,
    verbose=0
)

# Calculate one loss value per sample using the corrupted labels
per_sample_loss_fn = CategoricalCrossentropy(
    from_logits=True,
    reduction=tf.keras.losses.Reduction.NONE
)

training_losses = per_sample_loss_fn(
    y_train,
    train_logits
).numpy()

print(training_losses.shape)
print(pd.Series(training_losses).describe())
# Out:
# (8000,)
# count    8000.000000
# mean        0.559655
# std         0.471607
# min         0.037564
# 25%         0.236100
# 50%         0.280471
# 75%         0.737616
# max         2.549638
# dtype: float64

# %%
noise_loss_df = pd.DataFrame({
    "Train_ID": train_ids_original,
    "Clean_Label": train_df["clean_label"].to_numpy(),
    "Noisy_Label": train_df["noisy_label"].to_numpy(),
    "is_noisy": train_df["is_noisy"].to_numpy(),
    "Training_Loss": training_losses
})

print(noise_loss_df.head())
print(
    noise_loss_df.groupby("is_noisy")[
        "Training_Loss"
    ].describe()
)
# Out:
#    Train_ID  Clean_Label  Noisy_Label  is_noisy  Training_Loss
# 0         1            1            1         0       0.253127
# 1         2            1            1         0       0.726266
# 2         3            1            1         0       0.701762
# 3         4            1            1         0       0.250296
# 4         5            1            1         0       0.252989
#            count      mean       std       min       25%       50%       75%  \
# is_noisy
# 0         6400.0  0.381137  0.271789  0.037564  0.230303  0.250722  0.442602
# 1         1600.0  1.273724  0.423367  0.093290  0.971704  1.503817  1.574633
#
#                max
# is_noisy
# 0         2.200931
# 1         2.549638

# %%
noise_loss_df.to_csv(
    "Noise_GroundTruth_and_TrainingLoss.csv",
    index=False
)

# %%
train_df.to_csv(
    "NoisyLabel_TrainingData.csv",
    index=False
)

test_df.to_csv(
    "Clean_TestData.csv",
    index=False
)

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
#       Train_ID     Score
# 0            1  0.244800
# 1            2 -0.040638
# 2            3  0.027229
# 3            4  0.241008
# 4            5  0.240168
# ...        ...       ...
# 7995      8496  0.227912
# 7996      8497 -0.791891
# 7997      8498  0.224438
# 7998      8499  0.164666
# 7999      8500  0.318000
#
# [8000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID     Score
# 0            1  0.006162
# 1            2 -0.013262
# 2            3 -0.010094
# 3            4  0.005963
# 4            5  0.005228
# ...        ...       ...
# 7995      8496  0.005383
# 7996      8497 -0.014270
# 7997      8498  0.005413
# 7998      8499  0.028937
# 7999      8500  0.005826
#
# [8000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("NoisyLabel_TracIn_Scores.csv",index = False)
df_sorted.to_csv("NoisyLabel_FOIF_Scores.csv",index = False)
