# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
train_pool = 10000
test_size = 500
train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
seed=42

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
df = pd.read_csv("diamonds.csv")
# Out:
#        features/carat  features/clarity  features/color  features/cut  \
# 0                1.26                 2               4             2
# 1                0.80                 3               4             4
# 2                0.56                 4               2             4
# 3                1.51                 3               6             1
# 4                0.33                 6               5             4
# ...               ...               ...             ...           ...
# 53935            1.02                 2               4             2
# 53936            0.93                 2               4             3
# 53937            0.30                 4               5             4
# 53938            0.36                 3               2             4
# 53939            0.70                 1               2             2
#
#        features/depth  features/table  features/x  features/y  features/z  \
# 0           60.599998            60.0        6.97        7.00        4.23
# 1           62.099998            54.0        5.96        5.99        3.71
# 2           61.700001            54.0        5.28        5.32        3.27
# 3           64.000000            58.0        7.24        7.27        4.64
# 4           62.200001            54.0        4.43        4.45        2.76
# ...               ...             ...         ...         ...         ...
# 53935       62.900002            59.0        6.38        6.41        4.02
# 53936       61.799999            59.0        6.27        6.23        3.86
# 53937       62.400002            54.0        4.30        4.32        2.69
# 53938       61.500000            55.0        4.60        4.57        2.82
# 53939       60.700001            58.0        5.73        5.77        3.49
#
#         price
# 0      6546.0
# 1      3030.0
# 2      1915.0
# 3      6936.0
# 4       646.0
# ...       ...
# 53935  4796.0
# 53936  3750.0
# 53937   491.0
# 53938   807.0
# 53939  2195.0
#
# [53940 rows x 10 columns]

# %%
median_price = df["price"].median()
df["label"] = (df["price"] > median_price).astype(int)
df = df.drop(columns=['price'])

# %%
features = [
    "features/carat",
    "features/clarity",
    "features/color",
    "features/cut",
    "features/depth",
    "features/table",
    "features/x",
    "features/y",
    "features/z",
]

X = df[features]

X = StandardScaler().fit_transform(X)

nbrs = NearestNeighbors(n_neighbors=10500)

nbrs.fit(X)
# Out:
# NearestNeighbors(n_neighbors=10500)

# %%
# for center in np.random.choice(len(df),100):

#     distances, indices = nbrs.kneighbors(
#         X[center].reshape(1,-1)
#     )

#     local = df.iloc[indices[0]]

#     ratio = local["label"].mean()

#     if 0.4 < ratio < 0.6:

#         print(center)
#         print(ratio)

#         break

# %%
center = 32264

distances, indices = nbrs.kneighbors(
    X[center].reshape(1, -1)
)

local_df = df.iloc[indices[0]].copy()
local_distances = distances[0]
local_indices = indices[0]

print("Local size:", len(local_df))
print("Label ratio:", local_df["label"].mean())

print("\nDistance summary:")
print(pd.Series(local_distances).describe())
# Out:
# Local size: 10500
# Label ratio: 0.520095238095238
#
# Distance summary:
# count    10500.000000
# mean         1.818185
# std          0.334028
# min          0.000000
# 25%          1.627980
# 50%          1.896888
# 75%          2.086287
# max          2.231709
# dtype: float64

# %%
random_indices = np.random.choice(len(df), size=10500, replace=False)
random_distances = np.linalg.norm(
    X[random_indices] - X[center],
    axis=1
)

print("\nRandom distance summary:")
print(pd.Series(random_distances).describe())
# Out:
# Random distance summary:
# count    10500.000000
# mean         3.101650
# std          1.078652
# min          0.148894
# 25%          2.369623
# 50%          2.972903
# 75%          3.665986
# max         23.108859
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))

plt.hist(local_distances, bins=40, alpha=0.6, density=True, label="Local 10,500")
plt.hist(random_distances, bins=40, alpha=0.6, density=True, label="Random 10,500")

plt.xlabel("Distance to selected centre", fontsize=14)
plt.ylabel("Density", fontsize=14)
plt.legend(fontsize=12)
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
print("Mean distance")
print("Local :", np.mean(local_distances))
print("Random:", np.mean(random_distances))

print("Median distance")
print("Local :", np.median(local_distances))
print("Random:", np.median(random_distances))

print("Max distance")
print("Local :", np.max(local_distances))
print("Random:", np.max(random_distances))
# Out:
# Mean distance
# Local : 1.818184738698328
# Random: 3.101649596998204
# Median distance
# Local : 1.8968876503288916
# Random: 2.9729033262106954
# Max distance
# Local : 2.2317087702930634
# Random: 23.108859035142853

# %%
local_df = local_df.sample(frac=1, random_state=42)
chunks = np.array_split(local_df, 10)
# Out:
# D:\Python\pyfile\newnewinf\venv\new\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
for i, chunk in enumerate(chunks):

    d = np.linalg.norm(
        X[chunk.index] - X[center],
        axis=1
    )

    print(
        i+1,
        d.mean(),
        d.std(),
        chunk["label"].mean()
    )
# Out:
# 1 1.8093948346513444 0.34633427354842106 0.5238095238095238
# 2 1.8112271816166865 0.3305172427247881 0.49523809523809526
# 3 1.813174917644381 0.3381432255121973 0.54
# 4 1.801029195045253 0.3476267754251883 0.5190476190476191
# 5 1.8132068087711508 0.3343618902630504 0.5066666666666667
# 6 1.8287971323706402 0.3282929726505939 0.5171428571428571
# 7 1.8302800278694702 0.3209668335351515 0.5361904761904762
# 8 1.828076505547085 0.3249853261555477 0.5466666666666666
# 9 1.8215186981251121 0.34270135877807634 0.5085714285714286
# 10 1.8251420853421574 0.32361485293619763 0.5076190476190476

# %%
print(local_df)
# Out:
#        features/carat  features/clarity  features/color  features/cut  \
# 32264            0.70                 2               3             4
# 50793            0.71                 2               3             4
# 16617            0.71                 2               3             4
# 35033            0.71                 2               3             4
# 17105            0.75                 2               3             4
# ...               ...               ...             ...           ...
# 40128            0.53                 3               2             2
# 28254            0.51                 5               3             4
# 39758            0.56                 3               2             2
# 29696            0.73                 5               3             4
# 41846            1.21                 3               3             4
#
#        features/depth  features/table  features/x  features/y  features/z  \
# 32264       62.700001            57.0        5.69        5.64        3.55
# 50793       62.900002            57.0        5.67        5.62        3.55
# 16617       62.500000            57.0        5.72        5.64        3.55
# 35033       62.500000            57.0        5.67        5.69        3.55
# 17105       62.200001            57.0        5.84        5.80        3.62
# ...               ...             ...         ...         ...         ...
# 40128       63.200001            58.0        5.13        5.16        3.25
# 28254       61.599998            56.0        5.17        5.12        3.17
# 39758       62.000000            56.0        5.20        5.22        3.23
# 29696       61.000000            56.0        5.82        5.86        3.56
# 41846       62.000000            56.0        6.77        6.87        4.23
#
#        label
# 32264      0
# 50793      0
# 16617      0
# 35033      1
# 17105      1
# ...      ...
# 40128      0
# 28254      0
# 39758      0
# 29696      1
# 41846      1
#
# [10500 rows x 10 columns]

# %%
local_df = local_df.reset_index(drop=True)

# %%
feature_cols = [c for c in local_df.columns if c != "label"]

rename_dict = {
    old: f"feature_{i+1}"
    for i, old in enumerate(feature_cols)
}

local_df = local_df.rename(columns=rename_dict)

print(local_df.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0       0.70          2          3          4  62.700001       57.0
# 1       0.71          2          3          4  62.900002       57.0
# 2       0.71          2          3          4  62.500000       57.0
# 3       0.71          2          3          4  62.500000       57.0
# 4       0.75          2          3          4  62.200001       57.0
#
#    feature_7  feature_8  feature_9  label
# 0       5.69       5.64       3.55      0
# 1       5.67       5.62       3.55      0
# 2       5.72       5.64       3.55      0
# 3       5.67       5.69       3.55      1
# 4       5.84       5.80       3.62      1

# %%
df = local_df.copy()

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df['id'] = np.arange(1, len(df) + 1)
print(df)
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0           0.70          2          3          4  62.700001       57.0
# 1           0.71          2          3          4  62.900002       57.0
# 2           0.71          2          3          4  62.500000       57.0
# 3           0.71          2          3          4  62.500000       57.0
# 4           0.75          2          3          4  62.200001       57.0
# ...          ...        ...        ...        ...        ...        ...
# 10495       0.53          3          2          2  63.200001       58.0
# 10496       0.51          5          3          4  61.599998       56.0
# 10497       0.56          3          2          2  62.000000       56.0
# 10498       0.73          5          3          4  61.000000       56.0
# 10499       1.21          3          3          4  62.000000       56.0
#
#        feature_7  feature_8  feature_9  label     id
# 0           5.69       5.64       3.55      0      1
# 1           5.67       5.62       3.55      0      2
# 2           5.72       5.64       3.55      0      3
# 3           5.67       5.69       3.55      1      4
# 4           5.84       5.80       3.62      1      5
# ...          ...        ...        ...    ...    ...
# 10495       5.13       5.16       3.25      0  10496
# 10496       5.17       5.12       3.17      0  10497
# 10497       5.20       5.22       3.23      0  10498
# 10498       5.82       5.86       3.56      1  10499
# 10499       6.77       6.87       4.23      1  10500
#
# [10500 rows x 11 columns]

# %%
df = df.sample(
    frac=1,
    random_state=36
).reset_index(drop=True)

# %%
df_train_pool = df.iloc[:train_pool].reset_index(drop=True)
df_test = df.iloc[train_pool:].reset_index(drop=True)

# %%
print(df_train_pool.head())
print(df_test.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0       0.52          4          1          4  61.799999       56.0
# 1       1.11          1          4          4  62.700001       57.0
# 2       1.04          3          3          4  61.799999       56.0
# 3       1.08          2          2          3  61.299999       57.0
# 4       0.61          1          1          4  62.000000       54.0
#
#    feature_7  feature_8  feature_9  label    id
# 0       5.17       5.19       3.20      0  7350
# 1       6.59       6.66       4.14      1  5269
# 2       6.50       6.47       4.01      1  3421
# 3       6.63       6.58       4.05      1  8998
# 4       5.46       5.48       3.39      0  6344
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0       0.53          5          3          4  61.400002       57.0
# 1       0.74          1          3          2  63.799999       56.0
# 2       1.11          1          2          3  62.099998       58.0
# 3       1.01          2          2          3  63.000000       58.0
# 4       0.74          1          2          2  63.099998       58.0
#
#    feature_7  feature_8  feature_9  label     id
# 0       5.17       5.20       3.18      0  10195
# 1       5.70       5.74       3.65      1   8065
# 2       6.63       6.51       4.10      1   8611
# 3       6.33       6.29       3.98      1   3113
# 4       5.76       5.72       3.62      0   7398

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %%
nested_train_dfs = [df_train_pool.iloc[:size].reset_index(drop=True) for size in train_sizes]

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df = nested_train_dfs[0]

# %%
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]
IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
X_train = np.hstack((X_train, IDs))
y_train = to_categorical(y_train.values,num_classes=2)

print(X_train)
# Out:
# [[5.200e-01 4.000e+00 1.000e+00 ... 5.190e+00 3.200e+00 7.350e-07]
#  [1.110e+00 1.000e+00 4.000e+00 ... 6.660e+00 4.140e+00 5.269e-07]
#  [1.040e+00 3.000e+00 3.000e+00 ... 6.470e+00 4.010e+00 3.421e-07]
#  ...
#  [7.000e-01 3.000e+00 3.000e+00 ... 5.630e+00 3.510e+00 7.340e-08]
#  [7.200e-01 3.000e+00 3.000e+00 ... 5.760e+00 3.600e+00 8.200e-09]
#  [7.000e-01 2.000e+00 3.000e+00 ... 5.740e+00 3.510e+00 4.777e-07]]

# %%
test_df = df_test
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test)
# Out:
# [[5.3000e-01 5.0000e+00 3.0000e+00 ... 5.2000e+00 3.1800e+00 1.0195e-06]
#  [7.4000e-01 1.0000e+00 3.0000e+00 ... 5.7400e+00 3.6500e+00 8.0650e-07]
#  [1.1100e+00 1.0000e+00 2.0000e+00 ... 6.5100e+00 4.1000e+00 8.6110e-07]
#  ...
#  [7.0000e-01 4.0000e+00 3.0000e+00 ... 5.7500e+00 3.5000e+00 2.9850e-07]
#  [7.0000e-01 4.0000e+00 2.0000e+00 ... 5.7900e+00 3.4700e+00 9.1190e-07]
#  [9.0000e-01 3.0000e+00 4.0000e+00 ... 6.1500e+00 3.8500e+00 6.1100e-08]]

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 4/4 - 1s - loss: 0.7310 - accuracy: 0.5220 - val_loss: 3.6431 - val_accuracy: 0.4680 - 509ms/epoch - 127ms/step
# 4/4 - 0s - loss: 0.6844 - accuracy: 0.5690 - val_loss: 2.5080 - val_accuracy: 0.4680 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.6766 - accuracy: 0.5760 - val_loss: 1.6041 - val_accuracy: 0.4680 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.6673 - accuracy: 0.5900 - val_loss: 1.0301 - val_accuracy: 0.4700 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.6579 - accuracy: 0.6060 - val_loss: 0.7759 - val_accuracy: 0.5120 - 54ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.6476 - accuracy: 0.6190 - val_loss: 0.6832 - val_accuracy: 0.5700 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.6381 - accuracy: 0.6470 - val_loss: 0.6590 - val_accuracy: 0.5980 - 42ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.6286 - accuracy: 0.6720 - val_loss: 0.6496 - val_accuracy: 0.6420 - 59ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.6198 - accuracy: 0.6900 - val_loss: 0.6286 - val_accuracy: 0.6760 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.6110 - accuracy: 0.7030 - val_loss: 0.6215 - val_accuracy: 0.6860 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.6031 - accuracy: 0.7220 - val_loss: 0.6018 - val_accuracy: 0.7420 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.5951 - accuracy: 0.7260 - val_loss: 0.6071 - val_accuracy: 0.7260 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5877 - accuracy: 0.7370 - val_loss: 0.6050 - val_accuracy: 0.7300 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5809 - accuracy: 0.7470 - val_loss: 0.5895 - val_accuracy: 0.7700 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5737 - accuracy: 0.7590 - val_loss: 0.6003 - val_accuracy: 0.7560 - 34ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.5669 - accuracy: 0.7750 - val_loss: 0.6073 - val_accuracy: 0.7120 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5604 - accuracy: 0.7830 - val_loss: 0.6034 - val_accuracy: 0.7240 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5536 - accuracy: 0.7930 - val_loss: 0.5866 - val_accuracy: 0.7860 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5467 - accuracy: 0.7950 - val_loss: 0.5712 - val_accuracy: 0.7980 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.5401 - accuracy: 0.8050 - val_loss: 0.5604 - val_accuracy: 0.8000 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5334 - accuracy: 0.8100 - val_loss: 0.5553 - val_accuracy: 0.8060 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5268 - accuracy: 0.8130 - val_loss: 0.5558 - val_accuracy: 0.7900 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5202 - accuracy: 0.8120 - val_loss: 0.5419 - val_accuracy: 0.8100 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5137 - accuracy: 0.8170 - val_loss: 0.5264 - val_accuracy: 0.8320 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5071 - accuracy: 0.8210 - val_loss: 0.5220 - val_accuracy: 0.8380 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5006 - accuracy: 0.8210 - val_loss: 0.5193 - val_accuracy: 0.8360 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4940 - accuracy: 0.8220 - val_loss: 0.5112 - val_accuracy: 0.8360 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4875 - accuracy: 0.8240 - val_loss: 0.5019 - val_accuracy: 0.8320 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4810 - accuracy: 0.8260 - val_loss: 0.4953 - val_accuracy: 0.8340 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4746 - accuracy: 0.8300 - val_loss: 0.4878 - val_accuracy: 0.8360 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.4682 - accuracy: 0.8340 - val_loss: 0.4810 - val_accuracy: 0.8280 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4619 - accuracy: 0.8350 - val_loss: 0.4760 - val_accuracy: 0.8300 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4555 - accuracy: 0.8370 - val_loss: 0.4761 - val_accuracy: 0.8520 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4488 - accuracy: 0.8390 - val_loss: 0.4811 - val_accuracy: 0.8460 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4424 - accuracy: 0.8430 - val_loss: 0.4803 - val_accuracy: 0.8420 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4361 - accuracy: 0.8450 - val_loss: 0.4737 - val_accuracy: 0.8460 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4298 - accuracy: 0.8470 - val_loss: 0.4643 - val_accuracy: 0.8560 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4235 - accuracy: 0.8520 - val_loss: 0.4530 - val_accuracy: 0.8660 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.4173 - accuracy: 0.8570 - val_loss: 0.4421 - val_accuracy: 0.8640 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.4111 - accuracy: 0.8600 - val_loss: 0.4335 - val_accuracy: 0.8600 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4050 - accuracy: 0.8650 - val_loss: 0.4249 - val_accuracy: 0.8600 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.3989 - accuracy: 0.8660 - val_loss: 0.4181 - val_accuracy: 0.8540 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3929 - accuracy: 0.8670 - val_loss: 0.4110 - val_accuracy: 0.8500 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3869 - accuracy: 0.8690 - val_loss: 0.4042 - val_accuracy: 0.8460 - 54ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.3810 - accuracy: 0.8710 - val_loss: 0.3990 - val_accuracy: 0.8420 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3751 - accuracy: 0.8760 - val_loss: 0.3947 - val_accuracy: 0.8460 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3692 - accuracy: 0.8830 - val_loss: 0.3902 - val_accuracy: 0.8460 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3634 - accuracy: 0.8930 - val_loss: 0.3863 - val_accuracy: 0.8360 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.3576 - accuracy: 0.8960 - val_loss: 0.3832 - val_accuracy: 0.8420 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3519 - accuracy: 0.8970 - val_loss: 0.3814 - val_accuracy: 0.8360 - 66ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.3462 - accuracy: 0.8990 - val_loss: 0.3794 - val_accuracy: 0.8380 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3406 - accuracy: 0.9010 - val_loss: 0.3771 - val_accuracy: 0.8340 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3351 - accuracy: 0.9050 - val_loss: 0.3747 - val_accuracy: 0.8320 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3296 - accuracy: 0.9070 - val_loss: 0.3716 - val_accuracy: 0.8340 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3243 - accuracy: 0.9080 - val_loss: 0.3677 - val_accuracy: 0.8400 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3191 - accuracy: 0.9080 - val_loss: 0.3632 - val_accuracy: 0.8400 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.3139 - accuracy: 0.9120 - val_loss: 0.3584 - val_accuracy: 0.8420 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.3089 - accuracy: 0.9170 - val_loss: 0.3533 - val_accuracy: 0.8500 - 58ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.3040 - accuracy: 0.9180 - val_loss: 0.3480 - val_accuracy: 0.8540 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2993 - accuracy: 0.9190 - val_loss: 0.3429 - val_accuracy: 0.8640 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2946 - accuracy: 0.9240 - val_loss: 0.3379 - val_accuracy: 0.8680 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2900 - accuracy: 0.9250 - val_loss: 0.3330 - val_accuracy: 0.8680 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2855 - accuracy: 0.9270 - val_loss: 0.3283 - val_accuracy: 0.8660 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2812 - accuracy: 0.9280 - val_loss: 0.3235 - val_accuracy: 0.8700 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2769 - accuracy: 0.9300 - val_loss: 0.3186 - val_accuracy: 0.8720 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2728 - accuracy: 0.9320 - val_loss: 0.3145 - val_accuracy: 0.8720 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2687 - accuracy: 0.9330 - val_loss: 0.3112 - val_accuracy: 0.8700 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2647 - accuracy: 0.9330 - val_loss: 0.3082 - val_accuracy: 0.8740 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2609 - accuracy: 0.9340 - val_loss: 0.3054 - val_accuracy: 0.8740 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2571 - accuracy: 0.9380 - val_loss: 0.3027 - val_accuracy: 0.8760 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2535 - accuracy: 0.9370 - val_loss: 0.3002 - val_accuracy: 0.8820 - 61ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.2499 - accuracy: 0.9370 - val_loss: 0.2981 - val_accuracy: 0.8820 - 60ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.2465 - accuracy: 0.9380 - val_loss: 0.2961 - val_accuracy: 0.8800 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.2431 - accuracy: 0.9380 - val_loss: 0.2941 - val_accuracy: 0.8800 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2399 - accuracy: 0.9380 - val_loss: 0.2926 - val_accuracy: 0.8800 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2367 - accuracy: 0.9390 - val_loss: 0.2913 - val_accuracy: 0.8800 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.2336 - accuracy: 0.9410 - val_loss: 0.2897 - val_accuracy: 0.8800 - 61ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.2306 - accuracy: 0.9410 - val_loss: 0.2877 - val_accuracy: 0.8780 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2277 - accuracy: 0.9420 - val_loss: 0.2856 - val_accuracy: 0.8800 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2249 - accuracy: 0.9430 - val_loss: 0.2835 - val_accuracy: 0.8800 - 50ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.2222 - accuracy: 0.9430 - val_loss: 0.2817 - val_accuracy: 0.8820 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2195 - accuracy: 0.9450 - val_loss: 0.2801 - val_accuracy: 0.8820 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2169 - accuracy: 0.9450 - val_loss: 0.2785 - val_accuracy: 0.8820 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2144 - accuracy: 0.9450 - val_loss: 0.2767 - val_accuracy: 0.8840 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2120 - accuracy: 0.9450 - val_loss: 0.2750 - val_accuracy: 0.8840 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2096 - accuracy: 0.9450 - val_loss: 0.2732 - val_accuracy: 0.8840 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2073 - accuracy: 0.9450 - val_loss: 0.2714 - val_accuracy: 0.8840 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.2051 - accuracy: 0.9450 - val_loss: 0.2692 - val_accuracy: 0.8840 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2030 - accuracy: 0.9460 - val_loss: 0.2664 - val_accuracy: 0.8840 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.2009 - accuracy: 0.9470 - val_loss: 0.2635 - val_accuracy: 0.8860 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1988 - accuracy: 0.9490 - val_loss: 0.2607 - val_accuracy: 0.8860 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1968 - accuracy: 0.9470 - val_loss: 0.2577 - val_accuracy: 0.8920 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1949 - accuracy: 0.9470 - val_loss: 0.2545 - val_accuracy: 0.8980 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1930 - accuracy: 0.9480 - val_loss: 0.2513 - val_accuracy: 0.8980 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1912 - accuracy: 0.9480 - val_loss: 0.2483 - val_accuracy: 0.8980 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1894 - accuracy: 0.9480 - val_loss: 0.2456 - val_accuracy: 0.9000 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1876 - accuracy: 0.9480 - val_loss: 0.2429 - val_accuracy: 0.9040 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1859 - accuracy: 0.9480 - val_loss: 0.2401 - val_accuracy: 0.9060 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1843 - accuracy: 0.9470 - val_loss: 0.2376 - val_accuracy: 0.9080 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1826 - accuracy: 0.9480 - val_loss: 0.2353 - val_accuracy: 0.9080 - 52ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.1811 - accuracy: 0.9470 - val_loss: 0.2331 - val_accuracy: 0.9100 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1795 - accuracy: 0.9470 - val_loss: 0.2306 - val_accuracy: 0.9100 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1780 - accuracy: 0.9470 - val_loss: 0.2281 - val_accuracy: 0.9100 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1766 - accuracy: 0.9460 - val_loss: 0.2257 - val_accuracy: 0.9100 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1752 - accuracy: 0.9460 - val_loss: 0.2233 - val_accuracy: 0.9100 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1738 - accuracy: 0.9460 - val_loss: 0.2210 - val_accuracy: 0.9100 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1724 - accuracy: 0.9460 - val_loss: 0.2189 - val_accuracy: 0.9120 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1711 - accuracy: 0.9470 - val_loss: 0.2169 - val_accuracy: 0.9140 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1699 - accuracy: 0.9480 - val_loss: 0.2150 - val_accuracy: 0.9140 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1686 - accuracy: 0.9480 - val_loss: 0.2131 - val_accuracy: 0.9140 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1674 - accuracy: 0.9510 - val_loss: 0.2112 - val_accuracy: 0.9200 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.1662 - accuracy: 0.9510 - val_loss: 0.2092 - val_accuracy: 0.9200 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1651 - accuracy: 0.9520 - val_loss: 0.2073 - val_accuracy: 0.9200 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1640 - accuracy: 0.9520 - val_loss: 0.2052 - val_accuracy: 0.9240 - 60ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.1629 - accuracy: 0.9520 - val_loss: 0.2033 - val_accuracy: 0.9260 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1618 - accuracy: 0.9520 - val_loss: 0.2015 - val_accuracy: 0.9280 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1607 - accuracy: 0.9520 - val_loss: 0.1995 - val_accuracy: 0.9300 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1597 - accuracy: 0.9520 - val_loss: 0.1973 - val_accuracy: 0.9300 - 63ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.1587 - accuracy: 0.9520 - val_loss: 0.1951 - val_accuracy: 0.9300 - 65ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.1577 - accuracy: 0.9520 - val_loss: 0.1932 - val_accuracy: 0.9320 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1568 - accuracy: 0.9520 - val_loss: 0.1913 - val_accuracy: 0.9320 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1559 - accuracy: 0.9510 - val_loss: 0.1896 - val_accuracy: 0.9320 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1549 - accuracy: 0.9510 - val_loss: 0.1879 - val_accuracy: 0.9320 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1541 - accuracy: 0.9510 - val_loss: 0.1862 - val_accuracy: 0.9320 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1532 - accuracy: 0.9510 - val_loss: 0.1842 - val_accuracy: 0.9340 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1523 - accuracy: 0.9510 - val_loss: 0.1822 - val_accuracy: 0.9340 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1515 - accuracy: 0.9510 - val_loss: 0.1802 - val_accuracy: 0.9340 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1507 - accuracy: 0.9520 - val_loss: 0.1784 - val_accuracy: 0.9340 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1499 - accuracy: 0.9520 - val_loss: 0.1766 - val_accuracy: 0.9360 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1491 - accuracy: 0.9530 - val_loss: 0.1749 - val_accuracy: 0.9360 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1484 - accuracy: 0.9530 - val_loss: 0.1734 - val_accuracy: 0.9380 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1476 - accuracy: 0.9520 - val_loss: 0.1720 - val_accuracy: 0.9380 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1469 - accuracy: 0.9520 - val_loss: 0.1707 - val_accuracy: 0.9400 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1462 - accuracy: 0.9520 - val_loss: 0.1700 - val_accuracy: 0.9400 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1455 - accuracy: 0.9520 - val_loss: 0.1695 - val_accuracy: 0.9400 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1448 - accuracy: 0.9530 - val_loss: 0.1689 - val_accuracy: 0.9400 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1441 - accuracy: 0.9530 - val_loss: 0.1682 - val_accuracy: 0.9400 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1434 - accuracy: 0.9530 - val_loss: 0.1674 - val_accuracy: 0.9400 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1428 - accuracy: 0.9530 - val_loss: 0.1666 - val_accuracy: 0.9400 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1421 - accuracy: 0.9530 - val_loss: 0.1656 - val_accuracy: 0.9420 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1415 - accuracy: 0.9530 - val_loss: 0.1644 - val_accuracy: 0.9420 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1409 - accuracy: 0.9530 - val_loss: 0.1631 - val_accuracy: 0.9400 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1403 - accuracy: 0.9520 - val_loss: 0.1616 - val_accuracy: 0.9380 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1397 - accuracy: 0.9520 - val_loss: 0.1601 - val_accuracy: 0.9380 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1391 - accuracy: 0.9520 - val_loss: 0.1586 - val_accuracy: 0.9360 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1385 - accuracy: 0.9520 - val_loss: 0.1573 - val_accuracy: 0.9380 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1380 - accuracy: 0.9530 - val_loss: 0.1560 - val_accuracy: 0.9400 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1374 - accuracy: 0.9530 - val_loss: 0.1549 - val_accuracy: 0.9400 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1369 - accuracy: 0.9530 - val_loss: 0.1538 - val_accuracy: 0.9400 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1364 - accuracy: 0.9530 - val_loss: 0.1528 - val_accuracy: 0.9400 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1358 - accuracy: 0.9530 - val_loss: 0.1519 - val_accuracy: 0.9400 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1353 - accuracy: 0.9530 - val_loss: 0.1509 - val_accuracy: 0.9400 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1348 - accuracy: 0.9530 - val_loss: 0.1498 - val_accuracy: 0.9420 - 65ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.1343 - accuracy: 0.9530 - val_loss: 0.1488 - val_accuracy: 0.9420 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1339 - accuracy: 0.9530 - val_loss: 0.1478 - val_accuracy: 0.9420 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1334 - accuracy: 0.9530 - val_loss: 0.1468 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1329 - accuracy: 0.9530 - val_loss: 0.1459 - val_accuracy: 0.9440 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1325 - accuracy: 0.9530 - val_loss: 0.1450 - val_accuracy: 0.9460 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1320 - accuracy: 0.9530 - val_loss: 0.1440 - val_accuracy: 0.9480 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1316 - accuracy: 0.9530 - val_loss: 0.1430 - val_accuracy: 0.9480 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1312 - accuracy: 0.9530 - val_loss: 0.1421 - val_accuracy: 0.9460 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1307 - accuracy: 0.9530 - val_loss: 0.1412 - val_accuracy: 0.9460 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1303 - accuracy: 0.9530 - val_loss: 0.1404 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1299 - accuracy: 0.9530 - val_loss: 0.1396 - val_accuracy: 0.9460 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1295 - accuracy: 0.9530 - val_loss: 0.1389 - val_accuracy: 0.9460 - 58ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1291 - accuracy: 0.9530 - val_loss: 0.1382 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1287 - accuracy: 0.9530 - val_loss: 0.1375 - val_accuracy: 0.9460 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1283 - accuracy: 0.9540 - val_loss: 0.1369 - val_accuracy: 0.9460 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1280 - accuracy: 0.9540 - val_loss: 0.1364 - val_accuracy: 0.9460 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1276 - accuracy: 0.9540 - val_loss: 0.1359 - val_accuracy: 0.9460 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1272 - accuracy: 0.9540 - val_loss: 0.1354 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1269 - accuracy: 0.9540 - val_loss: 0.1349 - val_accuracy: 0.9460 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1265 - accuracy: 0.9540 - val_loss: 0.1344 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1262 - accuracy: 0.9540 - val_loss: 0.1339 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1258 - accuracy: 0.9540 - val_loss: 0.1334 - val_accuracy: 0.9480 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1255 - accuracy: 0.9540 - val_loss: 0.1328 - val_accuracy: 0.9480 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1252 - accuracy: 0.9560 - val_loss: 0.1320 - val_accuracy: 0.9500 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1248 - accuracy: 0.9560 - val_loss: 0.1312 - val_accuracy: 0.9480 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1245 - accuracy: 0.9560 - val_loss: 0.1304 - val_accuracy: 0.9480 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1242 - accuracy: 0.9560 - val_loss: 0.1298 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1239 - accuracy: 0.9560 - val_loss: 0.1292 - val_accuracy: 0.9460 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1236 - accuracy: 0.9560 - val_loss: 0.1287 - val_accuracy: 0.9440 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1233 - accuracy: 0.9560 - val_loss: 0.1282 - val_accuracy: 0.9440 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1230 - accuracy: 0.9570 - val_loss: 0.1278 - val_accuracy: 0.9440 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1227 - accuracy: 0.9560 - val_loss: 0.1274 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1224 - accuracy: 0.9560 - val_loss: 0.1271 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1221 - accuracy: 0.9560 - val_loss: 0.1268 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1219 - accuracy: 0.9560 - val_loss: 0.1265 - val_accuracy: 0.9440 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1216 - accuracy: 0.9560 - val_loss: 0.1263 - val_accuracy: 0.9440 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1213 - accuracy: 0.9560 - val_loss: 0.1260 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1210 - accuracy: 0.9560 - val_loss: 0.1257 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1208 - accuracy: 0.9560 - val_loss: 0.1254 - val_accuracy: 0.9440 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1205 - accuracy: 0.9560 - val_loss: 0.1251 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1203 - accuracy: 0.9560 - val_loss: 0.1247 - val_accuracy: 0.9440 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1200 - accuracy: 0.9560 - val_loss: 0.1243 - val_accuracy: 0.9460 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1198 - accuracy: 0.9560 - val_loss: 0.1240 - val_accuracy: 0.9460 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1195 - accuracy: 0.9560 - val_loss: 0.1236 - val_accuracy: 0.9460 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1193 - accuracy: 0.9560 - val_loss: 0.1233 - val_accuracy: 0.9480 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1190 - accuracy: 0.9560 - val_loss: 0.1229 - val_accuracy: 0.9480 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1188 - accuracy: 0.9560 - val_loss: 0.1226 - val_accuracy: 0.9500 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1185 - accuracy: 0.9560 - val_loss: 0.1223 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1183 - accuracy: 0.9560 - val_loss: 0.1220 - val_accuracy: 0.9500 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1181 - accuracy: 0.9560 - val_loss: 0.1217 - val_accuracy: 0.9500 - 34ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1179 - accuracy: 0.9560 - val_loss: 0.1214 - val_accuracy: 0.9500 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1176 - accuracy: 0.9560 - val_loss: 0.1212 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1174 - accuracy: 0.9570 - val_loss: 0.1210 - val_accuracy: 0.9500 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1172 - accuracy: 0.9570 - val_loss: 0.1208 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1170 - accuracy: 0.9570 - val_loss: 0.1206 - val_accuracy: 0.9500 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1168 - accuracy: 0.9570 - val_loss: 0.1204 - val_accuracy: 0.9500 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1166 - accuracy: 0.9570 - val_loss: 0.1203 - val_accuracy: 0.9500 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1164 - accuracy: 0.9570 - val_loss: 0.1201 - val_accuracy: 0.9500 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1162 - accuracy: 0.9570 - val_loss: 0.1199 - val_accuracy: 0.9500 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.1160 - accuracy: 0.9570 - val_loss: 0.1197 - val_accuracy: 0.9500 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1158 - accuracy: 0.9570 - val_loss: 0.1195 - val_accuracy: 0.9520 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1156 - accuracy: 0.9570 - val_loss: 0.1194 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1154 - accuracy: 0.9570 - val_loss: 0.1193 - val_accuracy: 0.9500 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1152 - accuracy: 0.9570 - val_loss: 0.1191 - val_accuracy: 0.9500 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1150 - accuracy: 0.9570 - val_loss: 0.1190 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1148 - accuracy: 0.9570 - val_loss: 0.1188 - val_accuracy: 0.9500 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1146 - accuracy: 0.9570 - val_loss: 0.1186 - val_accuracy: 0.9500 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1145 - accuracy: 0.9570 - val_loss: 0.1184 - val_accuracy: 0.9500 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1143 - accuracy: 0.9570 - val_loss: 0.1182 - val_accuracy: 0.9500 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1141 - accuracy: 0.9570 - val_loss: 0.1180 - val_accuracy: 0.9500 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1139 - accuracy: 0.9570 - val_loss: 0.1178 - val_accuracy: 0.9500 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1138 - accuracy: 0.9570 - val_loss: 0.1176 - val_accuracy: 0.9500 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1136 - accuracy: 0.9570 - val_loss: 0.1174 - val_accuracy: 0.9500 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1134 - accuracy: 0.9570 - val_loss: 0.1172 - val_accuracy: 0.9520 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1133 - accuracy: 0.9570 - val_loss: 0.1170 - val_accuracy: 0.9520 - 34ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1131 - accuracy: 0.9570 - val_loss: 0.1168 - val_accuracy: 0.9520 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1129 - accuracy: 0.9570 - val_loss: 0.1165 - val_accuracy: 0.9520 - 67ms/epoch - 17ms/step
# 4/4 - 0s - loss: 0.1128 - accuracy: 0.9570 - val_loss: 0.1163 - val_accuracy: 0.9520 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1126 - accuracy: 0.9570 - val_loss: 0.1160 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1125 - accuracy: 0.9570 - val_loss: 0.1158 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1123 - accuracy: 0.9570 - val_loss: 0.1156 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1121 - accuracy: 0.9570 - val_loss: 0.1154 - val_accuracy: 0.9540 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1120 - accuracy: 0.9570 - val_loss: 0.1152 - val_accuracy: 0.9540 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1118 - accuracy: 0.9570 - val_loss: 0.1150 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1117 - accuracy: 0.9570 - val_loss: 0.1148 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1116 - accuracy: 0.9580 - val_loss: 0.1146 - val_accuracy: 0.9540 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1114 - accuracy: 0.9580 - val_loss: 0.1144 - val_accuracy: 0.9540 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1113 - accuracy: 0.9580 - val_loss: 0.1143 - val_accuracy: 0.9560 - 65ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.1111 - accuracy: 0.9580 - val_loss: 0.1141 - val_accuracy: 0.9560 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1110 - accuracy: 0.9580 - val_loss: 0.1140 - val_accuracy: 0.9540 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1108 - accuracy: 0.9580 - val_loss: 0.1139 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1107 - accuracy: 0.9580 - val_loss: 0.1138 - val_accuracy: 0.9540 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1106 - accuracy: 0.9580 - val_loss: 0.1136 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1104 - accuracy: 0.9580 - val_loss: 0.1135 - val_accuracy: 0.9540 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1103 - accuracy: 0.9580 - val_loss: 0.1134 - val_accuracy: 0.9540 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1102 - accuracy: 0.9580 - val_loss: 0.1132 - val_accuracy: 0.9540 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.1101 - accuracy: 0.9580 - val_loss: 0.1130 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1099 - accuracy: 0.9590 - val_loss: 0.1128 - val_accuracy: 0.9580 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1098 - accuracy: 0.9590 - val_loss: 0.1126 - val_accuracy: 0.9580 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1097 - accuracy: 0.9590 - val_loss: 0.1124 - val_accuracy: 0.9580 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1096 - accuracy: 0.9590 - val_loss: 0.1122 - val_accuracy: 0.9580 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1094 - accuracy: 0.9590 - val_loss: 0.1121 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1093 - accuracy: 0.9580 - val_loss: 0.1120 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1092 - accuracy: 0.9580 - val_loss: 0.1118 - val_accuracy: 0.9580 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1091 - accuracy: 0.9580 - val_loss: 0.1117 - val_accuracy: 0.9580 - 57ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1090 - accuracy: 0.9580 - val_loss: 0.1116 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1088 - accuracy: 0.9580 - val_loss: 0.1114 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1087 - accuracy: 0.9580 - val_loss: 0.1113 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1086 - accuracy: 0.9580 - val_loss: 0.1111 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1085 - accuracy: 0.9580 - val_loss: 0.1110 - val_accuracy: 0.9560 - 52ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.1084 - accuracy: 0.9580 - val_loss: 0.1109 - val_accuracy: 0.9560 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.1083 - accuracy: 0.9580 - val_loss: 0.1107 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1082 - accuracy: 0.9580 - val_loss: 0.1106 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1081 - accuracy: 0.9580 - val_loss: 0.1105 - val_accuracy: 0.9560 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1080 - accuracy: 0.9580 - val_loss: 0.1103 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1079 - accuracy: 0.9580 - val_loss: 0.1102 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1078 - accuracy: 0.9580 - val_loss: 0.1100 - val_accuracy: 0.9560 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1076 - accuracy: 0.9580 - val_loss: 0.1099 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1075 - accuracy: 0.9580 - val_loss: 0.1097 - val_accuracy: 0.9540 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1074 - accuracy: 0.9580 - val_loss: 0.1096 - val_accuracy: 0.9520 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1073 - accuracy: 0.9580 - val_loss: 0.1095 - val_accuracy: 0.9520 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1072 - accuracy: 0.9580 - val_loss: 0.1093 - val_accuracy: 0.9520 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1072 - accuracy: 0.9580 - val_loss: 0.1092 - val_accuracy: 0.9520 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1071 - accuracy: 0.9580 - val_loss: 0.1091 - val_accuracy: 0.9520 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1070 - accuracy: 0.9580 - val_loss: 0.1090 - val_accuracy: 0.9520 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1069 - accuracy: 0.9580 - val_loss: 0.1089 - val_accuracy: 0.9520 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1068 - accuracy: 0.9580 - val_loss: 0.1088 - val_accuracy: 0.9520 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.1067 - accuracy: 0.9580 - val_loss: 0.1087 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1066 - accuracy: 0.9580 - val_loss: 0.1086 - val_accuracy: 0.9540 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1065 - accuracy: 0.9580 - val_loss: 0.1086 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1064 - accuracy: 0.9580 - val_loss: 0.1085 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1063 - accuracy: 0.9580 - val_loss: 0.1084 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1062 - accuracy: 0.9580 - val_loss: 0.1082 - val_accuracy: 0.9540 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1061 - accuracy: 0.9590 - val_loss: 0.1081 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1061 - accuracy: 0.9590 - val_loss: 0.1080 - val_accuracy: 0.9540 - 34ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1060 - accuracy: 0.9590 - val_loss: 0.1079 - val_accuracy: 0.9540 - 30ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1059 - accuracy: 0.9590 - val_loss: 0.1078 - val_accuracy: 0.9540 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1058 - accuracy: 0.9590 - val_loss: 0.1077 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.1057 - accuracy: 0.9600 - val_loss: 0.1076 - val_accuracy: 0.9520 - 34ms/epoch - 8ms/step
# 4/4 - 0s - loss: 0.1056 - accuracy: 0.9600 - val_loss: 0.1075 - val_accuracy: 0.9520 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1056 - accuracy: 0.9600 - val_loss: 0.1075 - val_accuracy: 0.9540 - 59ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.1055 - accuracy: 0.9600 - val_loss: 0.1074 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1054 - accuracy: 0.9600 - val_loss: 0.1073 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1053 - accuracy: 0.9600 - val_loss: 0.1072 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1052 - accuracy: 0.9600 - val_loss: 0.1071 - val_accuracy: 0.9540 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1052 - accuracy: 0.9600 - val_loss: 0.1070 - val_accuracy: 0.9540 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.1051 - accuracy: 0.9600 - val_loss: 0.1070 - val_accuracy: 0.9540 - 39ms/epoch - 10ms/step
# 16/16 - 0s - loss: 0.1070 - accuracy: 0.9540 - 31ms/epoch - 2ms/step
# 0.10696367919445038

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
#      Train_ID     Score
# 0        7350  0.006239
# 1        5269  0.000790
# 2        3421  0.000630
# 3        8998  0.000578
# 4        6344  0.004021
# ..        ...       ...
# 995      4440  0.000419
# 996       866 -0.026868
# 997       734 -0.011206
# 998        82  0.029813
# 999      4777  0.020962
#
# [1000 rows x 2 columns]

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#      Train_ID     Score
# 0        7350 -0.000004
# 1        5269  0.000004
# 2        3421  0.000004
# 3        8998  0.000004
# 4        6344 -0.000041
# ..        ...       ...
# 995      4440  0.000003
# 996       866 -0.001152
# 997       734  0.000541
# 998        82  0.000325
# 999      4777 -0.000158
#
# [1000 rows x 2 columns]

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
TracIn_sorted.to_csv("TC_Train_Set_1_diamonds.csv",index = False)
df_sorted.to_csv("IF_Train_Set_1_diamonds.csv",index = False)
