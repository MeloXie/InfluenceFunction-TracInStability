# %% [markdown]
# ## This is the code to train the model and acquire influence for Number of Samples Experiment

# %% [markdown]
# **Default Code**:
# The current default code is a runnable sample. It runs on the synthetic dataset generated with sklearn's make_classification function. The default version code provides the synthetic dataset with 16500 samples and 160 features in total. The separation is set to 5 to make sure the dataset is distinguishable by the model. All features are set to be informative to ensure they are of equal importance. The dataset has only two labels, so it is a binary classification problem. The default setting will then generate the training set and test set from the pool. The default training sample size is 8000, and the test size is 500. The number of features is set to 10. The model in default will be a Simple FeedForward Neural Network constructed by TensorFlow. The Influence Estimation methods we provide by default are the Influence Function and TracIn. If you simply press 'play', the default code will generate ranked influence lists for both Influence Function and TracIn with respect to the above mentioned setting in the root directory. The result lists could then be fed into other analyses.

# %% [markdown]
# **By default, this is exactly the same code as the base code. Please refer to the base code for more detailed explanation.**

# %% [markdown]
# **Guideline**:
# Read in / Construct Datasets -> **Choose the Training Sample Size** -> Pre-processing -> Model Training -> Influence Estimation -> Store the Ranked Influence lists -> **Change the Training Sample Size and Repeat all the process** -> ... -> **After all the training and estimation, feed the results into the analysis code**  (Remember to change the file name in the last block to save lists in different settings.)

# %% [markdown]
# # Import Area

# %% [markdown]
# Here is the area to place all the import codes. You don't need to change here unless you want to customise in later sections.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam

# %%
from deel.influenciae.common import InfluenceModel, ExactIHVP
from deel.influenciae.influence import FirstOrderInfluenceCalculator
from deel.influenciae.utils import ORDER
from deel.influenciae.trac_in import TracIn

# %%
import random
from keras.optimizers import SGD

# %%
from sklearn.datasets import make_classification

# %%
import time

# %% [markdown]
# # Dataset Construction Area

# %% [markdown]
# **You can use any dataset you wish here, either regression or classification. But in default, since we are using influenciae's IF and TC method, make sure they are split into train and test sets, and then stored as tensorflow dataset format. If you only want to change the dataset, you can only change the code in the first two blocks to read in/ generate your own dataset. But remember to have features X and target y before going to the third block. Also, if you wish to everything on your own, remember to add id inside the dataset.** Since our default code is for classification, the regression might need a lot of changes in all the following sections.
#
#
# **Input**: Dataset chosen(Usually in Features X and Target y format)
# **Output**: Tensorflow format Train and Test Set
# **Guideline**: Input -> Turn into Dataframe and add ID -> Pre-Processing -> Change the format to Tensorflow -> Output
#
# The default code now produces a synthetic dataset with 16500 pool, 160 features with binary classification problems. The later options will turn that into a 10 features, 8000 train set and 500 test set sample. Both sets will then be turned into TensorFlow format and will wait for training.
#
# **The most important thing in this code is changing the train size. In this experiment, all the other things are fixed, but the number of training sample is changing to test on different number of samples.**

# %% [markdown]
# 1. Set your default setting here. train_pool + test_size = Total Dataset Size. train_sizes determines the later subset data. Sep to make sure the dataset is distinguishable.

# %%
train_pool = 16000
test_size = 500
train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
n_features=160
seed=42
sep = 5

# %% [markdown]
# 2. Construct the Synthetic Dataset with Make Classification here. **Could replace this with other datasets with X and y.**

# %%
total_samples = train_pool + test_size

X, y = make_classification(n_samples=total_samples,
                           n_features=n_features,
                           n_informative=n_features,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           class_sep=sep,
                           random_state=seed)

# %% [markdown]
# 3. Turn the X and y into dataframe for easy further processing. Add ID column to easy retrieve samples within IF/TC.

# %%
df = pd.DataFrame(X, columns=[f'feature_{i+1}' for i in range(n_features)])
df['label'] = y
df['id'] = np.arange(1, len(df) + 1)
print(df)
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1       4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2      -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3       1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4       2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
# ...          ...        ...        ...        ...        ...        ...
# 16495  -6.716227  -3.941982   6.511306  -1.178930 -10.376654  -9.079567
# 16496   4.277247 -15.312607  10.519820  -0.178716  -3.619789 -10.264994
# 16497  -8.898158   2.233196  -6.868816  -1.021291   9.341948  15.122732
# 16498  -3.610179 -17.301590   2.750310   6.510539  -0.240444  -2.099331
# 16499 -17.536142   5.698689   9.265016   3.931781   6.659502  10.521925
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_153  \
# 0       8.887783  -4.063796  21.086774   -1.520991  ...     7.819484
# 1      -2.525553   9.558629   7.793142    4.989492  ...     0.182679
# 2     -17.248069   6.155376   3.674610    8.811081  ...     7.133064
# 3     -16.208869   2.459683  20.384366   11.957595  ...     6.951633
# 4     -16.237140  15.315085  12.821372   -1.751887  ...     4.459658
# ...          ...        ...        ...         ...  ...          ...
# 16495  -4.641685   2.222042  -7.869077  -12.255666  ...    -4.546759
# 16496  -0.316307  -5.902208  -1.288590    4.576726  ...    -7.428876
# 16497   1.245836  -3.054652  -0.862010    1.089771  ...     1.037077
# 16498   6.536393   4.578611  -8.949377  -16.968405  ...    -2.097471
# 16499  -1.995124   5.285654  -2.441093   13.462665  ...    21.396240
#
#        feature_154  feature_155  feature_156  feature_157  feature_158  \
# 0        -8.721757    -0.265044   -12.609638    20.374691    -1.570831
# 1        -0.204365     0.888607     3.551630     2.569427    -6.208564
# 2        16.611964    -3.646307    -7.176389     6.705201    -2.310830
# 3         2.328660     6.681308     1.769797    -4.039115    -5.922587
# 4         5.218489    12.759107   -13.026580    22.496523    -9.348923
# ...            ...          ...          ...          ...          ...
# 16495    -4.050163    -9.094683    17.398139    -9.798232   -11.915061
# 16496     6.799153     7.235603    -4.089953    13.648382    -6.782679
# 16497     0.432403    10.715410     7.253302     0.726265     6.259256
# 16498     7.160379   -14.985227    22.886270     0.205933     2.049345
# 16499    11.098062    19.261285     9.649843    -5.213003     3.549000
#
#        feature_159  feature_160  label     id
# 0         1.681914   -12.080108      0      1
# 1        15.227281   -11.197154      0      2
# 2         6.484147     6.494745      0      3
# 3         1.982110   -11.342025      0      4
# 4        -1.507289    -2.109601      0      5
# ...            ...          ...    ...    ...
# 16495    -9.204892    -0.940133      1  16496
# 16496     5.975577    -0.858158      0  16497
# 16497     9.247954     7.098226      0  16498
# 16498    -1.669219    -4.507195      1  16499
# 16499     1.238540    10.778987      0  16500
#
# [16500 rows x 162 columns]

# %%
df_train_pool = df.iloc[:train_pool].reset_index(drop=True)
df_test = df.iloc[train_pool:].reset_index(drop=True)

# %%
print(df_train_pool.head())
print(df_test.head())
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0 -11.782908  -8.132727  16.152943  -9.137928   4.798538 -31.164432
# 1   4.337057  -3.322490  -5.760765  -4.599484  13.619708  -0.447431
# 2  -6.162488  10.509963   8.350375   3.877896  10.781976  -3.668239
# 3   1.279108  -2.215843   5.809480  -6.197446   4.975266  -9.387154
# 4   2.271039  -3.547205   1.348749 -10.493556  10.239804  -7.990558
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   8.887783  -4.063796  21.086774   -1.520991  ...     7.819484    -8.721757
# 1  -2.525553   9.558629   7.793142    4.989492  ...     0.182679    -0.204365
# 2 -17.248069   6.155376   3.674610    8.811081  ...     7.133064    16.611964
# 3 -16.208869   2.459683  20.384366   11.957595  ...     6.951633     2.328660
# 4 -16.237140  15.315085  12.821372   -1.751887  ...     4.459658     5.218489
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -0.265044   -12.609638    20.374691    -1.570831     1.681914
# 1     0.888607     3.551630     2.569427    -6.208564    15.227281
# 2    -3.646307    -7.176389     6.705201    -2.310830     6.484147
# 3     6.681308     1.769797    -4.039115    -5.922587     1.982110
# 4    12.759107   -13.026580    22.496523    -9.348923    -1.507289
#
#    feature_160  label  id
# 0   -12.080108      0   1
# 1   -11.197154      0   2
# 2     6.494745      0   3
# 3   -11.342025      0   4
# 4    -2.109601      0   5
#
# [5 rows x 162 columns]
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   8.186701   1.756976  -3.511353  13.659343   5.483705 -10.949900
# 1  14.967977  -5.722160   3.950408 -13.784702  11.335362 -18.859072
# 2  -9.988432  -4.055041  -0.115356  11.196465 -16.064963  -8.859267
# 3 -11.848951  -2.649319   4.776790  -4.132250  17.601257  16.474988
# 4   5.367084   7.090506  -8.492735   7.735160   6.893680   4.421945
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_153  feature_154  \
# 0   2.760068 -10.072462  11.672101   13.301910  ...    -1.642295    -5.284690
# 1 -11.031748   3.485709   5.296748   -4.241424  ...     4.449477     9.646840
# 2 -10.954191  -9.738694   1.515229    6.760216  ...   -15.213665     3.202685
# 3   2.001569  15.994439  12.516982   12.461262  ...    -1.251628    26.544205
# 4  -8.181725  -5.288708   1.554211   -3.996913  ...    10.820747    -3.109014
#
#    feature_155  feature_156  feature_157  feature_158  feature_159  \
# 0    -6.683406    -4.249138     2.145855     4.493905     1.603028
# 1     4.716637     0.493215    16.669589     0.114925     2.073456
# 2     3.373245    11.608862   -16.135474    -5.296019   -11.790634
# 3    14.547684     3.009137    -3.386921    -5.009036    -3.927385
# 4     8.360912    11.710584     2.666601     3.784130     3.617174
#
#    feature_160  label     id
# 0    13.536012      1  16001
# 1    -9.846196      0  16002
# 2    -3.989249      1  16003
# 3     8.479217      0  16004
# 4     5.204375      1  16005
#
# [5 rows x 162 columns]

# %% [markdown]
# 4. Here, we choose the subset of the full dataset. By setting features_to_test, we have the subset feature size. By changing nested_train_dfs, we have different sample sizes.

# %%
features_to_test = 10
selected_features = [f'feature_{i+1}' for i in range(features_to_test)]

nested_train_dfs = [df_train_pool.iloc[:size].reset_index(drop=True) for size in train_sizes]
nested_train_dfs = [df[ selected_features + ['label', 'id'] ].copy()for df in nested_train_dfs]

df_test = df_test[ selected_features + ['label', 'id'] ].copy()

core_1000_ids = nested_train_dfs[0]['id'].tolist()

# %% [markdown]
# **The most important thing in this experiment is the following code**:
# Based on the train_sizes=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000] defined above, we could map the number of training samples with the following code. By choosing the number in [], we could modify the train set size. Therefore, only changing the following code block is enough to produce the experiment result successfully.

# %%
train_df = nested_train_dfs[9]

# %%
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]
IDs = X_train["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_train = X_train.drop(columns=["id"]).values.astype(np.float32)
X_train = np.hstack((X_train, IDs))
y_train = to_categorical(y_train.values,num_classes=2)

print(X_train)
# Out:
# [[-1.1782908e+01 -8.1327267e+00  1.6152943e+01 ...  2.1086775e+01
#   -1.5209914e+00  1.0000000e-10]
#  [ 4.3370576e+00 -3.3224895e+00 -5.7607651e+00 ...  7.7931418e+00
#    4.9894924e+00  2.0000000e-10]
#  [-6.1624880e+00  1.0509963e+01  8.3503752e+00 ...  3.6746099e+00
#    8.8110809e+00  3.0000000e-10]
#  ...
#  [ 8.1884413e+00  3.5860810e+00 -8.3239841e+00 ... -6.2182813e+00
#    3.3512471e+00  9.9980002e-07]
#  [ 4.5422335e+00  8.5544205e+00  5.2558408e+00 ...  6.6344051e+00
#    1.0818994e+01  9.9989995e-07]
#  [ 1.1336281e+00 -1.0786693e+01  3.3283224e+00 ... -1.2195547e+01
#   -1.2576809e+00  1.0000000e-06]]

# %%
test_df = df_test
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
IDs = X_test["id"].values.reshape(-1, 1).astype(np.float32)
IDs = IDs  / 1e10

X_test = X_test.drop(columns=["id"]).values.astype(np.float32)
X_test = np.hstack((X_test, IDs))
y_test = to_categorical(y_test.values,num_classes=2)

print(X_test)
# Out:
# [[ 8.1867008e+00  1.7569758e+00 -3.5113528e+00 ...  1.1672101e+01
#    1.3301909e+01  1.6000999e-06]
#  [ 1.4967977e+01 -5.7221599e+00  3.9504085e+00 ...  5.2967482e+00
#   -4.2414246e+00  1.6002000e-06]
#  [-9.9884319e+00 -4.0550404e+00 -1.1535553e-01 ...  1.5152292e+00
#    6.7602162e+00  1.6003000e-06]
#  ...
#  [-8.8981581e+00  2.2331958e+00 -6.8688164e+00 ... -8.6201030e-01
#    1.0897712e+00  1.6498000e-06]
#  [-3.6101794e+00 -1.7301590e+01  2.7503097e+00 ... -8.9493771e+00
#   -1.6968405e+01  1.6499000e-06]
#  [-1.7536142e+01  5.6986890e+00  9.2650166e+00 ... -2.4410927e+00
#    1.3462665e+01  1.6499999e-06]]

# %% [markdown]
# 5 (Optional) The following code below can display the samples distribution. Uncomment them to acquire the distribution plot.

# %%
# X_all = np.vstack([X_train, X_test])

# y_train_1d = np.argmax(y_train, axis=1)
# y_test_1d  = np.argmax(y_test, axis=1)
# y_all_1d = np.hstack([y_train_1d, y_test_1d])

# %%
# from sklearn.metrics import pairwise_distances
# from sklearn.manifold import MDS
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# D = pairwise_distances(X_all)

# %%
# X_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0).fit_transform(D)

# %%
# sns.scatterplot(x=X_mds[:,0], y=X_mds[:,1], hue=y_all_1d)
# plt.title("MDS – preserves original distances")

# %% [markdown]
# 6. Now we have the train_ds and test_ds for training

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %% [markdown]
# # Training Area

# %% [markdown]
# **Could modify the model as you wish here. Again, in default, influenciae relies on TensorFlow, so use the TensorFlow model if you only want to change the model. Remember: Store the InfluenceModel into the model_list with the loss function. The InfluenceModel will be used to obtain influence later. If you don't change the estimation methods, then the final output at this step shall always be the model_list**
#
# **Input**:Train and Test Set from Data Construction Section
# **Output**: Model List
# **Guideline**: Input -> Define the Model and Hyperparameters -> Train the Model -> Output
#
# Always remember to train the model, get the influence model and store that in model list, unless you wish to change the estimation methods.
#
# The default code now use the train and test set generated from the last section to train the model. The default hyperparameters are: 300 Epochs, Simple FeedForward Neural Network, CategoricalCrossEntropy Loss function, SGD optimizer. Within each epoch, the current model will be turned into an Influence Model and stored inside a model list. After the training, the model list will be passed to next section for influence estimation.

# %%
from tensorflow.keras.regularizers import l2

# %% [markdown]
# 1. **Could modify the model as you wish here as long as it is tensorflow.** Just remember: Store the InfluenceModel into the model_list with the loss function

# %%
seed_value = seed
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),  
    BatchNormalization(momentum=0.9),
    Dropout(0.0),
    Dense(8, activation='relu'),
    Dense(y_train.shape[1])
])
loss_fn = CategoricalCrossentropy(from_logits=True)
optimizer = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

epochs = 300
unreduced_loss_fn = CategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)
model_list = []
model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
for i in range(epochs):
  model.fit(train_ds.batch(256), epochs=1, validation_data=test_ds.batch(256), verbose=2)
  model_list.append(InfluenceModel(model, start_layer=-1, loss_function=unreduced_loss_fn))
base_loss, acc = model.evaluate(test_ds.batch(32), verbose=2)
print(base_loss)
# Out:
# 40/40 - 1s - loss: 0.8446 - accuracy: 0.4925 - val_loss: 0.7338 - val_accuracy: 0.5440 - 595ms/epoch - 15ms/step
# 40/40 - 0s - loss: 0.6577 - accuracy: 0.6310 - val_loss: 0.6077 - val_accuracy: 0.6940 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.5754 - accuracy: 0.7271 - val_loss: 0.5418 - val_accuracy: 0.7700 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.5236 - accuracy: 0.7759 - val_loss: 0.4939 - val_accuracy: 0.8140 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.4839 - accuracy: 0.8028 - val_loss: 0.4562 - val_accuracy: 0.8240 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.4516 - accuracy: 0.8218 - val_loss: 0.4253 - val_accuracy: 0.8440 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.4249 - accuracy: 0.8356 - val_loss: 0.4004 - val_accuracy: 0.8600 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.4033 - accuracy: 0.8449 - val_loss: 0.3804 - val_accuracy: 0.8660 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3856 - accuracy: 0.8519 - val_loss: 0.3636 - val_accuracy: 0.8680 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3710 - accuracy: 0.8561 - val_loss: 0.3498 - val_accuracy: 0.8700 - 99ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3588 - accuracy: 0.8613 - val_loss: 0.3380 - val_accuracy: 0.8780 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3484 - accuracy: 0.8655 - val_loss: 0.3279 - val_accuracy: 0.8840 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3395 - accuracy: 0.8685 - val_loss: 0.3189 - val_accuracy: 0.8860 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3317 - accuracy: 0.8711 - val_loss: 0.3110 - val_accuracy: 0.8900 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3249 - accuracy: 0.8738 - val_loss: 0.3041 - val_accuracy: 0.8900 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3188 - accuracy: 0.8755 - val_loss: 0.2978 - val_accuracy: 0.8940 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3133 - accuracy: 0.8776 - val_loss: 0.2921 - val_accuracy: 0.8960 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3083 - accuracy: 0.8797 - val_loss: 0.2868 - val_accuracy: 0.8940 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.3037 - accuracy: 0.8810 - val_loss: 0.2819 - val_accuracy: 0.8980 - 117ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2994 - accuracy: 0.8840 - val_loss: 0.2773 - val_accuracy: 0.8980 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2954 - accuracy: 0.8853 - val_loss: 0.2730 - val_accuracy: 0.8960 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2917 - accuracy: 0.8866 - val_loss: 0.2689 - val_accuracy: 0.8980 - 94ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2881 - accuracy: 0.8874 - val_loss: 0.2650 - val_accuracy: 0.8980 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2847 - accuracy: 0.8889 - val_loss: 0.2611 - val_accuracy: 0.9000 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2815 - accuracy: 0.8904 - val_loss: 0.2574 - val_accuracy: 0.9020 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2784 - accuracy: 0.8920 - val_loss: 0.2539 - val_accuracy: 0.9060 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2756 - accuracy: 0.8929 - val_loss: 0.2506 - val_accuracy: 0.9060 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2729 - accuracy: 0.8936 - val_loss: 0.2475 - val_accuracy: 0.9100 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2703 - accuracy: 0.8947 - val_loss: 0.2446 - val_accuracy: 0.9100 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2679 - accuracy: 0.8957 - val_loss: 0.2419 - val_accuracy: 0.9120 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2656 - accuracy: 0.8962 - val_loss: 0.2393 - val_accuracy: 0.9120 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2635 - accuracy: 0.8966 - val_loss: 0.2368 - val_accuracy: 0.9120 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2614 - accuracy: 0.8973 - val_loss: 0.2344 - val_accuracy: 0.9140 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2595 - accuracy: 0.8981 - val_loss: 0.2321 - val_accuracy: 0.9140 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2577 - accuracy: 0.8987 - val_loss: 0.2300 - val_accuracy: 0.9160 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2560 - accuracy: 0.8992 - val_loss: 0.2279 - val_accuracy: 0.9160 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2544 - accuracy: 0.8994 - val_loss: 0.2260 - val_accuracy: 0.9160 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2529 - accuracy: 0.8999 - val_loss: 0.2242 - val_accuracy: 0.9160 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2515 - accuracy: 0.9004 - val_loss: 0.2224 - val_accuracy: 0.9180 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2502 - accuracy: 0.9005 - val_loss: 0.2207 - val_accuracy: 0.9180 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2489 - accuracy: 0.9007 - val_loss: 0.2192 - val_accuracy: 0.9180 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2478 - accuracy: 0.9012 - val_loss: 0.2178 - val_accuracy: 0.9180 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2468 - accuracy: 0.9019 - val_loss: 0.2164 - val_accuracy: 0.9180 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2458 - accuracy: 0.9028 - val_loss: 0.2152 - val_accuracy: 0.9180 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2449 - accuracy: 0.9030 - val_loss: 0.2140 - val_accuracy: 0.9180 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2441 - accuracy: 0.9032 - val_loss: 0.2129 - val_accuracy: 0.9180 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2433 - accuracy: 0.9037 - val_loss: 0.2118 - val_accuracy: 0.9160 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2425 - accuracy: 0.9043 - val_loss: 0.2108 - val_accuracy: 0.9140 - 95ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2418 - accuracy: 0.9048 - val_loss: 0.2099 - val_accuracy: 0.9140 - 107ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2411 - accuracy: 0.9055 - val_loss: 0.2090 - val_accuracy: 0.9140 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2405 - accuracy: 0.9054 - val_loss: 0.2082 - val_accuracy: 0.9160 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2399 - accuracy: 0.9056 - val_loss: 0.2074 - val_accuracy: 0.9160 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2394 - accuracy: 0.9059 - val_loss: 0.2067 - val_accuracy: 0.9140 - 118ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2389 - accuracy: 0.9058 - val_loss: 0.2061 - val_accuracy: 0.9160 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2384 - accuracy: 0.9061 - val_loss: 0.2055 - val_accuracy: 0.9180 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2379 - accuracy: 0.9066 - val_loss: 0.2049 - val_accuracy: 0.9180 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2375 - accuracy: 0.9068 - val_loss: 0.2043 - val_accuracy: 0.9180 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2370 - accuracy: 0.9069 - val_loss: 0.2037 - val_accuracy: 0.9180 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2366 - accuracy: 0.9077 - val_loss: 0.2032 - val_accuracy: 0.9180 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2362 - accuracy: 0.9079 - val_loss: 0.2027 - val_accuracy: 0.9180 - 74ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2359 - accuracy: 0.9080 - val_loss: 0.2022 - val_accuracy: 0.9180 - 64ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2355 - accuracy: 0.9077 - val_loss: 0.2018 - val_accuracy: 0.9180 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2352 - accuracy: 0.9078 - val_loss: 0.2013 - val_accuracy: 0.9180 - 67ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2348 - accuracy: 0.9080 - val_loss: 0.2009 - val_accuracy: 0.9180 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2345 - accuracy: 0.9077 - val_loss: 0.2006 - val_accuracy: 0.9180 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2342 - accuracy: 0.9076 - val_loss: 0.2002 - val_accuracy: 0.9160 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2339 - accuracy: 0.9078 - val_loss: 0.1998 - val_accuracy: 0.9160 - 94ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2336 - accuracy: 0.9077 - val_loss: 0.1995 - val_accuracy: 0.9180 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2334 - accuracy: 0.9076 - val_loss: 0.1992 - val_accuracy: 0.9160 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2331 - accuracy: 0.9076 - val_loss: 0.1988 - val_accuracy: 0.9160 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2329 - accuracy: 0.9080 - val_loss: 0.1986 - val_accuracy: 0.9160 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2327 - accuracy: 0.9080 - val_loss: 0.1983 - val_accuracy: 0.9160 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2324 - accuracy: 0.9079 - val_loss: 0.1980 - val_accuracy: 0.9140 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2322 - accuracy: 0.9080 - val_loss: 0.1977 - val_accuracy: 0.9140 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2320 - accuracy: 0.9080 - val_loss: 0.1974 - val_accuracy: 0.9140 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2318 - accuracy: 0.9081 - val_loss: 0.1972 - val_accuracy: 0.9140 - 61ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2315 - accuracy: 0.9083 - val_loss: 0.1969 - val_accuracy: 0.9140 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2313 - accuracy: 0.9082 - val_loss: 0.1967 - val_accuracy: 0.9140 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2311 - accuracy: 0.9083 - val_loss: 0.1964 - val_accuracy: 0.9140 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2309 - accuracy: 0.9084 - val_loss: 0.1962 - val_accuracy: 0.9140 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2307 - accuracy: 0.9087 - val_loss: 0.1960 - val_accuracy: 0.9160 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2306 - accuracy: 0.9088 - val_loss: 0.1958 - val_accuracy: 0.9160 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2304 - accuracy: 0.9087 - val_loss: 0.1956 - val_accuracy: 0.9160 - 70ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2302 - accuracy: 0.9088 - val_loss: 0.1954 - val_accuracy: 0.9160 - 112ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2300 - accuracy: 0.9086 - val_loss: 0.1952 - val_accuracy: 0.9160 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2299 - accuracy: 0.9087 - val_loss: 0.1950 - val_accuracy: 0.9160 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2297 - accuracy: 0.9090 - val_loss: 0.1949 - val_accuracy: 0.9160 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2296 - accuracy: 0.9090 - val_loss: 0.1947 - val_accuracy: 0.9160 - 93ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2294 - accuracy: 0.9091 - val_loss: 0.1946 - val_accuracy: 0.9160 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2293 - accuracy: 0.9091 - val_loss: 0.1944 - val_accuracy: 0.9160 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2292 - accuracy: 0.9092 - val_loss: 0.1943 - val_accuracy: 0.9160 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2290 - accuracy: 0.9094 - val_loss: 0.1941 - val_accuracy: 0.9140 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2289 - accuracy: 0.9094 - val_loss: 0.1940 - val_accuracy: 0.9140 - 98ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2288 - accuracy: 0.9095 - val_loss: 0.1939 - val_accuracy: 0.9140 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2286 - accuracy: 0.9097 - val_loss: 0.1938 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2285 - accuracy: 0.9097 - val_loss: 0.1936 - val_accuracy: 0.9140 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2284 - accuracy: 0.9099 - val_loss: 0.1935 - val_accuracy: 0.9140 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2282 - accuracy: 0.9098 - val_loss: 0.1934 - val_accuracy: 0.9140 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2281 - accuracy: 0.9101 - val_loss: 0.1933 - val_accuracy: 0.9140 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2280 - accuracy: 0.9100 - val_loss: 0.1932 - val_accuracy: 0.9140 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2279 - accuracy: 0.9101 - val_loss: 0.1931 - val_accuracy: 0.9140 - 105ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2278 - accuracy: 0.9100 - val_loss: 0.1930 - val_accuracy: 0.9140 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2276 - accuracy: 0.9100 - val_loss: 0.1929 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2275 - accuracy: 0.9099 - val_loss: 0.1929 - val_accuracy: 0.9140 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2274 - accuracy: 0.9100 - val_loss: 0.1928 - val_accuracy: 0.9140 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2273 - accuracy: 0.9098 - val_loss: 0.1927 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2272 - accuracy: 0.9100 - val_loss: 0.1926 - val_accuracy: 0.9120 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2271 - accuracy: 0.9103 - val_loss: 0.1925 - val_accuracy: 0.9120 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2270 - accuracy: 0.9105 - val_loss: 0.1924 - val_accuracy: 0.9120 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2269 - accuracy: 0.9106 - val_loss: 0.1924 - val_accuracy: 0.9120 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2268 - accuracy: 0.9108 - val_loss: 0.1923 - val_accuracy: 0.9120 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2267 - accuracy: 0.9111 - val_loss: 0.1922 - val_accuracy: 0.9120 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2267 - accuracy: 0.9112 - val_loss: 0.1922 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2266 - accuracy: 0.9112 - val_loss: 0.1921 - val_accuracy: 0.9140 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2265 - accuracy: 0.9113 - val_loss: 0.1920 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2264 - accuracy: 0.9117 - val_loss: 0.1919 - val_accuracy: 0.9140 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2263 - accuracy: 0.9114 - val_loss: 0.1919 - val_accuracy: 0.9140 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2262 - accuracy: 0.9114 - val_loss: 0.1918 - val_accuracy: 0.9140 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2262 - accuracy: 0.9114 - val_loss: 0.1917 - val_accuracy: 0.9140 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2261 - accuracy: 0.9115 - val_loss: 0.1917 - val_accuracy: 0.9140 - 72ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2260 - accuracy: 0.9115 - val_loss: 0.1916 - val_accuracy: 0.9120 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2259 - accuracy: 0.9115 - val_loss: 0.1915 - val_accuracy: 0.9120 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2258 - accuracy: 0.9115 - val_loss: 0.1915 - val_accuracy: 0.9120 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2258 - accuracy: 0.9115 - val_loss: 0.1914 - val_accuracy: 0.9120 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2257 - accuracy: 0.9116 - val_loss: 0.1913 - val_accuracy: 0.9120 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2256 - accuracy: 0.9117 - val_loss: 0.1913 - val_accuracy: 0.9120 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2255 - accuracy: 0.9117 - val_loss: 0.1912 - val_accuracy: 0.9120 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2255 - accuracy: 0.9117 - val_loss: 0.1911 - val_accuracy: 0.9120 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2254 - accuracy: 0.9116 - val_loss: 0.1911 - val_accuracy: 0.9120 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2253 - accuracy: 0.9114 - val_loss: 0.1910 - val_accuracy: 0.9120 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2253 - accuracy: 0.9114 - val_loss: 0.1910 - val_accuracy: 0.9120 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2252 - accuracy: 0.9113 - val_loss: 0.1909 - val_accuracy: 0.9120 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2251 - accuracy: 0.9113 - val_loss: 0.1909 - val_accuracy: 0.9120 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2251 - accuracy: 0.9112 - val_loss: 0.1909 - val_accuracy: 0.9120 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2250 - accuracy: 0.9112 - val_loss: 0.1908 - val_accuracy: 0.9140 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2249 - accuracy: 0.9114 - val_loss: 0.1908 - val_accuracy: 0.9140 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2249 - accuracy: 0.9115 - val_loss: 0.1908 - val_accuracy: 0.9140 - 76ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2248 - accuracy: 0.9115 - val_loss: 0.1907 - val_accuracy: 0.9140 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2247 - accuracy: 0.9116 - val_loss: 0.1907 - val_accuracy: 0.9140 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2247 - accuracy: 0.9118 - val_loss: 0.1907 - val_accuracy: 0.9140 - 72ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2246 - accuracy: 0.9118 - val_loss: 0.1906 - val_accuracy: 0.9140 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2246 - accuracy: 0.9119 - val_loss: 0.1906 - val_accuracy: 0.9140 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2245 - accuracy: 0.9118 - val_loss: 0.1905 - val_accuracy: 0.9160 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2244 - accuracy: 0.9117 - val_loss: 0.1905 - val_accuracy: 0.9160 - 106ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2244 - accuracy: 0.9118 - val_loss: 0.1905 - val_accuracy: 0.9180 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2243 - accuracy: 0.9119 - val_loss: 0.1905 - val_accuracy: 0.9180 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2243 - accuracy: 0.9119 - val_loss: 0.1905 - val_accuracy: 0.9180 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2242 - accuracy: 0.9119 - val_loss: 0.1904 - val_accuracy: 0.9180 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2241 - accuracy: 0.9119 - val_loss: 0.1904 - val_accuracy: 0.9180 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2241 - accuracy: 0.9117 - val_loss: 0.1904 - val_accuracy: 0.9180 - 104ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2240 - accuracy: 0.9119 - val_loss: 0.1904 - val_accuracy: 0.9200 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2240 - accuracy: 0.9118 - val_loss: 0.1904 - val_accuracy: 0.9200 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2239 - accuracy: 0.9118 - val_loss: 0.1903 - val_accuracy: 0.9200 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2239 - accuracy: 0.9118 - val_loss: 0.1903 - val_accuracy: 0.9200 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2238 - accuracy: 0.9116 - val_loss: 0.1903 - val_accuracy: 0.9200 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2238 - accuracy: 0.9115 - val_loss: 0.1902 - val_accuracy: 0.9200 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2237 - accuracy: 0.9114 - val_loss: 0.1902 - val_accuracy: 0.9200 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2237 - accuracy: 0.9115 - val_loss: 0.1901 - val_accuracy: 0.9200 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2236 - accuracy: 0.9117 - val_loss: 0.1901 - val_accuracy: 0.9200 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2235 - accuracy: 0.9117 - val_loss: 0.1900 - val_accuracy: 0.9220 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2235 - accuracy: 0.9116 - val_loss: 0.1900 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2234 - accuracy: 0.9115 - val_loss: 0.1900 - val_accuracy: 0.9220 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2234 - accuracy: 0.9116 - val_loss: 0.1899 - val_accuracy: 0.9220 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2233 - accuracy: 0.9117 - val_loss: 0.1899 - val_accuracy: 0.9220 - 93ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2233 - accuracy: 0.9119 - val_loss: 0.1898 - val_accuracy: 0.9220 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2232 - accuracy: 0.9120 - val_loss: 0.1898 - val_accuracy: 0.9220 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2232 - accuracy: 0.9120 - val_loss: 0.1898 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2231 - accuracy: 0.9121 - val_loss: 0.1897 - val_accuracy: 0.9220 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2231 - accuracy: 0.9119 - val_loss: 0.1897 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2230 - accuracy: 0.9119 - val_loss: 0.1897 - val_accuracy: 0.9220 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2230 - accuracy: 0.9118 - val_loss: 0.1896 - val_accuracy: 0.9220 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2229 - accuracy: 0.9120 - val_loss: 0.1896 - val_accuracy: 0.9200 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2229 - accuracy: 0.9119 - val_loss: 0.1896 - val_accuracy: 0.9200 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2228 - accuracy: 0.9121 - val_loss: 0.1896 - val_accuracy: 0.9200 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2228 - accuracy: 0.9121 - val_loss: 0.1895 - val_accuracy: 0.9200 - 70ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2227 - accuracy: 0.9121 - val_loss: 0.1895 - val_accuracy: 0.9200 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2227 - accuracy: 0.9119 - val_loss: 0.1895 - val_accuracy: 0.9200 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2226 - accuracy: 0.9119 - val_loss: 0.1895 - val_accuracy: 0.9200 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2226 - accuracy: 0.9119 - val_loss: 0.1895 - val_accuracy: 0.9200 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2225 - accuracy: 0.9120 - val_loss: 0.1895 - val_accuracy: 0.9200 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2225 - accuracy: 0.9121 - val_loss: 0.1895 - val_accuracy: 0.9200 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2224 - accuracy: 0.9123 - val_loss: 0.1895 - val_accuracy: 0.9200 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2224 - accuracy: 0.9123 - val_loss: 0.1895 - val_accuracy: 0.9200 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2223 - accuracy: 0.9124 - val_loss: 0.1894 - val_accuracy: 0.9220 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2223 - accuracy: 0.9123 - val_loss: 0.1894 - val_accuracy: 0.9220 - 106ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2223 - accuracy: 0.9123 - val_loss: 0.1894 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2222 - accuracy: 0.9123 - val_loss: 0.1894 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2222 - accuracy: 0.9122 - val_loss: 0.1894 - val_accuracy: 0.9220 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2221 - accuracy: 0.9125 - val_loss: 0.1893 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2221 - accuracy: 0.9125 - val_loss: 0.1893 - val_accuracy: 0.9220 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2220 - accuracy: 0.9126 - val_loss: 0.1893 - val_accuracy: 0.9220 - 86ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2220 - accuracy: 0.9126 - val_loss: 0.1893 - val_accuracy: 0.9220 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2219 - accuracy: 0.9126 - val_loss: 0.1893 - val_accuracy: 0.9220 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2219 - accuracy: 0.9127 - val_loss: 0.1893 - val_accuracy: 0.9220 - 76ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2219 - accuracy: 0.9125 - val_loss: 0.1893 - val_accuracy: 0.9220 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2218 - accuracy: 0.9125 - val_loss: 0.1893 - val_accuracy: 0.9220 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2218 - accuracy: 0.9127 - val_loss: 0.1893 - val_accuracy: 0.9220 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2217 - accuracy: 0.9124 - val_loss: 0.1892 - val_accuracy: 0.9220 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2217 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9220 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2216 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9220 - 115ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2216 - accuracy: 0.9124 - val_loss: 0.1892 - val_accuracy: 0.9220 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2216 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9220 - 85ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2215 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9240 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2215 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9240 - 67ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2214 - accuracy: 0.9124 - val_loss: 0.1892 - val_accuracy: 0.9240 - 76ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2214 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.9240 - 71ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2213 - accuracy: 0.9124 - val_loss: 0.1891 - val_accuracy: 0.9240 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2213 - accuracy: 0.9124 - val_loss: 0.1891 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2213 - accuracy: 0.9123 - val_loss: 0.1891 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2212 - accuracy: 0.9122 - val_loss: 0.1891 - val_accuracy: 0.9260 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2212 - accuracy: 0.9121 - val_loss: 0.1891 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2211 - accuracy: 0.9123 - val_loss: 0.1890 - val_accuracy: 0.9260 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2211 - accuracy: 0.9124 - val_loss: 0.1890 - val_accuracy: 0.9240 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2211 - accuracy: 0.9125 - val_loss: 0.1890 - val_accuracy: 0.9260 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2210 - accuracy: 0.9126 - val_loss: 0.1890 - val_accuracy: 0.9240 - 64ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2210 - accuracy: 0.9126 - val_loss: 0.1889 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2210 - accuracy: 0.9126 - val_loss: 0.1889 - val_accuracy: 0.9240 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2209 - accuracy: 0.9127 - val_loss: 0.1889 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2209 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9240 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2209 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2208 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2208 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9240 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2208 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9240 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2207 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2207 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 64ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2207 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 72ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2206 - accuracy: 0.9128 - val_loss: 0.1887 - val_accuracy: 0.9240 - 84ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2206 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2206 - accuracy: 0.9126 - val_loss: 0.1887 - val_accuracy: 0.9240 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2205 - accuracy: 0.9128 - val_loss: 0.1887 - val_accuracy: 0.9240 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2205 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2205 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9240 - 93ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2204 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2204 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9240 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2204 - accuracy: 0.9129 - val_loss: 0.1888 - val_accuracy: 0.9240 - 77ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2203 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2203 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9240 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2203 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9240 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2202 - accuracy: 0.9129 - val_loss: 0.1888 - val_accuracy: 0.9240 - 102ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2202 - accuracy: 0.9129 - val_loss: 0.1888 - val_accuracy: 0.9240 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2202 - accuracy: 0.9129 - val_loss: 0.1888 - val_accuracy: 0.9240 - 105ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2202 - accuracy: 0.9129 - val_loss: 0.1889 - val_accuracy: 0.9240 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2201 - accuracy: 0.9129 - val_loss: 0.1889 - val_accuracy: 0.9240 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2201 - accuracy: 0.9130 - val_loss: 0.1889 - val_accuracy: 0.9240 - 107ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2201 - accuracy: 0.9130 - val_loss: 0.1888 - val_accuracy: 0.9260 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2200 - accuracy: 0.9130 - val_loss: 0.1888 - val_accuracy: 0.9260 - 117ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2200 - accuracy: 0.9129 - val_loss: 0.1888 - val_accuracy: 0.9260 - 88ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2200 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2200 - accuracy: 0.9130 - val_loss: 0.1888 - val_accuracy: 0.9260 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2199 - accuracy: 0.9130 - val_loss: 0.1888 - val_accuracy: 0.9260 - 73ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2199 - accuracy: 0.9130 - val_loss: 0.1889 - val_accuracy: 0.9260 - 118ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2199 - accuracy: 0.9130 - val_loss: 0.1889 - val_accuracy: 0.9260 - 112ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2199 - accuracy: 0.9129 - val_loss: 0.1889 - val_accuracy: 0.9260 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2198 - accuracy: 0.9128 - val_loss: 0.1889 - val_accuracy: 0.9260 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2198 - accuracy: 0.9128 - val_loss: 0.1889 - val_accuracy: 0.9260 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2198 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2198 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9260 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2197 - accuracy: 0.9125 - val_loss: 0.1888 - val_accuracy: 0.9260 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2197 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2197 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9280 - 66ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2196 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9280 - 74ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2196 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9280 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2196 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9280 - 80ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2196 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9280 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2195 - accuracy: 0.9126 - val_loss: 0.1888 - val_accuracy: 0.9260 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2195 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9260 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2195 - accuracy: 0.9127 - val_loss: 0.1888 - val_accuracy: 0.9260 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2195 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2194 - accuracy: 0.9128 - val_loss: 0.1888 - val_accuracy: 0.9260 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2194 - accuracy: 0.9129 - val_loss: 0.1887 - val_accuracy: 0.9260 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2194 - accuracy: 0.9129 - val_loss: 0.1887 - val_accuracy: 0.9260 - 99ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2194 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9260 - 98ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2193 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9260 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2193 - accuracy: 0.9127 - val_loss: 0.1887 - val_accuracy: 0.9260 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2193 - accuracy: 0.9128 - val_loss: 0.1887 - val_accuracy: 0.9260 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2193 - accuracy: 0.9128 - val_loss: 0.1887 - val_accuracy: 0.9260 - 83ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2192 - accuracy: 0.9127 - val_loss: 0.1886 - val_accuracy: 0.9280 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2192 - accuracy: 0.9127 - val_loss: 0.1886 - val_accuracy: 0.9280 - 108ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2192 - accuracy: 0.9126 - val_loss: 0.1886 - val_accuracy: 0.9280 - 79ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2192 - accuracy: 0.9128 - val_loss: 0.1886 - val_accuracy: 0.9280 - 118ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2191 - accuracy: 0.9128 - val_loss: 0.1885 - val_accuracy: 0.9280 - 78ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2191 - accuracy: 0.9129 - val_loss: 0.1885 - val_accuracy: 0.9280 - 100ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2191 - accuracy: 0.9129 - val_loss: 0.1885 - val_accuracy: 0.9280 - 81ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2191 - accuracy: 0.9129 - val_loss: 0.1885 - val_accuracy: 0.9280 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9129 - val_loss: 0.1885 - val_accuracy: 0.9280 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9129 - val_loss: 0.1885 - val_accuracy: 0.9280 - 82ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9129 - val_loss: 0.1884 - val_accuracy: 0.9280 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9130 - val_loss: 0.1884 - val_accuracy: 0.9280 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9130 - val_loss: 0.1884 - val_accuracy: 0.9280 - 72ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2189 - accuracy: 0.9130 - val_loss: 0.1884 - val_accuracy: 0.9280 - 75ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2189 - accuracy: 0.9130 - val_loss: 0.1883 - val_accuracy: 0.9280 - 120ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2189 - accuracy: 0.9130 - val_loss: 0.1883 - val_accuracy: 0.9280 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2189 - accuracy: 0.9130 - val_loss: 0.1883 - val_accuracy: 0.9280 - 87ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2188 - accuracy: 0.9131 - val_loss: 0.1883 - val_accuracy: 0.9280 - 92ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2188 - accuracy: 0.9131 - val_loss: 0.1883 - val_accuracy: 0.9280 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2188 - accuracy: 0.9130 - val_loss: 0.1882 - val_accuracy: 0.9280 - 89ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2188 - accuracy: 0.9130 - val_loss: 0.1882 - val_accuracy: 0.9280 - 91ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2188 - accuracy: 0.9130 - val_loss: 0.1882 - val_accuracy: 0.9280 - 90ms/epoch - 2ms/step
# 40/40 - 0s - loss: 0.2187 - accuracy: 0.9129 - val_loss: 0.1882 - val_accuracy: 0.9280 - 119ms/epoch - 3ms/step
# 40/40 - 0s - loss: 0.2187 - accuracy: 0.9130 - val_loss: 0.1882 - val_accuracy: 0.9280 - 92ms/epoch - 2ms/step
# 16/16 - 0s - loss: 0.1882 - accuracy: 0.9280 - 32ms/epoch - 2ms/step
# 0.18817757070064545

# %% [markdown]
# # Influence Estimation Area

# %% [markdown]
# **Again, you could use other influence analysis methods rather than IF/TC. You can also use any other Influence Function or TracIn implementation. Just Remember: 1. Make sure the package is unform throughout the framework. 2. Generate a Ranked influence list for each Influence Function and TracIn; Only the ranked influence list could be fed into the following analysis code.**
#
# **The default code now use the model list, train set and test set to estimate the influence, and produce a ranked influence list for both IF and TC. The results are then saved in the root directory.**
#
# **Input**:Model list from Training section, Train and Test Set from Data Construction Section
# **Output**: Two ranked Influence Lists for IF and TC.
# **Guideline**: Input -> Influence Estimation Methods -> Influence Matrix -> Output

# %% [markdown]
# 1. Influence Function: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use influence_matrix.

# %%
train_ids = []
test_ids = []
train_samples_np = np.array([x.numpy() for x, y in train_ds])
train_ids = [round(sample[-1] * 1e10) for sample in train_samples_np]

# %%
start_if = time.perf_counter()

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

influence_model = model_list[-1]
ihvp_calculator = ExactIHVP(influence_model, train_ds.batch(16))
influence_calculator = FirstOrderInfluenceCalculator(influence_model, train_ds, ihvp_calculator)

influence_matrix = np.zeros((num_test_samples, num_train_samples))

samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            influence_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(influence_matrix, axis=0).reshape(1, -1)
df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(df)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function ExactIHVP._compute_inv_hessian at 0x0000021176360160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function ExactIHVP._compute_inv_hessian at 0x0000021176360160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#       Train_ID     Score
# 0            1  0.027767
# 1            2  0.014881
# 2            3  0.004174
# 3            4  0.002700
# 4            5  0.002164
# ...        ...       ...
# 9995      9996  0.030038
# 9996      9997  0.031931
# 9997      9998  0.000715
# 9998      9999  0.017813
# 9999     10000  0.022952
#
# [10000 rows x 2 columns]

# %%
end_if = time.perf_counter()
runtime_if = end_if - start_if
print(f"FOIF Runtime: {runtime_if:.4f} seconds")
# Out:
# FOIF Runtime: 395.9902 seconds

# %% [markdown]
# 2. TracIn: Here we use the influenciae package. The following code will directly generate the influence list. If you wish to have the matrix, just use TracIn_matrix.

# %%
start_tc = time.perf_counter()

# %%
num_test_samples = len(test_ds)
num_train_samples = len(train_ids)
test_ids = []

TracIn_matrix = np.zeros((num_test_samples, num_train_samples))
influence_calculator = TracIn(
    model_list, 0.001
)
samples_to_explain = test_ds.take(num_test_samples).batch(1)
explanation_ds = influence_calculator.top_k(samples_to_explain, train_ds.batch(16), k=num_train_samples, order=ORDER.DESCENDING)
for test_idx,((sample, label), top_k_values, top_k_samples) in enumerate(explanation_ds.as_numpy_iterator()):
    test_sample_id = round(sample[0][-1] * 1e10)
    test_ids.append(test_sample_id)
    influential_ids = [round(s[-1] * 1e10) for s in top_k_samples[0]] 
    influence_scores = top_k_values[0]
    id_to_index = {train_id: idx for idx, train_id in enumerate(train_ids)}
    for inf_id, score in zip(influential_ids, influence_scores):
        if inf_id in id_to_index:
            TracIn_matrix[test_idx, id_to_index[inf_id]] = score

flattened_row = np.median(TracIn_matrix, axis=0).reshape(1, -1)
TracIn_df = pd.DataFrame({'Train_ID': train_ids, 'Score': flattened_row.flatten()})
print(TracIn_df)
# Out:
#       Train_ID         Score
# 0            1  5.376713e-04
# 1            2  9.908415e-05
# 2            3  1.347251e-05
# 3            4  1.314285e-05
# 4            5  1.143101e-05
# ...        ...           ...
# 9995      9996 -9.517032e-05
# 9996      9997 -1.563515e-05
# 9997      9998 -1.301336e-07
# 9998      9999  7.236763e-05
# 9999     10000 -7.840512e-06
#
# [10000 rows x 2 columns]

# %%
end_tc = time.perf_counter()
runtime_tc = end_tc - start_tc
print(f"TracIn Runtime: {runtime_tc:.4f} seconds")
# Out:
# TracIn Runtime: 542.9209 seconds

# %% [markdown]
# 3. Here we turn both influence lists to the ranked influence lists and then store them for further processing.

# %%
df_sorted = df.sort_values(by="Score", ascending=False).reset_index(drop=True)

TracIn_sorted = TracIn_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

# %%
# TracIn_sorted.to_csv("TC_Train_Set_1.csv",index = False)
# df_sorted.to_csv("IF_Train_Set_1.csv",index = False)
